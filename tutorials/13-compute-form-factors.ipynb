# %% [markdown]
# # Atomic form factors for chlorine-like iron ions

# %%
using JAC

# %% [markdown]
# In atomic physics, the **form factors** are generally taken as fast approximation to the (scattering) amplitude in forward direction at $\vartheta \approx 0$, if an incident quantum wave is scattered by an isolated atom with spherical-symmetric charge distribution. The form factor definition therefore depends on the particular type of incident radiation, such a photons, electrons or neutrons. Here, *as usual*, we restrict ourselves to the atomic **form factor for the elastic (x-ray) scattering of photons**.
#
# In JAC, the standard and modified form factors are calculated and tabulated by default for all selected levels of a given multiplet and for a list of pre-specified $q$-values (a.u.). Here, we shall compute these form factors as (one) selected atomic property for all levels of the [Ne] $3s^2 3p^5$ ground configuration of chlorine-like Fe and Kr ions. For this, we can perform again an `Atomic.Computation(...,  properties=[FormF, ..], configs=[..], formSettings=FormFactor.Settings(..), ..)`.
#
# Let us first consider the internal definition and the default settings of `FormFactor.Settings(..)`

# %%
? FormFactor.Settings
# Out:
#   struct  FormFactor.Settings ... defines a type for the details and
#   parameters of computing alpha-variation parameters.
#
#   + qList                    ::Array{Float64,1} ... List of q-values in [a.u.]
#   + printBefore   ::Bool             ... True if a list of selected levels is printed before the actual computations start.
#   + selectLevels             ::Bool             ... True if individual levels are selected for the computation.
#   + selectedLevels           ::Array{Level,1}   ... List of selected levels.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   FormFactor.Settings() ... constructor for an empty instance of
#   FormFactor.Settings for the computation of atomic form factors.

# %%
FormFactor.Settings()
# Out:
# qList:                    [0.0, 0.1, 1.0, 10.0]
# printBefore:   false
# selectLevels:             false
# selectedLevels:           Level[]

# %% [markdown]
# We wish to calculate form factor for three values of the momentum transfer $q = [0., 0.1, 1.0]$ and request the printout of a short overwiew table already before the form factor computations start. These settings and the (atomic) computation are then realized by simply calling:

# %%
fSettings = FormFactor.Settings([0., 0.1, 1.0], true, false, Int64[])
wa = Atomic.Computation(Atomic.Computation(), name="Form factors for chlorine-like Fe", grid=Radial.Grid(true), 
            nuclearModel=Nuclear.Model(26.), properties=[JAC.FormF], configs=[Configuration("[Ne] 3s^2 3p^5")],
            formSettings=fSettings )
perform(wa)
# Out:
# aa: NoProcess   multipoles:             EmMultipole[E1]
# gauges:                 UseGauge[UseCoulomb]
# calcAnisotropy:         false
# printBefore:            false
# selectLines:            false
# selectedLines:          Tuple{Int64,Int64}[]
# photonEnergyShift:      0.0
# mimimumPhotonEnergy:    0.0
# maximumPhotonEnergy:    0.0
#
#
# ... in performSCF ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^1 3p_3/2^4
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^2 3p_3/2^3
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 26.0 with mass = 55.38, radius R = 3.756573410087755 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -3.41095882e+02    -3.41097837e+02    +5.73282577e-06
#       2      2s_1/2      -8.54687335e+01    -8.54689584e+01    +2.63136714e-06
#       3      3s_1/2      -3.78995149e+01    -3.78994478e+01    -1.77118976e-06
#       4      4s_1/2      -2.12860102e+01    -2.12819385e+01    -1.91283922e-04
#       5      5s_1/2      -1.36596748e+01    -1.36039714e+01    -4.07794550e-03
#       6      6s_1/2      -1.02231533e+01    -9.43887322e+00    -7.67160661e-02
#       7      7s_1/2      -8.71004839e+00    -6.93005925e+00    -2.04360420e-01
#       8      8s_1/2      -6.39173280e+00    -5.30306679e+00    -1.70324081e-01
#       :       :
#      51     51s_1/2      +8.42794522e+07    -1.30041283e-01    +1.00000000e+00
#      52     52s_1/2      +1.28010239e+08    -1.25086123e-01    +1.00000000e+00
#      53     53s_1/2      +2.02324641e+08    -1.20408879e-01    +1.00000000e+00
#      54     54s_1/2      +3.44744353e+08    -1.15989152e-01    +1.00000000e+00
#      55     55s_1/2      +6.89589055e+08    -1.11808377e-01    +1.00000000e+00
#      56     56s_1/2      +2.35235601e+09    -1.07849636e-01    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 3s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -8.54689639e+01    -8.54689584e+01    -6.48489779e-08
#       2      3p_1/2      -3.78994938e+01    -3.78994478e+01    -1.21351773e-06
#       3      4p_1/2      -2.12835731e+01    -2.12819385e+01    -7.68010407e-05
#       4      5p_1/2      -1.36205252e+01    -1.36039714e+01    -1.21535783e-03
#       5      6p_1/2      -9.56125779e+00    -9.43887322e+00    -1.28000495e-02
#       6      7p_1/2      -7.52775477e+00    -6.93005925e+00    -7.93989094e-02
#       7      8p_1/2      -6.03969738e+00    -5.30306679e+00    -1.21964819e-01
#       8      9p_1/2      -4.48651176e+00    -4.18833237e+00    -6.64612987e-02
#       :       :
#      50     51p_1/2      +7.00735016e+07    -1.30041283e-01    +1.00000000e+00
#      51     52p_1/2      +1.05223801e+08    -1.25086123e-01    +1.00000000e+00
#      52     53p_1/2      +1.62933722e+08    -1.20408879e-01    +1.00000000e+00
#      53     54p_1/2      +2.66765784e+08    -1.15989152e-01    +1.00000000e+00
#      54     55p_1/2      +4.87784029e+08    -1.11808377e-01    +1.00000000e+00
#      55     56p_1/2      +1.16201287e+09    -1.07849636e-01    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 3p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -8.46909840e+01    -8.46909743e+01    -1.14756318e-07
#       2      3p_3/2      -3.76688504e+01    -3.76687634e+01    -2.30930719e-06
#       3      4p_3/2      -2.11877104e+01    -2.11846929e+01    -1.42417132e-04
#       4      5p_3/2      -1.36424365e+01    -1.35542226e+01    -6.46613863e-03
#       5      6p_3/2      -1.15227486e+01    -9.41010352e+00    -1.83345584e-01
#       6      7p_3/2      -9.11847384e+00    -6.91195226e+00    -2.41983649e-01
#       7      8p_3/2      -6.55244670e+00    -5.29094223e+00    -1.92524186e-01
#       8      9p_3/2      -4.81673112e+00    -4.17982022e+00    -1.32228867e-01
#       :       :
#      51     52p_3/2      +9.99498601e+07    -1.25042127e-01    +1.00000000e+00
#      52     53p_3/2      +1.53621355e+08    -1.20367328e-01    +1.00000000e+00
#      53     54p_3/2      +2.48089620e+08    -1.15949867e-01    +1.00000000e+00
#      54     55p_3/2      +4.40723192e+08    -1.11771197e-01    +1.00000000e+00
#      55     56p_3/2      +9.65224244e+08    -1.07814412e-01    +1.00000000e+00
#      56     57p_3/2      +3.73425631e+09    -1.04064077e-01    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# >> Use hydrogenic orbital from this symmetry block also for 3p_3/2.
# (Re-) Define the standard grid with 390 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.5032920e+02;   self-cons'cy = 1.5347e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.1605708e+01;   self-cons'cy = 4.6008e-01  [1.0000e+02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.6572814e+00;   self-cons'cy = 6.2810e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.8846867e+01;   self-cons'cy = 4.9531e-01  [1.0000e+02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.9631539e+00;   self-cons'cy = 6.5274e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.0830540e+01;   self-cons'cy = 4.6624e-01  [1.0000e+02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -8.4715129e+00;   self-cons'cy = 6.3279e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6707341e+02;   self-cons'cy = 3.2362e-02  [1.1918e+00 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.9371660e+01;   self-cons'cy = 1.0941e-01  [1.1918e+00 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0793953e+01;   self-cons'cy = 1.0985e-01  [1.1918e+00 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4836918e+01;   self-cons'cy = 9.4059e-02  [2.8690e-01 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.3697352e+00;   self-cons'cy = 8.1151e-02  [2.8690e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3849662e+01;   self-cons'cy = 4.6678e-02  [5.3029e+00 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.1350035e+00;   self-cons'cy = 3.7684e-02  [5.3029e+00 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6419082e+02;   self-cons'cy = 5.4259e-03  [1.6404e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.7926770e+01;   self-cons'cy = 1.8692e-02  [1.6404e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0323567e+01;   self-cons'cy = 2.2275e-02  [1.6404e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.3919036e+01;   self-cons'cy = 1.3350e-02  [6.6342e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1050511e+00;   self-cons'cy = 1.4327e-02  [6.6342e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3534103e+01;   self-cons'cy = 4.6830e-03  [1.1011e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0493502e+00;   self-cons'cy = 4.7103e-03  [1.1011e-01 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6459146e+02;   self-cons'cy = 7.5766e-04  [4.9238e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8128696e+01;   self-cons'cy = 2.6550e-03  [4.9238e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0388443e+01;   self-cons'cy = 3.1323e-03  [4.9238e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4026174e+01;   self-cons'cy = 1.5768e-03  [7.2862e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1354493e+00;   self-cons'cy = 1.6665e-03  [7.2862e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3558830e+01;   self-cons'cy = 3.6854e-04  [8.9629e-03 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0556938e+00;   self-cons'cy = 3.5038e-04  [8.9629e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454326e+02;   self-cons'cy = 9.1091e-05  [4.9856e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8104200e+01;   self-cons'cy = 3.2133e-04  [4.9856e-03 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0380471e+01;   self-cons'cy = 3.8386e-04  [4.9856e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4015393e+01;   self-cons'cy = 1.5845e-04  [7.4057e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1323806e+00;   self-cons'cy = 1.6799e-04  [7.4057e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557636e+01;   self-cons'cy = 1.7789e-05  [3.8220e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554415e+00;   self-cons'cy = 1.3928e-05  [3.8220e-04 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454829e+02;   self-cons'cy = 9.5013e-06  [4.8471e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106763e+01;   self-cons'cy = 3.3629e-05  [4.8471e-04 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381308e+01;   self-cons'cy = 4.0331e-05  [4.8471e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016274e+01;   self-cons'cy = 1.2955e-05  [5.9882e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326289e+00;   self-cons'cy = 1.3596e-05  [5.9882e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557572e+01;   self-cons'cy = 9.5793e-07  [3.6851e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554126e+00;   self-cons'cy = 1.6003e-06  [3.6851e-05 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454785e+02;   self-cons'cy = 8.3301e-07  [4.2862e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106538e+01;   self-cons'cy = 2.9547e-06  [4.2862e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381234e+01;   self-cons'cy = 3.5593e-06  [4.2862e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016227e+01;   self-cons'cy = 6.8787e-07  [3.0616e-06 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326162e+00;   self-cons'cy = 6.9495e-07  [3.0616e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557600e+01;   self-cons'cy = 4.2365e-07  [1.2548e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554218e+00;   self-cons'cy = 5.1114e-07  [1.2548e-05 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454787e+02;   self-cons'cy = 5.3666e-08  [2.7460e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106553e+01;   self-cons'cy = 1.9083e-07  [2.7460e-06 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381239e+01;   self-cons'cy = 2.3171e-07  [2.7460e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016226e+01;   self-cons'cy = 2.0905e-08  [1.2296e-07 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326157e+00;   self-cons'cy = 2.7926e-08  [1.2296e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557595e+01;   self-cons'cy = 7.5969e-08  [2.1474e-06 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554203e+00;   self-cons'cy = 8.6198e-08  [2.1474e-06 for sym-block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454787e+02;   self-cons'cy = 6.6440e-10  [3.0730e-08 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106553e+01;   self-cons'cy = 2.4306e-09  [3.0730e-08 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381239e+01;   self-cons'cy = 3.2874e-09  [3.0730e-08 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016227e+01;   self-cons'cy = 1.3054e-08  [6.4423e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326160e+00;   self-cons'cy = 1.4626e-08  [6.4423e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557596e+01;   self-cons'cy = 1.0442e-08  [2.8870e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554205e+00;   self-cons'cy = 1.1473e-08  [2.8870e-07 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 3/2^- ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    3/2 -     -1.242746372725031e+03    -3.381685127317562e+04    -3.381685127317562e+04
#      2    1/2 -     -1.242672314266558e+03    -3.381483603987407e+04    -3.381483603987407e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     7.405845847279124e-02    2.015233301549262e+00    2.015233301549262e+00
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     7.405845847279124e-02    2.015233301549262e+00    2.015233301549262e+00
#
# FormFactor.computeOutcomes(): The computation of the atomic form factors starts now ...
# -------------------------------------------------------------------------------------------
#
#   Selected FormFactor levels:
#
#   --------------------------------------------------------------------------------------
#      Level        J^P           Energy          q-values  ...
#                                  [eV]            [a.u.]
#   --------------------------------------------------------------------------------------
#          1       3/2 -      -3.38168513e+04    0.00e+00,  1.00e-01,  1.00e+00,
#          2       1/2 -      -3.38148360e+04    0.00e+00,  1.00e-01,  1.00e+00,
#   --------------------------------------------------------------------------------------
#
#   Standard and modified atomic form factors [note F^(standard) (0) = N_e]:
#
#   ----------------------------------------------------------------------------------------
#      Level        J^P           Energy          q [a.u.]      standard F     modified F
#                                  [eV]
#   ----------------------------------------------------------------------------------------
#          1       3/2 -      -3.38168513e+04    0.00000e+00    1.70000e+01    1.69910e+01
#                                                1.00000e-01    1.69916e+01    1.69827e+01
#                                                1.00000e+00    1.61993e+01    1.61900e+01
#          2       1/2 -      -3.38148360e+04    0.00000e+00    1.70000e+01    1.69910e+01
#                                                1.00000e-01    1.69916e+01    1.69826e+01
#                                                1.00000e+00    1.61978e+01    1.61885e+01
#   ----------------------------------------------------------------------------------------
#
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# Here, all the requested form factors are simply compiled in the last table; of course, we can easily repeat these computations also for chlorine-like Kr:

# %%
wa = Atomic.Computation(wa, name="Form factors for chlorine-like Kr", nuclearModel=Nuclear.Model(36.))
perform(wa)
# Out:
# aa: NoProcess   multipoles:             EmMultipole[E1]
# gauges:                 UseGauge[UseCoulomb]
# calcAnisotropy:         false
# printBefore:            false
# selectLines:            false
# selectedLines:          Tuple{Int64,Int64}[]
# photonEnergyShift:      0.0
# mimimumPhotonEnergy:    0.0
# maximumPhotonEnergy:    0.0
#
#
# ... in performSCF ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^1 3p_3/2^4
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^2 3p_3/2^3
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 36.0 with mass = 78.48, radius R = 4.149254741065642 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -6.59572821e+02    -6.59583512e+02    +1.62082037e-05
#       2      2s_1/2      -1.65624908e+02    -1.65626275e+02    +8.25757603e-06
#       3      3s_1/2      -7.32846489e+01    -7.32847802e+01    +1.79103668e-06
#       4      4s_1/2      -4.10937829e+01    -4.10855060e+01    -2.01414899e-04
#       5      5s_1/2      -2.63346130e+01    -2.62329647e+01    -3.85987126e-03
#       6      6s_1/2      -1.96911067e+01    -1.81861550e+01    -7.64279922e-02
#       7      7s_1/2      -1.69010929e+01    -1.33439712e+01    -2.10466964e-01
#       8      8s_1/2      -1.24069415e+01    -1.02061694e+01    -1.77382328e-01
#       :       :
#      51     51s_1/2      +8.41712737e+07    -2.49473490e-01    +1.00000000e+00
#      52     52s_1/2      +1.27902080e+08    -2.39964438e-01    +1.00000000e+00
#      53     53s_1/2      +2.02216491e+08    -2.30988877e-01    +1.00000000e+00
#      54     54s_1/2      +3.44636208e+08    -2.22507634e-01    +1.00000000e+00
#      55     55s_1/2      +6.89480911e+08    -2.14485064e-01    +1.00000000e+00
#      56     56s_1/2      +2.35224787e+09    -2.06888682e-01    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 3s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -1.65626270e+02    -1.65626275e+02    +3.22672116e-08
#       2      3p_1/2      -7.32848765e+01    -7.32847802e+01    -1.31407651e-06
#       3      4p_1/2      -4.10887818e+01    -4.10855060e+01    -7.97232774e-05
#       4      5p_1/2      -2.62621318e+01    -2.62329647e+01    -1.11061238e-03
#       5      6p_1/2      -1.84004311e+01    -1.81861550e+01    -1.16451662e-02
#       6      7p_1/2      -1.45438058e+01    -1.33439712e+01    -8.24979817e-02
#       7      8p_1/2      -1.17904060e+01    -1.02061694e+01    -1.34366590e-01
#       8      9p_1/2      -8.77064652e+00    -8.05762060e+00    -8.12968488e-02
#       :       :
#      50     51p_1/2      +6.99653047e+07    -2.49473490e-01    +1.00000000e+00
#      51     52p_1/2      +1.05115632e+08    -2.39964438e-01    +1.00000000e+00
#      52     53p_1/2      +1.62825568e+08    -2.30988877e-01    +1.00000000e+00
#      53     54p_1/2      +2.66657636e+08    -2.22507634e-01    +1.00000000e+00
#      54     55p_1/2      +4.87675884e+08    -2.14485064e-01    +1.00000000e+00
#      55     56p_1/2      +1.16190472e+09    -2.06888682e-01    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 3p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -1.62704878e+02    -1.62704858e+02    -1.23073879e-07
#       2      3p_3/2      -7.24181266e+01    -7.24179626e+01    -2.26455321e-06
#       3      4p_3/2      -4.07273174e+01    -4.07203638e+01    -1.70733257e-04
#       4      5p_3/2      -2.62217483e+01    -2.60463105e+01    -6.69054631e-03
#       5      6p_3/2      -2.21807619e+01    -1.80782839e+01    -1.84956587e-01
#       6      7p_3/2      -1.75360752e+01    -1.32761162e+01    -2.42925454e-01
#       7      8p_3/2      -1.25848123e+01    -1.01607532e+01    -1.92617819e-01
#       8      9p_3/2      -9.13787388e+00    -8.02574741e+00    -1.21705167e-01
#       :       :
#      51     52p_3/2      +9.98416882e+07    -2.39800176e-01    +1.00000000e+00
#      52     53p_3/2      +1.53513200e+08    -2.30833743e-01    +1.00000000e+00
#      53     54p_3/2      +2.47981472e+08    -2.22360963e-01    +1.00000000e+00
#      54     55p_3/2      +4.40615047e+08    -2.14346253e-01    +1.00000000e+00
#      55     56p_3/2      +9.65116100e+08    -2.06757178e-01    +1.00000000e+00
#      56     57p_3/2      +3.73414816e+09    -1.99564124e-01    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# >> Use hydrogenic orbital from this symmetry block also for 3p_3/2.
# (Re-) Define the standard grid with 390 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.3241361e+02;   self-cons'cy = 1.0668e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -8.8999823e+01;   self-cons'cy = 3.0093e-01  [1.0000e+02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.0303468e+01;   self-cons'cy = 4.1492e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3710037e+01;   self-cons'cy = 3.2854e-01  [1.0000e+02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -2.8592438e+01;   self-cons'cy = 4.3869e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.4104579e+01;   self-cons'cy = 3.1847e-01  [1.0000e+02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.8846485e+01;   self-cons'cy = 4.3028e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4844804e+02;   self-cons'cy = 1.4835e-02  [2.0496e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.6433002e+01;   self-cons'cy = 4.0086e-02  [2.0496e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2568803e+01;   self-cons'cy = 3.6031e-02  [2.0496e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9823222e+01;   self-cons'cy = 3.5228e-02  [8.5676e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0287116e+01;   self-cons'cy = 2.8782e-02  [8.5676e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7508253e+01;   self-cons'cy = 1.9833e-02  [1.1139e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9769499e+01;   self-cons'cy = 1.5747e-02  [1.1139e-01 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4662615e+02;   self-cons'cy = 1.6637e-03  [2.8947e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5563961e+01;   self-cons'cy = 4.5263e-03  [2.8947e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2284390e+01;   self-cons'cy = 4.3855e-03  [2.8947e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9216858e+01;   self-cons'cy = 3.3867e-03  [9.6175e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0105160e+01;   self-cons'cy = 3.0129e-03  [9.6175e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7250056e+01;   self-cons'cy = 1.4775e-03  [1.0256e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9693835e+01;   self-cons'cy = 1.2724e-03  [1.0256e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4679875e+02;   self-cons'cy = 1.5785e-04  [2.6857e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5646165e+01;   self-cons'cy = 4.2991e-04  [2.6857e-03 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2311242e+01;   self-cons'cy = 4.1568e-04  [2.6857e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9267246e+01;   self-cons'cy = 2.8231e-04  [7.8807e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0120151e+01;   self-cons'cy = 2.4891e-04  [7.8807e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7267824e+01;   self-cons'cy = 1.0181e-04  [6.8705e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9698953e+01;   self-cons'cy = 8.6162e-05  [6.8705e-04 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4678411e+02;   self-cons'cy = 1.3383e-05  [2.2908e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5639191e+01;   self-cons'cy = 3.6458e-05  [2.2908e-04 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2308955e+01;   self-cons'cy = 3.5388e-05  [2.2908e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9263388e+01;   self-cons'cy = 2.1608e-05  [6.0294e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0119005e+01;   self-cons'cy = 1.9034e-05  [6.0294e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7266668e+01;   self-cons'cy = 6.6253e-06  [4.4238e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9698624e+01;   self-cons'cy = 5.5379e-06  [4.4238e-05 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4678526e+02;   self-cons'cy = 1.0466e-06  [1.7950e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5639736e+01;   self-cons'cy = 2.8513e-06  [1.7950e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2309134e+01;   self-cons'cy = 2.7737e-06  [1.7950e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9263664e+01;   self-cons'cy = 1.5455e-06  [4.3042e-06 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0119086e+01;   self-cons'cy = 1.3591e-06  [4.3042e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7266738e+01;   self-cons'cy = 4.0300e-07  [2.6512e-06 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9698643e+01;   self-cons'cy = 3.3155e-07  [2.6512e-06 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4678517e+02;   self-cons'cy = 7.6642e-08  [1.3169e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5639696e+01;   self-cons'cy = 2.0879e-07  [1.3169e-06 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2309121e+01;   self-cons'cy = 2.0351e-07  [1.3169e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9263645e+01;   self-cons'cy = 1.0392e-07  [2.8889e-07 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0119081e+01;   self-cons'cy = 9.1229e-08  [2.8889e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7266734e+01;   self-cons'cy = 2.2462e-08  [1.4469e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9698642e+01;   self-cons'cy = 1.8065e-08  [1.4469e-07 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4678518e+02;   self-cons'cy = 5.2872e-09  [9.1007e-08 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5639699e+01;   self-cons'cy = 1.4403e-08  [9.1007e-08 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2309122e+01;   self-cons'cy = 1.4066e-08  [9.1007e-08 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9263646e+01;   self-cons'cy = 6.5530e-09  [1.8174e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0119081e+01;   self-cons'cy = 5.7413e-09  [1.8174e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7266734e+01;   self-cons'cy = 1.0924e-09  [6.7968e-09 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9698642e+01;   self-cons'cy = 8.4263e-10  [6.7968e-09 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 3/2^- ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    3/2 -     -2.585620974702492e+03    -7.035833044403818e+04    -7.035833044403818e+04
#      2    1/2 -     -2.585211778292307e+03    -7.034719564256261e+04    -7.034719564256261e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     4.091964101853591e-01    1.113480147555207e+01    1.113480147555207e+01
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     4.091964101853591e-01    1.113480147555207e+01    1.113480147555207e+01
#
# FormFactor.computeOutcomes(): The computation of the atomic form factors starts now ...
# -------------------------------------------------------------------------------------------
#
#   Selected FormFactor levels:
#
#   --------------------------------------------------------------------------------------
#      Level        J^P           Energy          q-values  ...
#                                  [eV]            [a.u.]
#   --------------------------------------------------------------------------------------
#          1       3/2 -      -7.03583304e+04    0.00e+00,  1.00e-01,  1.00e+00,
#          2       1/2 -      -7.03471956e+04    0.00e+00,  1.00e-01,  1.00e+00,
#   --------------------------------------------------------------------------------------
#
#   Standard and modified atomic form factors [note F^(standard) (0) = N_e]:
#
#   ----------------------------------------------------------------------------------------
#      Level        J^P           Energy          q [a.u.]      standard F     modified F
#                                  [eV]
#   ----------------------------------------------------------------------------------------
#          1       3/2 -      -7.03583304e+04    0.00000e+00    1.70000e+01    1.69498e+01
#                                                1.00000e-01    1.69967e+01    1.69465e+01
#                                                1.00000e+00    1.66753e+01    1.66252e+01
#          2       1/2 -      -7.03471956e+04    0.00000e+00    1.70000e+01    1.69498e+01
#                                                1.00000e-01    1.69967e+01    1.69465e+01
#                                                1.00000e+00    1.66742e+01    1.66241e+01
#   ----------------------------------------------------------------------------------------
#
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# In the future, we plan to extend this notebook to include also the computation of elastic and inelastic scattering cross sections.
