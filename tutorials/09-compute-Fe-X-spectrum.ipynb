# %% [markdown]
# # Compute the spectrum of Fe X

# %%
using JAC
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-10623442494393362226\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-8130180666112421\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-10623442494393362226\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")

# %% [markdown]
# Multiply charged ions have attracted continuous interest due to recent observations by the Solar and heliospheric Observatory (SOHO), the Far Ultraviolet Spectroscopic Explorer (FUSE) and several other astrophysical missions. In the extreme ultra-violet (EUV) range of spectra, for instance, many of the spectroscopically observed lines belong to the iron-group elements owing to their high abundance in different objects. Until the present, however, several of these lines remained unclassified because reliable theoretical predictions are often not available that consistently include relativistic and correlation effects.
#
# To demonstrate the use of the JAC toolbox, we here consider the level structure of Fe$^{9+}$ ions which, in spectroscopic notation, give rise to the spectrum Fe X. Several medium-to-large scale computations have been carried out to calculate the excitation energies and transition probabilities of (and among) the levels from the [Ne] $3s^2 3p^5$ -> $3s^2 3p^4 3d + 3s 3p^6$ configuration. These three configurations comprise in total 31 fine-structure levels with total angular momenta $J = 1/2, ..., 9/2$ (cf. Dong et al., 1999). Although the
# $3s^2 3p^4 3d + 3s 3p^6$ levels mainly decay by electric-dipole (E1) transitions, also M1, E2 and M2 multipole transitions have been considered in the literature. Below, we show how this *complete* Fe X spectrum can be calculated approximately by just a single call within the JAC toolbox.

# %% [markdown]
# However, before we shall perform this computation, let us define a standard grid for the computations:

# %%
grid = Radial.Grid("grid: exponential")
setDefaults("standard grid", grid)
# Out:
# Define a radial grid of type MeshGL with 400 grid points
#  [rnt=2.000e-06, h=5.000e-02, hp=0.000e+00, NoPoints=390, r_max=9.161e+02;
#   B-splines with break points at every 7th point, nsL=56, nsS=57, orderL=7, orderS=8, orderGL=7]
# (Re-) Define the standard grid with 390 grid points.

# %% [markdown]
# Moreover, we can show here how to select proper **physical units**, in which all the energies, rates, etc. are handled at input and output time. To see the present `settings` of this units, we can simply call:

# %%
Basics.display("settings")
# Out:
# Current settings of the JAC module:
# -----------------------------------
#
#   + Framework:                              relativistic
#   + Energy unit:                            eV
#   + Rate and transition probability unit:   1/s
#   + Cross section unit:                     barn
#   + Time unit:                              sec
#
#   + A standard grid has been defined; cf. Defaults.getDefaults()

# %% [markdown]
# Of course, we could easily change any of these units by a proper call to `setDefaults()`, but we shall leave the present (standard) choice for the given computations. Call `setDefaults()` to change these settings:

# %%
? setDefaults
# Out:
# search: setDefaults
#   Defaults.setDefaults() ... (re-) defines some 'standard' settings which are
#   common to all the computations with the JAC module, and which can be
#   'overwritten' by the user. –- An improper setting of some variable may lead
#   to an error message, if recognized immediately. The following defaults apply
#   if not specified otherwise by the user: the framework is 'relativistic',
#   energies are given in eV and cross sections in barn. Note that, internally,
#   atomic units are used throughout for all the computations within the
#   program. nothing is returned if not indicated otherwise.
#
#     •    ("framework: relativistic") or ("framework: non-relativistic") ...
#         to define a relativistic or non-relativistic framework for all
#         subsequent computations.
#
#     •    ("method: continuum, spherical Bessel") or ("method: continuum,
#         pure sine") or ("method: continuum, asymptotic Coulomb") or
#         ("method: continuum, nonrelativistic Coulomb") or ("method:
#         continuum, Galerkin") ... to define a a method for the generation
#         of the continuum orbitals as (pure) spherical Bessel, pure sine,
#         asymptotic Coulomb, nonrelativistic Coulomb orbital or by means of
#         the B-spline-Galerkin method.
#
#     •    ("method: normalization, pure sine") or ("method: normalization,
#         pure Coulomb") ... to define a method for the normalization of the
#         continuum orbitals as asymptotically (pure) sine or Coulomb
#         functions.
#
#     •    ("QED model: Petersburg") or ("QED model: Sydney") ... to define a
#         model for the computation of the QED corrections following the
#         work by Shabaev et al. (2011; Petersburg) or Flambaum and Ginges
#         (2004; Syney).
#
#     •    ("unit: energy", "eV") or ("unit: energy", "Kayser") or ("unit:
#         energy", "Hartree") or ("unit: energy", "Hz") or ("unit: energy",
#         "Hz") ... to (pre-) define the energy units for all further
#         printouts and communications with the JAC module.
#
#     •    ("unit: cross section", "a.u.") or ("unit: cross section", "barn")
#         or ("unit: cross section", "Mbarn") ... to (pre-) define the unit
#         for the printout of cross sections.
#
#     •    ("unit: rate", "a.u.") or ("unit: rate", "1/s") ... to (pre-)
#         define the unit for the printout of rates.
#
#     •    ("unit: time", "a.u.") or ("unit: time", "sec") or ("unit: time",
#         "fs") or ("unit: time", "as") ... to (pre-) define the unit for
#         the printout and communications of times with the JAC module.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#     •    ("relativistic subshell list", subshells::Array{Subshell,1};
#         printout::Bool=true) ... to (pre-) define internally the standard
#         relativistic subshell list on which the standard order of orbitals
#         is based.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#     •    ("standard grid", grid::Radial.Grid; printout::Bool=true) ... to
#         (pre-) define internally the standard radial grid which is used to
#         represent most orbitals.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#     •    ("QED: damped-hydrogenic", Znuc::Float64, wa::Array{Float64,1})
#         ... to (re-) define the lambda-C damped overlap integrals of the
#         lowest kappa-orbitals [ wa1s1/2, wa2p1/2, wa2p3/2, wa3d3/2,
#         wa3d5/2 ] for the (new) nuclear charge Znuc; nothing is returned.

# %% [markdown]
# Apparently, we can call `JAC.define()` also in order to open some ASCII (.txt) file into which all the final (important) results are printed for later reference and inspection.

# %%
setDefaults("print summary: open", "09-output-radiative.txt")

# %% [markdown]
# Next, we shall now describe the computation to be carried out. Apart from a title line (String) and nuclear model (cf. tutorial 03-setting-the-nucleus.ipynb), we here need to specify the initial- and final-state configurations that are to be included into the computation. This is done by defining an instance of an:
#
# ```julia
# comp = Atomic.Computation("Energies and Einstein coefficients for the spectrum Fe X",
#               Nuclear.Model(26.);
#               initialConfigs = [Configuration("[Ne] 3s 3p^6"),
#                                 Configuration("[Ne] 3s^2 3p^4 3d")],
#               finalConfigs   = [Configuration("[Ne] 3s^2 3p^5")],
#               process = Radiative,
#               processSettings = PhotoEmission.Settings(...) );
# ```
#
# In principle, any number of configurations can be specified as long as they are listed explicitly. Here, we have selected also the identifier `Radiative` to consider the computation of transition probabilities between the levels of the three configurations given above. All further details about any computation can be specified by means of some proper `settings` that are specific to each particular process, here `PhotoEmission.Settings()`. To better understand to which extent we can affect and control these computations, let us look at the definition of this data struct:

# %%
? PhotoEmission.Settings
# Out:
#   struct  PhotoEmission.Settings ... defines a type for the details and
#   parameters of computing radiative lines.
#
#   + multipoles              ::Array{EmMultipoles}     ... Specifies the (radiat. field) multipoles to be included.
#   + gauges                  ::Array{UseGauge}         ... Gauges to be included into the computations.
#   + calcAnisotropy          ::Bool                    ... True, if the anisotropy (structure) functions are to be
#                                                           calculated and false otherwise
#   + printBeforeComputation  ::Bool                    ... True, if all energies and lines are printed before comput.
#   + selectLines             ::Bool                    ... True, if lines are selected individually for the computat.
#   + selectedLines           ::Array{Tuple{Int64,Int64},1}  ... List of lines as tupels (inital-level, final-level).
#   + photonEnergyShift       ::Float64                 ... An overall energy shift for all photon energies.
#   + mimimumPhotonEnergy     ::Float64                 ... minimum transition energy for which (photon) transitions
#                                                           are included into the computation.
#   + maximumPhotonEnergy     ::Float64                 ... maximum transition energy for which (photon) transitions
#                                                           are included.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   PhotoEmission.Settings() ... constructor for the default values of radiative
#   line computations

# %% [markdown]
# Of course, we can always apply the default values for any particular compuation which, for present case, are given by:

# %%
PhotoEmission.Settings()
# Out:
# multipoles:             EmMultipole[E1]
# gauges:                 UseGauge[UseCoulomb]
# calcAnisotropy:         false
# printBeforeComputation: false
# selectLines:            false
# selectedLines:          Tuple{Int64,Int64}[]
# photonEnergyShift:      0.0
# mimimumPhotonEnergy:    0.0
# maximumPhotonEnergy:    0.0

# %% [markdown]
# Below, we wish to consider also other multipole transitions, namely E1, M1, E2, M2, and like perform all calculations within both, the Coulomb and Babushkin gauges. In addition, we shall **NOT** compute the (angular) anisotropy parameters nor do we wish to select individual transitions right from the beginning. This latter option might be interesting if large sets of configurations are to be considered. Moreover, we do not neither specify any (overall) shift nor restrict the photon energies, two features that are of particular interest for large data sets
#
#
# We these remarks in mind, we now specify the atomic computation in the form:

# %%
comp = Atomic.Computation("Energies and Einstein coefficients for the spectrum Fe X",  Nuclear.Model(26.);
              initialConfigs = [Configuration("[Ne] 3s 3p^6"), Configuration("[Ne] 3s^2 3p^4 3d")],
              finalConfigs   = [Configuration("[Ne] 3s^2 3p^5")], 
              process = Radiative, 
              processSettings = PhotoEmission.Settings([E1, M1, E2, M2], 
                                              [UseCoulomb, UseBabushkin], false, true, 
                                              false, Tuple{Int64,Int64}[], 0., 0., 10000. ) );
# Out:
# Define a radial grid of type MeshGL with 400 grid points
#  [rnt=2.000e-06, h=5.000e-02, hp=0.000e+00, NoPoints=390, r_max=9.161e+02;
#   B-splines with break points at every 7th point, nsL=56, nsS=57, orderL=7, orderS=8, orderGL=7]

# %% [markdown]
# All what is needed now is to **perform** this computation by the call:

# %%
perform(comp)
# Out:
# ... in perform['computation: SCF'] ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^1 3p_1/2^2 3p_3/2^4
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^0 3p_3/2^4 3d_3/2^0 3d_5/2^1
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2
-01    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 3d_5/2.
# (Re-) Define the standard grid with 390 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.5025798e+02;   self-cons'cy = 1.5361e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.1323697e+01;   self-cons'cy = 4.6360e-01  [1.0000e+02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.6066028e+00;   self-cons'cy = 6.2987e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.8574950e+01;   self-cons'cy = 4.9888e-01  [1.0000e+02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.9199055e+00;   self-cons'cy = 6.5430e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.0200421e+01;   self-cons'cy = 4.7428e-01  [1.0000e+02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -8.3138097e+00;   self-cons'cy = 6.3839e-01  [1.0000e+02 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -7.1702498e+00;   self-cons'cy = 6.8018e-01  [1.0000e+02 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -7.2581275e+00;   self-cons'cy = 6.7635e-01  [1.0000e+02 for sym-block kappa = -3]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6723941e+02;   self-cons'cy = 3.2815e-02  [1.1826e+00 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.9330876e+01;   self-cons'cy = 1.1333e-01  [1.1826e+00 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0762916e+01;   self-cons'cy = 1.1133e-01  [1.1826e+00 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4804819e+01;   self-cons'cy = 9.8294e-02  [2.9004e-01 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.3357483e+00;   self-cons'cy = 8.2051e-02  [2.9004e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3869403e+01;   self-cons'cy = 5.7265e-02  [2.1529e+00 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.1278088e+00;   self-cons'cy = 4.6670e-02  [2.1529e+00 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -6.9993300e+00;   self-cons'cy = 1.2062e-02  [2.9224e-02 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -6.9901646e+00;   self-cons'cy = 1.8807e-02  [2.5769e+00 for sym-block kappa = -3]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6433709e+02;   self-cons'cy = 5.4598e-03  [1.6270e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.7915690e+01;   self-cons'cy = 1.8320e-02  [1.6270e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0318217e+01;   self-cons'cy = 2.1095e-02  [1.6270e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.3923843e+01;   self-cons'cy = 1.2818e-02  [5.9114e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1001670e+00;   self-cons'cy = 1.2778e-02  [5.9114e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3525387e+01;   self-cons'cy = 5.1045e-03  [1.0966e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0394933e+00;   self-cons'cy = 4.8612e-03  [1.0966e-01 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -7.0691590e+00;   self-cons'cy = 4.9635e-03  [1.0390e-02 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -7.0558104e+00;   self-cons'cy = 4.6736e-03  [2.0653e-01 for sym-block kappa = -3]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6471493e+02;   self-cons'cy = 7.1418e-04  [3.6466e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8094168e+01;   self-cons'cy = 2.3481e-03  [3.6466e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0372240e+01;   self-cons'cy = 2.6110e-03  [3.6466e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4010631e+01;   self-cons'cy = 1.2775e-03  [4.9797e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1211760e+00;   self-cons'cy = 1.1530e-03  [4.9797e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3544287e+01;   self-cons'cy = 2.8179e-04  [4.0663e-03 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0426288e+00;   self-cons'cy = 1.7341e-04  [4.0663e-03 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -7.0588549e+00;   self-cons'cy = 7.2934e-04  [1.5416e-03 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -7.0472396e+00;   self-cons'cy = 6.0772e-04  [3.2717e-02 for sym-block kappa = -3]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6467467e+02;   self-cons'cy = 7.6057e-05  [3.5021e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8075563e+01;   self-cons'cy = 2.4424e-04  [3.5021e-03 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0366667e+01;   self-cons'cy = 2.6870e-04  [3.5021e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4004085e+01;   self-cons'cy = 9.6249e-05  [3.2253e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1198155e+00;   self-cons'cy = 7.4587e-05  [3.2253e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3544517e+01;   self-cons'cy = 3.4256e-06  [5.4166e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0429985e+00;   self-cons'cy = 2.0437e-05  [5.4166e-04 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -7.0599155e+00;   self-cons'cy = 7.5121e-05  [1.5892e-04 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -7.0480622e+00;   self-cons'cy = 5.8363e-05  [3.0602e-03 for sym-block kappa = -3]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6467811e+02;   self-cons'cy = 6.5014e-06  [2.6730e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8077107e+01;   self-cons'cy = 2.0269e-05  [2.6730e-04 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0367119e+01;   self-cons'cy = 2.1801e-05  [2.6730e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4004347e+01;   self-cons'cy = 3.8490e-06  [4.3003e-06 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1198354e+00;   self-cons'cy = 1.0943e-06  [4.3003e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3544268e+01;   self-cons'cy = 3.6997e-06  [1.4513e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0428959e+00;   self-cons'cy = 5.6691e-06  [1.4513e-04 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -7.0598331e+00;   self-cons'cy = 5.8405e-06  [1.2383e-05 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -7.0480035e+00;   self-cons'cy = 4.1672e-06  [2.1969e-04 for sym-block kappa = -3]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6467790e+02;   self-cons'cy = 3.8696e-07  [1.3783e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8077021e+01;   self-cons'cy = 1.1339e-06  [1.3783e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0367095e+01;   self-cons'cy = 1.1621e-06  [1.3783e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4004370e+01;   self-cons'cy = 3.4041e-07  [2.7268e-06 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1198466e+00;   self-cons'cy = 6.1322e-07  [2.7268e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3544312e+01;   self-cons'cy = 6.4920e-07  [2.0949e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0429109e+00;   self-cons'cy = 8.2674e-07  [2.0949e-05 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -7.0598368e+00;   self-cons'cy = 2.6413e-07  [5.6283e-07 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -7.0480055e+00;   self-cons'cy = 1.3939e-07  [7.4166e-06 for sym-block kappa = -3]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6467790e+02;   self-cons'cy = 1.4021e-09  [3.3689e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8077020e+01;   self-cons'cy = 8.6569e-09  [3.3689e-07 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0367095e+01;   self-cons'cy = 1.9488e-08  [3.3689e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4004363e+01;   self-cons'cy = 1.0585e-07  [5.5544e-07 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1198443e+00;   self-cons'cy = 1.2630e-07  [5.5544e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3544307e+01;   self-cons'cy = 8.0379e-08  [2.3091e-06 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0429092e+00;   self-cons'cy = 9.1774e-08  [2.3091e-06 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -7.0598370e+00;   self-cons'cy = 1.4423e-08  [3.0069e-08 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -7.0480057e+00;   self-cons'cy = 1.9321e-08  [1.0065e-06 for sym-block kappa = -3]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6467790e+02;   self-cons'cy = 3.9492e-09  [2.1184e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8077021e+01;   self-cons'cy = 1.3919e-08  [2.1184e-07 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0367095e+01;   self-cons'cy = 1.6204e-08  [2.1184e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4004364e+01;   self-cons'cy = 1.6030e-08  [7.3739e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1198446e+00;   self-cons'cy = 1.6848e-08  [7.3739e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3544307e+01;   self-cons'cy = 7.8769e-09  [2.0061e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0429094e+00;   self-cons'cy = 8.0558e-09  [2.0061e-07 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -7.0598369e+00;   self-cons'cy = 5.5508e-09  [1.1715e-08 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] =
for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.9371660e+01;   self-cons'cy = 1.0941e-01  [1.1918e+00 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0793953e+01;   self-cons'cy = 1.0985e-01  [1.1918e+00 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4836918e+01;   self-cons'cy = 9.4059e-02  [2.8690e-01 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.3697352e+00;   self-cons'cy = 8.1151e-02  [2.8690e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3849662e+01;   self-cons'cy = 4.6678e-02  [5.3029e+00 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.1350035e+00;   self-cons'cy = 3.7684e-02  [5.3029e+00 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6419082e+02;   self-cons'cy = 5.4259e-03  [1.6404e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.7926770e+01;   self-cons'cy = 1.8692e-02  [1.6404e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0323567e+01;   self-cons'cy = 2.2275e-02  [1.6404e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.3919036e+01;   self-cons'cy = 1.3350e-02  [6.6342e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1050511e+00;   self-cons'cy = 1.4327e-02  [6.6342e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3534103e+01;   self-cons'cy = 4.6830e-03  [1.1011e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0493502e+00;   self-cons'cy = 4.7103e-03  [1.1011e-01 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6459146e+02;   self-cons'cy = 7.5766e-04  [4.9238e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8128696e+01;   self-cons'cy = 2.6550e-03  [4.9238e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0388443e+01;   self-cons'cy = 3.1323e-03  [4.9238e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4026174e+01;   self-cons'cy = 1.5768e-03  [7.2862e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1354493e+00;   self-cons'cy = 1.6665e-03  [7.2862e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3558830e+01;   self-cons'cy = 3.6854e-04  [8.9629e-03 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0556938e+00;   self-cons'cy = 3.5038e-04  [8.9629e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454326e+02;   self-cons'cy = 9.1091e-05  [4.9856e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8104200e+01;   self-cons'cy = 3.2133e-04  [4.9856e-03 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0380471e+01;   self-cons'cy = 3.8386e-04  [4.9856e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4015393e+01;   self-cons'cy = 1.5845e-04  [7.4057e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1323806e+00;   self-cons'cy = 1.6799e-04  [7.4057e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557636e+01;   self-cons'cy = 1.7789e-05  [3.8220e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554415e+00;   self-cons'cy = 1.3928e-05  [3.8220e-04 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454829e+02;   self-cons'cy = 9.5013e-06  [4.8471e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106763e+01;   self-cons'cy = 3.3629e-05  [4.8471e-04 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381308e+01;   self-cons'cy = 4.0331e-05  [4.8471e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016274e+01;   self-cons'cy = 1.2955e-05  [5.9882e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326289e+00;   self-cons'cy = 1.3596e-05  [5.9882e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557572e+01;   self-cons'cy = 9.5793e-07  [3.6851e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554126e+00;   self-cons'cy = 1.6003e-06  [3.6851e-05 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454785e+02;   self-cons'cy = 8.3301e-07  [4.2862e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106538e+01;   self-cons'cy = 2.9547e-06  [4.2862e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381234e+01;   self-cons'cy = 3.5593e-06  [4.2862e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016227e+01;   self-cons'cy = 6.8787e-07  [3.0616e-06 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326162e+00;   self-cons'cy = 6.9495e-07  [3.0616e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557600e+01;   self-cons'cy = 4.2365e-07  [1.2548e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554218e+00;   self-cons'cy = 5.1114e-07  [1.2548e-05 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454787e+02;   self-cons'cy = 5.3666e-08  [2.7460e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106553e+01;   self-cons'cy = 1.9083e-07  [2.7460e-06 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381239e+01;   self-cons'cy = 2.3171e-07  [2.7460e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016226e+01;   self-cons'cy = 2.0905e-08  [1.2296e-07 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326157e+00;   self-cons'cy = 2.7926e-08  [1.2296e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557595e+01;   self-cons'cy = 7.5969e-08  [2.1474e-06 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554203e+00;   self-cons'cy = 8.6198e-08  [2.1474e-06 for sym-block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454787e+02;   self-cons'cy = 6.6440e-10  [3.0730e-08 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106553e+01;   self-cons'cy = 2.4306e-09  [3.0730e-08 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381239e+01;   self-cons'cy = 3.2874e-09  [3.0730e-08 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016227e+01;   self-cons'cy = 1.3054e-08  [6.4423e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326160e+00;   self-cons'cy = 1.4626e-08  [6.4423e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557596e+01;   self-cons'cy = 1.0442e-08  [2.8870e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554205e+00;   self-cons'cy = 1.1473e-08  [2.8870e-07 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 3/2^- ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    3/2 -     -1.242746372725031e+03    -3.381685127317562e+04    -3.381685127317562e+04
#      2    1/2 -     -1.242672314266558e+03    -3.381483603987407e+04    -3.381483603987407e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     7.405845847279124e-02    2.015233301549262e+00    2.015233301549262e+00
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     7.405845847279124e-02    2.015233301549262e+00    2.015233301549262e+00
# (Re-) Define a new standard subshell list.
#
# PhotoEmission.computeLines(): The computation of the transition amplitudes and properties starts now ...
# --------------------------------------------------------------------------------------------------------
#
#
#   Selected radiative lines:
#
#   -----------------------------------------------------------------------------------------------
#        i-level-f           i--J^P--f            Energy        List of multipoles
#                                                  [eV]
#   -----------------------------------------------------------------------------------------------
#          1 --    1      1/2 + --> 3/2 -     3.46007622e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#          1 --    2      1/2 + --> 1/2 -     3.25855288e+01    E1(Coulomb), E1(Babushkin)
#          2 --    1      7/2 + --> 3/2 -     4.71644789e+01    M2(Magnetic)
#          3 --    1      5/2 + --> 3/2 -     4.71654436e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#          3 --    2      5/2 + --> 1/2 -     4.51502103e+01    M2(Magnetic)
#          4 --    1      3/2 + --> 3/2 -     4.73187713e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#          4 --    2      3/2 + --> 1/2 -     4.53035380e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#          5 --    1      1/2 + --> 3/2 -     4.75122148e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#          5 --    2      1/2 + --> 1/2 -     4.54969815e+01    E1(Coulomb), E1(Babushkin)
#          7 --    1      7/2 + --> 3/2 -     5.15513241e+01    M2(Magnetic)
#          8 --    1      1/2 + --> 3/2 -     5.18177760e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#          8 --    2      1/2 + --> 1/2 -     4.98025427e+01    E1(Coulomb), E1(Babushkin)
#          9 --    1      5/2 + --> 3/2 -     5.20272955e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#          9 --    2      5/2 + --> 1/2 -     5.00120622e+01    M2(Magnetic)
#         10 --    1      3/2 + --> 3/2 -     5.22381610e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         10 --    2      3/2 + --> 1/2 -     5.02229277e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         11 --    1      3/2 + --> 3/2 -     5.28160873e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         11 --    2      3/2 + --> 1/2 -     5.08008540e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         12 --    1      1/2 + --> 3/2 -     5.33339049e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         12 --    2      1/2 + --> 1/2 -     5.13186716e+01    E1(Coulomb), E1(Babushkin)
#         13 --    1      3/2 + --> 3/2 -     5.34408293e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         13 --    2      3/2 + --> 1/2 -     5.14255960e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         14 --    1      3/2 + --> 3/2 -     5.40423306e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         14 --    2      3/2 + --> 1/2 -     5.20270973e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         15 --    1      7/2 + --> 3/2 -     5.42573198e+01    M2(Magnetic)
#         16 --    1      5/2 + --> 3/2 -     5.42958658e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         16 --    2      5/2 + --> 1/2 -     5.22806325e+01    M2(Magnetic)
#         17 --    1      5/2 + --> 3/2 -     5.46600496e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         17 --    2      5/2 + --> 1/2 -     5.26448163e+01    M2(Magnetic)
#         19 --    1      7/2 + --> 3/2 -     5.55564602e+01    M2(Magnetic)
#         20 --    1      5/2 + --> 3/2 -     5.60525625e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         20 --    2      5/2 + --> 1/2 -     5.40373291e+01    M2(Magnetic)
#         21 --    1      5/2 + --> 3/2 -     5.98727325e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         21 --    2      5/2 + --> 1/2 -     5.78574992e+01    M2(Magnetic)
#         22 --    1      7/2 + --> 3/2 -     6.03805936e+01    M2(Magnetic)
#         23 --    1      3/2 + --> 3/2 -     6.43671840e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         23 --    2      3/2 + --> 1/2 -     6.23519507e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         24 --    1      5/2 + --> 3/2 -     6.49412381e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         24 --    2      5/2 + --> 1/2 -     6.29260048e+01    M2(Magnetic)
#         25 --    1      1/2 + --> 3/2 -     7.11828509e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         25 --    2      1/2 + --> 1/2 -     6.91676176e+01    E1(Coulomb), E1(Babushkin)
#         26 --    1      3/2 + --> 3/2 -     7.17928147e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         26 --    2      3/2 + --> 1/2 -     6.97775814e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         27 --    1      1/2 + --> 3/2 -     7.25399895e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         27 --    2      1/2 + --> 1/2 -     7.05247562e+01    E1(Coulomb), E1(Babushkin)
#         28 --    1      5/2 + --> 3/2 -     7.38450057e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         28 --    2      5/2 + --> 1/2 -     7.18297723e+01    M2(Magnetic)
#         29 --    1      3/2 + --> 3/2 -     7.55367020e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#         29 --    2      3/2 + --> 1/2 -     7.35214687e+01    E1(Coulomb), E1(Babushkin), M2(Magnetic)
#   -----------------------------------------------------------------------------------------------
#
# Compute radiative E1 matrix of dimension 2 x 29 in the initial- and final-state bases for the transition [1-1] ... nz = 2
# done.
# Compute radiative E1 matrix of dimension 2 x 29 in the initial- and final-state bases for the transition [1-1] ... done.
# Compute radiative M2 matrix of dimension 2 x 29 in the initial- and final-state bases for the transition [1-1] ... done.
# Compute radiative E1 matrix of dimension 2 x 29 in the initial- and final-state bases for the transition [1-2] ... nz = 2
# done.
# Compute radiative E1 matrix of dimension 2 x 29 in the initial- and final-state bases for the transition [1-2] ... done.
# Compute radiative M2 matrix of dimension 2 x 29 in the initial- and final-state bases for the transition [2-1] ... done.
# Compute radiative E1 matrix of dimension 2 x 29 in the initial- and final-state bases for the transition [3-1] ... done.
# Compute radiative E1 matrix of dimension 2 x 29 in the initial- and final-state bases for the transition [3-1] ... done.
# Compute radiative M2 matrix of dimension 2 x 29 in the initial- and final-state bases for the transition [3-1] ... done.
# Compute radiative M2 matrix of dimension 2 x 29 in the initial- and final-state bases for the transition [3-2] ... done.
# Compute radiative E1 matrix of dimension 2 x 29 in the initial- and final-state bases for the transition [4-1] ... done.
# Compute radiative E1 matrix of dimension 2 x 29 in the initial- and final-state bases for the transition [4-1] ... done.
# Compute radiative M2 matrix of dimension 2 x 29 in the initial- and final-state bases for the transition [4-1] ... done.
# ...
#         29 --    1      3/2 + --> 3/2 -     7.55367020e+01        M2       Magnetic     4.55649290e-02  1.30866199e-12    1.84036982e-13    2.99913808e-17
#         29 --    2      3/2 + --> 1/2 -     7.35214687e+01        E1       Coulomb      6.97515696e+09  4.34522536e-01    5.94765920e-02    4.59113167e-06
#         29 --    2      3/2 + --> 1/2 -     7.35214687e+01        E1       Babushkin    1.38172240e+10  8.60754135e-01    1.17818337e-01    9.09466195e-06
#         29 --    2      3/2 + --> 1/2 -     7.35214687e+01        M2       Magnetic     3.39970677e+00  2.11787235e-10    2.89890211e-11    2.23772763e-15
#   -----------------------------------------------------------------------------------------------------------------------------------------------------------
#
#   PhotoEmission lifetimes (as derived from these computations):
#
#   ---------------------------------------------------------------------------------------------------------------
#      Level        J^P        Level energy      Used Gauge                  Lifetime                Decay widths
#                                  [eV]                               [a.u.]          [sec]             [eV]
#   ---------------------------------------------------------------------------------------------------------------
#          1       1/2 +      -3.37822505e+04    Coulomb          6.46424492e+06  1.56362602e-10    4.20952275e-06
#                                                Babushkin        5.04559570e+06  1.22047120e-10    5.39309680e-06
#          2       7/2 +      -3.37696868e+04    Coulomb          8.22444755e+14  1.98939867e-02    3.30859743e-14
#                                                Babushkin        8.22444755e+14  1.98939867e-02    3.30859743e-14
#          3       5/2 +      -3.37696858e+04    Coulomb          8.15042160e+05  1.97149265e-11    3.33864766e-05
#                                                Babushkin        1.09849788e+06  2.65713922e-11    2.47714507e-05
#          4       3/2 +      -3.37695325e+04    Coulomb          1.83285337e+06  4.43346016e-11    1.48464610e-05
#                                                Babushkin        2.66405958e+06  6.44405176e-11    1.02142558e-05
#          5       1/2 +      -3.37693391e+04    Coulomb          3.01665138e+06  7.29693052e-11    9.02039467e-06
#                                                Babushkin        4.06538438e+06  9.83369426e-11    6.69343499e-06
#          7       7/2 +      -3.37652999e+04    Coulomb          4.25604934e+16  1.02948907e+00    6.39357861e-16
#                                                Babushkin        4.25604934e+16  1.02948907e+00    6.39357861e-16
#          8       1/2 +      -3.37650335e+04    Coulomb          1.26476961e+06  3.05933129e-11    2.15148956e-05
#                                                Babushkin        1.41580670e+06  3.42467253e-11    1.92197043e-05
#          9       5/2 +      -3.37648240e+04    Coulomb          2.71901385e+06  6.57697979e-11    1.00078144e-05
#                                                Babushkin        3.09988417e+06  7.49826102e-11    8.77819444e-06
#         10       3/2 +      -3.37646131e+04    Coulomb          3.69064224e+06  8.92723639e-11    7.37307609e-06
#                                                Babushkin        4.56317893e+06  1.10378017e-10    5.96325203e-06
#                                                Babushkin        4.97695906e+06  1.20386879e-10    5.46747235e-06
#         29       3/2 +      -3.37413146e+04    Coulomb          5.01113885e+06  1.21213649e-10    5.43018001e-06
#                                                Babushkin        2.58159677e+06  6.24458377e-11    1.05405253e-05
#   ---------------------------------------------------------------------------------------------------------------
#
#   Anisotropy (structure) functions:
#
#   ---------------------------------------------------------------------------------------------------------------------------------------------------------
#        i-level-f           i--J^P--f            Energy        Multipoles           f_2 (Coulomb)    f_2 (Babushkin)    f_4 (Coulomb)    f_4 (Babushkin)
#                                                  [eV]
#   ---------------------------------------------------------------------------------------------------------------------------------------------------------
#          1 --    1      1/2 + --> 3/2 -     3.46007622e+01    E1, M2               0.00000000e+00    0.00000000e+00    0.00000000e+00    0.00000000e+00
#          1 --    2      1/2 + --> 1/2 -     3.25855288e+01    E1                   0.00000000e+00    0.00000000e+00    0.00000000e+00    0.00000000e+00
#          2 --    1      7/2 + --> 3/2 -     4.71644789e+01    M2                  -4.67609765e-01   -4.67609765e-01   -3.58161812e-01   -3.58161812e-01
#          3 --    1      5/2 + --> 3/2 -     4.71654436e+01    E1, M2               5.18685821e-02   -6.02161163e-02   -2.46700125e-07   -3.32497602e-07
#          3 --    2      5/2 + --> 1/2 -     4.51502103e+01    M2                  -5.34522484e-01   -5.34522484e-01   -6.17213400e-01   -6.17213400e-01
#          4 --    1      3/2 + --> 3/2 -     4.73187713e+01    E1, M2              -1.88216932e-02    1.97511013e-02    0.00000000e+00    0.00000000e+00
#          4 --    2      3/2 + --> 1/2 -     4.53035380e+01    E1, M2               8.55073921e-02   -1.03146579e-01    0.00000000e+00    0.00000000e+00
#          5 --    1      1/2 + --> 3/2 -     4.75122148e+01    E1, M2               0.00000000e+00    0.00000000e+00    0.00000000e+00    0.00000000e+00
#          5 --    2      1/2 + --> 1/2 -     4.54969815e+01    E1                   0.00000000e+00    0.00000000e+00    0.00000000e+00    0.00000000e+00
#          7 --    1      7/2 + --> 3/2 -     5.15513241e+01    M2                  -4.67609765e-01   -4.67609765e-01   -3.58161812e-01   -3.58161812e-01
#          8 --    1      1/2 + --> 3/2 -     5.18177760e+01    E1, M2               0.00000000e+00    0.00000000e+00    0.00000000e+00    0.00000000e+00
#          8 --    2      1/2 + --> 1/2 -     4.98025427e+01    E1                   0.00000000e+00    0.00000000e+00    0.00000000e+00    0.00000000e+00
#          9 --    1      5/2 + --> 3/2 -     5.20272955e+01    E1, M2               2.37312124e-02   -2.53385039e-02   -5.84068826e-07   -6.65883224e-07
#          9 --    2      5/2 + --> 1/2 -     5.00120622e+01    M2                  -5.34522484e-01   -5.34522484e-01   -6.17213400e-01   -6.17213400e-01
#         10 --    1      3/2 + --> 3/2 -     5.22381610e+01    E1, M2              -3.84877059e-02    4.25880691e-02    0.00000000e+00    0.00000000e+00
#         10 --    2      3/2 + --> 1/2 -     5.02229277e+01    E1, M2               5.04218437e-02   -5.60766657e-02    0.00000000e+00    0.00000000e+00
#         23 --    2      3/2 + --> 1/2 -     6.23519507e+01    E1, M2              -6.20722713e-02    5.52174371e-02    0.00000000e+00    0.00000000e+00
#         24 --    1      5/2 + --> 3/2 -     6.49412381e+01    E1, M2              -6.51068150e-02    5.54586641e-02    6.67592279e-06    4.84442066e-06
#         24 --    2      5/2 + --> 1/2 -     6.29260048e+01    M2                  -5.34522484e-01   -5.34522484e-01   -6.17213400e-01   -6.17213400e-01
#         25 --    1      1/2 + --> 3/2 -     7.11828509e+01    E1, M2               0.00000000e+00    0.00000000e+00    0.00000000e+00    0.00000000e+00
#         25 --    2      1/2 + --> 1/2 -     6.91676176e+01    E1                   0.00000000e+00    0.00000000e+00    0.00000000e+00    0.00000000e+00
#         26 --    1      3/2 + --> 3/2 -     7.17928147e+01    E1, M2               4.08516767e-01   -2.02253623e-01    0.00000000e+00    0.00000000e+00
#         26 --    2      3/2 + --> 1/2 -     6.97775814e+01    E1, M2              -1.63620327e-01    1.23278254e-01    0.00000000e+00    0.00000000e+00
#         27 --    1      1/2 + --> 3/2 -     7.25399895e+01    E1, M2               0.00000000e+00    0.00000000e+00    0.00000000e+00    0.00000000e+00
#         27 --    2      1/2 + --> 1/2 -     7.05247562e+01    E1                   0.00000000e+00    0.00000000e+00    0.00000000e+00    0.00000000e+00
#         28 --    1      5/2 + --> 3/2 -     7.38450057e+01    E1, M2              -1.71776313e-01    1.17730700e-01    1.51138499e-05    7.10007374e-06
#         28 --    2      5/2 + --> 1/2 -     7.18297723e+01    M2                  -5.34522484e-01   -5.34522484e-01   -6.17213400e-01   -6.17213400e-01
#         29 --    1      3/2 + --> 3/2 -     7.55367020e+01    E1, M2               1.25082531e-01   -9.52854369e-02    0.00000000e+00    0.00000000e+00
#         29 --    2      3/2 + --> 1/2 -     7.35214687e+01    E1, M2              -2.03707964e-01    1.44739579e-01    0.00000000e+00    0.00000000e+00
#   ---------------------------------------------------------------------------------------------------------------------------------------------------------
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# ... and which shows all the intermediate output of the computations. First, all the initial-state levels are calculated *self-consistently* due to the default values for such SCF and configuration-interaction computations, and similarly for all final-state levels. These computations include the definition of the CSF basis, the generation of *start* orbitals as well as the computation of the angular coefficients, the SCF interation and up to the set-up and diagonalization of the corresponding Hamiltonian matrix. Obviously, this gives rise to a full representation of all atomic levels of interest.
#
# These levels are then utilized to compute the (multipole) transitions amplitudes and rates. All final results are also tabulated in a neat format. However, since many of the internal tables of the JAC toolbox are *wider* than the standard widths of these notebooks, we shall first **close** our .txt summary file:

# %%
setDefaults("print summary: close", "")

# %% [markdown]
# This summary file **09-output-radiative.txt** can now be found in the current directory. As seen from these tables, the transition energies agree within 3..4 digits with a similar computation by other atomic structure codes, such as GRASP. Apart from the level splitting among the low-lying $3s 3p^6$, $3s^2 3p^4 3d$  $J=1/2$ levels, further comparision can be made also with the evaluated data from the NIST Spectroscopic Database, for instance, for the excitation energies from the $3s^2 3p^5$  $J = 3/2$ ground level.
