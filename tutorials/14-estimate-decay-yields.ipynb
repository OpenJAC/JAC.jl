# %% [markdown]
# # K-shell fluorescence & Auger yields for neon-like ions

# %%
using JAC

# %% [markdown]
# The fluorescence yield $\omega_r$ characterizes the probability of an inner-shell (core) hole to be filled under photon emission, in contrast and competition with other nonradiative processes. It fulfills together with the Auger yield $\omega_a$ the simple relations: $\omega_r + \omega_a = 1$ but generally requires to consider all possible (radiative and non-radiative) decay channels.
#
# In Jac, the computation of all fluorescence and Auger yields is always traced back to single-step **cascade computation**. Here, we wish to compute the fluorescence and Auger yields for a few neon-like ions, and like to see how the *fluorescence* increases with the nuclear charge. Similar as for other (level) properties, we can estimate the yields by performing an `Atomic.Computation(...,  properties=[Yields, ..], configs=[..], yieldSettings=DecayYield.Settings(..), ..)`.
#
# To understand, how we can control the computation of yields, let us have a look at the internal definition and the default settings of `DecayYield.Settings(..)`

# %%
? DecayYield.Settings
# Out:
#   struct  DecayYield.Settings ... defines a type for the details and
#   parameters of computing fluorescence and Auger yields.
#
#   + approach                 ::String         ... Determines the applied cascade approach for the yields: {"AverageSCA", "SCA"}.
#   + printBefore   ::Bool           ... True if a list of selected levels is to be printed before the actual computations start.
#   + selectLevels             ::Bool           ... True if individual levels are selected for the computation.
#   + selectedLevels           ::Array{Level,1} ... List of selected levels.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   DecayYield.Settings() ... constructor for an empty instance of
#   DecayYield.Settings for the computation of fluorescence and Auger yields.

# %%
DecayYield.Settings()
# Out:
# approach:                 AverageSCA
# printBefore:   false
# selectLevels:             false
# selectedLevels:           Level[]

# %% [markdown]
# Here, the approach refers to one particular *cascade approaches* (cf. User Guide, chapter 8) that are available in JAC; because of the internal program structure (i.e. the dependencies of the individual modules), however, this approach need to be provided in `String` notation as indicated above.
#
# To compute the fluorescence yields for neon-like Mg, we can specify also the SCA approach in the settings and run the computation by:

# %%
ySettings = DecayYield.Settings("SCA", true, false, Int64[])
wa = Atomic.Computation(Atomic.Computation(), name="Yield computations for neon-like Mg", grid=Radial.Grid(false),
                        nuclearModel=Nuclear.Model(12.), properties=[JAC.Yields],
                        configs=[Configuration("1s 2s^2 2p^6")], yieldSettings=ySettings )
perform(wa)
# Out:
# aa: NoProcess   multipoles:             EmMultipole[E1]
# gauges:                 UseGauge[UseCoulomb]
# calcAnisotropy:         false
# printBefore:            false
# selectLines:            false
# selectedLines:          Tuple{Int64,Int64}[]
# photonEnergyShift:      0.0
# mimimumPhotonEnergy:    0.0
# maximumPhotonEnergy:    0.0
#
#
# ... in performSCF ...
# >> include Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 12.0 with mass = 24.72, radius R = 3.0053184906569026 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -7.21385120e+01    -7.21385593e+01    +6.55305363e-07
#       2      2s_1/2      -1.80433022e+01    -1.80433081e+01    +3.29715683e-07
#       3      3s_1/2      -8.01539078e+00    -8.01539255e+00    +2.20004322e-07
#       4      4s_1/2      -4.50702466e+00    -4.50703270e+00    +1.78401724e-06
#       5      5s_1/2      -2.87591795e+00    -2.88376608e+00    +2.72891514e-03
#       6      6s_1/2      -1.78773268e+00    -2.00224317e+00    +1.19990249e-01
#       7      7s_1/2      -4.64467605e-01    -1.47082901e+00    +2.16669881e+00
#       8      8s_1/2      +1.25041928e+00    -1.12597992e+00    +1.90048189e+00
#       :       :
#      81     81s_1/2      +8.44665790e+07    -1.09749682e-02    +1.00000000e+00
#      82     82s_1/2      +1.28197549e+08    -1.07089061e-02    +1.00000000e+00
#      83     83s_1/2      +2.02512410e+08    -1.04524031e-02    +1.00000000e+00
#      84     84s_1/2      +3.44933213e+08    -1.02050067e-02    +1.00000000e+00
#      85     85s_1/2      +6.89780951e+08    -9.96629080e-03    +1.00000000e+00
#      86     86s_1/2      +2.35256495e+09    -9.73585407e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -1.80433081e+01    -1.80433081e+01    +4.75038913e-10
#       2      3p_1/2      -8.01539254e+00    -8.01539255e+00    +3.79917858e-10
#       3      4p_1/2      -4.50702770e+00    -4.50703270e+00    +1.10888762e-06
#       4      5p_1/2      -2.87746667e+00    -2.88376608e+00    +2.18922185e-03
#       5      6p_1/2      -1.81137026e+00    -2.00224317e+00    +1.05374874e-01
#       6      7p_1/2      -5.34552556e-01    -1.47082901e+00    +1.75151432e+00
#       7      8p_1/2      +1.12467633e+00    -1.12597992e+00    +2.00115908e+00
#       8      9p_1/2      +3.13880666e+00    -8.89584969e-01    +1.28341503e+00
#       :       :
#      80     81p_1/2      +7.02605267e+07    -1.09749682e-02    +1.00000000e+00
#      81     82p_1/2      +1.05410914e+08    -1.07089061e-02    +1.00000000e+00
#      82     83p_1/2      +1.63121124e+08    -1.04524031e-02    +1.00000000e+00
#      83     84p_1/2      +2.66953877e+08    -1.02050067e-02    +1.00000000e+00
#      84     85p_1/2      +4.87973862e+08    -9.96629080e-03    +1.00000000e+00
#      85     86p_1/2      +1.16220859e+09    -9.73585407e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -1.80086350e+01    -1.80086350e+01    +2.98087577e-13
#       2      3p_3/2      -8.00511740e+00    -8.00511740e+00    +2.08477548e-12
#       3      4p_3/2      -4.50269348e+00    -4.50269857e+00    +1.12940152e-06
#       4      5p_3/2      -2.87519135e+00    -2.88154739e+00    +2.21065154e-03
#       5      6p_3/2      -1.80931997e+00    -2.00095940e+00    +1.05917929e-01
#       6      7p_3/2      -5.31887756e-01    -1.47002067e+00    +1.76377986e+00
#       7      8p_3/2      +1.12791923e+00    -1.12543844e+00    +1.99780056e+00
#       8      9p_3/2      +3.14256034e+00    -8.89204706e-01    +1.28295549e+00
#       :       :
#      81     82p_3/2      +1.00137229e+08    -1.07084037e-02    +1.00000000e+00
#      82     83p_3/2      +1.53809020e+08    -1.04519186e-02    +1.00000000e+00
#      83     84p_3/2      +2.48277981e+08    -1.02045393e-02    +1.00000000e+00
#      84     85p_3/2      +4.40913257e+08    -9.96583973e-03    +1.00000000e+00
#      85     86p_3/2      +9.65419573e+08    -9.73541855e-03    +1.00000000e+00
#      86     87p_3/2      +3.73448114e+09    -9.51289734e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# (Re-) Define the standard grid with 600 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -4.6238171e+01;   self-cons'cy = 2.1880e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.4856398e+00;   self-cons'cy = 6.7619e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.6891643e+00;   self-cons'cy = 7.4058e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3567498e+00;   self-cons'cy = 6.8578e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.3328108e+01;   self-cons'cy = 7.1208e-02  [2.6052e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.5744875e+00;   self-cons'cy = 2.3055e-01  [2.6052e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.2356831e+00;   self-cons'cy = 2.2333e-01  [3.0683e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.8396153e+00;   self-cons'cy = 6.7099e-02  [6.7099e-02 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1140301e+01;   self-cons'cy = 2.0942e-02  [8.1410e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.7550879e+00;   self-cons'cy = 7.9326e-02  [8.1410e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7015454e+00;   self-cons'cy = 6.7295e-02  [8.5413e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7700036e+00;   self-cons'cy = 9.1479e-03  [1.3889e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1631461e+01;   self-cons'cy = 4.7791e-03  [1.7618e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.9256474e+00;   self-cons'cy = 1.7618e-02  [1.7618e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7875865e+00;   self-cons'cy = 1.1489e-02  [1.4802e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7569084e+00;   self-cons'cy = 1.7398e-03  [2.1340e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1551657e+01;   self-cons'cy = 7.7342e-04  [2.9000e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8971610e+00;   self-cons'cy = 2.9000e-03  [2.9000e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7797115e+00;   self-cons'cy = 1.0407e-03  [1.3637e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7659530e+00;   self-cons'cy = 1.2023e-03  [1.5374e-03 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1555975e+01;   self-cons'cy = 4.1876e-05  [1.5880e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8987166e+00;   self-cons'cy = 1.5880e-04  [1.5880e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7778176e+00;   self-cons'cy = 2.5060e-04  [3.2580e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7629992e+00;   self-cons'cy = 3.9232e-04  [5.0979e-04 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1558797e+01;   self-cons'cy = 2.7373e-05  [1.0292e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8997089e+00;   self-cons'cy = 1.0127e-04  [1.0292e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7790445e+00;   self-cons'cy = 1.6236e-04  [2.1081e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7636845e+00;   self-cons'cy = 9.1050e-05  [1.1983e-04 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557394e+01;   self-cons'cy = 1.3606e-05  [5.0578e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8992133e+00;   self-cons'cy = 5.0578e-05  [5.0578e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7786516e+00;   self-cons'cy = 5.1989e-05  [6.7498e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7635745e+00;   self-cons'cy = 1.4612e-05  [1.9613e-05 for sym-block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557805e+01;   self-cons'cy = 3.9857e-06  [1.4844e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8993587e+00;   self-cons'cy = 1.4844e-05  [1.4844e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7787415e+00;   self-cons'cy = 1.1900e-05  [1.5450e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7635800e+00;   self-cons'cy = 7.2005e-07  [1.1027e-06 for sym-block kappa = -2]
#
# Iteration 10 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557718e+01;   self-cons'cy = 8.4520e-07  [3.1532e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8993278e+00;   self-cons'cy = 3.1532e-06  [3.1532e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7787274e+00;   self-cons'cy = 1.8678e-06  [2.4250e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7635841e+00;   self-cons'cy = 5.4925e-07  [6.8139e-07 for sym-block kappa = -2]
#
# Iteration 11 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557730e+01;   self-cons'cy = 1.1569e-07  [4.3310e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8993321e+00;   self-cons'cy = 4.3310e-07  [4.3310e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7787280e+00;   self-cons'cy = 7.7109e-08  [1.0009e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7635821e+00;   self-cons'cy = 2.6639e-07  [3.4256e-07 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -1.500861610519451e+02    -4.084052464644366e+03    -4.084052464644366e+03
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# DecayYield.computeOutcomes(): The computation of the fluorescence & Auger yields starts now ...
# -----------------------------------------------------------------------------------------------
#
#   Selected DecayYield levels:
#
#   -------------------------------------------
#      Level        J^P           Energy
#                                  [eV]
#   -------------------------------------------
#          1       1/2 +      -4.08405246e+03
#   -------------------------------------------
#
# Perform a cascade computation for all radiative decay channels of the levels from the initial configurations:
# MethodError: no method matching JAC.Cascade.Computation(::String, ::Model, ::JAC.Radial.Grid, ::AsfSettings, ::JAC.Cascade.SCA, ::Array{JAC.Basics.AtomicProcess,1}, ::Array{Configuration,1}, ::Array{Tuple{Int64,Float64},1}, ::Int64, ::Int64, ::Array{Shell,1}, ::Array{Shell,1}, ::Array{JAC.Cascade.Step,1})
# Closest candidates are:
#   JAC.Cascade.Computation(::String, ::Model, ::JAC.Radial.Grid, ::AsfSettings, ::JAC.Cascade.AbstractCascadeApproach, ::Array{JAC.Basics.AtomicProcess,1}, ::Array{Configuration,1}, ::Array{Tuple{Int64,Float64},1}, ::Int64, ::Int64, ::Array{Shell,1}, ::Array{Shell,1}) at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:141
#   JAC.Cascade.Computation(::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any) at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:141
#
# Stacktrace:
#  [1] #computeOutcomes#1(::Bool, ::Function, ::Array{Configuration,1}, ::AsfSettings, ::Multiplet, ::Model, ::JAC.Radial.Grid, ::JAC.DecayYield.Settings) at /home/fritzsch/fri/JAC.jl/src/module-DecayYield.jl:111
#  [2] computeOutcomes(::Array{Configuration,1}, ::AsfSettings, ::Multiplet, ::Model, ::JAC.Radial.Grid, ::JAC.DecayYield.Settings) at /home/fritzsch/fri/JAC.jl/src/module-DecayYield.jl:94
#  [3] #perform#1(::Bool, ::Function, ::JAC.Atomic.Computation) at /home/fritzsch/fri/JAC.jl/src/module-BasicsPerform.jl:75
#  [4] perform(::JAC.Atomic.Computation) at /home/fritzsch/fri/JAC.jl/src/module-BasicsPerform.jl:23
#  [5] top-level scope at In[4]:5

# %% [markdown]
# Obviously, this results in a rather detailed output due to printed data of the underlying cascade computation. In this single-step cascade, all the neon-like configurations with total energies below of the given $1s 2s^2 2p^6$ configuration are generated automatically, together with all energetically allowed fluorine-like configuration due to the (Auger) emission of an electon. Here, we shall not discuss this output in detail but just go over to the final table: It report an fluorescence yield $\omega_r \approx 0.08$ in Babushkin gauge and a corresponding Auger yield of $\omega_a \approx 0.92$. The same yields in Coulomb gauge are (0., 1.), but this occurs since
# by default all radiative transitions are only considered in Babushkin (length) gauge. To modify this settings, the user would have to change the *call* of the cascade computations *inside* of the code.
#
# To see how the coupling of the radiation field and, hence, the fluorescence increases with an increasing  nuclear charge, let us next perform the same computations but for Z=18 and Z=26, respectively.

# %%
wa = Atomic.Computation(wa, name="Yield computations for neon-like Ar", nuclearModel=Nuclear.Model(18.))
perform(wa)
# Out:
# aa: NoProcess   multipoles:             EmMultipole[E1]
# gauges:                 UseGauge[UseCoulomb]
# calcAnisotropy:         false
# printBefore:            false
# selectLines:            false
# selectedLines:          Tuple{Int64,Int64}[]
# photonEnergyShift:      0.0
# mimimumPhotonEnergy:    0.0
# maximumPhotonEnergy:    0.0
#
#
# ... in performSCF ...
# >> include Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 18.0 with mass = 37.62, radius R = 3.37121133160794 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.62704537e+02    -1.62704858e+02    +1.97540666e-06
#       2      2s_1/2      -4.07203231e+01    -4.07203638e+01    +1.00176054e-06
#       3      3s_1/2      -1.80782718e+01    -1.80782839e+01    +6.69151099e-07
#       4      4s_1/2      -1.01607481e+01    -1.01607532e+01    +5.02099675e-07
#       5      5s_1/2      -6.49913616e+00    -6.49914079e+00    +7.11889336e-07
#       6      6s_1/2      -4.50885893e+00    -4.51139835e+00    +5.63207514e-04
#       7      7s_1/2      -3.19721414e+00    -3.31344481e+00    +3.63537325e-02
#       8      8s_1/2      -1.79121644e+00    -2.53622787e+00    +4.15924853e-01
#       :       :
#      81     81s_1/2      +8.43830939e+07    -2.46965924e-02    +1.00000000e+00
#      82     82s_1/2      +1.28114106e+08    -2.40978477e-02    +1.00000000e+00
#      83     83s_1/2      +2.02428988e+08    -2.35206159e-02    +1.00000000e+00
#      84     84s_1/2      +3.44849800e+08    -2.29638786e-02    +1.00000000e+00
#      85     85s_1/2      +6.89697541e+08    -2.24266769e-02    +1.00000000e+00
#      86     86s_1/2      +2.35248154e+09    -2.19081076e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -4.07203637e+01    -4.07203638e+01    +3.27602591e-09
#       2      3p_1/2      -1.80782839e+01    -1.80782839e+01    +2.59301913e-09
#       3      4p_1/2      -1.01607532e+01    -1.01607532e+01    +2.05352171e-09
#       4      5p_1/2      -6.49913927e+00    -6.49914079e+00    +2.32647400e-07
#       5      6p_1/2      -4.50929783e+00    -4.51139835e+00    +4.65820277e-04
#       6      7p_1/2      -3.20882111e+00    -3.31344481e+00    +3.26050278e-02
#       7      8p_1/2      -1.83594613e+00    -2.53622787e+00    +3.81428259e-01
#       8      9p_1/2      -6.83138667e-02    -2.00353566e+00    +2.83283891e+01
#       :       :
#      80     81p_1/2      +7.01770058e+07    -2.46965924e-02    +1.00000000e+00
#      81     82p_1/2      +1.05327451e+08    -2.40978477e-02    +1.00000000e+00
#      82     83p_1/2      +1.63037693e+08    -2.35206159e-02    +1.00000000e+00
#      83     84p_1/2      +2.66870460e+08    -2.29638786e-02    +1.00000000e+00
#      84     85p_1/2      +4.87890451e+08    -2.24266769e-02    +1.00000000e+00
#      85     86p_1/2      +1.16212518e+09    -2.19081076e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -4.05437672e+01    -4.05437672e+01    +3.61021715e-14
#       2      3p_3/2      -1.80259403e+01    -1.80259403e+01    -1.65160542e-13
#       3      4p_3/2      -1.01386787e+01    -1.01386787e+01    +1.24501348e-12
#       4      5p_3/2      -6.48784152e+00    -6.48784308e+00    +2.40622191e-07
#       5      6p_3/2      -4.50271375e+00    -4.50486250e+00    +4.77212781e-04
#       6      7p_3/2      -3.20353138e+00    -3.30933006e+00    +3.30256417e-02
#       7      8p_3/2      -1.82930558e+00    -2.53347193e+00    +3.84936424e-01
#       8      9p_3/2      -6.00867344e-02    -2.00160044e+00    +3.23118525e+01
#       :       :
#      81     82p_3/2      +1.00053758e+08    -2.40952931e-02    +1.00000000e+00
#      82     83p_3/2      +1.53725585e+08    -2.35181525e-02    +1.00000000e+00
#      83     84p_3/2      +2.48194563e+08    -2.29615022e-02    +1.00000000e+00
#      84     85p_3/2      +4.40829846e+08    -2.24243834e-02    +1.00000000e+00
#      85     86p_3/2      +9.65336164e+08    -2.19058931e-02    +1.00000000e+00
#      86     87p_3/2      +3.73439773e+09    -2.14051797e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# (Re-) Define the standard grid with 600 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2369708e+02;   self-cons'cy = 1.3620e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.7866211e+01;   self-cons'cy = 3.9009e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.5948796e+01;   self-cons'cy = 4.3713e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.6486616e+01;   self-cons'cy = 4.2183e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2991228e+02;   self-cons'cy = 2.4507e-02  [1.2638e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9747751e+01;   self-cons'cy = 5.0022e-02  [1.2638e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7624552e+01;   self-cons'cy = 4.9913e-02  [8.3343e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7362228e+01;   self-cons'cy = 2.5868e-02  [4.2092e-02 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2880391e+02;   self-cons'cy = 4.2842e-03  [2.6349e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9371578e+01;   self-cons'cy = 9.6160e-03  [2.6349e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7327478e+01;   self-cons'cy = 8.4995e-03  [1.5734e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7247755e+01;   self-cons'cy = 3.3075e-03  [6.0529e-03 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2896937e+02;   self-cons'cy = 6.4191e-04  [3.8431e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9427066e+01;   self-cons'cy = 1.4301e-03  [3.8431e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7366664e+01;   self-cons'cy = 1.1295e-03  [2.0505e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7259569e+01;   self-cons'cy = 3.4236e-04  [6.1481e-04 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2894753e+02;   self-cons'cy = 8.4699e-05  [5.1193e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9419700e+01;   self-cons'cy = 1.8961e-04  [5.1193e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7361918e+01;   self-cons'cy = 1.3665e-04  [2.4901e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258475e+01;   self-cons'cy = 3.1697e-05  [5.7238e-05 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2895014e+02;   self-cons'cy = 1.0116e-05  [6.1193e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9420581e+01;   self-cons'cy = 2.2689e-05  [6.1193e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362437e+01;   self-cons'cy = 1.4953e-05  [2.7176e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258558e+01;   self-cons'cy = 2.4017e-06  [4.2809e-06 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2894985e+02;   self-cons'cy = 1.0979e-06  [6.6553e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9420486e+01;   self-cons'cy = 2.4681e-06  [6.6553e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362386e+01;   self-cons'cy = 1.4671e-06  [2.6639e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258554e+01;   self-cons'cy = 1.0587e-07  [1.8372e-07 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2894988e+02;   self-cons'cy = 1.0676e-07  [1.1413e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9420495e+01;   self-cons'cy = 2.4062e-07  [1.1413e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362391e+01;   self-cons'cy = 1.2332e-07  [6.0717e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258554e+01;   self-cons'cy = 8.7173e-09  [3.6208e-07 for sym-block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2894988e+02;   self-cons'cy = 8.8689e-09  [5.5541e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9420494e+01;   self-cons'cy = 2.0043e-08  [5.5541e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362390e+01;   self-cons'cy = 7.5706e-09  [4.0017e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258554e+01;   self-cons'cy = 3.3229e-09  [3.7550e-07 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -3.830160470462017e+02    -1.042239750802867e+04    -1.042239750802867e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# DecayYield.computeOutcomes(): The computation of the fluorescence & Auger yields starts now ...
# -----------------------------------------------------------------------------------------------
#
#   Selected DecayYield levels:
#
#   -------------------------------------------
#      Level        J^P           Energy
#                                  [eV]
#   -------------------------------------------
#          1       1/2 +      -1.04223975e+04
#   -------------------------------------------
#
# Perform a cascade computation for all radiative decay channels of the levels from the initial configurations:
# MethodError: no method matching JAC.Cascade.Computation(::String, ::Model, ::JAC.Radial.Grid, ::AsfSettings, ::JAC.Cascade.SCA, ::Array{JAC.Basics.AtomicProcess,1}, ::Array{Configuration,1}, ::Array{Tuple{Int64,Float64},1}, ::Int64, ::Int64, ::Array{Shell,1}, ::Array{Shell,1}, ::Array{JAC.Cascade.Step,1})
# Closest candidates are:
#   JAC.Cascade.Computation(::String, ::Model, ::JAC.Radial.Grid, ::AsfSettings, ::JAC.Cascade.AbstractCascadeApproach, ::Array{JAC.Basics.AtomicProcess,1}, ::Array{Configuration,1}, ::Array{Tuple{Int64,Float64},1}, ::Int64, ::Int64, ::Array{Shell,1}, ::Array{Shell,1}) at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:141
#   JAC.Cascade.Computation(::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any) at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:141
#
# Stacktrace:
#  [1] #computeOutcomes#1(::Bool, ::Function, ::Array{Configuration,1}, ::AsfSettings, ::Multiplet, ::Model, ::JAC.Radial.Grid, ::JAC.DecayYield.Settings) at /home/fritzsch/fri/JAC.jl/src/module-DecayYield.jl:111
#  [2] computeOutcomes(::Array{Configuration,1}, ::AsfSettings, ::Multiplet, ::Model, ::JAC.Radial.Grid, ::JAC.DecayYield.Settings) at /home/fritzsch/fri/JAC.jl/src/module-DecayYield.jl:94
#  [3] #perform#1(::Bool, ::Function, ::JAC.Atomic.Computation) at /home/fritzsch/fri/JAC.jl/src/module-BasicsPerform.jl:75
#  [4] perform(::JAC.Atomic.Computation) at /home/fritzsch/fri/JAC.jl/src/module-BasicsPerform.jl:23
#  [5] top-level scope at In[5]:2

# %%
wa = Atomic.Computation(wa, name="Yield computations for neon-like Fe", nuclearModel=Nuclear.Model(26.))
perform(wa)
# Out:
# aa: NoProcess   multipoles:             EmMultipole[E1]
# gauges:                 UseGauge[UseCoulomb]
# calcAnisotropy:         false
# printBefore:            false
# selectLines:            false
# selectedLines:          Tuple{Int64,Int64}[]
# photonEnergyShift:      0.0
# mimimumPhotonEnergy:    0.0
# maximumPhotonEnergy:    0.0
#
#
# ... in performSCF ...
# >> include Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 26.0 with mass = 55.38, radius R = 3.756573410087755 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -3.41095880e+02    -3.41097837e+02    +5.73779765e-06
#       2      2s_1/2      -8.54687058e+01    -8.54689584e+01    +2.95488252e-06
#       3      3s_1/2      -3.78993728e+01    -3.78994478e+01    +1.97799571e-06
#       4      4s_1/2      -2.12819069e+01    -2.12819385e+01    +1.48493220e-06
#       5      5s_1/2      -1.36039552e+01    -1.36039714e+01    +1.18822726e-06
#       6      6s_1/2      -9.43886369e+00    -9.43887322e+00    +1.00917109e-06
#       7      7s_1/2      -6.92969312e+00    -6.93005925e+00    +5.28347779e-05
#       8      8s_1/2      -5.26642595e+00    -5.30306679e+00    +6.95743883e-03
#       :       :
#      81     81s_1/2      +8.42853319e+07    -5.15394375e-02    +1.00000000e+00
#      82     82s_1/2      +1.28016370e+08    -5.02897729e-02    +1.00000000e+00
#      83     83s_1/2      +2.02331265e+08    -4.90850138e-02    +1.00000000e+00
#      84     84s_1/2      +3.44752082e+08    -4.79230342e-02    +1.00000000e+00
#      85     85s_1/2      +6.89599825e+08    -4.68018324e-02    +1.00000000e+00
#      86     86s_1/2      +2.35238382e+09    -4.57195223e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -8.54689566e+01    -8.54689584e+01    +2.03865395e-08
#       2      3p_1/2      -3.78994472e+01    -3.78994478e+01    +1.61650470e-08
#       3      4p_1/2      -2.12819382e+01    -2.12819385e+01    +1.27954428e-08
#       4      5p_1/2      -1.36039712e+01    -1.36039714e+01    +1.04818164e-08
#       5      6p_1/2      -9.43887299e+00    -9.43887322e+00    +2.36883974e-08
#       6      7p_1/2      -6.92975579e+00    -6.93005925e+00    +4.37902848e-05
#       7      8p_1/2      -5.27007002e+00    -5.30306679e+00    +6.26116254e-03
#       8      9p_1/2      -3.79947046e+00    -4.18833237e+00    +1.02346342e-01
#       :       :
#      80     81p_1/2      +7.00792203e+07    -5.15394375e-02    +1.00000000e+00
#      81     82p_1/2      +1.05229702e+08    -5.02897729e-02    +1.00000000e+00
#      82     83p_1/2      +1.62939963e+08    -4.90850138e-02    +1.00000000e+00
#      83     84p_1/2      +2.66772740e+08    -4.79230342e-02    +1.00000000e+00
#      84     85p_1/2      +4.87792734e+08    -4.68018324e-02    +1.00000000e+00
#      85     86p_1/2      +1.16202747e+09    -4.57195223e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -8.46909743e+01    -8.46909743e+01    +6.47694747e-14
#       2      3p_3/2      -3.76687634e+01    -3.76687634e+01    +5.28161660e-14
#       3      4p_3/2      -2.11846929e+01    -2.11846929e+01    +1.33155324e-13
#       4      5p_3/2      -1.35542226e+01    -1.35542226e+01    -1.44947499e-13
#       5      6p_3/2      -9.41010337e+00    -9.41010352e+00    +1.60874215e-08
#       6      7p_3/2      -6.91163184e+00    -6.91195226e+00    +4.63601418e-05
#       7      8p_3/2      -5.25692477e+00    -5.29094223e+00    +6.47098059e-03
#       8      9p_3/2      -3.78493557e+00    -4.17982022e+00    +1.04330614e-01
#       :       :
#      81     82p_3/2      +9.99560042e+07    -5.02785564e-02    +1.00000000e+00
#      82     83p_3/2      +1.53627853e+08    -4.90741979e-02    +1.00000000e+00
#      83     84p_3/2      +2.48096841e+08    -4.79126000e-02    +1.00000000e+00
#      84     85p_3/2      +4.40732128e+08    -4.67917622e-02    +1.00000000e+00
#      85     86p_3/2      +9.65238448e+08    -4.57097995e-02    +1.00000000e+00
#      86     87p_3/2      +3.73430001e+09    -4.46649346e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# (Re-) Define the standard grid with 600 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8438062e+02;   self-cons'cy = 9.0675e-02  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.1572305e+01;   self-cons'cy = 2.4734e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.8295892e+01;   self-cons'cy = 2.7790e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.8394672e+01;   self-cons'cy = 2.7273e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.9025066e+02;   self-cons'cy = 1.0215e-02  [4.3555e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3406595e+01;   self-cons'cy = 1.7473e-02  [4.3555e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -5.0035145e+01;   self-cons'cy = 1.7688e-02  [1.1379e+00 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9401249e+01;   self-cons'cy = 1.0293e-02  [4.1361e-01 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8958750e+02;   self-cons'cy = 1.1437e-03  [3.5994e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3187637e+01;   self-cons'cy = 2.0541e-03  [3.5994e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9849536e+01;   self-cons'cy = 1.8582e-03  [7.2309e+00 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9315950e+01;   self-cons'cy = 8.6408e-04  [5.7754e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8965188e+02;   self-cons'cy = 1.1114e-04  [3.6268e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3208873e+01;   self-cons'cy = 1.9960e-04  [3.6268e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9866036e+01;   self-cons'cy = 1.6547e-04  [1.1499e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322538e+01;   self-cons'cy = 6.6790e-05  [4.2210e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964619e+02;   self-cons'cy = 9.8261e-06  [3.2064e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3206991e+01;   self-cons'cy = 1.7688e-05  [3.2064e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9864657e+01;   self-cons'cy = 1.3821e-05  [1.0733e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322040e+01;   self-cons'cy = 5.0425e-06  [3.1969e-04 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964666e+02;   self-cons'cy = 8.1786e-07  [2.6748e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3207148e+01;   self-cons'cy = 1.4740e-06  [2.6748e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9864767e+01;   self-cons'cy = 1.1029e-06  [8.4775e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322077e+01;   self-cons'cy = 3.7233e-07  [2.3576e-05 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964662e+02;   self-cons'cy = 6.5227e-08  [2.1360e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3207135e+01;   self-cons'cy = 1.1767e-07  [2.1360e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9864759e+01;   self-cons'cy = 8.5154e-08  [6.5485e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322074e+01;   self-cons'cy = 2.6977e-08  [1.7069e-06 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964663e+02;   self-cons'cy = 5.0370e-09  [1.6492e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3207136e+01;   self-cons'cy = 9.0934e-09  [1.6492e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9864759e+01;   self-cons'cy = 6.4060e-09  [4.9234e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322075e+01;   self-cons'cy = 1.9218e-09  [1.2149e-07 for sym-block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964663e+02;   self-cons'cy = 3.7907e-10  [1.2267e-08 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3207136e+01;   self-cons'cy = 6.8492e-10  [1.2267e-08 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9864759e+01;   self-cons'cy = 4.7166e-10  [3.6005e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322075e+01;   self-cons'cy = 1.3468e-10  [7.4391e-09 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -8.651826710929047e+02    -2.354281964092372e+04    -2.354281964092372e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# DecayYield.computeOutcomes(): The computation of the fluorescence & Auger yields starts now ...
# -----------------------------------------------------------------------------------------------
#
#   Selected DecayYield levels:
#
#   -------------------------------------------
#      Level        J^P           Energy
#                                  [eV]
#   -------------------------------------------
#          1       1/2 +      -2.35428196e+04
#   -------------------------------------------
#
# Perform a cascade computation for all radiative decay channels of the levels from the initial configurations:
# MethodError: no method matching JAC.Cascade.Computation(::String, ::Model, ::JAC.Radial.Grid, ::AsfSettings, ::JAC.Cascade.SCA, ::Array{JAC.Basics.AtomicProcess,1}, ::Array{Configuration,1}, ::Array{Tuple{Int64,Float64},1}, ::Int64, ::Int64, ::Array{Shell,1}, ::Array{Shell,1}, ::Array{JAC.Cascade.Step,1})
# Closest candidates are:
#   JAC.Cascade.Computation(::String, ::Model, ::JAC.Radial.Grid, ::AsfSettings, ::JAC.Cascade.AbstractCascadeApproach, ::Array{JAC.Basics.AtomicProcess,1}, ::Array{Configuration,1}, ::Array{Tuple{Int64,Float64},1}, ::Int64, ::Int64, ::Array{Shell,1}, ::Array{Shell,1}) at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:141
#   JAC.Cascade.Computation(::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any, ::Any) at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:141
#
# Stacktrace:
#  [1] #computeOutcomes#1(::Bool, ::Function, ::Array{Configuration,1}, ::AsfSettings, ::Multiplet, ::Model, ::JAC.Radial.Grid, ::JAC.DecayYield.Settings) at /home/fritzsch/fri/JAC.jl/src/module-DecayYield.jl:111
#  [2] computeOutcomes(::Array{Configuration,1}, ::AsfSettings, ::Multiplet, ::Model, ::JAC.Radial.Grid, ::JAC.DecayYield.Settings) at /home/fritzsch/fri/JAC.jl/src/module-DecayYield.jl:94
#  [3] #perform#1(::Bool, ::Function, ::JAC.Atomic.Computation) at /home/fritzsch/fri/JAC.jl/src/module-BasicsPerform.jl:75
#  [4] perform(::JAC.Atomic.Computation) at /home/fritzsch/fri/JAC.jl/src/module-BasicsPerform.jl:23
#  [5] top-level scope at In[6]:2

# %% [markdown]
# From the output of these three computations, we see that the fluorescence yield $\omega_r$ increase from 8 % (Z=12) to 28 % (Z=18) and up to 40 % (Z=26).

# %% [markdown]
# We could consider also the yields for the $2s$ hole state of argon which is known to decay by fast **Coster-Kronig transitions**. Because of the (very) low energies of the emitted Coster-Kronig electrons, these computations require however further care in order to obtain reliable estimates. Since all these yield computations are always based on (rather elaborate) *cascade computations*, further improvements of the yield-computations might be possible but will require advice and support by the community.
