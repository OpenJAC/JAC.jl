# %% [markdown]
# # Compute the low-lying levels of $C^{2+} 1s^2 (2s^2 + 2s2p + 2p^2)$: $\;$ SCF and configuration interaction calculations

# %%
using JAC

# %% [markdown]
# The low-lying levels (level structure) of beryllium-like ions, and especially C$^{2+}$, has been calculated in many case studies in the literature. While the level structure of these ions is still quite simple, they exhibit a considerable admixture of the $2s^2 2p^2$ configuration already for the $1s^2 2s^2\;\: ^1S_0$ ground level.
#
# We here show how the low-lying levels of C$^{2+}$ can be readily calculated in JAC by either following the default settings or by specifying further details for both, the SCF and configuration-interaction (CI) computations. As usual, we first need to specify a radial grid as well as the nuclear model for the subsequent computations:

# %%
grid     = Radial.Grid(true)
nucModel = Nuclear.Model(6., "Fermi")
# Out:
# Fermi nuclear model for Z = 6.0 with mass = 12.18, radius R = 2.4934845703596404 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.

# %% [markdown]
# For a *quick* computation of the ground level of C$^{2+}$ ions, we can simply use the **standard settings** as given by `AsfSettings()`:

# %%
basis     = Basics.performSCF([Configuration("1s^2 2s^2")], nucModel, grid, AsfSettings())
multiplet = Basics.performCI(basis, nucModel, grid, AsfSettings());
# Out:
# ... in performSCF ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 6.0 with mass = 12.18, radius R = 2.4934845703596404 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.80086331e+01    -1.80086350e+01    +1.02975186e-07
#       2      2s_1/2      -4.50269994e+00    -4.50269857e+00    -3.04296207e-07
#       3      3s_1/2      -2.00097395e+00    -2.00095940e+00    -7.26977235e-06
#       4      4s_1/2      -1.12570260e+00    -1.12543844e+00    -2.34662195e-04
#       5      5s_1/2      -7.22414340e-01    -7.20234830e-01    -3.01698058e-03
#       6      6s_1/2      -5.43264102e-01    -5.00139888e-01    -7.93798335e-02
#       7      7s_1/2      -4.77865934e-01    -3.67436826e-01    -2.31088052e-01
#       8      8s_1/2      -3.50581452e-01    -2.81311119e-01    -1.97586987e-01
#       9      9s_1/2      -2.55481885e-01    -2.22265641e-01    -1.30014087e-01
#      10     10s_1/2      -1.85069169e-01    -1.80031939e-01    -2.72180936e-02
#      11     11s_1/2      -1.33033147e-01    -1.48784504e-01    +1.18401741e-01
#      12     12s_1/2      -9.50813929e-02    -1.25018733e-01    +3.14860131e-01
#      13     13s_1/2      -6.77310055e-02    -1.06523685e-01    +5.72746251e-01
#      14     14s_1/2      -4.82121344e-02    -9.18486436e-02    +9.05093906e-01
#      15     15s_1/2      -3.44174218e-02    -8.00097188e-02    +1.32468659e+00
#      16     16s_1/2      -2.47884553e-02    -7.03205343e-02    +1.83682599e+00
#      17     17s_1/2      -1.81747522e-02    -6.22904546e-02    +2.42730695e+00
#      18     18s_1/2      -1.37086758e-02    -5.55612291e-02    +3.05299751e+00
#      19     19s_1/2      -1.07321042e-02    -4.98663309e-02    +3.64646356e+00
#      20     20s_1/2      -8.76208016e-03    -4.50041540e-02    +4.13624084e+00
#      21     21s_1/2      -7.45863673e-03    -4.08199215e-02    +4.47283948e+00
#      22     22s_1/2      -6.46198621e-03    -3.71932146e-02    +4.75569390e+00
#      23     23s_1/2      +1.11731644e-01    -3.40292102e-02    +1.30456197e+00
#      24     24s_1/2      +2.95042157e+00    -3.12524195e-02    +1.01059253e+00
#      25     25s_1/2      +1.10978057e+01    -2.88021434e-02    +1.00259530e+00
#      26     26s_1/2      +3.10005139e+01    -2.66291266e-02    +1.00085899e+00
#      27     27s_1/2      +7.58521980e+01    -2.46930634e-02    +1.00032554e+00
#      28     28s_1/2      +1.72338486e+02    -2.29607143e-02    +1.00013323e+00
#      29     29s_1/2      +3.73849231e+02    -2.14044706e-02    +1.00005725e+00
#      30     30s_1/2      +7.84851451e+02    -2.00012468e-02    +1.00002548e+00
#      31     31s_1/2      +1.60203610e+03    -1.87316200e-02    +1.00001169e+00
#      32     32s_1/2      +3.17279393e+03    -1.75791539e-02    +1.00000554e+00
#      33     33s_1/2      +6.05417753e+03    -1.65298645e-02    +1.00000273e+00
#      34     34s_1/2      +1.10392962e+04    -1.55717933e-02    +1.00000141e+00
#      35     35s_1/2      +1.91520583e+04    -1.46946655e-02    +1.00000077e+00
#      36     36s_1/2      +3.16852441e+04    -1.38896135e-02    +1.00000044e+00
#      37     37s_1/2      +5.03504967e+04    -1.31489512e-02    +1.00000026e+00
#      38     38s_1/2      +7.75326459e+04    -1.24659907e-02    +1.00000016e+00
#       :       :
#      57     57s_1/2      +8.45595432e+07    -5.54035017e-03    +1.00000000e+00
#      58     58s_1/2      +1.28290116e+08    -5.35094755e-03    +1.00000000e+00
#      59     59s_1/2      +2.02604410e+08    -5.17109386e-03    +1.00000000e+00
#      60     60s_1/2      +3.45024075e+08    -5.00015784e-03    +1.00000000e+00
#      61     61s_1/2      +6.89868760e+08    -4.83755953e-03    +1.00000000e+00
#      62     62s_1/2      +2.35263571e+09    -4.68276538e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# (Re-) Define the standard grid with 390 grid points.
# >>  for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.0316230e+01;   self-cons'cy = 2.7158e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.2238992e+00;   self-cons'cy = 5.7256e-01  [1.0000e+02 for sym-block kappa = -1]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1298726e+01;   self-cons'cy = 4.5454e-02  [1.7353e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4578100e+00;   self-cons'cy = 8.7225e-02  [1.7353e-01 for sym-block kappa = -1]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1135296e+01;   self-cons'cy = 7.2849e-03  [3.6560e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4168211e+00;   self-cons'cy = 1.4259e-02  [3.6560e-02 for sym-block kappa = -1]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1162290e+01;   self-cons'cy = 1.2106e-03  [5.6712e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4235023e+00;   self-cons'cy = 2.3523e-03  [5.6712e-03 for sym-block kappa = -1]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1157825e+01;   self-cons'cy = 2.0003e-04  [9.4619e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4223956e+00;   self-cons'cy = 3.8887e-04  [9.4619e-04 for sym-block kappa = -1]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1158564e+01;   self-cons'cy = 3.3082e-05  [1.5618e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4225785e+00;   self-cons'cy = 6.4291e-05  [1.5618e-04 for sym-block kappa = -1]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1158442e+01;   self-cons'cy = 5.4703e-06  [2.5831e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4225483e+00;   self-cons'cy = 1.0631e-05  [2.5831e-05 for sym-block kappa = -1]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1158462e+01;   self-cons'cy = 9.0458e-07  [4.2711e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4225533e+00;   self-cons'cy = 1.7578e-06  [4.2711e-06 for sym-block kappa = -1]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1158458e+01;   self-cons'cy = 1.4958e-07  [7.0623e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4225525e+00;   self-cons'cy = 2.9067e-07  [7.0623e-07 for sym-block kappa = -1]
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^+ ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.387435 seconds (431.63 k allocations: 21.145 MiB, 1.85% gc time)
#    ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    0 +     -3.641932029351340e+01    -9.910201830928128e+02    -9.910201830928128e+02
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]

# %% [markdown]
# ... and, similarly, also for the 10 lowest levels of C$^{2+}$ ions as they arise from the
# $C^{2+} 1s^2 (2s^2 + 2s2p + 2p^2)$ configurations:

# %%
basis     = Basics.performSCF([Configuration("1s^2 2s^2"), Configuration("1s^2 2s 2p"), Configuration("1s^2 2p^2")], 
                              nucModel, grid, AsfSettings())
multiplet = Basics.performCI(basis, nucModel, grid, AsfSettings());
# Out:
# ... in performSCF ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^0 2p_3/2^1
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^1 2p_3/2^0
# >> include Configuration: 1s_1/2^2 2p_1/2^0 2p_3/2^2
# >> include Configuration: 1s_1/2^2 2p_1/2^1 2p_3/2^1
# >> include Configuration: 1s_1/2^2 2p_1/2^2 2p_3/2^0
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 6.0 with mass = 12.18, radius R = 2.4934845703596404 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.80086331e+01    -1.80086350e+01    +1.02975186e-07
#       2      2s_1/2      -4.50269994e+00    -4.50269857e+00    -3.04296207e-07
#       3      3s_1/2      -2.00097395e+00    -2.00095940e+00    -7.26977235e-06
#       4      4s_1/2      -1.12570260e+00    -1.12543844e+00    -2.34662195e-04
#       5      5s_1/2      -7.22414340e-01    -7.20234830e-01    -3.01698058e-03
#       6      6s_1/2      -5.43264102e-01    -5.00139888e-01    -7.93798335e-02
#       7      7s_1/2      -4.77865934e-01    -3.67436826e-01    -2.31088052e-01
#       8      8s_1/2      -3.50581452e-01    -2.81311119e-01    -1.97586987e-01
#       9      9s_1/2      -2.55481885e-01    -2.22265641e-01    -1.30014087e-01
#      10     10s_1/2      -1.85069169e-01    -1.80031939e-01    -2.72180936e-02
#      11     11s_1/2      -1.33033147e-01    -1.48784504e-01    +1.18401741e-01
#      12     12s_1/2      -9.50813929e-02    -1.25018733e-01    +3.14860131e-01
#      13     13s_1/2      -6.77310055e-02    -1.06523685e-01    +5.72746251e-01
#      14     14s_1/2      -4.82121344e-02    -9.18486436e-02    +9.05093906e-01
#      15     15s_1/2      -3.44174218e-02    -8.00097188e-02    +1.32468659e+00
#      16     16s_1/2      -2.47884553e-02    -7.03205343e-02    +1.83682599e+00
#      17     17s_1/2      -1.81747522e-02    -6.22904546e-02    +2.42730695e+00
#      18     18s_1/2      -1.37086758e-02    -5.55612291e-02    +3.05299751e+00
#      19     19s_1/2      -1.07321042e-02    -4.98663309e-02    +3.64646356e+00
#      20     20s_1/2      -8.76208016e-03    -4.50041540e-02    +4.13624084e+00
#      21     21s_1/2      -7.45863673e-03    -4.08199215e-02    +4.47283948e+00
#      22     22s_1/2      -6.46198621e-03    -3.71932146e-02    +4.75569390e+00
#      23     23s_1/2      +1.11731644e-01    -3.40292102e-02    +1.30456197e+00
#      24     24s_1/2      +2.95042157e+00    -3.12524195e-02    +1.01059253e+00
-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.0954888e+00;   self-cons'cy = 9.9837e-03  [2.2525e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1125824e+01;   self-cons'cy = 1.3788e-03  [6.3017e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4073480e+00;   self-cons'cy = 2.6048e-03  [6.3017e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.0985913e+00;   self-cons'cy = 2.1295e-03  [3.7455e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.0978024e+00;   self-cons'cy = 1.0548e-03  [2.2228e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1121783e+01;   self-cons'cy = 1.8166e-04  [7.6607e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4064549e+00;   self-cons'cy = 3.1739e-04  [7.6607e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.0980770e+00;   self-cons'cy = 2.3413e-04  [4.0387e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.0975646e+00;   self-cons'cy = 1.0834e-04  [2.3371e-04 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1122288e+01;   self-cons'cy = 2.2733e-05  [8.6755e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4065575e+00;   self-cons'cy = 3.6480e-05  [8.6755e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.0981294e+00;   self-cons'cy = 2.3863e-05  [4.1489e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.0975872e+00;   self-cons'cy = 1.0299e-05  [2.2512e-05 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1122228e+01;   self-cons'cy = 2.7232e-06  [9.3224e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4065463e+00;   self-cons'cy = 3.9804e-06  [9.3224e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.0981245e+00;   self-cons'cy = 2.2245e-06  [3.8989e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.0975853e+00;   self-cons'cy = 8.7245e-07  [1.9579e-06 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1122235e+01;   self-cons'cy = 3.1302e-07  [9.4193e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4065475e+00;   self-cons'cy = 4.1031e-07  [9.4193e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.0981249e+00;   self-cons'cy = 1.7993e-07  [3.2053e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.0975854e+00;   self-cons'cy = 5.8188e-08  [1.3894e-07 for sym-block kappa = -2]
# Compute CI matrix of dimension 2 x 2 for the symmetry 1^- ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.033445 seconds (55.86 k allocations: 1.157 MiB)
#    ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 1^+ ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.016898 seconds (25.76 k allocations: 472.531 KiB)
#    ... done.
# Compute CI matrix of dimension 3 x 3 for the symmetry 0^+ ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.044852 seconds (51.44 k allocations: 999.094 KiB)
#    ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 2^- ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.011741 seconds (25.76 k allocations: 472.531 KiB)
#    ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^- ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.011263 seconds (25.58 k allocations: 469.672 KiB)
#    ... done.
# Compute CI matrix of dimension 2 x 2 for the symmetry 2^+ ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.041784 seconds (43.03 k allocations: 797.297 KiB)
#    ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    0 +     -3.648596917529763e+01    -9.928337915428449e+02    -9.928337915428449e+02
#      2    0 -     -3.624303152842097e+01    -9.862231214548937e+02    -9.862231214548937e+02
#      3    1 -     -3.624287324425467e+01    -9.862188143233435e+02    -9.862188143233435e+02
#      4    2 -     -3.624255613818946e+01    -9.862101854277939e+02    -9.862101854277939e+02
#      5    1 -     -3.597168313522570e+01    -9.788393555817504e+02    -9.788393555817504e+02
#      6    0 +     -3.585249814728530e+01    -9.755961668671150e+02    -9.755961668671150e+02
#      7    1 +     -3.585234667334547e+01    -9.755920450512665e+02    -9.755920450512665e+02
#      8    2 +     -3.585204533465503e+01    -9.755838452078381e+02    -9.755838452078381e+02
#      9    2 +     -3.577601912668715e+01    -9.735150667151873e+02    -9.735150667151873e+02
#     10    0 +     -3.559491135391519e+01    -9.685868731990670e+02    -9.685868731990670e+02
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    0 -     2.429376468766620e-01    6.610670087951296e+00    6.610670087951296e+00
#      3    1 -     1.582841663037016e-04    4.307131550143900e-03    4.307131550143900e-03
#      4    2 -     3.171060652036317e-04    8.628895549539313e-03    8.628895549539313e-03
#      5    1 -     2.708730029637607e-01    7.370829846043496e+00    7.370829846043496e+00
#      6    0 +     1.191849879404074e-01    3.243188714635472e+00    3.243188714635472e+00
#      7    1 +     1.514739398231768e-04    4.121815848498715e-03    4.121815848498715e-03
#      8    2 +     3.013386904413551e-04    8.199843428360998e-03    8.199843428360998e-03
#      9    2 +     7.602620796787818e-02    2.068778492650733e+00    2.068778492650733e+00
#     10    0 +     1.811077727719663e-01    4.928193516120421e+00    4.928193516120421e+00
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    0 -     2.429376468766620e-01    6.610670087951296e+00    6.610670087951296e+00
#      3    1 -     2.430959310429657e-01    6.614977219501440e+00    6.614977219501440e+00
#      4    2 -     2.434130371081693e-01    6.623606115050979e+00    6.623606115050979e+00
#      5    1 -     5.142860400719300e-01    1.399443596109448e+01    1.399443596109448e+01
#      6    0 +     6.334710280123375e-01    1.723762467572995e+01    1.723762467572995e+01
#      7    1 +     6.336225019521606e-01    1.724174649157845e+01    1.724174649157845e+01
#      8    2 +     6.339238406426020e-01    1.724994633500681e+01    1.724994633500681e+01
#      9    2 +     7.099500486104802e-01    1.931872482765754e+01    1.931872482765754e+01
#     10    0 +     8.910578213824465e-01    2.424691834377796e+01    2.424691834377796e+01

# %% [markdown]
# From the comparison of the two ground-state energies, we see that the admixture of the $2p^2$ configuration has lowered the (total) ground state energy by about 1.8 eV, a rather remarkable admixture, as the $\: ^3P_0$ is just 6.6 eV above of the ground level.
#
# Further control about these electronic computations can be obtained by modifying the (so-called) **settings**. In general, all computations of the electronic structure, properties and processes as well as all more advanced computations can be controlled quite in details by various settings that are associated to the different computational requests. The SCF and configuration interaction calculations are controlled by `AsfSettings` that specify all details for the generation of the ASF. We can first have a look at the internal representation of these settings:

# %%
? AsfSettings
# Out:
# search: AsfSettings
#   struct  ManyElectron.AsfSettings ... a struct for defining the settings for
#   the atomic state functions, i.e. the self-consistent-field (SCF) and CI
#   computations
#
#   + generateScf          ::Bool               ... True, if a SCF need to be generated, and false otherwise (frozen orbitals).
#   + breitScf             ::Bool               ... True, if Breit interaction is to be included into the SCF computations.
#   + methodScf            ::AbstractScField    ... Specify the SCF method, for instance, Basics.ALField(), etc.
#   + startScf             ::String             ... Specify how the start orbitals are obtained ["hydrogenic", "fromOrbitals"].
#   + startOrbitals        ::Dict{Subshell, Orbital}  ... List of start orbitals; hydrogenic orbitals are used
#                                                         if not found in this list.
#   + levelsScf            ::Array{Int64,1}     ... Levels on which the optimization need to be carried out.
#   + maxIterationsScf     ::Int64              ... maximum number of SCF iterations
#   + accuracyScf          ::Float64            ... convergence criterion for the SCF field.
#   + shellSequenceScf     ::Array{Subshell,1}  ... Sequence of subshells to be optimized.
#   + frozenSubshells      ::Array{Subshell,1}  ... Sequence of subshells to be kept frozen.
#
#   + coulombCI            ::Bool               ... logical flag to include Coulomb interactions.
#   + breitCI              ::Bool               ... logical flag to include Breit interactions.
#   + qedModel             ::AbstractQedModel   ... model for estimating QED corrections {NoneQed(), QedPetersburg(), QedSydney()}.
#   + methodCI             ::String             ... method for diagonalizing the matrix.
#   + jjLS                 ::LSjjSettings       ... settings to control a jj-LS transformation of atomic level, if requested.
#
#   + selectLevelsCI       ::Bool                          ... true, if specific level (number)s have been selected.
#   + selectedLevelsCI     ::Array{Int64,1}                ... Level number that have been selected.
#   + selectSymmetriesCI   ::Bool                          ... true, if specific level symmetries have been selected.
#   + selectedSymmetriesCI ::Array{LevelSymmetry,1}        ... Level symmetries that have been selected.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   ManyElectron.AsfSettings() ... constructor for setting the default values.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   ManyElectron.AsfSettings(settings::AsfSettings;
#
#           generateScf=..,       breitScf=..,            methodScf=..,          startScf=..,               startOrbitals=..,
#           levelsScf=..,         maxIterationsScf=..,    accuracyScf=..,        shellSequenceScf=..,       frozenSubshells=..,
#           coulombCI=..,         breitCI=..,             qedModel=..,           methodCI=..,               jjLS=..,
#           selectLevelsCI=..,    selectedLevelsCI=..,    selectSymmetriesCI=.., selectedSymmetriesCI=..,   printout::Bool=false)
#   ... constructor for re-defining a settings::AsfSettings.

# %% [markdown]
# ... as well as how the standard settings are presently defined:

# %%
defaultAsfSettings = AsfSettings()
# Out:
# generateScf:          false
# breitScf:             false
# methodScf:            JAC.Basics.DFSField()
# startScf:             hydrogenic
# startOrbitals:        Dict{Subshell,Orbital}()
# levelsScf:            [1]
# maxIterationsScf:     24
# accuracyScf:          1.0e-6
# shellSequenceScf:     Subshell[]
# frozenSubshells:      Subshell[]
# coulombCI:            true
# breitCI:              false
# qedModel :            NoneQed()
# methodCI:             eigen
# jjLS :                false
# selectLevelsCI:       false
# selectedLevelsCI:     Int64[]
# selectSymmetriesCI:   false
# selectedSymmetriesCI: LevelSymmetry[]

# %% [markdown]
# From this list, we easily see that the self-consistent field is by default based on a *(mean) Dirac-Fock-Slater* potential, a choice which we could overwrite by `meanCH` or any pre-defined potential. At present, however, no full treatment of the exchange interaction has yet been implemented in this first release of the program. The standard settings also show that the SCF is usually based on just the lowest level (cf. `levelScf`) as well as on the accuracy `1.0e-6` to terminate the SCF computations. Moreover, the individual orbitals are improved due to the standard subshell order (cf. `shellSequenceScf`).
#
# For the CI parameters, the treatment of the Breit and QED interaction is of particular interest. At present, both are set to `false`. QED estimates can either be neglected (`NoneQed()`) or estimated by using an effective Hamiltonian approach due to Shabaev and coworkers  (`QedPetersburg()`) or effective potential approach (`QedSydney()`; Flambaum et al.) However, further tests need to be done to better understand the reliability of these QED estimates to the level structure and state represetation of the ASF.
#
# As seen from the settings above, moreover, there are special features in order to *select* individual levels for the CI computations, either in terms of their (relative) level No within the given multiplet or in terms of their *level symmetry*, i.e. their total angular momentum and parity, respectively. A boolean value `selectLevelsCI` or `selectSymmetriesCI` here indicates whether (and which) of these selections are made. The selection of individual symmetries, in particular, may considerably reduced the computational effort as the Hamiltonian matrix will then be calculated only for the selected symmetries.
#
# In principle, these standard settings can be easily *re-defined* within the code by simply modifying the contructor `AsfSetings()` with no additional arguments. Alternatively, we can easily *overwrite* those parameters in some given (instance of) `AsfSetting` which we just wish to modify. This is achieved by

# %%
asfSettings = AsfSettings(defaultAsfSettings; generateScf=true, jjLS=LSjjSettings(true), 
                          selectedSymmetriesCI=[LevelSymmetry(0,"+"), LevelSymmetry(1,"-")] )
# Out:
# generateScf:          true
# breitScf:             false
# methodScf:            JAC.Basics.DFSField()
# startScf:             hydrogenic
# startOrbitals:        Dict{Subshell,Orbital}()
# levelsScf:            [1]
# maxIterationsScf:     24
# accuracyScf:          1.0e-6
# shellSequenceScf:     Subshell[]
# frozenSubshells:      Subshell[]
# coulombCI:            true
# breitCI:              false
# qedModel :            NoneQed()
# methodCI:             eigen
# jjLS :                true
# selectLevelsCI:       false
# selectedLevelsCI:     Int64[]
# selectSymmetriesCI:   false
# selectedSymmetriesCI: LevelSymmetry[0 +, 1 -]

# %%
basis     = Basics.performSCF([Configuration("1s^2 2s^2"), Configuration("1s^2 2s 2p"), 
                               Configuration("1s^2 2p^2"), Configuration("1s^2 3s^2"), 
                               Configuration("1s^2 3p^2")],  nucModel, grid, asfSettings)
multiplet = Basics.performCI(basis, nucModel, grid, asfSettings);
# Out:
# ... in performSCF ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^0 2p_3/2^1
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^1 2p_3/2^0
# >> include Configuration: 1s_1/2^2 2p_1/2^0 2p_3/2^2
# >> include Configuration: 1s_1/2^2 2p_1/2^1 2p_3/2^1
# >> include Configuration: 1s_1/2^2 2p_1/2^2 2p_3/2^0
# >> include Configuration: 1s_1/2^2 3s_1/2^2
# >> include Configuration: 1s_1/2^2 3p_1/2^0 3p_3/2^2
# >> include Configuration: 1s_1/2^2 3p_1/2^1 3p_3/2^1
# >> include Configuration: 1s_1/2^2 3p_1/2^2 3p_3/2^0
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 6.0 with mass = 12.18, radius R = 2.4934845703596404 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.80086331e+01    -1.80086350e+01    +1.02975186e-07
#       2      2s_1/2      -4.50269994e+00    -4.50269857e+00    -3.04296207e-07
#       3      3s_1/2      -2.00097395e+00    -2.00095940e+00    -7.26977235e-06
#       4      4s_1/2      -1.12570260e+00    -1.12543844e+00    -2.34662195e-04
#       5      5s_1/2      -7.22414340e-01    -7.20234830e-01    -3.01698058e-03
#       6      6s_1/2      -5.43264102e-01    -5.00139888e-01    -7.93798335e-02
#       7      7s_1/2      -4.77865934e-01    -3.67436826e-01    -2.31088052e-01
#       8      8s_1/2      -3.50581452e-01    -2.81311119e-01    -1.97586987e-01
#       9      9s_1/2      -2.55481885e-01    -2.22265641e-01    -1.30014087e-01
#      10     10s_1/2      -1.85069169e-01    -1.80031939e-01    -2.72180936e-02
#      11     11s_1/2      -1.33033147e-01    -1.48784504e-01    +1.18401741e-01
#      12     12s_1/2      -9.50813929e-02    -1.25018733e-01    +3.14860131e-01
-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# >> Use hydrogenic orbital from this symmetry block also for 3p_3/2.
# (Re-) Define the standard grid with 390 grid points.
# >>  for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.0558214e+01;   self-cons'cy = 2.6081e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.3423669e+00;   self-cons'cy = 5.4068e-01  [1.0000e+02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -4.1672760e-01;   self-cons'cy = 6.5527e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.0764506e+00;   self-cons'cy = 6.1412e-01  [1.0000e+02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.5366295e-01;   self-cons'cy = 6.9960e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.1545036e+00;   self-cons'cy = 5.9169e-01  [1.0000e+02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -3.8676778e-01;   self-cons'cy = 6.7595e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1609808e+01;   self-cons'cy = 4.7437e-02  [4.7041e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.6448833e+00;   self-cons'cy = 1.0127e-01  [4.7041e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -5.1720807e-01;   self-cons'cy = 1.0759e-01  [4.7041e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.3383093e+00;   self-cons'cy = 1.0844e-01  [2.4150e-01 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -4.4197686e-01;   self-cons'cy = 1.1100e-01  [2.4150e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.3252818e+00;   self-cons'cy = 6.8868e-02  [2.5475e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -4.3842602e-01;   self-cons'cy = 6.2601e-02  [2.5475e-01 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1462040e+01;   self-cons'cy = 6.4047e-03  [9.6063e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.6025369e+00;   self-cons'cy = 1.3040e-02  [9.6063e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -5.0586452e-01;   self-cons'cy = 1.1088e-02  [9.6063e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.3061598e+00;   self-cons'cy = 1.2157e-02  [3.6891e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -4.3292866e-01;   self-cons'cy = 1.0342e-02  [3.6891e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.3066899e+00;   self-cons'cy = 7.0639e-03  [4.5236e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -4.3313089e-01;   self-cons'cy = 6.0755e-03  [4.5236e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1478595e+01;   self-cons'cy = 7.2167e-04  [7.1361e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.6064784e+00;   self-cons'cy = 1.2283e-03  [7.1361e-03 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -5.0689003e-01;   self-cons'cy = 1.0126e-03  [7.1361e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.3087842e+00;   self-cons'cy = 1.0036e-03  [2.6477e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -4.3367495e-01;   self-cons'cy = 8.6117e-04  [2.6477e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.3080641e+00;   self-cons'cy = 5.2555e-04  [2.8056e-03 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -4.3352408e-01;   self-cons'cy = 4.5369e-04  [2.8056e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1476780e+01;   self-cons'cy = 7.9080e-05  [6.6308e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.6061132e+00;   self-cons'cy = 1.1369e-04  [6.6308e-04 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -5.0679805e-01;   self-cons'cy = 9.0740e-05  [6.6308e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.3085794e+00;   self-cons'cy = 7.8217e-05  [2.2258e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -4.3361580e-01;   self-cons'cy = 6.8203e-05  [2.2258e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.3079633e+00;   self-cons'cy = 3.8521e-05  [2.2988e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -4.3349430e-01;   self-cons'cy = 3.4352e-05  [2.2988e-04 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1476972e+01;   self-cons'cy = 8.3857e-06  [5.2651e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.6061451e+00;   self-cons'cy = 9.9263e-06  [5.2651e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -5.0680573e-01;   self-cons'cy = 7.5780e-06  [5.2651e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.3085931e+00;   self-cons'cy = 5.2034e-06  [1.4843e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -4.3361983e-01;   self-cons'cy = 4.6491e-06  [1.4843e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.3079693e+00;   self-cons'cy = 2.2951e-06  [1.4183e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -4.3349617e-01;   self-cons'cy = 2.1590e-06  [1.4183e-05 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1476952e+01;   self-cons'cy = 8.7383e-07  [4.1032e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.6061424e+00;   self-cons'cy = 8.4159e-07  [4.1032e-06 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -5.0680512e-01;   self-cons'cy = 6.0758e-07  [4.1032e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.3085924e+00;   self-cons'cy = 2.6342e-07  [8.4205e-07 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -4.3361961e-01;   self-cons'cy = 2.5637e-07  [8.4205e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.3079691e+00;   self-cons'cy = 8.2816e-08  [6.9627e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -4.3349609e-01;   self-cons'cy = 9.8659e-08  [6.9627e-07 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1476954e+01;   self-cons'cy = 8.9550e-08  [2.7946e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.6061426e+00;   self-cons'cy = 6.7722e-08  [2.7946e-07 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -5.0680516e-01;   self-cons'cy = 4.4662e-08  [2.7946e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.3085924e+00;   self-cons'cy = 3.7075e-10  [1.5868e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -4.3361961e-01;   self-cons'cy = 4.2469e-09  [1.5868e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.3079691e+00;   self-cons'cy = 6.3145e-09  [1.5034e-08 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -4.3349609e-01;   self-cons'cy = 1.9953e-09  [1.5034e-08 for sym-block kappa = -2]
# Compute CI matrix of dimension 2 x 2 for the symmetry 1^- ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.021999 seconds (51.62 k allocations: 953.641 KiB)
#    ... done.
# Compute CI matrix of dimension 2 x 2 for the symmetry 1^+ ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.052379 seconds (54.17 k allocations: 1.010 MiB)
#    ... done.
# Compute CI matrix of dimension 6 x 6 for the symmetry 0^+ ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.167349 seconds (108.82 k allocations: 2.347 MiB)
#    ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 2^- ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.011373 seconds (25.63 k allocations: 470.859 KiB)
#    ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^- ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.011319 seconds (25.81 k allocations: 473.719 KiB)
#    ... done.
# Compute CI matrix of dimension 4 x 4 for the symmetry 2^+ ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.156613 seconds (90.96 k allocations: 1.787 MiB)
#    ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    0 +     -3.648798233288576e+01    -9.928885723510945e+02    -9.928885723510945e+02
#      2    0 -     -3.624425434740460e+01    -9.862563960542897e+02    -9.862563960542897e+02
#      3    1 -     -3.624410608145462e+01    -9.862523615322912e+02    -9.862523615322912e+02
#      4    2 -     -3.624380908761706e+01    -9.862442799183318e+02    -9.862442799183318e+02
#      5    1 -     -3.596230427746874e+01    -9.785841438628991e+02    -9.785841438628991e+02
#      6    0 +     -3.584833188633060e+01    -9.754827971320167e+02    -9.754827971320167e+02
#      7    1 +     -3.584819173184616e+01    -9.754789833342383e+02    -9.754789833342383e+02
#      8    2 +     -3.584791267909676e+01    -9.754713899221542e+02    -9.754713899221542e+02
#      9    2 +     -3.576686418122875e+01    -9.732659479603267e+02    -9.732659479603267e+02
#     10    0 +     -3.557520030981454e+01    -9.680505083691870e+02    -9.680505083691870e+02
#     11    0 +     -3.407634347897444e+01    -9.272645365564831e+02    -9.272645365564831e+02
