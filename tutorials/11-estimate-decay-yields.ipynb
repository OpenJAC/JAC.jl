# %% [markdown]
# # K-shell fluorescence & Auger yields for neon-like ions

# %%
using JAC
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-6810019685444926887\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-11756203875945853184\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio/main\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n        console.warn(\"Loading WebIO Jupyter extension on an ad-hoc basis. Consider enabling the WebIO nbextension for a stabler experience (this should happen automatically when building WebIO).\");\n        require([\"/assetserver/408bec45a46837488559cc915f1f252902507b97-dist/main.js\"], function (webIOModule) {\n            webIOModule.load_ipython_extension();\n        });\n        warning_div.innerHTML = \"<strong>Loading WebIO Jupyter extension on an ad-hoc basis. Consider enabling the WebIO nbextension for a stabler experience (this should happen automatically when building WebIO).</strong>\";\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<div\n    id=\"webio-warning-6810019685444926887\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    <!-- TODO: link to installation docs. -->\n</div>\n")

# %% [markdown]
# The fluorescence yield $\omega_r$ characterizes the probability of an inner-shell (core) hole to be filled under photon emission, in contrast and competition with other nonradiative processes. It fulfills together with the Auger yield $\omega_a$ the simple relations: $\omega_r + \omega_a = 1$ but generally requires to consider all possible (radiative and non-radiative) decay channels.
#
# In Jac, the computation of all fluorescence and Auger yields is always traced back to single-step **cascade computations**. Here, we wish to compute the fluorescence and Auger yields for neon-like ions and to see how the *fluorescence* increases with the nuclear charge. Similar as for other (level) properties, we can estimate the yields by performing an `Atomic.Computation(...,  properties=[Yields, ..], configs=[..], yieldSettings=DecayYield.Settings(..), ..)`.
#
# To understand, how we can control the computation of yields, let us have a look at the internal definition and the default settings of `DecayYield.Settings(..)`

# %%
? DecayYield.Settings
# Out:
#   struct  DecayYield.Settings ... defines a type for the details and
#   parameters of computing fluorescence and Auger yields.
#
#   + approach                 ::String         ... Identifier to determine the cascade approach that is applied for the yield computation:
#                                                     {"AverageSCA", SCA}
#   + printBeforeComputation   ::Bool           ... True if a list of selected levels is to be printed before the actual computations start.
#   + selectLevels             ::Bool           ... True if individual levels are selected for the computation.
#   + selectedLevels           ::Array{Level,1} ... List of selected levels.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   DecayYield.Settings() ... constructor for an empty instance of
#   DecayYield.Settings for the computation of fluorescence and Auger yields.

# %%
DecayYield.Settings()
# Out:
# approach:                 AverageSCA
# printBeforeComputation:   false
# selectLevels:             false
# selectedLevels:           Level[]

# %% [markdown]
# Here, the approach refers to one *cascade approaches* (cf. User Guide, chapter 8) that are available in JAC; because of the internal structure, however, this approach need to be provided in `String` notation as indicated above.
#
# To compute the fluorescence yields for neon-like Mg, we can specify the settings and computation as well as run the computation by:

# %%
settings=DecayYield.Settings("SCA", true, false, Int64[])
wa = Atomic.Computation("Yield computations for neon-like Mg",  Nuclear.Model(12.); 
            properties=[JAC.Yields],
            grid=JAC.Radial.Grid("grid: by given parameters"; rnt = 2.0e-5, h = 5.0e-2, 
                                                              hp = 2.0e-2, NoPoints = 600),
            configs=[Configuration("1s 2s^2 2p^6")], yieldSettings=settings )
perform(wa)
# Out:
# Define a radial grid of type MeshGL with 610 grid points
#  [rnt=2.000e-05, h=5.000e-02, hp=2.000e-02, NoPoints=600, r_max=7.066e+00;
#   B-splines wit break points at every 7th point, nsL=86, nsS=87, orderL=7, orderS=8, orderGL=7]
# shellOccList = SubString{String}["1s", "2s^2", "2p^6"]
#
# ... in perform('computation: SCF', ...
# perform-aa: Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 12.0 with mass = 24.72, radius R = 3.0053184906569026 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -7.21385120e+01    -7.21385593e+01    +6.55305160e-07
#       2      2s_1/2      -1.80433022e+01    -1.80433081e+01    +3.29715650e-07
#       3      3s_1/2      -8.01539078e+00    -8.01539255e+00    +2.20004591e-07
#       4      4s_1/2      -4.50703181e+00    -4.50703270e+00    +1.96691399e-07
#       5      5s_1/2      -2.88304774e+00    -2.88376608e+00    +2.49162895e-04
#       6      6s_1/2      -1.94286866e+00    -2.00224317e+00    +3.05602288e-02
#       7      7s_1/2      -1.00442427e+00    -1.47082901e+00    +4.64350334e-01
#       8      8s_1/2      +2.26494377e-01    -1.12597992e+00    +5.97133718e+00
#       :       :
#      81     81s_1/2      +8.27826203e+06    -1.09749682e-02    +1.00000000e+00
#      82     82s_1/2      +1.26126782e+07    -1.07089061e-02    +1.00000000e+00
#      83     83s_1/2      +2.00177380e+07    -1.04524031e-02    +1.00000000e+00
#      84     84s_1/2      +3.42471110e+07    -1.02050067e-02    +1.00000000e+00
#      85     85s_1/2      +6.87292829e+07    -9.96629080e-03    +1.00000000e+00
#      86     86s_1/2      +2.35021437e+08    -9.73585407e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 1s_1/2.
# Use hydrogenic orbital from this symmetriy block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -1.80433081e+01    -1.80433081e+01    +4.77405642e-10
#       2      3p_1/2      -8.01539254e+00    -8.01539255e+00    +3.77447480e-10
#       3      4p_1/2      -4.50703260e+00    -4.50703270e+00    +2.15493661e-08
#       4      5p_1/2      -2.88320700e+00    -2.88376608e+00    +1.93909355e-04
#       5      6p_1/2      -1.95042447e+00    -2.00224317e+00    +2.65679116e-02
#       6      7p_1/2      -1.03943191e+00    -1.47082901e+00    +4.15031615e-01
#       7      8p_1/2      +1.54817176e-01    -1.12597992e+00    +8.27296507e+00
#       8      9p_1/2      +1.63213342e+00    -8.89584969e-01    +1.54504427e+00
#       :       :
#      80     81p_1/2      +6.87879060e+06    -1.09749682e-02    +1.00000000e+00
#      81     82p_1/2      +1.03527977e+07    -1.07089061e-02    +1.00000000e+00
#      82     83p_1/2      +1.60904508e+07    -1.04524031e-02    +1.00000000e+00
#      83     84p_1/2      +2.64542155e+07    -1.02050067e-02    +1.00000000e+00
#      84     85p_1/2      +4.85487024e+07    -9.96629080e-03    +1.00000000e+00
#      85     86p_1/2      +1.15974317e+08    -9.73585407e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -1.80086350e+01    -1.80086350e+01    -3.76012522e-13
#       2      3p_3/2      -8.00511740e+00    -8.00511740e+00    +9.83028781e-14
#       3      4p_3/2      -4.50269847e+00    -4.50269857e+00    +2.17202233e-08
#       4      5p_3/2      -2.88098177e+00    -2.88154739e+00    +1.96328277e-04
#       5      6p_3/2      -1.94885404e+00    -2.00095940e+00    +2.67364069e-02
#       6      7p_3/2      -1.03749621e+00    -1.47002067e+00    +4.16892570e-01
#       7      8p_3/2      +1.57245691e-01    -1.12543844e+00    +8.15719733e+00
#       8      9p_3/2      +1.63499696e+00    -8.89204706e-01    +1.54385710e+00
#       :       :
#      81     82p_3/2      +9.83710486e+06    -1.07084037e-02    +1.00000000e+00
#      82     83p_3/2      +1.51659945e+07    -1.04519186e-02    +1.00000000e+00
#      83     84p_3/2      +2.45900396e+07    -1.02045393e-02    +1.00000000e+00
#      84     85p_3/2      +4.38442795e+07    -9.96583973e-03    +1.00000000e+00
#      85     86p_3/2      +9.62957393e+07    -9.73541855e-03    +1.00000000e+00
#      86     87p_3/2      +3.73227319e+08    -9.51289734e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_3/2.
# Re-define the standard grid with 600 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -4.6238171e+01;   self-cons'cy = 2.1880e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.4856397e+00;   self-cons'cy = 6.7619e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.6891643e+00;   self-cons'cy = 7.4058e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3567500e+00;   self-cons'cy = 6.8578e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.3328108e+01;   self-cons'cy = 7.1208e-02  [3.7526e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.5744876e+00;   self-cons'cy = 2.3055e-01  [3.7526e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.2356832e+00;   self-cons'cy = 2.2333e-01  [2.2333e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.8396152e+00;   self-cons'cy = 6.7098e-02  [6.7098e-02 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1140300e+01;   self-cons'cy = 2.0942e-02  [1.6930e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.7550879e+00;   self-cons'cy = 7.9326e-02  [1.6930e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7015454e+00;   self-cons'cy = 6.7295e-02  [7.5517e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7700036e+00;   self-cons'cy = 9.1478e-03  [1.0937e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1631461e+01;   self-cons'cy = 4.7791e-03  [3.1872e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.9256474e+00;   self-cons'cy = 1.7618e-02  [3.1872e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7875865e+00;   self-cons'cy = 1.1489e-02  [1.1489e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7569084e+00;   self-cons'cy = 1.7398e-03  [1.7398e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1551657e+01;   self-cons'cy = 7.7342e-04  [5.3864e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8971610e+00;   self-cons'cy = 2.9000e-03  [5.3864e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7797115e+00;   self-cons'cy = 1.0407e-03  [1.0785e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7659530e+00;   self-cons'cy = 1.2023e-03  [1.2040e-03 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1555974e+01;   self-cons'cy = 4.1876e-05  [2.6354e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8987166e+00;   self-cons'cy = 1.5880e-04  [2.6354e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7778176e+00;   self-cons'cy = 2.5060e-04  [2.5712e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7629992e+00;   self-cons'cy = 3.9232e-04  [3.9908e-04 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1558797e+01;   self-cons'cy = 2.7373e-05  [1.9763e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8997089e+00;   self-cons'cy = 1.0127e-04  [1.9763e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7790445e+00;   self-cons'cy = 1.6236e-04  [1.6639e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7636845e+00;   self-cons'cy = 9.1050e-05  [9.3584e-05 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557394e+01;   self-cons'cy = 1.3606e-05  [9.6120e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8992132e+00;   self-cons'cy = 5.0578e-05  [9.6120e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7786516e+00;   self-cons'cy = 5.1989e-05  [5.3292e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7635745e+00;   self-cons'cy = 1.4612e-05  [1.5279e-05 for sym-block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557805e+01;   self-cons'cy = 3.9857e-06  [2.7907e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8993587e+00;   self-cons'cy = 1.4844e-05  [2.7907e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7787415e+00;   self-cons'cy = 1.1900e-05  [1.2198e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7635799e+00;   self-cons'cy = 7.2005e-07  [8.4497e-07 for sym-block kappa = -2]
#
# Iteration 10 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557718e+01;   self-cons'cy = 8.4520e-07  [5.8692e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8993278e+00;   self-cons'cy = 3.1532e-06  [5.8692e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7787274e+00;   self-cons'cy = 1.8678e-06  [1.9146e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7635841e+00;   self-cons'cy = 5.4925e-07  [5.4925e-07 for sym-block kappa = -2]
#
# Iteration 11 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557730e+01;   self-cons'cy = 1.1569e-07  [7.9006e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8993320e+00;   self-cons'cy = 4.3310e-07  [7.9006e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7787280e+00;   self-cons'cy = 7.7108e-08  [7.9063e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7635821e+00;   self-cons'cy = 2.6639e-07  [2.6844e-07 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -1.500861609591577e+02    -4.084052462119494e+03    -4.084052462119494e+03
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# DecayYield.computeOutcomes(): The computation of the fluorescence & Auger yields starts now ...
# -----------------------------------------------------------------------------------------------
#
#   Selected DecayYield levels:
#
#   -------------------------------------------
#      Level        J^P           Energy
#                                  [eV]
#   -------------------------------------------
#          1       1/2 +      -4.08405246e+03
#   -------------------------------------------
#
# Perform a cascade computation for all radiative decay channels of the levels from the initial configurations:
#
# * Initial levels of the given cascade, relative to the lowest, and their given occupation:
#
#   ----------------------------------------------------------------
#     Level  J Parity          Energy [eV]         rel. occupation
#   ----------------------------------------------------------------
#        1     1/2 +      0.000000000000000e+00           0.0
#   ----------------------------------------------------------------
#
#   Electron configuration used in the cascade:
#
#     Configuration(s) with 9 electrons:
#       1s^1 2s^2 2p^6    av. BE = -1779.0  [eV]      (1)
#       1s^2 2s^1 2p^6    av. BE = -2993.0  [eV]      (2)
#       1s^2 2s^2 2p^5    av. BE = -3032.0  [eV]      (3)
#
#   A total of 3 configuration have been defined for this cascade, and selected configurations could be removed here:  [currently not supported]
#
#
#   In the cascade approach JAC.Cascade.SCA(), the following assumptions/simplifications are made:
#     + orbitals are generated independently for each multiplet (block);
#     + configuration interaction is included for each block;
#     + only E1 dipole transitions are applied in all radiative decay stets;
#
#   Multiplet computations for 1s^1 2s^2 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^5  with 9 electrons ... and 2 CSF done.
#
# * Configuration 'blocks' (multiplets) in the given cascade model:
#
#   --------------------------------------------------------------------------------------------------------------------------------------
#       No.   Configurations                                                                             Range of total energies [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------
#         1   1s^1 2s^2 2p^6                                                                             -4084.0 ... -4084.0
#         2   1s^2 2s^1 2p^6                                                                             -5299.0 ... -5299.0
#         3   1s^2 2s^2 2p^5                                                                             -5340.0 ... -5340.0
#   --------------------------------------------------------------------------------------------------------------------------------------
#
# * Steps that are defined for the current cascade due to the given approach:
#
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    Step-No   Process     Initial:  No CSF, configuration(s)                         Final:  No CSF, configuration(s)                           Energies from ... to in [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        1     Radiative     1, 1s^1 2s^2 2p^6                                          1, 1s^2 2s^1 2p^6                                        1215.0 ... 1215.0
#        2     Radiative     1, 1s^1 2s^2 2p^6                                          2, 1s^2 2s^2 2p^5                                        1256.0 ... 1256.0
#        3     Radiative     1, 1s^2 2s^1 2p^6                                          2, 1s^2 2s^2 2p^5                                        41.0 ... 41.0
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#   Here, modify the individual steps explicitly in the code, if needed, ...... and just do it !!
#
#   A total of 3 steps are still defined in the cascade.
#
#   1) Perform Radiative amplitude computations for up to 1 lines (without selection rules):
#      Step 1:: A total of 0 Radiative lines are calculated, giving now rise to a total of 0 Radiative lines.
#
#   2) Perform Radiative amplitude computations for up to 2 lines (without selection rules):
#      Step 2:: A total of 2 Radiative lines are calculated, giving now rise to a total of 2 Radiative lines.
#
#   3) Perform Radiative amplitude computations for up to 2 lines (without selection rules):
#      Step 3:: A total of 2 Radiative lines are calculated, giving now rise to a total of 4 Radiative lines.
#
# Perform a cascade computation for all (single-electron) Auger decay channels of the levels from the initial configurations:
#
# * Initial levels of the given cascade, relative to the lowest, and their given occupation:
#
#   ----------------------------------------------------------------
#     Level  J Parity          Energy [eV]         rel. occupation
#   ----------------------------------------------------------------
#        1     1/2 +      0.000000000000000e+00           0.0
#   ----------------------------------------------------------------
#
#   Electron configuration used in the cascade:
#
#     Configuration(s) with 9 electrons:
#       1s^1 2s^2 2p^6    av. BE = -1779.0  [eV]      (1)
#       1s^2 2s^1 2p^6    av. BE = -2993.0  [eV]      (2)
#       1s^2 2s^2 2p^5    av. BE = -3032.0  [eV]      (3)
#
#     Configuration(s) with 8 electrons:
#       1s^2 2s^0 2p^6    av. BE = -2905.0  [eV]      (4)
#       1s^2 2s^1 2p^5    av. BE = -2944.0  [eV]      (5)
#       1s^2 2s^2 2p^4    av. BE = -2983.0  [eV]      (6)
#
#   A total of 6 configuration have been defined for this cascade, and selected configurations could be removed here:  [currently not supported]
#
#
#   In the cascade approach JAC.Cascade.SCA(), the following assumptions/simplifications are made:
#     + orbitals are generated independently for each multiplet (block);
#     + configuration interaction is included for each block;
#     + only E1 dipole transitions are applied in all radiative decay stets;
#
#   Multiplet computations for 1s^1 2s^2 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^5  with 9 electrons ... and 2 CSF done.
#   Multiplet computations for 1s^2 2s^0 2p^6  with 8 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^5  with 8 electrons ... and 4 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^4  with 8 electrons ... and 5 CSF done.
#
# * Configuration 'blocks' (multiplets) in the given cascade model:
#
#   --------------------------------------------------------------------------------------------------------------------------------------
#       No.   Configurations                                                                             Range of total energies [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------
#         1   1s^1 2s^2 2p^6                                                                             -4084.0 ... -4084.0
#         2   1s^2 2s^1 2p^6                                                                             -5299.0 ... -5299.0
#         3   1s^2 2s^2 2p^5                                                                             -5340.0 ... -5340.0
#         4   1s^2 2s^0 2p^6                                                                             -5148.0 ... -5148.0
#         5   1s^2 2s^1 2p^5                                                                             -5196.0 ... -5181.0
#         6   1s^2 2s^2 2p^4                                                                             -5233.0 ... -5221.0
#   --------------------------------------------------------------------------------------------------------------------------------------
#
# * Steps that are defined for the current cascade due to the given approach:
#
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    Step-No   Process     Initial:  No CSF, configuration(s)                         Final:  No CSF, configuration(s)                           Energies from ... to in [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        1     Auger         1, 1s^1 2s^2 2p^6                                          1, 1s^2 2s^0 2p^6                                        1064.0 ... 1064.0
#        2     Auger         1, 1s^1 2s^2 2p^6                                          4, 1s^2 2s^1 2p^5                                        1097.0 ... 1112.0
#        3     Auger         1, 1s^1 2s^2 2p^6                                          5, 1s^2 2s^2 2p^4                                        1137.0 ... 1149.0
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#   Here, modify the individual steps explicitly in the code, if needed, ...... and just do it !!
#
#   A total of 3 steps are still defined in the cascade.
#
#   1) Perform Auger amplitude computations for up to 1 lines (without selection rules):
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=0.0000e+00).
#      Step 1:: A total of 1 Auger lines are calculated, giving now rise to a total of 1 Auger lines.
#
#   2) Perform Auger amplitude computations for up to 4 lines (without selection rules):
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=0.0000e+00).
#      Step 2:: A total of 4 Auger lines are calculated, giving now rise to a total of 5 Auger lines.
#
#   3) Perform Auger amplitude computations for up to 5 lines (without selection rules):
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=4.4409e-16).
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=4.4409e-16).
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=4.4409e-16).
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=4.0000e+00 (Delta-Zbar=4.4409e-16).
#      Step 3:: A total of 5 Auger lines are calculated, giving now rise to a total of 10 Auger lines.
# ** compareKey = LevelKey[1/2 + (1), en=-150.08616095915772, occ=0.0]
# ** compareKey = LevelKey[1/2 + (1), en=-150.08616095915772, occ=0.0]
#
#   Fluorescence and Auger decay yields:
#
#     + No_R, rate_R, omega_R  ... number of fluorescence lines, total fluorescence rate and yield.
#     + No_A, rate_A, omega_A  ... number of Auger lines, total Auger rate and Auger yield.
#     + Approach:  SCA  ... all fluorescence rates and yields only in Babushkin gauge.
#
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#      Level        J^P           Energy          No_R    Cou -- rate_R  -- Bab    Cou -- omega_R -- Bab     No_A      rate_A      Cou -- omega_A -- Bab
#                                  [eV]
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#          1       1/2 +      -4.08405246e+03     0002    0.0000e+00 4.3175e-04    0.0000e+00 7.7684e-02     0010    5.1260e-03    1.0000e+00 9.2232e-01
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# Obviously, this results in a rather detailed output due to printed data of the underlying cascade computation. In this single-step cascade, all the neon-like configurations with total energies below of the given $1s 2s^2 2p^6$ configuration above are generated automatically, together with all energetically allowed fluorine-like configuration due to the (Auger) emission of an electon. Here, we shall not discuss this output in detail but just go over to the final table: It report an fluorescence yield $\omega_r \approx 0.08$ in Babushkin gauge and a corresponding Auger yield of $\omega_a \approx 0.92$. The same yields in Coulomb gauge are (0., 1.), but this occurs since
# by default all radiative transitions are only considered in Babushkin (length) gauge. To modify this settings, the user would have to change the *call* of the cascade computations within the code.
#
# To see how the coupling of the radiation field and, hence, the fluorescence increases with an increasing  nuclear charge, let us perform the same computations but for Z=18 and Z=26, respectively.

# %%
wa = Atomic.Computation("Yield computations for neon-like Ar",  Nuclear.Model(18.); 
            properties=[JAC.Yields],
            grid=JAC.Radial.Grid("grid: by given parameters"; rnt = 2.0e-5, h = 5.0e-2, 
                                                              hp = 2.0e-2, NoPoints = 600),
            configs=[Configuration("1s 2s^2 2p^6")], yieldSettings=settings )
perform(wa)
# Out:
# Define a radial grid of type MeshGL with 610 grid points
#  [rnt=2.000e-05, h=5.000e-02, hp=2.000e-02, NoPoints=600, r_max=7.066e+00;
#   B-splines wit break points at every 7th point, nsL=86, nsS=87, orderL=7, orderS=8, orderGL=7]
# shellOccList = SubString{String}["1s", "2s^2", "2p^6"]
#
# ... in perform('computation: SCF', ...
# perform-aa: Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 18.0 with mass = 37.62, radius R = 3.37121133160794 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.62704537e+02    -1.62704858e+02    +1.97540668e-06
#       2      2s_1/2      -4.07203231e+01    -4.07203638e+01    +1.00176088e-06
#       3      3s_1/2      -1.80782718e+01    -1.80782839e+01    +6.69151854e-07
#       4      4s_1/2      -1.01607481e+01    -1.01607532e+01    +5.02098324e-07
#       5      5s_1/2      -6.49913816e+00    -6.49914079e+00    +4.04674652e-07
#       6      6s_1/2      -4.51128363e+00    -4.51139835e+00    +2.54289510e-05
#       7      7s_1/2      -3.29414166e+00    -3.31344481e+00    +5.85984140e-03
#       8      8s_1/2      -2.27023773e+00    -2.53622787e+00    +1.17164002e-01
#       :       :
#      81     81s_1/2      +8.20458024e+06    -2.46965924e-02    +1.00000000e+00
#      82     82s_1/2      +1.25318288e+07    -2.40978477e-02    +1.00000000e+00
#      83     83s_1/2      +1.99346953e+07    -2.35206159e-02    +1.00000000e+00
#      84     84s_1/2      +3.41637618e+07    -2.29638786e-02    +1.00000000e+00
#      85     85s_1/2      +6.86459264e+07    -2.24266769e-02    +1.00000000e+00
#      86     86s_1/2      +2.34938069e+08    -2.19081076e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 1s_1/2.
# Use hydrogenic orbital from this symmetriy block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -4.07203637e+01    -4.07203638e+01    +3.27491928e-09
#       2      3p_1/2      -1.80782839e+01    -1.80782839e+01    +2.59298081e-09
#       3      4p_1/2      -1.01607532e+01    -1.01607532e+01    +2.05175021e-09
#       4      5p_1/2      -6.49914076e+00    -6.49914079e+00    +3.83903056e-09
#       5      6p_1/2      -4.51130697e+00    -4.51139835e+00    +2.02565546e-05
#       6      7p_1/2      -3.29647822e+00    -3.31344481e+00    +5.14688332e-03
#       7      8p_1/2      -2.28880846e+00    -2.53622787e+00    +1.08099660e-01
#       8      9p_1/2      -1.04362917e+00    -2.00353566e+00    +9.19777373e-01
#       :       :
#      80     81p_1/2      +6.81108715e+06    -2.46965924e-02    +1.00000000e+00
#      81     82p_1/2      +1.02749674e+07    -2.40978477e-02    +1.00000000e+00
#      82     83p_1/2      +1.60081745e+07    -2.35206159e-02    +1.00000000e+00
#      83     84p_1/2      +2.63709350e+07    -2.29638786e-02    +1.00000000e+00
#      84     85p_1/2      +4.84653355e+07    -2.24266769e-02    +1.00000000e+00
#      85     86p_1/2      +1.15890947e+08    -2.19081076e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -4.05437672e+01    -4.05437672e+01    -8.74513765e-14
#       2      3p_3/2      -1.80259403e+01    -1.80259403e+01    -2.02213265e-13
#       3      4p_3/2      -1.01386787e+01    -1.01386787e+01    +5.14404669e-13
#       4      5p_3/2      -6.48784307e+00    -6.48784308e+00    +2.26628490e-09
#       5      6p_3/2      -4.50476844e+00    -4.50486250e+00    +2.08815519e-05
#       6      7p_3/2      -3.29209270e+00    -3.30933006e+00    +5.23599041e-03
#       7      8p_3/2      -2.28412863e+00    -2.53347193e+00    +1.09163425e-01
#       8      9p_3/2      -1.03767340e+00    -2.00160044e+00    +9.28931038e-01
#       :       :
#      81     82p_3/2      +9.75999642e+06    -2.40952931e-02    +1.00000000e+00
#      82     83p_3/2      +1.50837712e+07    -2.35181525e-02    +1.00000000e+00
#      83     84p_3/2      +2.45067105e+07    -2.29615022e-02    +1.00000000e+00
#      84     85p_3/2      +4.37609001e+07    -2.24243834e-02    +1.00000000e+00
#      85     86p_3/2      +9.62123803e+07    -2.19058931e-02    +1.00000000e+00
#      86     87p_3/2      +3.73143951e+08    -2.14051797e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_3/2.
# Re-define the standard grid with 600 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2369707e+02;   self-cons'cy = 1.3620e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.7866211e+01;   self-cons'cy = 3.9009e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.5948796e+01;   self-cons'cy = 4.3713e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.6486616e+01;   self-cons'cy = 4.2183e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2991228e+02;   self-cons'cy = 2.4507e-02  [1.3614e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9747751e+01;   self-cons'cy = 5.0022e-02  [1.3614e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7624552e+01;   self-cons'cy = 4.9913e-02  [1.7064e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7362228e+01;   self-cons'cy = 2.5868e-02  [8.2545e-02 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2880390e+02;   self-cons'cy = 4.2842e-03  [2.2903e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9371578e+01;   self-cons'cy = 9.6160e-03  [2.2903e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7327477e+01;   self-cons'cy = 8.4995e-03  [2.6316e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7247755e+01;   self-cons'cy = 3.3075e-03  [1.0708e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2896937e+02;   self-cons'cy = 6.4191e-04  [3.4838e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9427066e+01;   self-cons'cy = 1.4301e-03  [3.4838e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7366664e+01;   self-cons'cy = 1.1295e-03  [3.5570e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7259569e+01;   self-cons'cy = 3.4236e-04  [1.1033e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2894753e+02;   self-cons'cy = 8.4699e-05  [4.6072e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9419700e+01;   self-cons'cy = 1.8961e-04  [4.6072e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7361918e+01;   self-cons'cy = 1.3665e-04  [4.2925e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258475e+01;   self-cons'cy = 3.1697e-05  [1.0193e-04 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2895014e+02;   self-cons'cy = 1.0116e-05  [5.5166e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9420581e+01;   self-cons'cy = 2.2689e-05  [5.5166e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362437e+01;   self-cons'cy = 1.4953e-05  [4.6942e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258558e+01;   self-cons'cy = 2.4017e-06  [7.6698e-06 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2894985e+02;   self-cons'cy = 1.0979e-06  [6.0027e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9420485e+01;   self-cons'cy = 2.4681e-06  [6.0027e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362386e+01;   self-cons'cy = 1.4672e-06  [4.6010e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258554e+01;   self-cons'cy = 1.0587e-07  [3.4911e-07 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2894988e+02;   self-cons'cy = 1.0674e-07  [5.7213e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9420495e+01;   self-cons'cy = 2.4062e-07  [5.7213e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362391e+01;   self-cons'cy = 1.2331e-07  [3.6635e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258554e+01;   self-cons'cy = 8.7198e-09  [9.6875e-09 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -3.830160466495013e+02    -1.042239749723391e+04    -1.042239749723391e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# DecayYield.computeOutcomes(): The computation of the fluorescence & Auger yields starts now ...
# -----------------------------------------------------------------------------------------------
#
#   Selected DecayYield levels:
#
#   -------------------------------------------
#      Level        J^P           Energy
#                                  [eV]
#   -------------------------------------------
#          1       1/2 +      -1.04223975e+04
#   -------------------------------------------
#
# Perform a cascade computation for all radiative decay channels of the levels from the initial configurations:
#
# * Initial levels of the given cascade, relative to the lowest, and their given occupation:
#
#   ----------------------------------------------------------------
#     Level  J Parity          Energy [eV]         rel. occupation
#   ----------------------------------------------------------------
#        1     1/2 +      0.000000000000000e+00           0.0
#   ----------------------------------------------------------------
#
#   Electron configuration used in the cascade:
#
#     Configuration(s) with 9 electrons:
#       1s^1 2s^2 2p^6    av. BE = -5362.0  [eV]      (1)
#       1s^2 2s^1 2p^6    av. BE = -8242.0  [eV]      (2)
#       1s^2 2s^2 2p^5    av. BE = -8317.0  [eV]      (3)
#
#   A total of 3 configuration have been defined for this cascade, and selected configurations could be removed here:  [currently not supported]
#
#
#   In the cascade approach JAC.Cascade.SCA(), the following assumptions/simplifications are made:
#     + orbitals are generated independently for each multiplet (block);
#     + configuration interaction is included for each block;
#     + only E1 dipole transitions are applied in all radiative decay stets;
#
#   Multiplet computations for 1s^1 2s^2 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^5  with 9 electrons ... and 2 CSF done.
#
# * Configuration 'blocks' (multiplets) in the given cascade model:
#
#   --------------------------------------------------------------------------------------------------------------------------------------
#       No.   Configurations                                                                             Range of total energies [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------
#         1   1s^1 2s^2 2p^6                                                                             -10422.0 ... -10422.0
#         2   1s^2 2s^1 2p^6                                                                             -13319.0 ... -13319.0
#         3   1s^2 2s^2 2p^5                                                                             -13396.0 ... -13394.0
#   --------------------------------------------------------------------------------------------------------------------------------------
#
# * Steps that are defined for the current cascade due to the given approach:
#
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    Step-No   Process     Initial:  No CSF, configuration(s)                         Final:  No CSF, configuration(s)                           Energies from ... to in [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        1     Radiative     1, 1s^1 2s^2 2p^6                                          1, 1s^2 2s^1 2p^6                                        2897.0 ... 2897.0
#        2     Radiative     1, 1s^1 2s^2 2p^6                                          2, 1s^2 2s^2 2p^5                                        2972.0 ... 2974.0
#        3     Radiative     1, 1s^2 2s^1 2p^6                                          2, 1s^2 2s^2 2p^5                                        75.0 ... 77.0
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#   Here, modify the individual steps explicitly in the code, if needed, ...... and just do it !!
#
#   A total of 3 steps are still defined in the cascade.
#
#   1) Perform Radiative amplitude computations for up to 1 lines (without selection rules):
#      Step 1:: A total of 0 Radiative lines are calculated, giving now rise to a total of 0 Radiative lines.
#
#   2) Perform Radiative amplitude computations for up to 2 lines (without selection rules):
#      Step 2:: A total of 2 Radiative lines are calculated, giving now rise to a total of 2 Radiative lines.
#
#   3) Perform Radiative amplitude computations for up to 2 lines (without selection rules):
#      Step 3:: A total of 2 Radiative lines are calculated, giving now rise to a total of 4 Radiative lines.
#
# Perform a cascade computation for all (single-electron) Auger decay channels of the levels from the initial configurations:
#
# * Initial levels of the given cascade, relative to the lowest, and their given occupation:
#
#   ----------------------------------------------------------------
#     Level  J Parity          Energy [eV]         rel. occupation
#   ----------------------------------------------------------------
#        1     1/2 +      0.000000000000000e+00           0.0
#   ----------------------------------------------------------------
#
#   Electron configuration used in the cascade:
#
#     Configuration(s) with 9 electrons:
#       1s^1 2s^2 2p^6    av. BE = -5362.0  [eV]      (1)
#       1s^2 2s^1 2p^6    av. BE = -8242.0  [eV]      (2)
#       1s^2 2s^2 2p^5    av. BE = -8317.0  [eV]      (3)
#
#     Configuration(s) with 8 electrons:
#       1s^2 2s^0 2p^6    av. BE = -7915.0  [eV]      (4)
#       1s^2 2s^1 2p^5    av. BE = -7991.0  [eV]      (5)
#       1s^2 2s^2 2p^4    av. BE = -8067.0  [eV]      (6)
#
#   A total of 6 configuration have been defined for this cascade, and selected configurations could be removed here:  [currently not supported]
#
#
#   In the cascade approach JAC.Cascade.SCA(), the following assumptions/simplifications are made:
#     + orbitals are generated independently for each multiplet (block);
#     + configuration interaction is included for each block;
#     + only E1 dipole transitions are applied in all radiative decay stets;
#
#   Multiplet computations for 1s^1 2s^2 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^5  with 9 electrons ... and 2 CSF done.
#   Multiplet computations for 1s^2 2s^0 2p^6  with 8 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^5  with 8 electrons ... and 4 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^4  with 8 electrons ... and 5 CSF done.
#
# * Configuration 'blocks' (multiplets) in the given cascade model:
#
#   --------------------------------------------------------------------------------------------------------------------------------------
#       No.   Configurations                                                                             Range of total energies [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------
#         1   1s^1 2s^2 2p^6                                                                             -10422.0 ... -10422.0
#         2   1s^2 2s^1 2p^6                                                                             -13319.0 ... -13319.0
#         3   1s^2 2s^2 2p^5                                                                             -13396.0 ... -13394.0
#         4   1s^2 2s^0 2p^6                                                                             -12764.0 ... -12764.0
#         5   1s^2 2s^1 2p^5                                                                             -12851.0 ... -12825.0
#         6   1s^2 2s^2 2p^4                                                                             -12918.0 ... -12897.0
#   --------------------------------------------------------------------------------------------------------------------------------------
#
# * Steps that are defined for the current cascade due to the given approach:
#
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    Step-No   Process     Initial:  No CSF, configuration(s)                         Final:  No CSF, configuration(s)                           Energies from ... to in [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        1     Auger         1, 1s^1 2s^2 2p^6                                          1, 1s^2 2s^0 2p^6                                        2341.0 ... 2341.0
#        2     Auger         1, 1s^1 2s^2 2p^6                                          4, 1s^2 2s^1 2p^5                                        2403.0 ... 2429.0
#        3     Auger         1, 1s^1 2s^2 2p^6                                          5, 1s^2 2s^2 2p^4                                        2474.0 ... 2496.0
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#   Here, modify the individual steps explicitly in the code, if needed, ...... and just do it !!
#
#   A total of 3 steps are still defined in the cascade.
#
#   1) Perform Auger amplitude computations for up to 1 lines (without selection rules):
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
#      Step 1:: A total of 1 Auger lines are calculated, giving now rise to a total of 1 Auger lines.
#
#   2) Perform Auger amplitude computations for up to 4 lines (without selection rules):
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
#      Step 2:: A total of 4 Auger lines are calculated, giving now rise to a total of 5 Auger lines.
#
#   3) Perform Auger amplitude computations for up to 5 lines (without selection rules):
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.0000e+01 (Delta-Zbar=0.0000e+00).
#      Step 3:: A total of 5 Auger lines are calculated, giving now rise to a total of 10 Auger lines.
# ** compareKey = LevelKey[1/2 + (1), en=-383.0160466495013, occ=0.0]
# ** compareKey = LevelKey[1/2 + (1), en=-383.0160466495013, occ=0.0]
#
#   Fluorescence and Auger decay yields:
#
#     + No_R, rate_R, omega_R  ... number of fluorescence lines, total fluorescence rate and yield.
#     + No_A, rate_A, omega_A  ... number of Auger lines, total Auger rate and Auger yield.
#     + Approach:  SCA  ... all fluorescence rates and yields only in Babushkin gauge.
#
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#      Level        J^P           Energy          No_R    Cou -- rate_R  -- Bab    Cou -- omega_R -- Bab     No_A      rate_A      Cou -- omega_A -- Bab
#                                  [eV]
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#          1       1/2 +      -1.04223975e+04     0002    0.0000e+00 2.9032e-03    0.0000e+00 3.0930e-01     0010    6.4830e-03    1.0000e+00 6.9070e-01
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %%
wa = Atomic.Computation("Yield computations for neon-like Fe",  Nuclear.Model(26.); 
            properties=[JAC.Yields],
            grid=JAC.Radial.Grid("grid: by given parameters"; rnt = 2.0e-5, h = 5.0e-2, 
                                                              hp = 2.0e-2, NoPoints = 600),
            configs=[Configuration("1s 2s^2 2p^6")], yieldSettings=settings )
perform(wa)
# Out:
# Define a radial grid of type MeshGL with 610 grid points
#  [rnt=2.000e-05, h=5.000e-02, hp=2.000e-02, NoPoints=600, r_max=7.066e+00;
#   B-splines wit break points at every 7th point, nsL=86, nsS=87, orderL=7, orderS=8, orderGL=7]
# shellOccList = SubString{String}["1s", "2s^2", "2p^6"]
#
# ... in perform('computation: SCF', ...
# perform-aa: Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 26.0 with mass = 55.38, radius R = 3.756573410087755 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -3.41095880e+02    -3.41097837e+02    +5.73779778e-06
#       2      2s_1/2      -8.54687058e+01    -8.54689584e+01    +2.95488235e-06
#       3      3s_1/2      -3.78993728e+01    -3.78994478e+01    +1.97799554e-06
#       4      4s_1/2      -2.12819069e+01    -2.12819385e+01    +1.48493211e-06
#       5      5s_1/2      -1.36039552e+01    -1.36039714e+01    +1.18822790e-06
#       6      6s_1/2      -9.43886387e+00    -9.43887322e+00    +9.90181521e-07
#       7      7s_1/2      -6.93004718e+00    -6.93005925e+00    +1.74068598e-06
#       8      8s_1/2      -5.30039822e+00    -5.30306679e+00    +5.03465922e-04
#       :       :
#      81     81s_1/2      +8.11518655e+06    -5.15394375e-02    +1.00000001e+00
#      82     82s_1/2      +1.24361167e+07    -5.02897729e-02    +1.00000000e+00
#      83     83s_1/2      +1.98373115e+07    -4.90850138e-02    +1.00000000e+00
#      84     84s_1/2      +3.40661386e+07    -4.79230342e-02    +1.00000000e+00
#      85     85s_1/2      +6.85482724e+07    -4.68018324e-02    +1.00000000e+00
#      86     86s_1/2      +2.34840395e+08    -4.57195223e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 1s_1/2.
# Use hydrogenic orbital from this symmetriy block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -8.54689566e+01    -8.54689584e+01    +2.03864306e-08
#       2      3p_1/2      -3.78994472e+01    -3.78994478e+01    +1.61653579e-08
#       3      4p_1/2      -2.12819382e+01    -2.12819385e+01    +1.27959883e-08
#       4      5p_1/2      -1.36039712e+01    -1.36039714e+01    +1.04824408e-08
#       5      6p_1/2      -9.43887313e+00    -9.43887322e+00    +8.89803761e-09
#       6      7p_1/2      -6.93005408e+00    -6.93005925e+00    +7.45369358e-07
#       7      8p_1/2      -5.30072628e+00    -5.30306679e+00    +4.41544385e-04
#       8      9p_1/2      -4.10366266e+00    -4.18833237e+00    +2.06327156e-02
#       :       :
#      80     81p_1/2      +6.72779578e+06    -5.15394375e-02    +1.00000001e+00
#      81     82p_1/2      +1.01817944e+07    -5.02897729e-02    +1.00000000e+00
#      82     83p_1/2      +1.59113591e+07    -4.90850138e-02    +1.00000000e+00
#      83     84p_1/2      +2.62733704e+07    -4.79230342e-02    +1.00000000e+00
#      84     85p_1/2      +4.83676827e+07    -4.68018324e-02    +1.00000000e+00
#      85     86p_1/2      +1.15793273e+08    -4.57195223e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -8.46909743e+01    -8.46909743e+01    +1.02523702e-13
#       2      3p_3/2      -3.76687634e+01    -3.76687634e+01    -1.52978252e-13
#       3      4p_3/2      -2.11846929e+01    -2.11846929e+01    -5.78403922e-13
#       4      5p_3/2      -1.35542226e+01    -1.35542226e+01    -2.06281522e-13
#       5      6p_3/2      -9.41010352e+00    -9.41010352e+00    +5.78393169e-11
#       6      7p_3/2      -6.91194679e+00    -6.91195226e+00    +7.91771807e-07
#       7      8p_3/2      -5.28849919e+00    -5.29094223e+00    +4.61953143e-04
#       8      9p_3/2      -4.09318638e+00    -4.17982022e+00    +2.11653788e-02
#       :       :
#      81     82p_3/2      +9.66737059e+06    -5.02785564e-02    +1.00000001e+00
#      82     83p_3/2      +1.49869724e+07    -4.90741979e-02    +1.00000000e+00
#      83     84p_3/2      +2.44091193e+07    -4.79126000e-02    +1.00000000e+00
#      84     85p_3/2      +4.36632491e+07    -4.67917622e-02    +1.00000000e+00
#      85     86p_3/2      +9.61147213e+07    -4.57097995e-02    +1.00000000e+00
#      86     87p_3/2      +3.73046276e+08    -4.46649346e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_3/2.
# Re-define the standard grid with 600 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8438061e+02;   self-cons'cy = 9.0675e-02  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.1572305e+01;   self-cons'cy = 2.4734e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.8295892e+01;   self-cons'cy = 2.7790e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.8394671e+01;   self-cons'cy = 2.7273e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.9025065e+02;   self-cons'cy = 1.0215e-02  [3.6468e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3406594e+01;   self-cons'cy = 1.7473e-02  [3.6468e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -5.0035144e+01;   self-cons'cy = 1.7688e-02  [2.8089e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9401249e+01;   self-cons'cy = 1.0293e-02  [1.5922e-02 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8958750e+02;   self-cons'cy = 1.1437e-03  [4.3170e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3187637e+01;   self-cons'cy = 2.0541e-03  [4.3170e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9849536e+01;   self-cons'cy = 1.8582e-03  [3.0675e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9315949e+01;   self-cons'cy = 8.6408e-04  [1.4036e-03 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8965188e+02;   self-cons'cy = 1.1114e-04  [4.1920e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3208873e+01;   self-cons'cy = 1.9960e-04  [4.1920e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9866035e+01;   self-cons'cy = 1.6547e-04  [2.7184e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322537e+01;   self-cons'cy = 6.6790e-05  [1.0792e-04 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964619e+02;   self-cons'cy = 9.8261e-06  [3.7197e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3206991e+01;   self-cons'cy = 1.7688e-05  [3.7197e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9864657e+01;   self-cons'cy = 1.3821e-05  [2.2704e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322040e+01;   self-cons'cy = 5.0425e-06  [8.1425e-06 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964666e+02;   self-cons'cy = 8.1786e-07  [3.1018e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3207148e+01;   self-cons'cy = 1.4740e-06  [3.1018e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9864767e+01;   self-cons'cy = 1.1029e-06  [1.8110e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322077e+01;   self-cons'cy = 3.7233e-07  [6.0063e-07 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964662e+02;   self-cons'cy = 6.5227e-08  [2.4779e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3207135e+01;   self-cons'cy = 1.1767e-07  [2.4779e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9864758e+01;   self-cons'cy = 8.5154e-08  [1.3973e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322074e+01;   self-cons'cy = 2.6978e-08  [4.3419e-08 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -8.651826697027728e+02    -2.354281960309631e+04    -2.354281960309631e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# DecayYield.computeOutcomes(): The computation of the fluorescence & Auger yields starts now ...
# -----------------------------------------------------------------------------------------------
#
#   Selected DecayYield levels:
#
#   -------------------------------------------
#      Level        J^P           Energy
#                                  [eV]
#   -------------------------------------------
#          1       1/2 +      -2.35428196e+04
#   -------------------------------------------
#
# Perform a cascade computation for all radiative decay channels of the levels from the initial configurations:
#
# * Initial levels of the given cascade, relative to the lowest, and their given occupation:
#
#   ----------------------------------------------------------------
#     Level  J Parity          Energy [eV]         rel. occupation
#   ----------------------------------------------------------------
#        1     1/2 +      0.000000000000000e+00           0.0
#   ----------------------------------------------------------------
#
#   Electron configuration used in the cascade:
#
#     Configuration(s) with 9 electrons:
#       1s^1 2s^2 2p^6    av. BE = -13121.0  [eV]      (1)
#       1s^2 2s^1 2p^6    av. BE = -19388.0  [eV]      (2)
#       1s^2 2s^2 2p^5    av. BE = -19513.0  [eV]      (3)
#
#   A total of 3 configuration have been defined for this cascade, and selected configurations could be removed here:  [currently not supported]
#
#
#   In the cascade approach JAC.Cascade.SCA(), the following assumptions/simplifications are made:
#     + orbitals are generated independently for each multiplet (block);
#     + configuration interaction is included for each block;
#     + only E1 dipole transitions are applied in all radiative decay stets;
#
#   Multiplet computations for 1s^1 2s^2 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^5  with 9 electrons ... and 2 CSF done.
#
# * Configuration 'blocks' (multiplets) in the given cascade model:
#
#   --------------------------------------------------------------------------------------------------------------------------------------
#       No.   Configurations                                                                             Range of total energies [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------
#         1   1s^1 2s^2 2p^6                                                                             -23543.0 ... -23543.0
#         2   1s^2 2s^1 2p^6                                                                             -29854.0 ... -29854.0
#         3   1s^2 2s^2 2p^5                                                                             -29989.0 ... -29976.0
#   --------------------------------------------------------------------------------------------------------------------------------------
#
# * Steps that are defined for the current cascade due to the given approach:
#
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    Step-No   Process     Initial:  No CSF, configuration(s)                         Final:  No CSF, configuration(s)                           Energies from ... to in [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        1     Radiative     1, 1s^1 2s^2 2p^6                                          1, 1s^2 2s^1 2p^6                                        6311.0 ... 6311.0
#        2     Radiative     1, 1s^1 2s^2 2p^6                                          2, 1s^2 2s^2 2p^5                                        6433.0 ... 6446.0
#        3     Radiative     1, 1s^2 2s^1 2p^6                                          2, 1s^2 2s^2 2p^5                                        122.0 ... 135.0
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#   Here, modify the individual steps explicitly in the code, if needed, ...... and just do it !!
#
#   A total of 3 steps are still defined in the cascade.
#
#   1) Perform Radiative amplitude computations for up to 1 lines (without selection rules):
#      Step 1:: A total of 0 Radiative lines are calculated, giving now rise to a total of 0 Radiative lines.
#
#   2) Perform Radiative amplitude computations for up to 2 lines (without selection rules):
#      Step 2:: A total of 2 Radiative lines are calculated, giving now rise to a total of 2 Radiative lines.
#
#   3) Perform Radiative amplitude computations for up to 2 lines (without selection rules):
#      Step 3:: A total of 2 Radiative lines are calculated, giving now rise to a total of 4 Radiative lines.
#
# Perform a cascade computation for all (single-electron) Auger decay channels of the levels from the initial configurations:
#
# * Initial levels of the given cascade, relative to the lowest, and their given occupation:
#
#   ----------------------------------------------------------------
#     Level  J Parity          Energy [eV]         rel. occupation
#   ----------------------------------------------------------------
#        1     1/2 +      0.000000000000000e+00           0.0
#   ----------------------------------------------------------------
#
#   Electron configuration used in the cascade:
#
#     Configuration(s) with 9 electrons:
#       1s^1 2s^2 2p^6    av. BE = -13121.0  [eV]      (1)
#       1s^2 2s^1 2p^6    av. BE = -19388.0  [eV]      (2)
#       1s^2 2s^2 2p^5    av. BE = -19513.0  [eV]      (3)
#
#     Configuration(s) with 8 electrons:
#       1s^2 2s^0 2p^6    av. BE = -18543.0  [eV]      (4)
#       1s^2 2s^1 2p^5    av. BE = -18668.0  [eV]      (5)
#       1s^2 2s^2 2p^4    av. BE = -18793.0  [eV]      (6)
#
#   A total of 6 configuration have been defined for this cascade, and selected configurations could be removed here:  [currently not supported]
#
#
#   In the cascade approach JAC.Cascade.SCA(), the following assumptions/simplifications are made:
#     + orbitals are generated independently for each multiplet (block);
#     + configuration interaction is included for each block;
#     + only E1 dipole transitions are applied in all radiative decay stets;
#
#   Multiplet computations for 1s^1 2s^2 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^5  with 9 electrons ... and 2 CSF done.
#   Multiplet computations for 1s^2 2s^0 2p^6  with 8 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^5  with 8 electrons ... and 4 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^4  with 8 electrons ... and 5 CSF done.
#
# * Configuration 'blocks' (multiplets) in the given cascade model:
#
#   --------------------------------------------------------------------------------------------------------------------------------------
#       No.   Configurations                                                                             Range of total energies [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------
#         1   1s^1 2s^2 2p^6                                                                             -23543.0 ... -23543.0
#         2   1s^2 2s^1 2p^6                                                                             -29854.0 ... -29854.0
#         3   1s^2 2s^2 2p^5                                                                             -29989.0 ... -29976.0
#         4   1s^2 2s^0 2p^6                                                                             -28368.0 ... -28368.0
#         5   1s^2 2s^1 2p^5                                                                             -28517.0 ... -28473.0
#         6   1s^2 2s^2 2p^4                                                                             -28633.0 ... -28589.0
#   --------------------------------------------------------------------------------------------------------------------------------------
#
# * Steps that are defined for the current cascade due to the given approach:
#
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    Step-No   Process     Initial:  No CSF, configuration(s)                         Final:  No CSF, configuration(s)                           Energies from ... to in [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        1     Auger         1, 1s^1 2s^2 2p^6                                          1, 1s^2 2s^0 2p^6                                        4825.0 ... 4825.0
#        2     Auger         1, 1s^1 2s^2 2p^6                                          4, 1s^2 2s^1 2p^5                                        4930.0 ... 4974.0
#        3     Auger         1, 1s^1 2s^2 2p^6                                          5, 1s^2 2s^2 2p^4                                        5046.0 ... 5090.0
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#   Here, modify the individual steps explicitly in the code, if needed, ...... and just do it !!
#
#   A total of 3 steps are still defined in the cascade.
#
#   1) Perform Auger amplitude computations for up to 1 lines (without selection rules):
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
#      Step 1:: A total of 1 Auger lines are calculated, giving now rise to a total of 1 Auger lines.
#
#   2) Perform Auger amplitude computations for up to 4 lines (without selection rules):
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
#      Step 2:: A total of 4 Auger lines are calculated, giving now rise to a total of 5 Auger lines.
#
#   3) Perform Auger amplitude computations for up to 5 lines (without selection rules):
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
#      Step 3:: A total of 5 Auger lines are calculated, giving now rise to a total of 10 Auger lines.
# ** compareKey = LevelKey[1/2 + (1), en=-865.1826697027728, occ=0.0]
# ** compareKey = LevelKey[1/2 + (1), en=-865.1826697027728, occ=0.0]
#
#   Fluorescence and Auger decay yields:
#
#     + No_R, rate_R, omega_R  ... number of fluorescence lines, total fluorescence rate and yield.
#     + No_A, rate_A, omega_A  ... number of Auger lines, total Auger rate and Auger yield.
#     + Approach:  SCA  ... all fluorescence rates and yields only in Babushkin gauge.
#
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#      Level        J^P           Energy          No_R    Cou -- rate_R  -- Bab    Cou -- omega_R -- Bab     No_A      rate_A      Cou -- omega_A -- Bab
#                                  [eV]
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#          1       1/2 +      -2.35428196e+04     0002    0.0000e+00 1.4823e-02    0.0000e+00 6.8045e-01     0010    6.9610e-03    1.0000e+00 3.1955e-01
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# From the output of these three computations, we see that the fluorescence yield $\omega_r$ increase from 8 % (Z=12) to 28 % (Z=18) and up to 40 % (Z=26).

# %% [markdown]
# We could consider also the yields for the $2s$ hole state of argon which is known to decay by fast Coster-Kronig transitions. Because of the (very) low energies of the emitted Coster-Kronig electrons, these computations require further care in order to obtain reliable estimate. Since all these yield computations are always based on (elaborate) *cascade computations*, further improvements are possible but will require advice and support by the community.
