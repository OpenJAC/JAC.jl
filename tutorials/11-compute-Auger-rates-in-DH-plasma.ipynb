# %% [markdown]
# # Compute K-LL Auger rates for neon-like iron in a Debye-Hückel potential

# %%
using JAC

# %% [markdown]
# A plasma environment generally affects both, the level structure of atoms and ions as well their rates and cross sections. In this tutorial, we wish to compute the K-LL rates for neon-like iron in a Debye-Hückel potential following the work by Deprince *et al* (2019).
#
# A Debye-Hückel potential may affect the Auger rates of an atom or ion in three different ways: (i) the level structure due to the screened electron-nucleus and electron-electron interaction; (ii) the shape of the potential, seen by the emitted electrons, due to the plasma screening of the ionic core; as well as (iii) the screening of the electron-electron interaction within the Auger matrix. In the present implementation, only the (screened) Coulomb interaction can be taken into account for the computation of the plasma-modified Auger rates, i.e. **no** Breit interactions nor QED estimates are supported by the JAC program.
#
# As with most other (atomic) processes, the compuation of plasma-modified Auger is supported in JAC by a special process identifier `AugerInPlasma` and the corresponding settings `PlasmaShift.AugerSettings`. These settings can be used to define the screening parameter $\lambda$.

# %% [markdown]
# Let us start again from the `PlasmaShift.AugerSettings` to understand what and how we can control the computations:

# %%
? PlasmaShift.AugerSettings
# Out:
#   struct  PlasmaShift.AugerSettings ... defines a type for the details and
#   parameters of computing Auger rates with plasma interactions.
#
#   + plasmaModel            ::AbstractPlasmaModel           ... Specify a particular plasma model, e.g. ion-sphere, debye.
#   + lambdaDebye            ::Float64                       ... The lambda parameter of different plasma models.
#   + ionSphereR0            ::Float64                       ... The effective radius of the ion-sphere model.
#   + NoBoundElectrons       ::Int64                         ... Effective number of bound electrons.
#   + printBefore ::Bool                          ... True, if all energies and lines are printed before their evaluation.
#   + selectLines            ::Bool                          ... True, if lines are selected individually for the computations.
#   + selectedLines          ::Array{Tuple{Int64,Int64},1}   ... List of lines, given by tupels (inital-level, final-level).
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   PlasmaShift.AugerSettings() ... constructor for a standard instance of
#   PlasmaShift.AugerSettings.

# %%
PlasmaShift.AugerSettings()   # show the default values
# Out:
# plasmaModel:             Debye-Hueckel model
# lambdaDebye:             0.25
# ionSphereR0:             0.0
# NoBoundElectrons:        0
# printBefore:  true
# selectLines:             false
# selectedLines:           Tuple{Int64,Int64}[]

# %% [markdown]
# We can re-define these settings by specifying the screening parameter and the selected lines to be
# calculated:

# %%
pSettings = PlasmaShift.AugerSettings(PlasmaShift.DebyeHueckel(), 0.1, 0., 0, true, true, [(1,1), (1,2)])
# Out:
# plasmaModel:             Debye-Hueckel model
# lambdaDebye:             0.1
# ionSphereR0:             0.0
# NoBoundElectrons:        0
# printBefore:  true
# selectLines:             true
# selectedLines:           Tuple{Int64,Int64}[(1, 1), (1, 2)]

# %% [markdown]
# As usual, we can now defined and run the desired computation by *defining* and *performing* an
# `Atomic.Computation()`:

# %%
grid = Radial.Grid(Radial.Grid(true), rnt = 2.0e-5, h = 5.0e-2, hp = 1.3e-2, NoPoints = 600)
wa   = Atomic.Computation(Atomic.Computation(), name="K-LL Auger spectrum in a Debye-Hueckel potential",  
              grid=grid, nuclearModel=Nuclear.Model(26.), 
              initialConfigs=[Configuration("1s 2s^2 2p^6")],
              finalConfigs  =[Configuration("1s^2 2s^2 2p^4"), Configuration("1s^2 2s 2p^5"), 
                              Configuration("1s^2 2p^6")], process = JAC.AugerInPlasma, processSettings = pSettings)
perform(wa)
# Out:
# aa: AugerInPlasma   plasmaModel:             Debye-Hueckel model
# lambdaDebye:             0.1
# ionSphereR0:             0.0
# NoBoundElectrons:        0
# printBefore:  true
# selectLines:             true
# selectedLines:           Tuple{Int64,Int64}[(1, 1), (1, 2)]
#
#
# ... in performSCF ...
# >> include Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 26.0 with mass = 55.38, radius R = 3.756573410087755 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -3.41095880e+02    -3.41097837e+02    +5.73779935e-06
#       2      2s_1/2      -8.54687058e+01    -8.54689584e+01    +2.95488326e-06
#       3      3s_1/2      -3.78993728e+01    -3.78994478e+01    +1.97799614e-06
#       4      4s_1/2      -2.12819069e+01    -2.12819385e+01    +1.48493324e-06
#       5      5s_1/2      -1.36039551e+01    -1.36039714e+01    +1.19928767e-06
#       6      6s_1/2      -9.43827711e+00    -9.43887322e+00    +6.31585275e-05
#       7      7s_1/2      -6.86074034e+00    -6.93005925e+00    +1.01037062e-02
#       8      8s_1/2      -4.54762624e+00    -5.30306679e+00    +1.66117555e-01
#       :       :
#      81     81s_1/2      +8.11833866e+06    -5.15394375e-02    +1.00000001e+00
#      82     82s_1/2      +1.24394087e+07    -5.02897729e-02    +1.00000000e+00
#      83     83s_1/2      +1.98408719e+07    -4.90850138e-02    +1.00000000e+00
#      84     84s_1/2      +3.40702958e+07    -4.79230342e-02    +1.00000000e+00
#      85     85s_1/2      +6.85540679e+07    -4.68018324e-02    +1.00000000e+00
#      86     86s_1/2      +2.34855364e+08    -4.57195223e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -8.54689566e+01    -8.54689584e+01    +2.03867984e-08
#       2      3p_1/2      -3.78994472e+01    -3.78994478e+01    +1.61656652e-08
#       3      4p_1/2      -2.12819382e+01    -2.12819385e+01    +1.27950699e-08
#       4      5p_1/2      -1.36039711e+01    -1.36039714e+01    +1.86090378e-08
#       5      6p_1/2      -9.43839681e+00    -9.43887322e+00    +5.04756713e-05
#       6      7p_1/2      -6.86872594e+00    -6.93005925e+00    +8.92935756e-03
#       7      8p_1/2      -4.59807887e+00    -5.30306679e+00    +1.53322276e-01
#       8      9p_1/2      -1.73179950e+00    -4.18833237e+00    +1.41848572e+00
#       :       :
#      80     81p_1/2      +6.73085891e+06    -5.15394375e-02    +1.00000001e+00
#      81     82p_1/2      +1.01849611e+07    -5.02897729e-02    +1.00000000e+00
#      82     83p_1/2      +1.59147128e+07    -4.90850138e-02    +1.00000000e+00
#      83     84p_1/2      +2.62771111e+07    -4.79230342e-02    +1.00000000e+00
#      84     85p_1/2      +4.83723667e+07    -4.68018324e-02    +1.00000000e+00
#      85     86p_1/2      +1.15801133e+08    -4.57195223e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -8.46909743e+01    -8.46909743e+01    +2.20820282e-13
#       2      3p_3/2      -3.76687634e+01    -3.76687634e+01    +2.65778493e-13
#       3      4p_3/2      -2.11846929e+01    -2.11846929e+01    +4.78956683e-13
#       4      5p_3/2      -1.35542225e+01    -1.35542226e+01    +8.96898213e-09
#       5      6p_3/2      -9.40959864e+00    -9.41010352e+00    +5.36560869e-05
#       6      7p_3/2      -6.84869826e+00    -6.91195226e+00    +9.23591574e-03
#       7      8p_3/2      -4.57523921e+00    -5.29094223e+00    +1.56429638e-01
#       8      9p_3/2      -1.70268596e+00    -4.17982022e+00    +1.45483918e+00
#       :       :
#      81     82p_3/2      +9.67065945e+06    -5.02785564e-02    +1.00000001e+00
#      82     83p_3/2      +1.49904603e+07    -4.90741979e-02    +1.00000000e+00
#      83     84p_3/2      +2.44130013e+07    -4.79126000e-02    +1.00000000e+00
#      84     85p_3/2      +4.36680562e+07    -4.67917622e-02    +1.00000000e+00
#      85     86p_3/2      +9.61223650e+07    -4.57097995e-02    +1.00000000e+00
#      86     87p_3/2      +3.73069802e+08    -4.46649346e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# (Re-) Define the standard grid with 600 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8438118e+02;   self-cons'cy = 9.0674e-02  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.1573110e+01;   self-cons'cy = 2.4734e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.8296776e+01;   self-cons'cy = 2.7789e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.8395506e+01;   self-cons'cy = 2.7272e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.9025088e+02;   self-cons'cy = 1.0215e-02  [1.1996e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3407305e+01;   self-cons'cy = 1.7472e-02  [1.1996e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -5.0035914e+01;   self-cons'cy = 1.7686e-02  [7.9648e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9402033e+01;   self-cons'cy = 1.0292e-02  [4.3995e-02 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8958783e+02;   self-cons'cy = 1.1435e-03  [1.5368e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3188385e+01;   self-cons'cy = 2.0537e-03  [1.5368e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9850338e+01;   self-cons'cy = 1.8579e-03  [9.1270e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9316747e+01;   self-cons'cy = 8.6393e-04  [3.9816e-03 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8965219e+02;   self-cons'cy = 1.1111e-04  [1.4775e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3209615e+01;   self-cons'cy = 1.9954e-04  [1.4775e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9866833e+01;   self-cons'cy = 1.6542e-04  [8.0432e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9323334e+01;   self-cons'cy = 6.6773e-05  [3.0537e-04 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964650e+02;   self-cons'cy = 9.8223e-06  [1.3122e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3207733e+01;   self-cons'cy = 1.7681e-05  [1.3122e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9865455e+01;   self-cons'cy = 1.3815e-05  [6.7206e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322836e+01;   self-cons'cy = 5.0407e-06  [2.3042e-05 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964698e+02;   self-cons'cy = 8.1747e-07  [1.0941e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3207890e+01;   self-cons'cy = 1.4733e-06  [1.0941e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9865565e+01;   self-cons'cy = 1.1024e-06  [5.3599e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322873e+01;   self-cons'cy = 3.7218e-07  [1.6996e-06 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964694e+02;   self-cons'cy = 6.5190e-08  [8.7377e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3207878e+01;   self-cons'cy = 1.1760e-07  [8.7377e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9865557e+01;   self-cons'cy = 8.5104e-08  [4.1367e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322870e+01;   self-cons'cy = 2.6964e-08  [1.2303e-07 for sym-block kappa = -2]
# Compute DebyeHueckel-CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -8.455722665115613e+02    -2.300919335185241e+04    -2.300919335185241e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# ... in performSCF ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^0 2p_3/2^4
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^1 2p_3/2^3
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^2
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^1 2p_3/2^4
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^2 2p_3/2^3
# >> include Configuration: 1s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 26.0 with mass = 55.38, radius R = 3.756573410087755 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -3.41095880e+02    -3.41097837e+02    +5.73779935e-06
#       2      2s_1/2      -8.54687058e+01    -8.54689584e+01    +2.95488326e-06
#       3      3s_1/2      -3.78993728e+01    -3.78994478e+01    +1.97799614e-06
#       4      4s_1/2      -2.12819069e+01    -2.12819385e+01    +1.48493324e-06
#       5      5s_1/2      -1.36039551e+01    -1.36039714e+01    +1.19928767e-06
#       6      6s_1/2      -9.43827711e+00    -9.43887322e+00    +6.31585275e-05
#       7      7s_1/2      -6.86074034e+00    -6.93005925e+00    +1.01037062e-02
#       8      8s_1/2      -4.54762624e+00    -5.30306679e+00    +1.66117555e-01
#       :       :
#      81     81s_1/2      +8.11833866e+06    -5.15394375e-02    +1.00000001e+00
#      82     82s_1/2      +1.24394087e+07    -5.02897729e-02    +1.00000000e+00
#      83     83s_1/2      +1.98408719e+07    -4.90850138e-02    +1.00000000e+00
#      84     84s_1/2      +3.40702958e+07    -4.79230342e-02    +1.00000000e+00
#      85     85s_1/2      +6.85540679e+07    -4.68018324e-02    +1.00000000e+00
#      86     86s_1/2      +2.34855364e+08    -4.57195223e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -8.54689566e+01    -8.54689584e+01    +2.03867984e-08
#       2      3p_1/2      -3.78994472e+01    -3.78994478e+01    +1.61656652e-08
#       3      4p_1/2      -2.12819382e+01    -2.12819385e+01    +1.27950699e-08
#       4      5p_1/2      -1.36039711e+01    -1.36039714e+01    +1.86090378e-08
#       5      6p_1/2      -9.43839681e+00    -9.43887322e+00    +5.04756713e-05
#       6      7p_1/2      -6.86872594e+00    -6.93005925e+00    +8.92935756e-03
#       7      8p_1/2      -4.59807887e+00    -5.30306679e+00    +1.53322276e-01
#       8      9p_1/2      -1.73179950e+00    -4.18833237e+00    +1.41848572e+00
#       :       :
#      80     81p_1/2      +6.73085891e+06    -5.15394375e-02    +1.00000001e+00
#      81     82p_1/2      +1.01849611e+07    -5.02897729e-02    +1.00000000e+00
#      82     83p_1/2      +1.59147128e+07    -4.90850138e-02    +1.00000000e+00
#      83     84p_1/2      +2.62771111e+07    -4.79230342e-02    +1.00000000e+00
#      84     85p_1/2      +4.83723667e+07    -4.68018324e-02    +1.00000000e+00
#      85     86p_1/2      +1.15801133e+08    -4.57195223e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -8.46909743e+01    -8.46909743e+01    +2.20820282e-13
#       2      3p_3/2      -3.76687634e+01    -3.76687634e+01    +2.65778493e-13
#       3      4p_3/2      -2.11846929e+01    -2.11846929e+01    +4.78956683e-13
#       4      5p_3/2      -1.35542225e+01    -1.35542226e+01    +8.96898213e-09
#       5      6p_3/2      -9.40959864e+00    -9.41010352e+00    +5.36560869e-05
#       6      7p_3/2      -6.84869826e+00    -6.91195226e+00    +9.23591574e-03
#       7      8p_3/2      -4.57523921e+00    -5.29094223e+00    +1.56429638e-01
#       8      9p_3/2      -1.70268596e+00    -4.17982022e+00    +1.45483918e+00
#       :       :
#      81     82p_3/2      +9.67065945e+06    -5.02785564e-02    +1.00000001e+00
#      82     83p_3/2      +1.49904603e+07    -4.90741979e-02    +1.00000000e+00
#      83     84p_3/2      +2.44130013e+07    -4.79126000e-02    +1.00000000e+00
#      84     85p_3/2      +4.36680562e+07    -4.67917622e-02    +1.00000000e+00
#      85     86p_3/2      +9.61223650e+07    -4.57097995e-02    +1.00000000e+00
#      86     87p_3/2      +3.73069802e+08    -4.46649346e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# (Re-) Define the standard grid with 600 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8171032e+02;   self-cons'cy = 9.5352e-02  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.4263186e+01;   self-cons'cy = 2.2332e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -5.0970415e+01;   self-cons'cy = 2.5285e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -5.0960454e+01;   self-cons'cy = 2.4866e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8652171e+02;   self-cons'cy = 8.4673e-03  [1.1734e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.5679853e+01;   self-cons'cy = 1.2885e-02  [1.1734e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -5.2283326e+01;   self-cons'cy = 1.2715e-02  [1.3968e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -5.1716536e+01;   self-cons'cy = 7.3637e-03  [8.8620e-02 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8612128e+02;   self-cons'cy = 6.9928e-04  [8.9802e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.5556152e+01;   self-cons'cy = 1.1121e-03  [8.9802e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -5.2182633e+01;   self-cons'cy = 9.6388e-04  [9.5768e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -5.1670977e+01;   self-cons'cy = 4.4066e-04  [5.1059e-03 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8614988e+02;   self-cons'cy = 4.9986e-05  [6.4554e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.5564920e+01;   self-cons'cy = 7.8909e-05  [6.4554e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -5.2189065e+01;   self-cons'cy = 6.1627e-05  [6.1703e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -5.1673476e+01;   self-cons'cy = 2.4181e-05  [2.8072e-04 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8614803e+02;   self-cons'cy = 3.2419e-06  [4.1588e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.5564356e+01;   self-cons'cy = 5.0766e-06  [4.1588e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -5.2188682e+01;   self-cons'cy = 3.6778e-06  [3.6788e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -5.1673343e+01;   self-cons'cy = 1.2905e-06  [1.4961e-05 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8614814e+02;   self-cons'cy = 1.9700e-07  [2.5126e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.5564390e+01;   self-cons'cy = 3.0625e-07  [2.5126e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -5.2188703e+01;   self-cons'cy = 2.0918e-07  [2.0915e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -5.1673350e+01;   self-cons'cy = 6.7128e-08  [7.7723e-07 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8614813e+02;   self-cons'cy = 1.1412e-08  [1.4484e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.5564388e+01;   self-cons'cy = 1.7633e-08  [1.4484e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -5.2188702e+01;   self-cons'cy = 1.1473e-08  [1.1467e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -5.1673350e+01;   self-cons'cy = 3.4097e-09  [3.9414e-08 for sym-block kappa = -2]
# Compute DebyeHueckel-CI matrix of dimension 3 x 3 for the symmetry 0^+ ...   ... done.
# Compute DebyeHueckel-CI matrix of dimension 1 x 1 for the symmetry 0^- ...   ... done.
# Compute DebyeHueckel-CI matrix of dimension 1 x 1 for the symmetry 1^+ ...   ... done.
# Compute DebyeHueckel-CI matrix of dimension 2 x 2 for the symmetry 1^- ...   ... done.
# Compute DebyeHueckel-CI matrix of dimension 1 x 1 for the symmetry 2^- ...   ... done.
# Compute DebyeHueckel-CI matrix of dimension 2 x 2 for the symmetry 2^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    2 +     -1.034392326498369e+03    -2.814724889247300e+04    -2.814724889247300e+04
#      2    0 +     -1.034057071210114e+03    -2.813812613140903e+04    -2.813812613140903e+04
#      3    1 +     -1.033980760035135e+03    -2.813604959856905e+04    -2.813604959856905e+04
#      4    2 +     -1.033603471745753e+03    -2.812578306128586e+04    -2.812578306128586e+04
#      5    0 +     -1.032918098981672e+03    -2.810713311843485e+04    -2.810713311843485e+04
#      6    2 -     -1.030139748316118e+03    -2.803153034597552e+04    -2.803153034597552e+04
#      7    1 -     -1.029850990690903e+03    -2.802367285076960e+04    -2.802367285076960e+04
#      8    0 -     -1.029644354314977e+03    -2.801804998857850e+04    -2.801804998857850e+04
#      9    1 -     -1.028509139260793e+03    -2.798715921352337e+04    -2.798715921352337e+04
#     10    0 +     -1.024462321397342e+03    -2.787703969048838e+04    -2.787703969048838e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    0 +     3.352552882556665e-01    9.122761063971314e+00    9.122761063971314e+00
#      3    1 +     7.631117497862761e-02    2.076532839983201e+00    2.076532839983201e+00
#      4    2 +     3.772882893815677e-01    1.026653728318730e+01    1.026653728318730e+01
#      5    0 +     6.853727640811940e-01    1.864994285100776e+01    1.864994285100776e+01
#      6    2 -     2.778350665554626e+00    7.560277245933085e+01    7.560277245933085e+01
#      7    1 -     2.887576252142026e-01    7.857495205922151e+00    7.857495205922151e+00
#      8    0 -     2.066363759263368e-01    5.622862191105384e+00    5.622862191105384e+00
#      9    1 -     1.135215054184300e+00    3.089077505512421e+01    3.089077505512421e+01
#     10    0 +     4.046817863450769e+00    1.101195230349905e+02    1.101195230349905e+02
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    0 +     3.352552882556665e-01    9.122761063971314e+00    9.122761063971314e+00
#      3    1 +     4.115664632342941e-01    1.119929390395452e+01    1.119929390395452e+01
#      4    2 +     7.888547526158618e-01    2.146583118714182e+01    2.146583118714182e+01
#      5    0 +     1.474227516697056e+00    4.011577403814958e+01    4.011577403814958e+01
#      6    2 -     4.252578182251682e+00    1.157185464974804e+02    1.157185464974804e+02
#      7    1 -     4.541335807465884e+00    1.235760417034026e+02    1.235760417034026e+02
#      8    0 -     4.747972183392221e+00    1.291989038945080e+02    1.291989038945080e+02
#      9    1 -     5.883187237576522e+00    1.600896789496322e+02    1.600896789496322e+02
#     10    0 +     9.930005101027291e+00    2.702092019846227e+02    2.702092019846227e+02
#
# AutoIonization.computeLinesPlasma(): The computation of Auger rates starts now ...
# ----------------------------------------------------------------------------------
#
#
#   Selected Auger lines:
#
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#        i-level-f           i--J^P--f            Energy          Energy e_A      List of kappas and total symmetries
#                                                  [eV]              [eV]         partial (total J^P)
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#          1 --    1       1/2 + --> 2 +      -2.30091934e+04    5.13805554e+03   d_5/2 (1/2 +),  d_3/2 (1/2 +)
#          1 --    2       1/2 + --> 0 +      -2.30091934e+04    5.12893278e+03   s_1/2 (1/2 +)
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# > Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# ┌ Warning: Adapt a proper continuum orbital for the plasma potential
# └ @ JAC.AutoIonization /home/fritzsch/fri/JAC.jl/src/module-AutoIonization.jl:270
# > Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# ┌ Warning: Adapt a proper Auger amplitude for the plasma e-e interaction
# └ @ JAC.AutoIonization /home/fritzsch/fri/JAC.jl/src/module-AutoIonization.jl:274
# ┌ Warning: Adapt a proper continuum orbital for the plasma potential
# └ @ JAC.AutoIonization /home/fritzsch/fri/JAC.jl/src/module-AutoIonization.jl:270
# ┌ Warning: Adapt a proper Auger amplitude for the plasma e-e interaction
# └ @ JAC.AutoIonization /home/fritzsch/fri/JAC.jl/src/module-AutoIonization.jl:274
# ┌ Warning: Adapt a proper continuum orbital for the plasma potential
# └ @ JAC.AutoIonization /home/fritzsch/fri/JAC.jl/src/module-AutoIonization.jl:270
# > Radial potential with effective charge Zbar=1.8000e+01 (Delta-Zbar=0.0000e+00).
# ┌ Warning: Adapt a proper Auger amplitude for the plasma e-e interaction
# └ @ JAC.AutoIonization /home/fritzsch/fri/JAC.jl/src/module-AutoIonization.jl:274
#
#   Auger rates (without angular parameters):
#
#   -------------------------------------------------------------------------------------------------------------------
#        i-level-f           i--J^P--f            Energy         Electron energy     Auger rate          alpha_2
#                                                  [eV]               [eV]              [1/s]
#   -------------------------------------------------------------------------------------------------------------------
#          1 --    1       1/2 + --> 2 +      -2.30091934e+04    5.13805554e+03    5.19511019e+17      0.00000e+00
#          1 --    2       1/2 + --> 0 +      -2.30091934e+04    5.12893278e+03    2.59755509e+17      0.00000e+00
#   -------------------------------------------------------------------------------------------------------------------
#
#   Auger lifetimes, total rates and widths:
#
#   -------------------------------------------------------------------------------------------------------------------
#      Level       J^P         Lifetime          Total rate                              Widths
#                                [sec]              [1/s]             Hartrees           Kaysers             eV
#   -------------------------------------------------------------------------------------------------------------------
#          1      1/2 +     1.28325795e-18     7.79266528e+17      1.88495559e+01    4.13699932e+06    5.12922542e+02
#   -------------------------------------------------------------------------------------------------------------------
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# Similar computation will be made available also for photoionization cross sections in the near future.
