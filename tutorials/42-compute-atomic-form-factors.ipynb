# %% [markdown]
# # Atomic form factors for chlorine-like iron ions

# %%
using JAC

# %% [markdown]
# In atomic physics, the **form factors** are generally taken as fast approximation to the (scattering) amplitude in forward direction at $\vartheta \approx 0$, if an incident quantum wave is scattered by an isolated atom with spherical-symmetric charge distribution. The form factor definition therefore depends on the particular type of incident radiation, such a photons, electrons or neutrons. Here, *as usual*, we restrict ourselves to the atomic **form factor for the elastic (x-ray) scattering of photons**.
#
# In JAC, the standard and modified form factors are calculated and tabulated by default for all selected levels of a given multiplet and for a list of pre-specified $q$-values (a.u.). Here, we shall compute these form factors as (one) selected atomic property for all levels of the [Ne] $3s^2 3p^5$ ground configuration of chlorine-like Fe and Kr ions. For this, we can perform again an `Atomic.Computation(...,  properties=[FormF, ..], configs=[..], formSettings=FormFactor.Settings(..), ..)`.
#
# Let us first consider the internal definition and the default settings of `FormFactor.Settings(..)`

# %%
? FormFactor.Settings
# Out:
#   struct  FormFactor.Settings ... defines a type for the details and
#   parameters of computing alpha-variation parameters.
#
#   + qList                    ::Array{Float64,1} ... List of q-values in [a.u.]
#   + printBefore   ::Bool             ... True if a list of selected levels is printed before the actual computations start.
#   + selectLevels             ::Bool             ... True if individual levels are selected for the computation.
#   + selectedLevels           ::Array{Level,1}   ... List of selected levels.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   FormFactor.Settings() ... constructor for an empty instance of
#   FormFactor.Settings for the computation of atomic form factors.

# %%
FormFactor.Settings()
# Out:
# qList:                    [0.0, 0.1, 1.0, 10.0]
# printBefore:   false
# selectLevels:             false
# selectedLevels:           Level[]

# %% [markdown]
# We wish to calculate form factor for three values of the momentum transfer $q = [0., 0.1, 1.0]$ and request the printout of a short overwiew table already before the form factor computations start. These settings and the (atomic) computation are then realized by simply calling:

# %%
fSettings = FormFactor.Settings([0., 0.1, 1.0], true, false, Int64[])
wa = Atomic.Computation(Atomic.Computation(), name="Form factors for chlorine-like Fe", grid=Radial.Grid(true), 
            nuclearModel=Nuclear.Model(26.), properties=[JAC.FormF], configs=[Configuration("[Ne] 3s^2 3p^5")],
            formSettings=fSettings )
perform(wa)
# Out:
# ... in performSCF ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^1 3p_3/2^4
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^2 3p_3/2^3
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 26.0 with mass = 55.38, radius R = 3.756573410087755 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -3.41095882e+02    -3.41097837e+02    +5.73282564e-06
#       2      2s_1/2      -8.54687335e+01    -8.54689584e+01    +2.63136790e-06
#       3      3s_1/2      -3.78995149e+01    -3.78994478e+01    -1.77114873e-06
#       4      4s_1/2      -2.12860100e+01    -2.12819385e+01    -1.91276379e-04
#       5      5s_1/2      -1.36596695e+01    -1.36039714e+01    -4.07755799e-03
#       6      6s_1/2      -1.02229687e+01    -9.43887322e+00    -7.66993935e-02
#       7      7s_1/2      -8.70989688e+00    -6.93005925e+00    -2.04346579e-01
#       8      8s_1/2      -6.39168168e+00    -5.30306679e+00    -1.70317444e-01
#       :       :
#      57     57s_1/2      +8.42794522e+07    -1.04097479e-01    +1.00000000e+00
#      58     58s_1/2      +1.28010239e+08    -1.00537779e-01    +1.00000000e+00
#      59     59s_1/2      +2.02324641e+08    -9.71575946e-02    +1.00000000e+00
#      60     60s_1/2      +3.44744353e+08    -9.39450561e-02    +1.00000000e+00
#      61     61s_1/2      +6.89589055e+08    -9.08892574e-02    +1.00000000e+00
#      62     62s_1/2      +2.35235601e+09    -8.79801654e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 3s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      
 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -8.4715129e+00;   self-cons'cy = 6.3279e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6707341e+02;   self-cons'cy = 3.2362e-02  [1.0528e+00 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.9371660e+01;   self-cons'cy = 1.0941e-01  [1.0528e+00 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0793953e+01;   self-cons'cy = 1.0985e-01  [1.0528e+00 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4836918e+01;   self-cons'cy = 9.4059e-02  [2.8686e-01 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.3697352e+00;   self-cons'cy = 8.1151e-02  [2.8686e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3849662e+01;   self-cons'cy = 4.6678e-02  [1.5009e+00 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.1350035e+00;   self-cons'cy = 3.7684e-02  [1.5009e+00 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6419082e+02;   self-cons'cy = 5.4259e-03  [1.6221e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.7926770e+01;   self-cons'cy = 1.8692e-02  [1.6221e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0323567e+01;   self-cons'cy = 2.2275e-02  [1.6221e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.3919036e+01;   self-cons'cy = 1.3350e-02  [6.6332e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1050511e+00;   self-cons'cy = 1.4327e-02  [6.6332e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3534103e+01;   self-cons'cy = 4.6830e-03  [1.0950e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0493502e+00;   self-cons'cy = 4.7103e-03  [1.0950e-01 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6459146e+02;   self-cons'cy = 7.5766e-04  [5.1247e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8128696e+01;   self-cons'cy = 2.6550e-03  [5.1247e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0388443e+01;   self-cons'cy = 3.1323e-03  [5.1247e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4026174e+01;   self-cons'cy = 1.5768e-03  [7.2852e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1354493e+00;   self-cons'cy = 1.6665e-03  [7.2852e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3558830e+01;   self-cons'cy = 3.6854e-04  [8.5537e-03 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0556938e+00;   self-cons'cy = 3.5038e-04  [8.5537e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454326e+02;   self-cons'cy = 9.1091e-05  [4.5901e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8104200e+01;   self-cons'cy = 3.2133e-04  [4.5901e-03 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0380471e+01;   self-cons'cy = 3.8386e-04  [4.5901e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4015393e+01;   self-cons'cy = 1.5845e-04  [7.4047e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1323806e+00;   self-cons'cy = 1.6799e-04  [7.4047e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557636e+01;   self-cons'cy = 1.7789e-05  [3.6951e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554415e+00;   self-cons'cy = 1.3928e-05  [3.6951e-04 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454829e+02;   self-cons'cy = 9.5013e-06  [4.4066e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106763e+01;   self-cons'cy = 3.3629e-05  [4.4066e-04 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381308e+01;   self-cons'cy = 4.0331e-05  [4.4066e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016274e+01;   self-cons'cy = 1.2955e-05  [5.9874e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326289e+00;   self-cons'cy = 1.3596e-05  [5.9874e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557572e+01;   self-cons'cy = 9.5793e-07  [3.5611e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554126e+00;   self-cons'cy = 1.6003e-06  [3.5611e-05 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454785e+02;   self-cons'cy = 8.3301e-07  [3.9018e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106538e+01;   self-cons'cy = 2.9547e-06  [3.9018e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381234e+01;   self-cons'cy = 3.5593e-06  [3.9018e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016227e+01;   self-cons'cy = 6.8787e-07  [3.0611e-06 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326162e+00;   self-cons'cy = 6.9495e-07  [3.0611e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557600e+01;   self-cons'cy = 4.2365e-07  [1.2126e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554218e+00;   self-cons'cy = 5.1114e-07  [1.2126e-05 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454787e+02;   self-cons'cy = 5.3666e-08  [2.4995e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106553e+01;   self-cons'cy = 1.9083e-07  [2.4995e-06 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381239e+01;   self-cons'cy = 2.3170e-07  [2.4995e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016226e+01;   self-cons'cy = 2.0906e-08  [1.2296e-07 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326157e+00;   self-cons'cy = 2.7928e-08  [1.2296e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557595e+01;   self-cons'cy = 7.5969e-08  [2.0749e-06 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554203e+00;   self-cons'cy = 8.6197e-08  [2.0749e-06 for sym-block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454787e+02;   self-cons'cy = 6.6423e-10  [2.7978e-08 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106553e+01;   self-cons'cy = 2.4307e-09  [2.7978e-08 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381239e+01;   self-cons'cy = 3.2875e-09  [2.7978e-08 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016227e+01;   self-cons'cy = 1.3055e-08  [6.4412e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326160e+00;   self-cons'cy = 1.4627e-08  [6.4412e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557596e+01;   self-cons'cy = 1.0443e-08  [2.7843e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554205e+00;   self-cons'cy = 1.1471e-08  [2.7843e-07 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 3/2^- ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    3/2 -     -1.242746372724362e+03    -3.381685127315740e+04    -3.381685127315740e+04
#      2    1/2 -     -1.242672314265846e+03    -3.381483603985468e+04    -3.381483603985468e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     7.405845851599224e-02    2.015233302724821e+00    2.015233302724821e+00
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     7.405845851599224e-02    2.015233302724821e+00    2.015233302724821e+00
#
# FormFactor.computeOutcomes(): The computation of the atomic form factors starts now ...
# -------------------------------------------------------------------------------------------
#
#   Selected FormFactor levels:
#
#   --------------------------------------------------------------------------------------
#      Level        J^P           Energy          q-values  ...
#                                  [eV]            [a.u.]
#   --------------------------------------------------------------------------------------
#          1       3/2 -      -3.38168513e+04    0.00e+00,  1.00e-01,  1.00e+00,
#          2       1/2 -      -3.38148360e+04    0.00e+00,  1.00e-01,  1.00e+00,
#   --------------------------------------------------------------------------------------
#
#   Standard and modified atomic form factors [note F^(standard) (0) = N_e]:
#
#   ----------------------------------------------------------------------------------------
#      Level        J^P           Energy          q [a.u.]      standard F     modified F
#                                  [eV]
#   ----------------------------------------------------------------------------------------
#          1       3/2 -      -3.38168513e+04    0.00000e+00    1.70000e+01    1.69910e+01
#                                                1.00000e-01    1.69916e+01    1.69827e+01
#                                                1.00000e+00    1.61993e+01    1.61900e+01
#          2       1/2 -      -3.38148360e+04    0.00000e+00    1.70000e+01    1.69910e+01
#                                                1.00000e-01    1.69916e+01    1.69826e+01
#                                                1.00000e+00    1.61978e+01    1.61885e+01
#   ----------------------------------------------------------------------------------------
#
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# Here, all the requested form factors are simply compiled in the last table; of course, we can easily repeat these computations also for chlorine-like Kr:

# %%
wa = Atomic.Computation(wa, name="Form factors for chlorine-like Kr", nuclearModel=Nuclear.Model(36.))
perform(wa)
# Out:
# ... in performSCF ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^1 3p_3/2^4
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^2 3p_3/2^3
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 36.0 with mass = 78.48, radius R = 4.149254741065642 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      
-01    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# >> Use hydrogenic orbital from this symmetry block also for 3p_3/2.
# (Re-) Define the standard grid with 390 grid points.
# >>  for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.3241361e+02;   self-cons'cy = 1.0668e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -8.8999823e+01;   self-cons'cy = 3.0093e-01  [1.0000e+02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.0303468e+01;   self-cons'cy = 4.1492e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3710037e+01;   self-cons'cy = 3.2854e-01  [1.0000e+02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -2.8592438e+01;   self-cons'cy = 4.3869e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.4104579e+01;   self-cons'cy = 3.1847e-01  [1.0000e+02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.8846485e+01;   self-cons'cy = 4.3028e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4844804e+02;   self-cons'cy = 1.4835e-02  [2.0495e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.6433002e+01;   self-cons'cy = 4.0086e-02  [2.0495e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2568803e+01;   self-cons'cy = 3.6031e-02  [2.0495e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9823222e+01;   self-cons'cy = 3.5228e-02  [8.5675e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0287116e+01;   self-cons'cy = 2.8782e-02  [8.5675e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7508253e+01;   self-cons'cy = 1.9833e-02  [1.1138e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9769499e+01;   self-cons'cy = 1.5747e-02  [1.1138e-01 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4662615e+02;   self-cons'cy = 1.6637e-03  [2.8947e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5563961e+01;   self-cons'cy = 4.5263e-03  [2.8947e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2284390e+01;   self-cons'cy = 4.3855e-03  [2.8947e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9216858e+01;   self-cons'cy = 3.3867e-03  [9.6174e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0105160e+01;   self-cons'cy = 3.0129e-03  [9.6174e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7250056e+01;   self-cons'cy = 1.4775e-03  [1.0256e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9693835e+01;   self-cons'cy = 1.2724e-03  [1.0256e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4679875e+02;   self-cons'cy = 1.5785e-04  [2.6857e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5646165e+01;   self-cons'cy = 4.2991e-04  [2.6857e-03 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2311242e+01;   self-cons'cy = 4.1568e-04  [2.6857e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9267246e+01;   self-cons'cy = 2.8231e-04  [7.8806e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0120151e+01;   self-cons'cy = 2.4891e-04  [7.8806e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7267824e+01;   self-cons'cy = 1.0181e-04  [6.8704e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9698953e+01;   self-cons'cy = 8.6162e-05  [6.8704e-04 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4678411e+02;   self-cons'cy = 1.3383e-05  [2.2908e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5639191e+01;   self-cons'cy = 3.6458e-05  [2.2908e-04 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2308955e+01;   self-cons'cy = 3.5388e-05  [2.2908e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9263388e+01;   self-cons'cy = 2.1608e-05  [6.0293e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0119005e+01;   self-cons'cy = 1.9034e-05  [6.0293e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7266668e+01;   self-cons'cy = 6.6253e-06  [4.4237e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9698624e+01;   self-cons'cy = 5.5379e-06  [4.4237e-05 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4678526e+02;   self-cons'cy = 1.0466e-06  [1.7949e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5639736e+01;   self-cons'cy = 2.8513e-06  [1.7949e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2309134e+01;   self-cons'cy = 2.7737e-06  [1.7949e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9263664e+01;   self-cons'cy = 1.5455e-06  [4.3041e-06 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0119086e+01;   self-cons'cy = 1.3591e-06  [4.3041e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7266738e+01;   self-cons'cy = 4.0300e-07  [2.6512e-06 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9698643e+01;   self-cons'cy = 3.3155e-07  [2.6512e-06 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4678517e+02;   self-cons'cy = 7.6642e-08  [1.3169e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5639696e+01;   self-cons'cy = 2.0879e-07  [1.3169e-06 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2309121e+01;   self-cons'cy = 2.0351e-07  [1.3169e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9263645e+01;   self-cons'cy = 1.0392e-07  [2.8888e-07 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0119081e+01;   self-cons'cy = 9.1229e-08  [2.8888e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7266734e+01;   self-cons'cy = 2.2462e-08  [1.4467e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9698642e+01;   self-cons'cy = 1.8064e-08  [1.4467e-07 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4678518e+02;   self-cons'cy = 5.2871e-09  [9.1007e-08 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5639699e+01;   self-cons'cy = 1.4402e-08  [9.1007e-08 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2309122e+01;   self-cons'cy = 1.4065e-08  [9.1007e-08 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9263646e+01;   self-cons'cy = 6.5528e-09  [1.8177e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0119081e+01;   self-cons'cy = 5.7412e-09  [1.8177e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7266734e+01;   self-cons'cy = 1.0922e-09  [6.7699e-09 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9698642e+01;   self-cons'cy = 8.4314e-10  [6.7699e-09 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 3/2^- ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    3/2 -     -2.585620974699660e+03    -7.035833044396109e+04    -7.035833044396109e+04
#      2    1/2 -     -2.585211778289228e+03    -7.034719564247884e+04    -7.034719564247884e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     4.091964104313774e-01    1.113480148224657e+01    1.113480148224657e+01
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     4.091964104313774e-01    1.113480148224657e+01    1.113480148224657e+01
#
# FormFactor.computeOutcomes(): The computation of the atomic form factors starts now ...
# -------------------------------------------------------------------------------------------
#
#   Selected FormFactor levels:
#
#   --------------------------------------------------------------------------------------
#      Level        J^P           Energy          q-values  ...
#                                  [eV]            [a.u.]
#   --------------------------------------------------------------------------------------
#          1       3/2 -      -7.03583304e+04    0.00e+00,  1.00e-01,  1.00e+00,
#          2       1/2 -      -7.03471956e+04    0.00e+00,  1.00e-01,  1.00e+00,
#   --------------------------------------------------------------------------------------
#
#   Standard and modified atomic form factors [note F^(standard) (0) = N_e]:
#
#   ----------------------------------------------------------------------------------------
#      Level        J^P           Energy          q [a.u.]      standard F     modified F
#                                  [eV]
#   ----------------------------------------------------------------------------------------
#          1       3/2 -      -7.03583304e+04    0.00000e+00    1.70000e+01    1.69498e+01
#                                                1.00000e-01    1.69967e+01    1.69465e+01
#                                                1.00000e+00    1.66753e+01    1.66252e+01
#          2       1/2 -      -7.03471956e+04    0.00000e+00    1.70000e+01    1.69498e+01
#                                                1.00000e-01    1.69967e+01    1.69465e+01
#                                                1.00000e+00    1.66742e+01    1.66241e+01
#   ----------------------------------------------------------------------------------------
#
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# In the future, we plan to extend this notebook to include also the computation of elastic and inelastic scattering cross sections.
