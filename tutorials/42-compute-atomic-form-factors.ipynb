# %% [markdown]
# # Atomic form factors for chlorine-like iron ions

# %%
using JAC

# %% [markdown]
# In atomic physics, the **form factors** are generally taken as fast approximation to the (scattering) amplitude in forward direction at $\vartheta \approx 0$, if an incident quantum wave is scattered by an isolated atom with spherical-symmetric charge distribution. The form factor definition therefore depends on the particular type of incident radiation, such a photons, electrons or neutrons. Here, *as usual*, we restrict ourselves to the atomic **form factor for the elastic (x-ray) scattering of photons**.
#
# In JAC, the standard and modified form factors are calculated and tabulated by default for all selected levels of a given multiplet and for a list of pre-specified $q$-values (a.u.). Here, we shall compute these form factors as (one) selected atomic property for all levels of the [Ne] $3s^2 3p^5$ ground configuration of chlorine-like Fe and Kr ions. For this, we can perform again an `Atomic.Computation(...,  properties=[FormF, ..], configs=[..], formSettings=FormFactor.Settings(..), ..)`.
#
# Let us first consider the internal definition and the default settings of `FormFactor.Settings(..)`

# %%
? FormFactor.Settings
# Out:
#   struct FormFactor.Settings <: AbstractPropertySettings ... defines a type
#   for the details and parameters of computing alpha-variation parameters.
#
#   + qList                    ::Array{Float64,1} ... List of q-values in [a.u.]
#   + printBefore              ::Bool             ... True if a list of selected levels is printed before the
#                                                     actual computations start.
#   + levelSelection           ::LevelSelection   ... Specifies the selected levels, if any.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   FormFactor.Settings() ... constructor for an empty instance of
#   FormFactor.Settings for the computation of atomic form factors.

# %%
FormFactor.Settings()
# Out:
# qList:                    [0.0, 0.1, 1.0, 10.0]
# printBefore:              false
# levelSelection:           Inactive LevelSelection.

# %% [markdown]
# We wish to calculate form factor for three values of the momentum transfer $q = [0., 0.1, 1.0]$ and request the printout of a short overwiew table already before the form factor computations start. These settings and the (atomic) computation are then realized by simply calling:

# %%
fSettings = FormFactor.Settings([0., 0.1, 1.0], true, LevelSelection())
wa = Atomic.Computation(Atomic.Computation(), name="Form factors for chlorine-like Fe", grid=Radial.Grid(true), 
            nuclearModel=Nuclear.Model(26.), configs=[Configuration("[Ne] 3s^2 3p^5")],
            propertySettings=[fSettings] )
perform(wa)
# Out:
# ... in performSCF ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^1 3p_3/2^4
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^2 3p_3/2^3
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 26.0 with mass = 55.38, radius R = 3.756573410087755 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -3.41095882e+02    -3.41097837e+02    +5.73311610e-06
#       2      2s_1/2      -8.54687357e+01    -8.54689584e+01    +2.60532193e-06
#       3      3s_1/2      -3.78995842e+01    -3.78994478e+01    -3.59853081e-06
#       4      4s_1/2      -2.12867978e+01    -2.12819385e+01    -2.28278309e-04
#       5      5s_1/2      -1.36512733e+01    -1.36039714e+01    -3.46501490e-03
#       6      6s_1/2      -1.02310357e+01    -9.43887322e+00    -7.74273999e-02
#       7      7s_1/2      -8.90147750e+00    -6.93005925e+00    -2.21470902e-01
#       8      8s_1/2      -6.53712432e+00    -5.30306679e+00    -1.88776819e-01
#       9      9s_1/2      -4.74910062e+00    -4.18833237e+00    -1.18078832e-01
#      31     32p_3/2      +4.09900068e+03    -3.30255569e-01    +1.00008057e+00
#      32     33p_3/2      +7.87036256e+03    -3.10538528e-01    +1.00003946e+00
#      33     34p_3/2      +1.42302012e+04    -2.92535903e-01    +1.00002056e+00
#      34     35p_3/2      +2.43197548e+04    -2.76054548e-01    +1.00001135e+00
#      35     36p_3/2      +3.96125671e+04    -2.60927768e-01    +1.00000659e+00
#      36     37p_3/2      +6.21282334e+04    -2.47011090e-01    +1.00000398e+00
#      37     38p_3/2      +9.47354856e+04    -2.34178802e-01    +1.00000247e+00
#      38     39p_3/2      +1.41547913e+05    -2.22321100e-01    +1.00000157e+00
#       :       :
#      55     56p_3/2      +7.61716803e+07    -1.07814412e-01    +1.00000000e+00
#      56     57p_3/2      +1.16282188e+08    -1.04064077e-01    +1.00000000e+00
#      57     58p_3/2      +1.85096390e+08    -1.00506075e-01    +1.00000000e+00
#      58     59p_3/2      +3.18904219e+08    -9.71274767e-02    +1.00000000e+00
#      59     60p_3/2      +6.47240399e+08    -9.39164194e-02    +1.00000000e+00
#      60     61p_3/2      +2.01299416e+09    -9.08620064e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# >> Use hydrogenic orbital from this symmetry block also for 3p_3/2.
# (Re-) Define the standard grid with 392 grid points.
# >>  for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.5032946e+02;   self-cons'cy = 1.5347e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.1605901e+01;   self-cons'cy = 4.6007e-01  [1.0000e+02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.6572128e+00;   self-cons'cy = 6.2810e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.8847003e+01;   self-cons'cy = 4.9531e-01  [1.0000e+02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.9631337e+00;   self-cons'cy = 6.5274e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.0830648e+01;   self-cons'cy = 4.6624e-01  [1.0000e+02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -8.4715174e+00;   self-cons'cy = 6.3279e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6707338e+02;   self-cons'cy = 3.2361e-02  [6.6342e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.9371651e+01;   self-cons'cy = 1.0941e-01  [6.6342e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0793965e+01;   self-cons'cy = 1.0985e-01  [6.6342e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4836904e+01;   self-cons'cy = 9.4057e-02  [2.0295e-01 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.3697398e+00;   self-cons'cy = 8.1153e-02  [2.0295e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3849658e+01;   self-cons'cy = 4.6676e-02  [2.3955e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.1350079e+00;   self-cons'cy = 3.7684e-02  [2.3955e-01 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6419084e+02;   self-cons'cy = 5.4258e-03  [2.5920e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.7926779e+01;   self-cons'cy = 1.8692e-02  [2.5920e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0323571e+01;   self-cons'cy = 2.2275e-02  [2.5920e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.3919041e+01;   self-cons'cy = 1.3350e-02  [4.2653e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1050546e+00;   self-cons'cy = 1.4327e-02  [4.2653e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3534107e+01;   self-cons'cy = 4.6829e-03  [4.2353e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0493533e+00;   self-cons'cy = 4.7103e-03  [4.2353e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6459146e+02;   self-cons'cy = 7.5763e-04  [3.0339e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8128697e+01;   self-cons'cy = 2.6549e-03  [3.0339e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0388446e+01;   self-cons'cy = 3.1322e-03  [3.0339e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4026176e+01;   self-cons'cy = 1.5768e-03  [4.7791e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1354528e+00;   self-cons'cy = 1.6665e-03  [4.7791e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3558833e+01;   self-cons'cy = 3.6853e-04  [3.0113e-03 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0556971e+00;   self-cons'cy = 3.5039e-04  [3.0113e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454326e+02;   self-cons'cy = 9.1086e-05  [3.8011e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8104203e+01;   self-cons'cy = 3.2130e-04  [3.8011e-03 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0380474e+01;   self-cons'cy = 3.8384e-04  [3.8011e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4015396e+01;   self-cons'cy = 1.5844e-04  [4.8446e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1323841e+00;   self-cons'cy = 1.6799e-04  [4.8446e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557639e+01;   self-cons'cy = 1.7790e-05  [1.2693e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554448e+00;   self-cons'cy = 1.3931e-05  [1.2693e-04 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454829e+02;   self-cons'cy = 9.5006e-06  [3.9659e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106766e+01;   self-cons'cy = 3.3627e-05  [3.9659e-04 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381312e+01;   self-cons'cy = 4.0329e-05  [3.9659e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016277e+01;   self-cons'cy = 1.2955e-05  [3.9190e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326324e+00;   self-cons'cy = 1.3596e-05  [3.9190e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557575e+01;   self-cons'cy = 9.5746e-07  [1.2541e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554159e+00;   self-cons'cy = 1.5997e-06  [1.2541e-05 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454785e+02;   self-cons'cy = 8.3296e-07  [3.4828e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106541e+01;   self-cons'cy = 2.9545e-06  [3.4828e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381238e+01;   self-cons'cy = 3.5591e-06  [3.4828e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016230e+01;   self-cons'cy = 6.8797e-07  [2.0050e-06 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326197e+00;   self-cons'cy = 6.9509e-07  [2.0050e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557603e+01;   self-cons'cy = 4.2355e-07  [4.2300e-06 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554251e+00;   self-cons'cy = 5.1104e-07  [4.2300e-06 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454788e+02;   self-cons'cy = 5.3666e-08  [2.2401e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106555e+01;   self-cons'cy = 1.9083e-07  [2.2401e-06 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381243e+01;   self-cons'cy = 2.3170e-07  [2.2401e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016229e+01;   self-cons'cy = 2.0880e-08  [8.0131e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326192e+00;   self-cons'cy = 2.7898e-08  [8.0131e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557598e+01;   self-cons'cy = 7.5954e-08  [7.2228e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554236e+00;   self-cons'cy = 8.6181e-08  [7.2228e-07 for sym-block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6454788e+02;   self-cons'cy = 6.6507e-10  [2.6503e-08 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.8106555e+01;   self-cons'cy = 2.4337e-09  [2.6503e-08 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.0381243e+01;   self-cons'cy = 3.2891e-09  [2.6503e-08 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4016230e+01;   self-cons'cy = 1.3050e-08  [4.2114e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -9.1326195e+00;   self-cons'cy = 1.4620e-08  [4.2114e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3557599e+01;   self-cons'cy = 1.0441e-08  [9.6812e-08 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -9.0554238e+00;   self-cons'cy = 1.1469e-08  [9.6812e-08 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^- ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 3/2^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    3/2 -     -1.242746359813715e+03    -3.381685092184081e+04    -3.381685092184081e+04
#      2    1/2 -     -1.242672300350070e+03    -3.381483566118713e+04    -3.381483566118713e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     7.405946364542615e-02    2.015260653689847e+00    2.015260653689847e+00
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     7.405946364542615e-02    2.015260653689847e+00    2.015260653689847e+00
#
# FormFactor.computeOutcomes(): The computation of the atomic form factors starts now ...
# -------------------------------------------------------------------------------------------
#
#   Selected FormFactor levels:
#
#   --------------------------------------------------------------------------------------
#      Level        J^P           Energy          q-values  ...
#                                  [eV]            [a.u.]
#   --------------------------------------------------------------------------------------
#          1       3/2 -      -3.38168509e+04    0.00e+00,  1.00e-01,  1.00e+00,
#          2       1/2 -      -3.38148357e+04    0.00e+00,  1.00e-01,  1.00e+00,
#   --------------------------------------------------------------------------------------
#
#   Standard and modified atomic form factors [note F^(standard) (0) = N_e]:
#
#   ----------------------------------------------------------------------------------------
#      Level        J^P           Energy          q [a.u.]      standard F     modified F
#                                  [eV]
#   ----------------------------------------------------------------------------------------
#          1       3/2 -      -3.38168509e+04    0.00000e+00    1.70000e+01    1.69910e+01
#                                                1.00000e-01    1.69916e+01    1.69827e+01
#                                                1.00000e+00    1.61993e+01    1.61899e+01
#          2       1/2 -      -3.38148357e+04    0.00000e+00    1.70000e+01    1.69910e+01
#                                                1.00000e-01    1.69916e+01    1.69826e+01
#                                                1.00000e+00    1.61978e+01    1.61885e+01
#   ----------------------------------------------------------------------------------------
#
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# Here, all the requested form factors are simply compiled in the last table; of course, we can easily repeat these computations also for chlorine-like Kr:

# %%
wa = Atomic.Computation(wa, name="Form factors for chlorine-like Kr", nuclearModel=Nuclear.Model(36.))
perform(wa)
# Out:
# ... in performSCF ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^1 3p_3/2^4
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^2 3p_3/2^3
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 36.0 with mass = 78.48, radius R = 4.149254741065642 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -6.59572821e+02    -6.59583512e+02    +1.62084215e-05
#       2      2s_1/2      -1.65624908e+02    -1.65626275e+02    +8.25453573e-06
#       3      3s_1/2      -7.32848259e+01    -7.32847802e+01    -6.24078173e-07
#       4      4s_1/2      -4.10942234e+01    -4.10855060e+01    -2.12131776e-04
#       5      5s_1/2      -2.63069847e+01    -2.62329647e+01    -2.81369885e-03
#       6      6s_1/2      -1.96026436e+01    -1.81861550e+01    -7.22600831e-02
#       7      7s_1/2      -1.73105038e+01    -1.33439712e+01    -2.29140218e-01
#       8      8s_1/2      -1.27256993e+01    -1.02061694e+01    -1.97987543e-01
#       9      9s_1/2      -9.27186803e+00    -8.05762060e+00    -1.30960387e-01
#      10     10s_1/2      -6.71611652e+00    -6.52236165e+00    -2.88492424e-02
#      11     11s_1/2      -4.82721708e+00    -5.38741725e+00    +1.16050336e-01
#      12     12s_1/2      -3.44854882e+00    -4.52482297e+00    +3.12094800e-01
#      13     13s_1/2      -2.45331530e+00    -3.85393639e+00    +5.70909529e-01
#      14     14s_1/2      -1.74040182e+00    -3.32189248e+00    +9.08692830e-01
#      15     15s_1/2      -1.23242716e+00    -2.89286643e+00    +1.34729201e+00
#      37     38p_3/2      +9.23791997e+04    -4.49146904e-01    +1.00000486e+00
#      38     39p_3/2      +1.38201189e+05    -4.26399825e-01    +1.00000309e+00
#       :       :
#      55     56p_3/2      +7.60635035e+07    -2.06757178e-01    +1.00000000e+00
#      56     57p_3/2      +1.16174043e+08    -1.99564124e-01    +1.00000000e+00
#      57     58p_3/2      +1.84988269e+08    -1.92740010e-01    +1.00000000e+00
#      58     59p_3/2      +3.18796132e+08    -1.86260029e-01    +1.00000000e+00
#      59     60p_3/2      +6.47132419e+08    -1.80101425e-01    +1.00000000e+00
#      60     61p_3/2      +2.01288792e+09    -1.74243293e-01    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# >> Use hydrogenic orbital from this symmetry block also for 3p_3/2.
# (Re-) Define the standard grid with 392 grid points.
# >>  for various B-spline matrices:
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.3241384e+02;   self-cons'cy = 1.0668e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -8.8999985e+01;   self-cons'cy = 3.0093e-01  [1.0000e+02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.0303337e+01;   self-cons'cy = 4.1493e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3710163e+01;   self-cons'cy = 3.2854e-01  [1.0000e+02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -2.8592396e+01;   self-cons'cy = 4.3869e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.4104674e+01;   self-cons'cy = 3.1847e-01  [1.0000e+02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.8846463e+01;   self-cons'cy = 4.3028e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4844801e+02;   self-cons'cy = 1.4835e-02  [1.3056e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.6432985e+01;   self-cons'cy = 4.0085e-02  [1.3056e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2568778e+01;   self-cons'cy = 3.6033e-02  [1.3056e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9823207e+01;   self-cons'cy = 3.5227e-02  [6.6651e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0287110e+01;   self-cons'cy = 2.8783e-02  [6.6651e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7508253e+01;   self-cons'cy = 1.9833e-02  [6.2135e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9769502e+01;   self-cons'cy = 1.5747e-02  [6.2135e-02 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4662618e+02;   self-cons'cy = 1.6637e-03  [1.7195e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5563980e+01;   self-cons'cy = 4.5261e-03  [1.7195e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2284406e+01;   self-cons'cy = 4.3848e-03  [1.7195e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9216877e+01;   self-cons'cy = 3.3866e-03  [7.3017e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0105181e+01;   self-cons'cy = 3.0125e-03  [7.3017e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7250071e+01;   self-cons'cy = 1.4774e-03  [5.3855e-03 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9693853e+01;   self-cons'cy = 1.2722e-03  [5.3855e-03 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4679877e+02;   self-cons'cy = 1.5784e-04  [1.6104e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5646178e+01;   self-cons'cy = 4.2988e-04  [1.6104e-03 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2311252e+01;   self-cons'cy = 4.1560e-04  [1.6104e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9267260e+01;   self-cons'cy = 2.8229e-04  [5.9989e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0120169e+01;   self-cons'cy = 2.4887e-04  [5.9989e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7267839e+01;   self-cons'cy = 1.0181e-04  [3.6283e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9698970e+01;   self-cons'cy = 8.6143e-05  [3.6283e-04 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4678413e+02;   self-cons'cy = 1.3382e-05  [1.3722e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5639205e+01;   self-cons'cy = 3.6456e-05  [1.3722e-04 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2308966e+01;   self-cons'cy = 3.5381e-05  [1.3722e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9263403e+01;   self-cons'cy = 2.1607e-05  [4.5892e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0119023e+01;   self-cons'cy = 1.9030e-05  [4.5892e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7266682e+01;   self-cons'cy = 6.6248e-06  [2.3359e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9698641e+01;   self-cons'cy = 5.5366e-06  [2.3359e-05 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4678528e+02;   self-cons'cy = 1.0466e-06  [1.0752e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5639750e+01;   self-cons'cy = 2.8511e-06  [1.0752e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2309145e+01;   self-cons'cy = 2.7731e-06  [1.0752e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9263679e+01;   self-cons'cy = 1.5453e-06  [3.2766e-06 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0119105e+01;   self-cons'cy = 1.3588e-06  [3.2766e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7266753e+01;   self-cons'cy = 4.0296e-07  [1.4005e-06 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9698660e+01;   self-cons'cy = 3.3147e-07  [1.4005e-06 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.4678519e+02;   self-cons'cy = 7.6635e-08  [7.8881e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -9.5639710e+01;   self-cons'cy = 2.0876e-07  [7.8881e-07 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.2309132e+01;   self-cons'cy = 2.0346e-07  [7.8881e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9263660e+01;   self-cons'cy = 1.0391e-07  [2.1994e-07 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0119099e+01;   self-cons'cy = 9.1210e-08  [2.1994e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.7266749e+01;   self-cons'cy = 2.2459e-08  [7.6463e-08 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9698659e+01;   self-cons'cy = 1.8060e-08  [7.6463e-08 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^- ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 3/2^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    3/2 -     -2.585621028055229e+03    -7.035833189584008e+04    -7.035833189584008e+04
#      2    1/2 -     -2.585211835298085e+03    -7.034719719376885e+04    -7.034719719376885e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     4.091927571435008e-01    1.113470207121991e+01    1.113470207121991e+01
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     4.091927571435008e-01    1.113470207121991e+01    1.113470207121991e+01
#
# FormFactor.computeOutcomes(): The computation of the atomic form factors starts now ...
# -------------------------------------------------------------------------------------------
#
#   Selected FormFactor levels:
#
#   --------------------------------------------------------------------------------------
#      Level        J^P           Energy          q-values  ...
#                                  [eV]            [a.u.]
#   --------------------------------------------------------------------------------------
#          1       3/2 -      -7.03583319e+04    0.00e+00,  1.00e-01,  1.00e+00,
#          2       1/2 -      -7.03471972e+04    0.00e+00,  1.00e-01,  1.00e+00,
#   --------------------------------------------------------------------------------------
#
#   Standard and modified atomic form factors [note F^(standard) (0) = N_e]:
#
#   ----------------------------------------------------------------------------------------
#      Level        J^P           Energy          q [a.u.]      standard F     modified F
#                                  [eV]
#   ----------------------------------------------------------------------------------------
#          1       3/2 -      -7.03583319e+04    0.00000e+00    1.70000e+01    1.69498e+01
#                                                1.00000e-01    1.69967e+01    1.69465e+01
#                                                1.00000e+00    1.66753e+01    1.66252e+01
#          2       1/2 -      -7.03471972e+04    0.00000e+00    1.70000e+01    1.69498e+01
#                                                1.00000e-01    1.69967e+01    1.69465e+01
#                                                1.00000e+00    1.66742e+01    1.66241e+01
#   ----------------------------------------------------------------------------------------
#
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# In the future, we plan to extend this notebook to include also the computation of elastic and inelastic scattering cross sections.
