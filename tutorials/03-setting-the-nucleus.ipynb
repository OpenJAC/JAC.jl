# %% [markdown]
# # Nuclear parameters & potential

# %%
include("../src/jac.jl")  ## using JAC
# Out:
# HTML{String}("    <script class='js-collapse-script'>\n        var curMatch =\n            window.location.href\n            .match(/(.*?)\\/notebooks\\/.*\\.ipynb/);\n\n        curMatch = curMatch ||\n            window.location.href\n            .match(/(.*?)\\/apps\\/.*\\.ipynb/);\n\n        if ( curMatch ) {\n            \$('head').append('<base href=\"' + curMatch[1] + '/\">');\n        }\n    </script>\n")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/b5211b19a5aa56f2c76a4f66df0ec7b35773f4c6-assets/webio/dist/bundle.js'></script>")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/b5211b19a5aa56f2c76a4f66df0ec7b35773f4c6-assets/providers/ijulia_setup.js'></script>")
# HTML{String}("  <script class='js-collapse-script'>\n    \$('.js-collapse-script').parent('.output_subarea').css('padding', '0');\n  </script>\n")

# %%
using Interact

# %% [markdown]
# The charge and shape of the nucleus is essential to understand the electronic level structure and which processes may occur in an atom or ion. Usually, these and other nuclear parameters need to be defined prior to the generation of wave functions and the computation of atomic amplitudes, properties and processes.
#
# In JAC, all information about the underlying nuclear model are kept in the data structure Nuclear.Model which carries the following information:

# %%
? Nuclear.Model
# Out:
#   struct  Nuclear.Model ... defines a type for the nuclear model, i.e. for its
#   form and parameters.
#
#   + Z        ::Float64         ... nuclear charge
#   + model    ::String          ... identifier of the nuclear model: {"Fermi", "Point", "Uniform"}
#   + mass     ::Float64         ... atomic mass
#   + radius   ::Float64         ... (root-mean square) radius of a uniform or Fermi-distributed nucleus
#   + spinI    ::AngularJ64      ... nuclear spin I, must be >= 0
#   + mu       ::Float64         ... magnetic dipole moment in Bohr magnetons
#   + Q        ::Float64         ... electric qadrupole moment
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   JAC.Nuclear.Model(Z::Real) ... constructor just for a given nuclear charge
#   Z, and where a Fermi model is defined with a = 1.0 and c = 1.0 for the
#   moment. Both, the nuclear spin and moments are all set to zero in this case.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   JAC.Nuclear.Model(Z::Real, model::String) ... constructor just for a given
#   nuclear charge Z and model = {"Fermi", "point", "uniform"}, and where
#   further parameters are defined approximately. Both, the nuclear spin and
#   moments are all set to zero in this case.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   JAC.Nuclear.Model(gui::Guint; model::Nuclear.Model=Model(36.0)) ...
#   constructor that is defined by a graphical user interface.

# %% [markdown]
# For quick and simple computations, it is often sufficient to just specify the nuclear charge Z and to leave all other parameters to their default values. For example, we here define such a nucleus for xenon (Z=54) and will immediatly see the details of this specification:

# %%
wa = Nuclear.Model(54.)
# Out:
# Fermi nuclear model for Z = 54.0 with mass = 122.58, radius R = 4.722849091608491 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.

# %% [markdown]
# Of course, we can also specify all details about the nucleus by using the standard constructor:

# %%
wb = Nuclear.Model(54., "uniform", 132., 5.75, AngularJ64(5//2), 1.0, 2.0)
# Out:
# Uniform nuclear model for Z = 54.0 with mass = 132.0, radius R = 5.75 fm and nuclear spin I = 5/2, dipole moment mu = 1.0 and quadrupole moment Q = 2.0.

# %% [raw]
# ... or we make use of the **graphical (GUI)** constructor by starting from scratch or by just refining a previous nuclear model. For this, all values can first be set and then 'updated'. This constructor returns an Observable whose value is obtained by obs[]:

# %%
wx = Nuclear.Model(Gui)
# Out:
# (div { style=Dict("display"=>"flex","flex-direction"=>"column") }
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>0.0em) }
#       "Nuclear model with: "))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 1 listeners. Value:
# 36), Observable{Int64} with 1 listeners. Value:
# 36, Scope("knockout-component-99aa2055-9d3a-4d77-b4a7-d3c10591b322", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["charge"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>110,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 1 listeners. Value:
# 36, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":36}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-99aa2055-9d3a-4d77-b4a7-d3c10591b322\",\"id\":\"ob_42\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-99aa2055-9d3a-4d77-b4a7-d3c10591b322\",\"id\":\"ob_41\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope))))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:dropdown,Any}(OrderedDict{Symbol,Any}(:options=>Observable{Any} with 2 listeners. Value:
# ["Fermi", "Fermi", "point", "uniform"],:index=>Observable{Any} with 2 listeners. Value:
# 2), Observable{Any} with 1 listeners. Value:
# "Fermi", Scope("knockout-component-bd94af5f-f99e-47ac-b0b0-8fabdc44981c", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :select), Any[], Dict{Symbol,Any}(:attributes=>Dict{Union{String, Symbol},Any}(Symbol("data-bind")=>"options : options_js, value : index, optionsText: 'key', optionsValue: 'val', valueAllowUnset: true, optionsAfterRender: disablePlaceholder")), 0)], Dict{Symbol,Any}(:className=>"select "), 1), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("options_js"=>(Observable{Any} with 1 listeners. Value:
# OrderedDict[OrderedDict{String,Any}("key"=>"Fermi","val"=>1,"id"=>"idOBpcOQ1x"), OrderedDict{String,Any}("key"=>"Fermi","val"=>2,"id"=>"idwIlo2J89"), OrderedDict{String,Any}("key"=>"point","val"=>3,"id"=>"idWXVeeoEU"), OrderedDict{String,Any}("key"=>"uniform","val"=>4,"id"=>"idBBZk5k83")], nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 2, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"options_js\\\":[{\\\"key\\\":\\\"Fermi\\\",\\\"val\\\":1,\\\"id\\\":\\\"idOBpcOQ1x\\\"},{\\\"key\\\":\\\"Fermi\\\",\\\"val\\\":2,\\\"id\\\":\\\"idwIlo2J89\\\"},{\\\"key\\\":\\\"point\\\",\\\"val\\\":3,\\\"id\\\":\\\"idWXVeeoEU\\\"},{\\\"key\\\":\\\"uniform\\\",\\\"val\\\":4,\\\"id\\\":\\\"idBBZk5k83\\\"}],\\\"index\\\":2}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        [this[\"disablePlaceholder\"]=function(option, item) {\n    ko.applyBindingsToNode(option, {disable: item.val == 0}, item);\n}\n]\n        \n        [this[\"options_js\"].subscribe((function (val){!(this.valueFromJulia[\"options_js\"]) ? (WebIO.setval({\"name\":\"options_js\",\"scope\":\"knockout-component-bd94af5f-f99e-47ac-b0b0-8fabdc44981c\",\"id\":\"ob_47\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"options_js\"]=false}),self),this[\"index\"].subscribe((function (val){!(this.valueFromJulia[\"index\"]) ? (WebIO.setval({\"name\":\"index\",\"scope\":\"knockout-component-bd94af5f-f99e-47ac-b0b0-8fabdc44981c\",\"id\":\"ob_46\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"index\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"options_js"=>Any[JSString("(function (val){return (val!=this.model[\"options_js\"]()) ? (this.valueFromJulia[\"options_js\"]=true, this.model[\"options_js\"](val)) : undefined})")],"index"=>Any[JSString("(function (val){return (val!=this.model[\"index\"]()) ? (this.valueFromJulia[\"index\"]=true, this.model[\"index\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 78.48), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 78.48, Scope("knockout-component-7ac8c74e-0bef-4dbd-8c30-c3998313c75a", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["mass  "], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 78.48, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":78.48}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-7ac8c74e-0bef-4dbd-8c30-c3998313c75a\",\"id\":\"ob_49\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-7ac8c74e-0bef-4dbd-8c30-c3998313c75a\",\"id\":\"ob_48\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 4.14925), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 4.149254741065642, Scope("knockout-component-b604a54b-cc21-4ded-8b82-f90512a46f1d", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["radius"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 4.14925, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":4.149254741065642}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-b604a54b-cc21-4ded-8b82-f90512a46f1d\",\"id\":\"ob_51\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-b604a54b-cc21-4ded-8b82-f90512a46f1d\",\"id\":\"ob_50\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope))))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Int64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Int64}} with 1 listeners. Value:
# 0), Observable{Union{Nothing, Int64}} with 1 listeners. Value:
# 0, Scope("knockout-component-538cda2c-a0ba-4bac-a0d3-67816d76dae5", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["2*spin"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Int64}} with 1 listeners. Value:
# 0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-538cda2c-a0ba-4bac-a0d3-67816d76dae5\",\"id\":\"ob_53\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-538cda2c-a0ba-4bac-a0d3-67816d76dae5\",\"id\":\"ob_52\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 0.0), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 0.0, Scope("knockout-component-0b796eeb-2252-4e04-992e-777ccd540898", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["mu    "], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 0.0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":0.0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-0b796eeb-2252-4e04-992e-777ccd540898\",\"id\":\"ob_55\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-0b796eeb-2252-4e04-992e-777ccd540898\",\"id\":\"ob_54\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 0.0), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 0.0, Scope("knockout-component-232a6006-fa7d-4406-bfc4-c222a3871722", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["Q     "], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 0.0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":0.0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-232a6006-fa7d-4406-bfc4-c222a3871722\",\"id\":\"ob_57\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-232a6006-fa7d-4406-bfc4-c222a3871722\",\"id\":\"ob_56\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:button,Int64}(OrderedDict{Symbol,Any}(), Observable{Int64} with 1 listeners. Value:
# 0, Scope("knockout-component-77cffd01-232d-4de8-9c0d-964dfa5b3558", Node{WebIO.DOM}(WebIO.DOM(:html, :button), Any["Update"], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}("data-bind"=>"click : function () {this.clicks(this.clicks()+1)}"),:className=>"button is-primary",:style=>Dict{String,Any}()), 1), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("clicks"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"clicks\\\":0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"clicks\"].subscribe((function (val){!(this.valueFromJulia[\"clicks\"]) ? (WebIO.setval({\"name\":\"clicks\",\"scope\":\"knockout-component-77cffd01-232d-4de8-9c0d-964dfa5b3558\",\"id\":\"ob_58\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"clicks\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"clicks"=>Any[JSString("(function (val){return (val!=this.model[\"clicks\"]()) ? (this.valueFromJulia[\"clicks\"]=true, this.model[\"clicks\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:1), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))))
# Observable{Any} with 0 listeners. Value:
# Fermi nuclear model for Z = 36.0 with mass = 78.48, radius R = 4.149254741065642 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.

# %%
wd = wx[]
# Out:
# Fermi nuclear model for Z = 36.0 with mass = 78.48, radius R = 4.149254741065642 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 2.0.

# %%
wx = Nuclear.Model(Gui; model=wb)
# Out:
# (div { style=Dict("display"=>"flex","flex-direction"=>"column") }
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>0.0em) }
#       "Nuclear model with: "))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 1 listeners. Value:
# 54), Observable{Int64} with 1 listeners. Value:
# 54, Scope("knockout-component-994740b1-d4f6-44b2-963e-a32b4963ca27", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["charge"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>110,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 1 listeners. Value:
# 54, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":54}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-994740b1-d4f6-44b2-963e-a32b4963ca27\",\"id\":\"ob_62\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-994740b1-d4f6-44b2-963e-a32b4963ca27\",\"id\":\"ob_61\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope))))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:dropdown,Any}(OrderedDict{Symbol,Any}(:options=>Observable{Any} with 2 listeners. Value:
# ["uniform", "Fermi", "point", "uniform"],:index=>Observable{Any} with 2 listeners. Value:
# 4), Observable{Any} with 1 listeners. Value:
# "uniform", Scope("knockout-component-b59ba182-d503-4fdc-b40b-00820fea6b9f", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :select), Any[], Dict{Symbol,Any}(:attributes=>Dict{Union{String, Symbol},Any}(Symbol("data-bind")=>"options : options_js, value : index, optionsText: 'key', optionsValue: 'val', valueAllowUnset: true, optionsAfterRender: disablePlaceholder")), 0)], Dict{Symbol,Any}(:className=>"select "), 1), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("options_js"=>(Observable{Any} with 1 listeners. Value:
# OrderedDict[OrderedDict{String,Any}("key"=>"uniform","val"=>1,"id"=>"idG0nnKWtd"), OrderedDict{String,Any}("key"=>"Fermi","val"=>2,"id"=>"idFeayiwow"), OrderedDict{String,Any}("key"=>"point","val"=>3,"id"=>"idQHm8Mrma"), OrderedDict{String,Any}("key"=>"uniform","val"=>4,"id"=>"idSD60IX6T")], nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 4, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"options_js\\\":[{\\\"key\\\":\\\"uniform\\\",\\\"val\\\":1,\\\"id\\\":\\\"idG0nnKWtd\\\"},{\\\"key\\\":\\\"Fermi\\\",\\\"val\\\":2,\\\"id\\\":\\\"idFeayiwow\\\"},{\\\"key\\\":\\\"point\\\",\\\"val\\\":3,\\\"id\\\":\\\"idQHm8Mrma\\\"},{\\\"key\\\":\\\"uniform\\\",\\\"val\\\":4,\\\"id\\\":\\\"idSD60IX6T\\\"}],\\\"index\\\":4}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        [this[\"disablePlaceholder\"]=function(option, item) {\n    ko.applyBindingsToNode(option, {disable: item.val == 0}, item);\n}\n]\n        \n        [this[\"options_js\"].subscribe((function (val){!(this.valueFromJulia[\"options_js\"]) ? (WebIO.setval({\"name\":\"options_js\",\"scope\":\"knockout-component-b59ba182-d503-4fdc-b40b-00820fea6b9f\",\"id\":\"ob_67\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"options_js\"]=false}),self),this[\"index\"].subscribe((function (val){!(this.valueFromJulia[\"index\"]) ? (WebIO.setval({\"name\":\"index\",\"scope\":\"knockout-component-b59ba182-d503-4fdc-b40b-00820fea6b9f\",\"id\":\"ob_66\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"index\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"options_js"=>Any[JSString("(function (val){return (val!=this.model[\"options_js\"]()) ? (this.valueFromJulia[\"options_js\"]=true, this.model[\"options_js\"](val)) : undefined})")],"index"=>Any[JSString("(function (val){return (val!=this.model[\"index\"]()) ? (this.valueFromJulia[\"index\"]=true, this.model[\"index\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 132.0), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 132.0, Scope("knockout-component-cad8980c-47f6-4d28-af74-49e0caa2c004", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["mass  "], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 132.0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":132.0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-cad8980c-47f6-4d28-af74-49e0caa2c004\",\"id\":\"ob_69\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-cad8980c-47f6-4d28-af74-49e0caa2c004\",\"id\":\"ob_68\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 5.75), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 5.75, Scope("knockout-component-b97037a7-070d-42d7-a77d-5c064ac9126a", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["radius"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 5.75, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":5.75}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-b97037a7-070d-42d7-a77d-5c064ac9126a\",\"id\":\"ob_71\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-b97037a7-070d-42d7-a77d-5c064ac9126a\",\"id\":\"ob_70\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope))))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Int64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Int64}} with 1 listeners. Value:
# 5), Observable{Union{Nothing, Int64}} with 1 listeners. Value:
# 5, Scope("knockout-component-0566ed38-5630-4e78-8882-3eea53913894", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["2*spin"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Int64}} with 1 listeners. Value:
# 5, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":5}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-0566ed38-5630-4e78-8882-3eea53913894\",\"id\":\"ob_73\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-0566ed38-5630-4e78-8882-3eea53913894\",\"id\":\"ob_72\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 1.0), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 1.0, Scope("knockout-component-b36f417f-2941-417e-831e-975f93d40fbd", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["mu    "], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 1.0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":1.0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-b36f417f-2941-417e-831e-975f93d40fbd\",\"id\":\"ob_75\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-b36f417f-2941-417e-831e-975f93d40fbd\",\"id\":\"ob_74\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 2.0), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 2.0, Scope("knockout-component-57c0987e-99f0-4dae-96f4-ae3fded386aa", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["Q     "], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 2.0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":2.0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-57c0987e-99f0-4dae-96f4-ae3fded386aa\",\"id\":\"ob_77\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-57c0987e-99f0-4dae-96f4-ae3fded386aa\",\"id\":\"ob_76\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:button,Int64}(OrderedDict{Symbol,Any}(), Observable{Int64} with 1 listeners. Value:
# 0, Scope("knockout-component-47ca692e-526c-453d-8ca6-807cb4ddd7c4", Node{WebIO.DOM}(WebIO.DOM(:html, :button), Any["Update"], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}("data-bind"=>"click : function () {this.clicks(this.clicks()+1)}"),:className=>"button is-primary",:style=>Dict{String,Any}()), 1), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("clicks"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/Q4IkI/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/Ohu5Y/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"clicks\\\":0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"clicks\"].subscribe((function (val){!(this.valueFromJulia[\"clicks\"]) ? (WebIO.setval({\"name\":\"clicks\",\"scope\":\"knockout-component-47ca692e-526c-453d-8ca6-807cb4ddd7c4\",\"id\":\"ob_78\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"clicks\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"clicks"=>Any[JSString("(function (val){return (val!=this.model[\"clicks\"]()) ? (this.valueFromJulia[\"clicks\"]=true, this.model[\"clicks\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:1), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))))
# Observable{Any} with 0 listeners. Value:
# Uniform nuclear model for Z = 54.0 with mass = 132.0, radius R = 5.75 fm and nuclear spin I = 5/2, dipole moment mu = 1.0 and quadrupole moment Q = 2.0.

# %%
wd = wx[]
# Out:
# Uniform nuclear model for Z = 54.0 with mass = 135.0, radius R = 5.75 fm and nuclear spin I = 5/2, dipole moment mu = 1.0 and quadrupole moment Q = 4.0.
