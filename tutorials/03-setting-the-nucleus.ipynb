# %% [markdown]
# # Nuclear parameters & potential

# %% [markdown]
# **Improve the appearence of this and other notebooks:** In order to modify the cell-output of the notebooks and to better print the wide tables, please, create or modify the file ~/.jupyter/custom/custom.css in your home directory and add the line: div.output_area pre { font-size: 7pt;}

# %%
using JAC

# %%
using Interact

# %% [markdown]
# The charge and shape of the nucleus is essential to understand the electronic level structure and which particular processes may occur in an atom or ion. Usually, these and other nuclear parameters need to be defined prior to the generation of wave functions and the computation of atomic amplitudes, properties and processes.
#
# In JAC, all information about the underlying nuclear model are kept in the data structure `Nuclear.Model` which carries the following information:

# %%
? Nuclear.Model
# Out:
#   struct  Nuclear.Model ... defines a type for the nuclear model, i.e. for its
#   form and parameters.
#
#   + Z        ::Float64         ... nuclear charge
#   + model    ::String          ... identifier of the nuclear model: {"Fermi", "Point", "Uniform"}
#   + mass     ::Float64         ... atomic mass
#   + radius   ::Float64         ... (root-mean square) radius of a uniform or Fermi-distributed nucleus
#   + spinI    ::AngularJ64      ... nuclear spin I, must be >= 0
#   + mu       ::Float64         ... magnetic dipole moment in Bohr magnetons
#   + Q        ::Float64         ... electric qadrupole moment
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   JAC.Nuclear.Model(Z::Real) ... constructor just for a given nuclear charge
#   Z, and where a Fermi model is defined with a = 1.0 and c = 1.0 for the
#   moment. Both, the nuclear spin and moments are all set to zero in this case.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   JAC.Nuclear.Model(Z::Real, model::String) ... constructor just for a given
#   nuclear charge Z and model = {"Fermi", "point", "uniform"}, and where
#   further parameters are defined approximately. Both, the nuclear spin and
#   moments are all set to zero in this case.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   JAC.Nuclear.Model(gui::Guint; model::Nuclear.Model=Model(36.0)) ...
#   constructor that is defined by a graphical user interface.

# %% [markdown]
# For quick and simple computations, it is often sufficient to just specify the nuclear charge $Z$ and to leave all other parameters to their default values. For example, we here define such a nucleus for xenon $(Z=54)$ and will immediatly see the details of this specification:

# %%
wa = Nuclear.Model(54.)
# Out:
# Fermi nuclear model for Z = 54.0 with mass = 122.58, radius R = 4.722849091608491 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.

# %% [markdown]
# Of course, we can also specify all details about the nucleus by using the standard constructor:

# %%
wb = Nuclear.Model(54., "uniform", 132., 5.75, AngularJ64(5//2), 1.0, 2.0)
# Out:
# Uniform nuclear model for Z = 54.0 with mass = 132.0, radius R = 5.75 fm and nuclear spin I = 5/2, dipole moment mu = 1.0 and quadrupole moment Q = 2.0.

# %% [markdown]
# ... or we make use of the **graphical (GUI)** constructor by starting from scratch or by just refining a previous nuclear model. For this, all values can first be set and then *up-dated*. This constructor returns an observable whose value is obtained by obs[]:

# %%
wx = Nuclear.Model(Gui)
# Out:
# (div { style=Dict("display"=>"flex","flex-direction"=>"column") }
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>0.0em) }
#       "Nuclear model with: "))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 1 listeners. Value:
# 36), Observable{Int64} with 1 listeners. Value:
# 36, Scope("knockout-component-62b437be-c4f8-461a-9189-355f7378c1ae", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["charge"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>110,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 1 listeners. Value:
# 36, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":36}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-62b437be-c4f8-461a-9189-355f7378c1ae\",\"id\":\"ob_02\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-62b437be-c4f8-461a-9189-355f7378c1ae\",\"id\":\"ob_01\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope))))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:dropdown,Any}(OrderedDict{Symbol,Any}(:options=>Observable{Any} with 2 listeners. Value:
# ["Fermi", "Fermi", "point", "uniform"],:index=>Observable{Any} with 2 listeners. Value:
# 2), Observable{Any} with 1 listeners. Value:
# "Fermi", Scope("knockout-component-48f7f15e-2637-4259-8973-0aa6d089ee86", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :select), Any[], Dict{Symbol,Any}(:attributes=>Dict{Union{String, Symbol},Any}(Symbol("data-bind")=>"options : options_js, value : index, optionsText: 'key', optionsValue: 'val', valueAllowUnset: true, optionsAfterRender: disablePlaceholder")), 0)], Dict{Symbol,Any}(:className=>"select "), 1), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("options_js"=>(Observable{Any} with 1 listeners. Value:
# OrderedDict[OrderedDict{String,Any}("key"=>"Fermi","val"=>1,"id"=>"idiiCPmPuB"), OrderedDict{String,Any}("key"=>"Fermi","val"=>2,"id"=>"idrqNp2BF5"), OrderedDict{String,Any}("key"=>"point","val"=>3,"id"=>"ideBnsy9bF"), OrderedDict{String,Any}("key"=>"uniform","val"=>4,"id"=>"idBgardR5O")], nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 2, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"options_js\\\":[{\\\"key\\\":\\\"Fermi\\\",\\\"val\\\":1,\\\"id\\\":\\\"idiiCPmPuB\\\"},{\\\"key\\\":\\\"Fermi\\\",\\\"val\\\":2,\\\"id\\\":\\\"idrqNp2BF5\\\"},{\\\"key\\\":\\\"point\\\",\\\"val\\\":3,\\\"id\\\":\\\"ideBnsy9bF\\\"},{\\\"key\\\":\\\"uniform\\\",\\\"val\\\":4,\\\"id\\\":\\\"idBgardR5O\\\"}],\\\"index\\\":2}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        [this[\"disablePlaceholder\"]=function(option, item) {\n    ko.applyBindingsToNode(option, {disable: item.val == 0}, item);\n}\n]\n        \n        [this[\"options_js\"].subscribe((function (val){!(this.valueFromJulia[\"options_js\"]) ? (WebIO.setval({\"name\":\"options_js\",\"scope\":\"knockout-component-48f7f15e-2637-4259-8973-0aa6d089ee86\",\"id\":\"ob_07\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"options_js\"]=false}),self),this[\"index\"].subscribe((function (val){!(this.valueFromJulia[\"index\"]) ? (WebIO.setval({\"name\":\"index\",\"scope\":\"knockout-component-48f7f15e-2637-4259-8973-0aa6d089ee86\",\"id\":\"ob_06\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"index\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"options_js"=>Any[JSString("(function (val){return (val!=this.model[\"options_js\"]()) ? (this.valueFromJulia[\"options_js\"]=true, this.model[\"options_js\"](val)) : undefined})")],"index"=>Any[JSString("(function (val){return (val!=this.model[\"index\"]()) ? (this.valueFromJulia[\"index\"]=true, this.model[\"index\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 78.48), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 78.48, Scope("knockout-component-a70cead9-3e3d-4d8b-91a9-6bc56ce1ff15", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["mass  "], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 78.48, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":78.48}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-a70cead9-3e3d-4d8b-91a9-6bc56ce1ff15\",\"id\":\"ob_09\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-a70cead9-3e3d-4d8b-91a9-6bc56ce1ff15\",\"id\":\"ob_08\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 4.14925), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 4.149254741065642, Scope("knockout-component-47af63fb-9cf5-49f6-90f3-b2294d6c470c", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["radius"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 4.14925, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":4.149254741065642}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-47af63fb-9cf5-49f6-90f3-b2294d6c470c\",\"id\":\"ob_11\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-47af63fb-9cf5-49f6-90f3-b2294d6c470c\",\"id\":\"ob_10\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope))))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Int64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Int64}} with 1 listeners. Value:
# 0), Observable{Union{Nothing, Int64}} with 1 listeners. Value:
# 0, Scope("knockout-component-ae1bbb81-5580-45e7-87f4-853e61c53b73", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["2*spin"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Int64}} with 1 listeners. Value:
# 0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-ae1bbb81-5580-45e7-87f4-853e61c53b73\",\"id\":\"ob_13\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-ae1bbb81-5580-45e7-87f4-853e61c53b73\",\"id\":\"ob_12\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 0.0), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 0.0, Scope("knockout-component-6b01072c-6747-4034-9b0f-87c9dc3de8b4", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["mu    "], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 0.0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":0.0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-6b01072c-6747-4034-9b0f-87c9dc3de8b4\",\"id\":\"ob_15\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-6b01072c-6747-4034-9b0f-87c9dc3de8b4\",\"id\":\"ob_14\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 0.0), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 0.0, Scope("knockout-component-85a442df-6b41-4433-b1be-1367408d9ad5", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["Q     "], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 0.0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":0.0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-85a442df-6b41-4433-b1be-1367408d9ad5\",\"id\":\"ob_17\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-85a442df-6b41-4433-b1be-1367408d9ad5\",\"id\":\"ob_16\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:button,Int64}(OrderedDict{Symbol,Any}(), Observable{Int64} with 1 listeners. Value:
# 0, Scope("knockout-component-17c971f7-14d1-48e8-8894-5ddf093f099f", Node{WebIO.DOM}(WebIO.DOM(:html, :button), Any["Update"], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}("data-bind"=>"click : function () {this.clicks(this.clicks()+1)}"),:className=>"button is-primary",:style=>Dict{String,Any}()), 1), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("clicks"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"clicks\\\":0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"clicks\"].subscribe((function (val){!(this.valueFromJulia[\"clicks\"]) ? (WebIO.setval({\"name\":\"clicks\",\"scope\":\"knockout-component-17c971f7-14d1-48e8-8894-5ddf093f099f\",\"id\":\"ob_18\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"clicks\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"clicks"=>Any[JSString("(function (val){return (val!=this.model[\"clicks\"]()) ? (this.valueFromJulia[\"clicks\"]=true, this.model[\"clicks\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:1), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))))
# Observable{Any} with 0 listeners. Value:
# Fermi nuclear model for Z = 36.0 with mass = 78.48, radius R = 4.149254741065642 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.

# %%
wd = wx[]
# Out:
# Fermi nuclear model for Z = 36.0 with mass = 78.48, radius R = 4.149254741065642 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.

# %%
wx = Nuclear.Model(Gui; model=wb)
# Out:
# (div { style=Dict("display"=>"flex","flex-direction"=>"column") }
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>0.0em) }
#       "Nuclear model with: "))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Int64} with 1 listeners. Value:
# 54), Observable{Int64} with 1 listeners. Value:
# 54, Scope("knockout-component-bbee0a4c-2519-488c-b960-0ba8dc25e7e7", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["charge"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>110,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Int64} with 1 listeners. Value:
# 54, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":54}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-bbee0a4c-2519-488c-b960-0ba8dc25e7e7\",\"id\":\"ob_22\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-bbee0a4c-2519-488c-b960-0ba8dc25e7e7\",\"id\":\"ob_21\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope))))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:dropdown,Any}(OrderedDict{Symbol,Any}(:options=>Observable{Any} with 2 listeners. Value:
# ["uniform", "Fermi", "point", "uniform"],:index=>Observable{Any} with 2 listeners. Value:
# 4), Observable{Any} with 1 listeners. Value:
# "uniform", Scope("knockout-component-c14a4507-3e05-462e-a2fb-db8293f22a20", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :select), Any[], Dict{Symbol,Any}(:attributes=>Dict{Union{String, Symbol},Any}(Symbol("data-bind")=>"options : options_js, value : index, optionsText: 'key', optionsValue: 'val', valueAllowUnset: true, optionsAfterRender: disablePlaceholder")), 0)], Dict{Symbol,Any}(:className=>"select "), 1), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("options_js"=>(Observable{Any} with 1 listeners. Value:
# OrderedDict[OrderedDict{String,Any}("key"=>"uniform","val"=>1,"id"=>"idJIKAbJlX"), OrderedDict{String,Any}("key"=>"Fermi","val"=>2,"id"=>"idaIhRHFID"), OrderedDict{String,Any}("key"=>"point","val"=>3,"id"=>"idMYTzNy6Q"), OrderedDict{String,Any}("key"=>"uniform","val"=>4,"id"=>"idLZtn6DYe")], nothing),"index"=>(Observable{Any} with 2 listeners. Value:
# 4, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"options_js\\\":[{\\\"key\\\":\\\"uniform\\\",\\\"val\\\":1,\\\"id\\\":\\\"idJIKAbJlX\\\"},{\\\"key\\\":\\\"Fermi\\\",\\\"val\\\":2,\\\"id\\\":\\\"idaIhRHFID\\\"},{\\\"key\\\":\\\"point\\\",\\\"val\\\":3,\\\"id\\\":\\\"idMYTzNy6Q\\\"},{\\\"key\\\":\\\"uniform\\\",\\\"val\\\":4,\\\"id\\\":\\\"idLZtn6DYe\\\"}],\\\"index\\\":4}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        [this[\"disablePlaceholder\"]=function(option, item) {\n    ko.applyBindingsToNode(option, {disable: item.val == 0}, item);\n}\n]\n        \n        [this[\"options_js\"].subscribe((function (val){!(this.valueFromJulia[\"options_js\"]) ? (WebIO.setval({\"name\":\"options_js\",\"scope\":\"knockout-component-c14a4507-3e05-462e-a2fb-db8293f22a20\",\"id\":\"ob_27\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"options_js\"]=false}),self),this[\"index\"].subscribe((function (val){!(this.valueFromJulia[\"index\"]) ? (WebIO.setval({\"name\":\"index\",\"scope\":\"knockout-component-c14a4507-3e05-462e-a2fb-db8293f22a20\",\"id\":\"ob_26\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"index\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"options_js"=>Any[JSString("(function (val){return (val!=this.model[\"options_js\"]()) ? (this.valueFromJulia[\"options_js\"]=true, this.model[\"options_js\"](val)) : undefined})")],"index"=>Any[JSString("(function (val){return (val!=this.model[\"index\"]()) ? (this.valueFromJulia[\"index\"]=true, this.model[\"index\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 132.0), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 132.0, Scope("knockout-component-126b48f9-a5c7-46e6-8137-aa442142749d", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["mass  "], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 132.0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":132.0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-126b48f9-a5c7-46e6-8137-aa442142749d\",\"id\":\"ob_29\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-126b48f9-a5c7-46e6-8137-aa442142749d\",\"id\":\"ob_28\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 5.75), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 5.75, Scope("knockout-component-e858cfab-f798-47a5-aff4-1b1061cfc404", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["radius"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 5.75, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":5.75}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-e858cfab-f798-47a5-aff4-1b1061cfc404\",\"id\":\"ob_31\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-e858cfab-f798-47a5-aff4-1b1061cfc404\",\"id\":\"ob_30\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope))))
#   (div { style=Dict("display"=>"flex","flex-direction"=>"row") }
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Int64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Int64}} with 1 listeners. Value:
# 5), Observable{Union{Nothing, Int64}} with 1 listeners. Value:
# 5, Scope("knockout-component-e2545234-e615-43c4-8ba5-244ed05dfa8b", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["2*spin"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Int64}} with 1 listeners. Value:
# 5, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":5}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-e2545234-e615-43c4-8ba5-244ed05dfa8b\",\"id\":\"ob_33\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-e2545234-e615-43c4-8ba5-244ed05dfa8b\",\"id\":\"ob_32\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 1.0), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 1.0, Scope("knockout-component-b4887170-4e89-4e80-8c30-b2ef81a480a7", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["mu    "], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 1.0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":1.0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-b4887170-4e89-4e80-8c30-b2ef81a480a7\",\"id\":\"ob_35\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-b4887170-4e89-4e80-8c30-b2ef81a480a7\",\"id\":\"ob_34\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:spinbox,Union{Nothing, Float64}}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64} with 1 listeners. Value:
# 0,:value=>Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 2.0), Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 2.0, Scope("knockout-component-0c42dfd5-04db-4eae-9fae-934cbc6139eb", Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["Q     "], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-left")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}(:type=>"number",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}"),:placeholder=>"",:className=>"input ",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-center")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[], Dict{Symbol,Any}(), 0)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row-right")), 1)], Dict{Symbol,Any}(:attributes=>Dict("class"=>"interact-flex-row")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing),"value"=>(Observable{Union{Nothing, Float64}} with 1 listeners. Value:
# 2.0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"changes\\\":0,\\\"value\\\":2.0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"changes\"].subscribe((function (val){!(this.valueFromJulia[\"changes\"]) ? (WebIO.setval({\"name\":\"changes\",\"scope\":\"knockout-component-0c42dfd5-04db-4eae-9fae-934cbc6139eb\",\"id\":\"ob_37\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"changes\"]=false}),self),this[\"value\"].subscribe((function (val){!(this.valueFromJulia[\"value\"]) ? (WebIO.setval({\"name\":\"value\",\"scope\":\"knockout-component-0c42dfd5-04db-4eae-9fae-934cbc6139eb\",\"id\":\"ob_36\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"value\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"changes"=>Any[JSString("(function (val){return (val!=this.model[\"changes\"]()) ? (this.valueFromJulia[\"changes\"]=true, this.model[\"changes\"](val)) : undefined})")],"value"=>Any[JSString("(function (val){return (val!=this.model[\"value\"]()) ? (this.valueFromJulia[\"value\"]=true, this.model[\"value\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:2), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))
#     (div { style=Dict("padding"=>1.0em) }
#       Widget{:button,Int64}(OrderedDict{Symbol,Any}(), Observable{Int64} with 1 listeners. Value:
# 0, Scope("knockout-component-09b211f2-ad58-4b44-a62a-5ebcfe53275b", Node{WebIO.DOM}(WebIO.DOM(:html, :button), Any["Update"], Dict{Symbol,Any}(:attributes=>Dict{Any,Any}("data-bind"=>"click : function () {this.clicks(this.clicks()+1)}"),:className=>"button is-primary",:style=>Dict{String,Any}()), 1), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("clicks"=>(Observable{Int64} with 1 listeners. Value:
# 0, nothing)), Set(String[]), nothing, Any["knockout"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout.js", "knockout_punches"=>"/home/fritzsch/.julia/packages/Knockout/JIqpG/src/../assets/knockout_punches.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/all.js", "/home/fritzsch/.julia/packages/InteractBase/PTCUD/src/../assets/style.css", "/home/fritzsch/.julia/packages/InteractBulma/PH56C/src/../assets/main.css"], Dict{Any,Any}("_promises"=>Dict{Any,Any}("importsLoaded"=>Any[JSString("function (ko, koPunches) {\n    ko.punches.enableAll();\n    ko.bindingHandlers.numericValue = {\n        init : function(element, valueAccessor, allBindings, data, context) {\n            var stringified = ko.observable(ko.unwrap(valueAccessor()));\n            stringified.subscribe(function(value) {\n                var val = parseFloat(value);\n                if (!isNaN(val)) {\n                    valueAccessor()(val);\n                }\n            })\n            valueAccessor().subscribe(function(value) {\n                var str = JSON.stringify(value);\n                if ((str == \"0\") && ([\"-0\", \"-0.\"].indexOf(stringified()) >= 0))\n                     return;\n                 if ([\"null\", \"\"].indexOf(str) >= 0)\n                     return;\n                stringified(str);\n            })\n            ko.applyBindingsToNode(element, { value: stringified, valueUpdate: allBindings.get('valueUpdate')}, context);\n        }\n    };\n    var json_data = JSON.parse(\"{\\\"clicks\\\":0}\");\n    var self = this;\n    function AppViewModel() {\n        for (var key in json_data) {\n            var el = json_data[key];\n            this[key] = Array.isArray(el) ? ko.observableArray(el) : ko.observable(el);\n        }\n        \n        \n        [this[\"clicks\"].subscribe((function (val){!(this.valueFromJulia[\"clicks\"]) ? (WebIO.setval({\"name\":\"clicks\",\"scope\":\"knockout-component-09b211f2-ad58-4b44-a62a-5ebcfe53275b\",\"id\":\"ob_38\",\"type\":\"observable\"},val)) : undefined; return this.valueFromJulia[\"clicks\"]=false}),self)]\n        \n    }\n    self.model = new AppViewModel();\n    self.valueFromJulia = {};\n    for (var key in json_data) {\n        self.valueFromJulia[key] = false;\n    }\n    ko.applyBindings(self.model, self.dom);\n}\n")]),"clicks"=>Any[JSString("(function (val){return (val!=this.model[\"clicks\"]()) ? (this.valueFromJulia[\"clicks\"]=true, this.model[\"clicks\"](val)) : undefined})")]), WebIO.ConnectionPool(Channel{Any}(sz_max:9223372036854775807,sz_curr:1), Set(AbstractConnection[]), Channel{AbstractConnection}(sz_max:32,sz_curr:0))), getfield(Base, Symbol("##52#53")){getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}},typeof(scope)}(getfield(WebIO, Symbol("#dom#15")){getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}}(getfield(WebIO, Symbol("##dom#13#14")){Dict{Any,Any},WebIO.DOM}(Dict{Any,Any}(:className=>"field"), WebIO.DOM(:html, :div))), Widgets.scope)))))
# Observable{Any} with 0 listeners. Value:
# Uniform nuclear model for Z = 54.0 with mass = 132.0, radius R = 5.75 fm and nuclear spin I = 5/2, dipole moment mu = 1.0 and quadrupole moment Q = 2.0.

# %%
wd = wx[]
# Out:
# Uniform nuclear model for Z = 54.0 with mass = 132.0, radius R = 5.75 fm and nuclear spin I = 5/2, dipole moment mu = 1.0 and quadrupole moment Q = 2.0.
