# %% [markdown]
# # Photoionization of atomic argon: compute cross sections and angular parameters

# %%
using JAC

# %% [markdown]
# Here, we wish to calculate the cross sections and the $\beta_2$ angular parameters for the photoionzation of atomic argon by linearly-polarized synchrotron radiation. Since the ionization process depends on the energy and polarization of the incident radiatian, the **standard settings** (although available be default) are of less help, and at least the photon energies should be specified in advance.

# %% [markdown]
# Therefore, let us first have a look how these settings are defined internally:

# %%
? PhotoIonization.Settings
# Out:
#   struct  PhotoIonization.Settings ... defines a type for the details and
#   parameters of computing photoionization lines.
#
#   + multipoles              ::Array{EmMultipole}           ... Specifies the multipoles of the radiation field that are to be included.
#   + gauges                  ::Array{UseGauge}              ... Specifies the gauges to be included into the computations.
#   + photonEnergies          ::Array{Float64,1}             ... List of photon energies.
#   + calcAnisotropy          ::Bool                         ... True, if the beta anisotropy parameters are to be calculated and false otherwise.
#   + calcPartialCs           ::Bool                         ... True, if partial cross sections are to be calculated and false otherwise.
#   + calcTensors             ::Bool                         ... True, if the statistical tensors of the excited atom are to be calculated and
#                                                                false otherwise.
#   + printBeforeComputation  ::Bool                         ... True, if all energies and lines are printed before their evaluation.
#   + selectLines             ::Bool                         ... True, if lines are selected individually for the computations.
#   + selectedLines           ::Array{Tuple{Int64,Int64},1}  ... List of lines, given by tupels (inital-level, final-level).
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   JAC.PhotoIonization.Settings() ... constructor for the default values of
#   photoionization line computations

# %%
PhotoIonization.Settings()
# Out:
# multipoles:               EmMultipole[E1]
# gauges:                   UseGauge[Coulomb]
# photonEnergies:           Float64[]
# calcAnisotropy:           false
# calcPartialCs:            false
# calcTensors:              false
# printBeforeComputation:   false
# selectLines:              false
# selectedLines:            Tuple{Int64,Int64}[]

# %% [markdown]
# As seen from these settings, the default only includes the E1 photoionization amplitudes, the use of Coulomb gauge, and *no* photon energies are yet defined.

# %% [markdown]
# We here wish to calculate the cross sections from just the Ar $3s^2 3p^6$ $^1S_0$ ground level at the two photon energies 50 eV and 100 eV, respectively. For this, let us re-set the energy units (to eV) and the `Photoionization.Settings` to:

# %%
JAC.define("unit: energy", "eV")
e1 = JAC.convert("energy: to atomic",  50.)
e2 = JAC.convert("energy: to atomic", 100.)
# Out:
# 3.674932248085465

# %%
photoSettings = PhotoIonization.Settings(EmMultipole[E1], UseGauge[JAC.UseCoulomb, JAC.UseBabushkin], 
                                         Float64[e1, e2], true, true, false, true, 
                                         false, Tuple{Int64,Int64}[])
# Out:
# multipoles:               EmMultipole[E1]
# gauges:                   UseGauge[Coulomb, Babushkin]
# photonEnergies:           [1.83747, 3.67493]
# calcAnisotropy:           true
# calcPartialCs:            true
# calcTensors:              false
# printBeforeComputation:   true
# selectLines:              false
# selectedLines:            Tuple{Int64,Int64}[]

# %% [markdown]
# With these settings, we can proceed standard lines and compute the cross section and $\beta_2$ parameters by:

# %%
wa = Atomic.Computation("Photoionization of Ar: cross sections + beta's",  
            Nuclear.Model(18.);  grid=JAC.Radial.Grid("grid: by given parameters"; rnt = 2.0e-6, 
                                                      h = 5.0e-2, hp = 1.0e-2, NoPoints = 600),
            initialConfigs=[Configuration("[Ne] 2s^2 2p^6")],
            finalConfigs  =[Configuration("[Ne] 2s^2 2p^5")], 
            process = JAC.Photo,  processSettings=photoSettings)
perform(wa)
# Out:
# Define a radial grid of type MeshGL with 610 grid points
#  [rnt=2.000e-06, h=5.000e-02, hp=1.000e-02, NoPoints=600, r_max=3.229e+00;
#   B-splines wit break points at every 7th point, nsL=86, nsS=87, orderL=7, orderS=8, orderGL=7]
# shellOccList = SubString{String}["[Ne]", "2s^2", "2p^6"]
# shellOccList = SubString{String}["[Ne]", "2s^2", "2p^5"]
#
# ... in perform('computation: SCF', ...
# perform-aa: Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 18.0 with mass = 37.62, radius R = 3.37121133160794 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.62704537e+02    -1.62704858e+02    +1.97540708e-06
#       2      2s_1/2      -4.07203231e+01    -4.07203638e+01    +1.00176066e-06
#       3      3s_1/2      -1.80782716e+01    -1.80782839e+01    +6.78213906e-07
#       4      4s_1/2      -1.01576391e+01    -1.01607532e+01    +3.06574905e-04
#       5      5s_1/2      -6.18815324e+00    -6.49914079e+00    +5.02553070e-02
#       6      6s_1/2      -2.16830815e+00    -4.51139835e+00    +1.08060757e+00
#       7      7s_1/2      +3.23232411e+00    -3.31344481e+00    +2.02509671e+00
#       8      8s_1/2      +9.96182647e+00    -2.53622787e+00    +1.25459466e+00
#       :       :
#      81     81s_1/2      +8.43889721e+07    -2.46965924e-02    +1.00000000e+00
#      82     82s_1/2      +1.28120237e+08    -2.40978477e-02    +1.00000000e+00
#      83     83s_1/2      +2.02435611e+08    -2.35206159e-02    +1.00000000e+00
#      84     84s_1/2      +3.44857528e+08    -2.29638786e-02    +1.00000000e+00
#      85     85s_1/2      +6.89708310e+08    -2.24266769e-02    +1.00000000e+00
#      86     86s_1/2      +2.35250935e+09    -2.19081076e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 1s_1/2.
# Use hydrogenic orbital from this symmetriy block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -4.07203637e+01    -4.07203638e+01    +3.27569595e-09
#       2      3p_1/2      -1.80782838e+01    -1.80782839e+01    +7.69713778e-09
#       3      4p_1/2      -1.01585245e+01    -1.01607532e+01    +2.19389863e-04
#       4      5p_1/2      -6.23708888e+00    -6.49914079e+00    +4.20150992e-02
#       5      6p_1/2      -2.38742077e+00    -4.51139835e+00    +8.89653641e-01
#       6      7p_1/2      +2.78929930e+00    -3.31344481e+00    +2.18791297e+00
#       7      8p_1/2      +9.26172001e+00    -2.53622787e+00    +1.27383983e+00
#       8      9p_1/2      +1.69478011e+01    -2.00353566e+00    +1.11821803e+00
#       :       :
#      80     81p_1/2      +7.01827229e+07    -2.46965924e-02    +1.00000000e+00
#      81     82p_1/2      +1.05333351e+08    -2.40978477e-02    +1.00000000e+00
#      82     83p_1/2      +1.63043934e+08    -2.35206159e-02    +1.00000000e+00
#      83     84p_1/2      +2.66877415e+08    -2.29638786e-02    +1.00000000e+00
#      84     85p_1/2      +4.87899156e+08    -2.24266769e-02    +1.00000000e+00
#      85     86p_1/2      +1.16213979e+09    -2.19081076e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -4.05437672e+01    -4.05437672e+01    +1.47037485e-13
#       2      3p_3/2      -1.80259402e+01    -1.80259403e+01    +5.43352820e-09
#       3      4p_3/2      -1.01363834e+01    -1.01386787e+01    +2.26440230e-04
#       4      5p_3/2      -6.22239989e+00    -6.48784308e+00    +4.26592947e-02
#       5      6p_3/2      -2.36828850e+00    -4.50486250e+00    +9.02159518e-01
#       6      7p_3/2      +2.81395254e+00    -3.30933006e+00    +2.17604331e+00
#       7      8p_3/2      +9.29143989e+00    -2.53347193e+00    +1.27266731e+00
#       8      9p_3/2      +1.69823633e+01    -2.00160044e+00    +1.11786348e+00
#       :       :
#      81     82p_3/2      +1.00059900e+08    -2.40952931e-02    +1.00000000e+00
#      82     83p_3/2      +1.53732082e+08    -2.35181525e-02    +1.00000000e+00
#      83     84p_3/2      +2.48201784e+08    -2.29615022e-02    +1.00000000e+00
#      84     85p_3/2      +4.40838781e+08    -2.24243834e-02    +1.00000000e+00
#      85     86p_3/2      +9.65350367e+08    -2.19058931e-02    +1.00000000e+00
#      86     87p_3/2      +3.73444144e+09    -2.14051797e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_3/2.
# Re-define the standard grid with 600 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.13585258e+02;   self-consistency = 1.777817e-01  [1.000000e+02 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.48975296e+01;   self-consistency = 4.642897e-01  [1.000000e+02 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.28092795e+01;   self-consistency = 5.214136e-01  [1.000000e+02 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.35125513e+01;   self-consistency = 5.000565e-01  [1.000000e+02 for symmetry block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.22008916e+02;   self-consistency = 3.575495e-02  [1.642320e-01 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.72790888e+01;   self-consistency = 7.401521e-02  [1.642320e-01 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.48448270e+01;   self-consistency = 7.360742e-02  [1.120715e-01 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.45328879e+01;   self-consistency = 3.638155e-02  [5.390132e-02 for symmetry block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.20379344e+02;   self-consistency = 6.722980e-03  [3.977004e-02 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.67344978e+01;   self-consistency = 1.601098e-02  [3.977004e-02 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.44311475e+01;   self-consistency = 1.413034e-02  [2.447319e-02 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.43833620e+01;   self-consistency = 5.170998e-03  [8.873337e-03 for symmetry block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.20642915e+02;   self-consistency = 1.093555e-03  [6.170587e-03 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.68205568e+01;   self-consistency = 2.564710e-03  [6.170587e-03 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.44890503e+01;   self-consistency = 2.002156e-03  [3.372567e-03 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.43989567e+01;   self-consistency = 5.418160e-04  [9.083082e-04 for symmetry block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.20605460e+02;   self-consistency = 1.552542e-04  [8.803115e-04 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.68083142e+01;   self-consistency = 3.640492e-04  [8.803115e-04 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.44816569e+01;   self-consistency = 2.552024e-04  [4.318055e-04 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.43976095e+01;   self-consistency = 4.678396e-05  [7.880989e-05 for symmetry block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.20610187e+02;   self-consistency = 1.959334e-05  [1.103199e-04 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.68098506e+01;   self-consistency = 4.569952e-05  [1.103199e-04 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.44824802e+01;   self-consistency = 2.842748e-05  [4.803201e-05 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.43976762e+01;   self-consistency = 2.316846e-06  [3.902398e-06 for symmetry block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.20609662e+02;   self-consistency = 2.176676e-06  [1.217052e-05 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.68096810e+01;   self-consistency = 5.045617e-06  [1.217052e-05 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.44824035e+01;   self-consistency = 2.650042e-06  [4.473107e-06 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.43976824e+01;   self-consistency = 2.151451e-07  [3.618081e-07 for symmetry block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.20609710e+02;   self-consistency = 2.024622e-07  [1.118609e-06 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.68096966e+01;   self-consistency = 4.644687e-07  [1.118609e-06 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.44824084e+01;   self-consistency = 1.697734e-07  [2.856809e-07 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.43976798e+01;   self-consistency = 9.061681e-08  [1.525173e-07 for symmetry block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.20609707e+02;   self-consistency = 1.293029e-08  [6.902927e-08 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.68096956e+01;   self-consistency = 2.879291e-08  [6.902927e-08 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.44824085e+01;   self-consistency = 2.895424e-09  [5.102681e-09 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.43976803e+01;   self-consistency = 1.838642e-08  [3.094475e-08 for symmetry block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    0 +     -5.077838478460214e+02    -1.381750229845903e+04    -1.381750229845903e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# ... in perform('computation: SCF', ...
# perform-aa: Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^1 2p_3/2^4
# perform-aa: Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^3
# (Re-) Define a new standard subshell list.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 18.0 with mass = 37.62, radius R = 3.37121133160794 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.62704537e+02    -1.62704858e+02    +1.97540708e-06
#       2      2s_1/2      -4.07203231e+01    -4.07203638e+01    +1.00176066e-06
#       3      3s_1/2      -1.80782716e+01    -1.80782839e+01    +6.78213906e-07
#       4      4s_1/2      -1.01576391e+01    -1.01607532e+01    +3.06574905e-04
#       5      5s_1/2      -6.18815324e+00    -6.49914079e+00    +5.02553070e-02
#       6      6s_1/2      -2.16830815e+00    -4.51139835e+00    +1.08060757e+00
#       7      7s_1/2      +3.23232411e+00    -3.31344481e+00    +2.02509671e+00
#       8      8s_1/2      +9.96182647e+00    -2.53622787e+00    +1.25459466e+00
#       :       :
#      81     81s_1/2      +8.43889721e+07    -2.46965924e-02    +1.00000000e+00
#      82     82s_1/2      +1.28120237e+08    -2.40978477e-02    +1.00000000e+00
#      83     83s_1/2      +2.02435611e+08    -2.35206159e-02    +1.00000000e+00
#      84     84s_1/2      +3.44857528e+08    -2.29638786e-02    +1.00000000e+00
#      85     85s_1/2      +6.89708310e+08    -2.24266769e-02    +1.00000000e+00
#      86     86s_1/2      +2.35250935e+09    -2.19081076e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 1s_1/2.
# Use hydrogenic orbital from this symmetriy block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -4.07203637e+01    -4.07203638e+01    +3.27569595e-09
#       2      3p_1/2      -1.80782838e+01    -1.80782839e+01    +7.69713778e-09
#       3      4p_1/2      -1.01585245e+01    -1.01607532e+01    +2.19389863e-04
#       4      5p_1/2      -6.23708888e+00    -6.49914079e+00    +4.20150992e-02
#       5      6p_1/2      -2.38742077e+00    -4.51139835e+00    +8.89653641e-01
#       6      7p_1/2      +2.78929930e+00    -3.31344481e+00    +2.18791297e+00
#       7      8p_1/2      +9.26172001e+00    -2.53622787e+00    +1.27383983e+00
#       8      9p_1/2      +1.69478011e+01    -2.00353566e+00    +1.11821803e+00
#       :       :
#      80     81p_1/2      +7.01827229e+07    -2.46965924e-02    +1.00000000e+00
#      81     82p_1/2      +1.05333351e+08    -2.40978477e-02    +1.00000000e+00
#      82     83p_1/2      +1.63043934e+08    -2.35206159e-02    +1.00000000e+00
#      83     84p_1/2      +2.66877415e+08    -2.29638786e-02    +1.00000000e+00
#      84     85p_1/2      +4.87899156e+08    -2.24266769e-02    +1.00000000e+00
#      85     86p_1/2      +1.16213979e+09    -2.19081076e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -4.05437672e+01    -4.05437672e+01    +1.47037485e-13
#       2      3p_3/2      -1.80259402e+01    -1.80259403e+01    +5.43352820e-09
#       3      4p_3/2      -1.01363834e+01    -1.01386787e+01    +2.26440230e-04
#       4      5p_3/2      -6.22239989e+00    -6.48784308e+00    +4.26592947e-02
#       5      6p_3/2      -2.36828850e+00    -4.50486250e+00    +9.02159518e-01
#       6      7p_3/2      +2.81395254e+00    -3.30933006e+00    +2.17604331e+00
#       7      8p_3/2      +9.29143989e+00    -2.53347193e+00    +1.27266731e+00
#       8      9p_3/2      +1.69823633e+01    -2.00160044e+00    +1.11786348e+00
#       :       :
#      81     82p_3/2      +1.00059900e+08    -2.40952931e-02    +1.00000000e+00
#      82     83p_3/2      +1.53732082e+08    -2.35181525e-02    +1.00000000e+00
#      83     84p_3/2      +2.48201784e+08    -2.29615022e-02    +1.00000000e+00
#      84     85p_3/2      +4.40838781e+08    -2.24243834e-02    +1.00000000e+00
#      85     86p_3/2      +9.65350367e+08    -2.19058931e-02    +1.00000000e+00
#      86     87p_3/2      +3.73444144e+09    -2.14051797e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_3/2.
# Re-define the standard grid with 600 grid points.
# (Re-) Define a storage array for various B-spline matrices:
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.17873407e+02;   self-consistency = 1.597814e-01  [1.000000e+02 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.73106397e+01;   self-consistency = 4.033999e-01  [1.000000e+02 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.53414587e+01;   self-consistency = 4.526950e-01  [1.000000e+02 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.58800606e+01;   self-consistency = 4.371151e-01  [1.000000e+02 for symmetry block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.24334681e+02;   self-consistency = 2.667654e-02  [4.268682e-01 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.91496021e+01;   self-consistency = 5.043747e-02  [4.268682e-01 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.68598750e+01;   self-consistency = 4.715383e-02  [2.063278e-01 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.66354801e+01;   self-consistency = 2.323257e-02  [1.014094e-01 for symmetry block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.23331176e+02;   self-consistency = 4.051854e-03  [1.105221e-01 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.88229524e+01;   self-consistency = 8.602259e-03  [1.105221e-01 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.66299052e+01;   self-consistency = 6.866867e-03  [3.806783e-02 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.65567605e+01;   self-consistency = 2.371627e-03  [1.255210e-02 for symmetry block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.23460769e+02;   self-consistency = 5.251112e-04  [1.296280e-02 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.88645375e+01;   self-consistency = 1.103419e-03  [1.296280e-02 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.66547847e+01;   self-consistency = 7.474761e-04  [3.983215e-03 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.65626000e+01;   self-consistency = 1.763176e-04  [9.097938e-04 for symmetry block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.23446226e+02;   self-consistency = 5.889913e-05  [1.465567e-03 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.88598884e+01;   self-consistency = 1.232376e-04  [1.465567e-03 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.66524101e+01;   self-consistency = 7.129236e-05  [3.814430e-04 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.65622976e+01;   self-consistency = 9.128144e-06  [4.685978e-05 for symmetry block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.23447661e+02;   self-consistency = 5.811016e-06  [1.432611e-04 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.88603433e+01;   self-consistency = 1.206084e-05  [1.432611e-04 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.66526016e+01;   self-consistency = 5.749447e-06  [3.070150e-05 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.65622945e+01;   self-consistency = 9.534636e-08  [5.698830e-07 for symmetry block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.23447538e+02;   self-consistency = 4.963888e-07  [1.211137e-05 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.88603049e+01;   self-consistency = 1.019166e-06  [1.211137e-05 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.66525899e+01;   self-consistency = 3.508809e-07  [1.867943e-06 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.65622982e+01;   self-consistency = 1.127657e-07  [5.940709e-07 for symmetry block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.23447547e+02;   self-consistency = 3.417694e-08  [8.176415e-07 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.88603075e+01;   self-consistency = 6.877162e-08  [8.176415e-07 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.66525901e+01;   self-consistency = 6.854539e-09  [3.549306e-08 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.65622975e+01;   self-consistency = 2.043635e-08  [1.069186e-07 for symmetry block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 3/2^- ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    3/2 -     -4.923122138628395e+02    -1.339649769378252e+04    -1.339649769378252e+04
#      2    1/2 -     -4.922269354159841e+02    -1.339417714904595e+04    -1.339417714904595e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     8.527844685534092e-02    2.320544736566737e+00    2.320544736566737e+00
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     8.527844685534092e-02    2.320544736566737e+00    2.320544736566737e+00
#
# JAC.PhotoIonization.computeLines(): The computation of photo-ionization and properties starts now ...
# -----------------------------------------------------------------------------------------------------
#
#
#   Selected photoionization lines:
#
#   -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        i-level-f           i--J^P--f        Energy_fi      omega      Energy e_p    List of multipoles, gauges, kappas and total symmetries
#                                                [eV]         [eV]         [eV]       partial (multipole, gauge, total J^P)
#   -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#
#   Photoionization cross sections:
#
#   -------------------------------------------------------------------------------------------------------------------------------------
#        i-level-f          i--J^P--f        f--Energy--i        omega        Energy e_p     Multipoles   Cou -- Cross section -- Bab
#                                                [eV]            [eV]            [eV]                        [barn]          [barn]
#   -------------------------------------------------------------------------------------------------------------------------------------
#   -------------------------------------------------------------------------------------------------------------------------------------
#
#   Partial cross sections for ionization by plane wave photons with ...
#
#   Not yet implemented !!
# JAC.warn():  Reset global array JAC_WARNINGS.

# %% [markdown]
# What can be seen from this output ?? .. and what else could be controlled ?? ... for this, we refer the user to the manual.
