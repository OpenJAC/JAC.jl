# %% [markdown]
# # Expand the atomic state functions in a LS-coupled basis

# %%
using JAC
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-13518485693392362216\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-15793725197321149729\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-13518485693392362216\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")

# %% [markdown]
# In atomic spectroscopy, the (standard) LSJ-notation of levels is frequently applied for classifying the low-lying level structures of atoms or ions. This generally requires a *unitary transformation* from a jjJ --> LSJ-coupled basis which critically depend on the shell-structure of the atoms. Since a lack of providing a fast and proper spectroscopic notation from relativistic structure calculations may hamper the interpretation and analysis of many (computed) results, `JAC` readily provides such transformation (though presently restricted to levels with **not more than two open non-relativistic shells**).
#
# Let us first consider the low-lying $1s^2 2s 2p\; ^{1,3}P$ levels of beryllium-like ions, whose LSJ-decompositions quickly changes from a nearly pure LSJ-coupling for neutral beryllium as the nuclear charge increases along the isoelectronic sequence. We can see this, for instance, by considering the $^1P_1 - ^3P_1$ mixing for these ions.
#
# Most easily, the transformation of atomic states from a jjJ-coupled into a LSJ-coupled basis is made after the Hamiltonian matrix has been diagonalized. In particular, such a jjJ --> LSJ transformation is performed if we set `LSjj.Settings(true)` in `Asf.Settings(...)`.
#
# For this, let us first briefly recall the definion of `AsfSettings(..)`

# %%
? AsfSettings
# Out:
# search: AsfSettings
#   struct  ManyElectron.AsfSettings ... a struct for defining the settings for
#   the atomic state functions, i.e. the self-consistent-field (SCF) and CI
#   computations
#
#   + generateScf          ::Bool               ... True, if a SCF need to be generated, and false otherwise (frozen orbitals).
#   + breitScf             ::Bool               ... True, if Breit interaction is to be included into the SCF computations.
#   + methodScf            ::String             ... Specify the SCF method: ["AL", "OL", "EOL", "meanDFS", "meanHS"].
#   + startScf             ::String             ... Specify how the start orbitals are obtained ["hydrogenic", "fromOrbitals"].
#   + startOrbitals        ::Dict{Subshell, Orbital}  ... List of start orbitals; hydrogenic orbitals are used
#                                                         if not found in this list.
#   + levelsScf            ::Array{Int64,1}     ... Levels on which the optimization need to be carried out.
#   + maxIterationsScf     ::Int64              ... maximum number of SCF iterations
#   + accuracyScf          ::Float64            ... convergence criterion for the SCF field.
#   + shellSequenceScf     ::Array{Subshell,1}  ... Sequence of subshells to be optimized.
#   + frozenSubshells      ::Array{Subshell,1}  ... Sequence of subshells to be kept frozen.
#
#   + coulombCI            ::Bool               ... logical flag to include Coulomb interactions.
#   + breitCI              ::Bool               ... logical flag to include Breit interactions.
#   + qedModel             ::AbstractQedModel   ... model for estimating QED corrections {NoneQed(), QedPetersburg(), QedSydney()}.
#   + methodCI             ::String             ... method for diagonalizing the matrix.
#   + jjLS                 ::LSjjSettings       ... settings to control a jj-LS transformation of atomic level, if requested.
#
#   + selectLevelsCI       ::Bool                          ... true, if specific level (number)s have been selected.
#   + selectedLevelsCI     ::Array{Int64,1}                ... Level number that have been selected.
#   + selectSymmetriesCI   ::Bool                          ... true, if specific level symmetries have been selected.
#   + selectedSymmetriesCI ::Array{LevelSymmetry,1}        ... Level symmetries that have been selected.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   ManyElectron.AsfSettings() ... constructor for setting the default values.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   ManyElectron.AsfSettings(settings::AsfSettings;
#
#           generateScf=..,       breitScf=..,            methodScf=..,          startScf=..,               startOrbitals=..,
#           levelsScf=..,         maxIterationsScf=..,    accuracyScf=..,        shellSequenceScf=..,       frozenSubshells=..,
#           coulombCI=..,         breitCI=..,             qedModel=..,           methodCI=..,               jjLS=..,
#           selectLevelsCI=..,    selectedLevelsCI=..,    selectSymmetriesCI=.., selectedSymmetriesCI=..,   printout::Bool=false)
#   ... constructor for re-defining a settings::AsfSettings.

# %% [markdown]
# and define it as follows:

# %%
asfSettings = AsfSettings(AsfSettings(); generateScf=true, maxIterationsScf=20, jjLS=LSjjSettings(true))
# Out:
# generateScf:          true
# breitScf:             false
# methodScf:            meanDFS
# startScf:             hydrogenic
# startOrbitals:        Dict{Subshell,Orbital}()
# levelsScf:            [1]
# maxIterationsScf:     20
# accuracyScf:          1.0e-6
# shellSequenceScf:     Subshell[]
# frozenSubshells:      Subshell[]
# coulombCI:            true
# breitCI:              false
# qedModel :            NoneQed()
# methodCI:             eigen
# jjLS :                true
# selectLevelsCI:       false
# selectedLevelsCI:     Int64[]
# selectSymmetriesCI:   false
# selectedSymmetriesCI: LevelSymmetry[]

# %% [markdown]
# With these settings, we can calculate the five lowest levels of neutral beryllium due to the $1s^2 (2s^2 + 2s 2p)$ configurations, and which includes the $^1P_1 - ^3P_1$ levels.

# %%
wa = Atomic.Computation("jj-LS level transformation",  Nuclear.Model(4.); 
                        configs=[Configuration("[He] 2s^2"), Configuration("[He] 2s 2p")],  
                        asfSettings=asfSettings )
perform(wa)
# Out:
# Define a radial grid of type MeshGL with 400 grid points
#  [rnt=2.000e-06, h=5.000e-02, hp=0.000e+00, NoPoints=390, r_max=9.161e+02;
#   B-splines with break points at every 7th point, nsL=56, nsS=57, orderL=7, orderS=8, orderGL=7]
#
# ... in perform['computation: SCF'] ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^0 2p_3/2^1
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^1 2p_3/2^0
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 4.0 with mass = 8.08, radius R = 2.247554858082373 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -8.00170451e+00    -8.00170477e+00    +3.27214942e-08
#       2      2s_1/2      -2.00053329e+00    -2.00053275e+00    -2.70620128e-07
#       3      3s_1/2      -8.89087769e-01    -8.89078304e-01    -1.06460554e-05
#       4      4s_1/2      -5.00168012e-01    -5.00086566e-01    -1.62838411e-04
#       5      5s_1/2      -3.20397933e-01    -3.20046366e-01    -1.09728279e-03
#       6      6s_1/2      -2.36183014e-01    -2.22249843e-01    -5.89931103e-02
#       7      7s_1/2      -2.18779779e-01    -1.63283055e-01    -2.53664779e-01
#       8      8s_1/2      -1.60420234e-01    -1.25012068e-01    -2.20721319e-01
#       :       :
#      51     51s_1/2      +8.45987008e+07    -3.07579074e-03    +1.00000000e+00
#      52     52s_1/2      +1.28329099e+08    -2.95862767e-03    +1.00000000e+00
#      53     53s_1/2      +2.02643300e+08    -2.84803376e-03    +1.00000000e+00
#      54     54s_1/2      +3.45062923e+08    -2.74352692e-03    +1.00000000e+00
#      55     55s_1/2      +6.89907592e+08    -2.64466852e-03    +1.00000000e+00
#      56     56s_1/2      +2.35267454e+09    -2.55105871e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      
for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -7.2930669e-02;   self-cons'cy = 8.1813e-02  [8.1813e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -7.1396860e-02;   self-cons'cy = 1.1281e-01  [1.1281e-01 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.8516742e+00;   self-cons'cy = 8.6223e-03  [1.2361e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9216152e-01;   self-cons'cy = 2.8275e-02  [1.2361e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -6.2759529e-02;   self-cons'cy = 7.4959e-02  [7.4959e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -6.3733612e-02;   self-cons'cy = 5.6710e-02  [5.6710e-02 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.8470566e+00;   self-cons'cy = 5.9979e-04  [1.1119e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9354871e-01;   self-cons'cy = 3.5965e-03  [1.1119e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -6.6336299e-02;   self-cons'cy = 2.7706e-02  [2.7706e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -6.5954633e-02;   self-cons'cy = 1.7126e-02  [1.7126e-02 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.8450740e+00;   self-cons'cy = 2.5774e-04  [4.2128e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9224194e-01;   self-cons'cy = 3.3873e-03  [4.2128e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -6.5405727e-02;   self-cons'cy = 7.0636e-03  [7.0636e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -6.5460877e-02;   self-cons'cy = 3.7572e-03  [3.7572e-03 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.8461709e+00;   self-cons'cy = 1.4261e-04  [1.1269e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9270510e-01;   self-cons'cy = 1.2032e-03  [1.1269e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -6.5578655e-02;   self-cons'cy = 1.3202e-03  [1.3202e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -6.5532196e-02;   self-cons'cy = 5.4445e-04  [5.4445e-04 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.8458324e+00;   self-cons'cy = 4.4001e-05  [2.1523e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9258901e-01;   self-cons'cy = 3.0131e-04  [2.1523e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -6.5561598e-02;   self-cons'cy = 1.3007e-04  [1.3007e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -6.5531774e-02;   self-cons'cy = 3.2201e-06  [5.3815e-05 for sym-block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.8459080e+00;   self-cons'cy = 9.8250e-06  [2.2966e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9260986e-01;   self-cons'cy = 5.4119e-05  [2.2966e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -6.5558397e-02;   self-cons'cy = 2.4410e-05  [2.4410e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -6.5527682e-02;   self-cons'cy = 3.1222e-05  [3.1222e-05 for sym-block kappa = -2]
#
# Iteration 10 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.8458967e+00;   self-cons'cy = 1.4685e-06  [3.2597e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9260808e-01;   self-cons'cy = 4.6127e-06  [3.2597e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -6.5560750e-02;   self-cons'cy = 1.7945e-05  [1.7945e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -6.5529416e-02;   self-cons'cy = 1.3230e-05  [1.3230e-05 for sym-block kappa = -2]
#
# Iteration 11 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.8458969e+00;   self-cons'cy = 2.5119e-08  [2.7324e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9260758e-01;   self-cons'cy = 1.3064e-06  [2.7324e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -6.5559959e-02;   self-cons'cy = 6.0314e-06  [6.0314e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -6.5528936e-02;   self-cons'cy = 3.6580e-06  [3.6580e-06 for sym-block kappa = -2]
#
# Iteration 12 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.8458975e+00;   self-cons'cy = 7.7440e-08  [9.4585e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9260789e-01;   self-cons'cy = 8.2105e-07  [9.4585e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -6.5560149e-02;   self-cons'cy = 1.4451e-06  [1.4451e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -6.5529033e-02;   self-cons'cy = 7.3623e-07  [7.3623e-07 for sym-block kappa = -2]
#
# Iteration 13 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.8458972e+00;   self-cons'cy = 3.3861e-08  [2.3140e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9260779e-01;   self-cons'cy = 2.6471e-07  [2.3140e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -6.5560117e-02;   self-cons'cy = 2.4256e-07  [2.4256e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -6.5529021e-02;   self-cons'cy = 8.8641e-08  [1.6800e-07 for sym-block kappa = -2]
#
# Iteration 14 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.8458973e+00;   self-cons'cy = 9.5157e-09  [1.0105e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9260782e-01;   self-cons'cy = 6.1430e-08  [1.0105e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -6.5560119e-02;   self-cons'cy = 1.4731e-08  [1.8536e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -6.5529020e-02;   self-cons'cy = 7.0312e-09  [2.3755e-07 for sym-block kappa = -2]
#
# Iteration 15 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.8458973e+00;   self-cons'cy = 1.9520e-09  [2.8152e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9260781e-01;   self-cons'cy = 9.8726e-09  [2.8152e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -6.5560120e-02;   self-cons'cy = 8.4388e-09  [4.3852e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -6.5529021e-02;   self-cons'cy = 8.3478e-09  [1.6132e-07 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 2^- ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^+ ...   ... done.
# Compute CI matrix of dimension 2 x 2 for the symmetry 1^- ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    0 +     -1.457095905949554e+01    -3.964959916495494e+02    -3.964959916495494e+02
#      2    0 -     -1.450418357886903e+01    -3.946789382695503e+02    -3.946789382695503e+02
#      3    1 -     -1.450417391529235e+01    -3.946786753102350e+02    -3.946786753102350e+02
#      4    2 -     -1.450415458740445e+01    -3.946781493716163e+02    -3.946781493716163e+02
#      5    1 -     -1.437768201564115e+01    -3.912366554004231e+02    -3.912366554004231e+02
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    0 -     6.677548062651439e-02    1.817053379999115e+00    1.817053379999115e+00
#      3    1 -     9.663576676643970e-06    2.629593152820278e-04    2.629593152820278e-04
#      4    2 -     1.932788790348638e-05    5.259386186930565e-04    5.259386186930565e-04
#      5    1 -     1.264725717632960e-01    3.441493971193198e+00    3.441493971193198e+00
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    0 -     6.677548062651439e-02    1.817053379999115e+00    1.817053379999115e+00
#      3    1 -     6.678514420319104e-02    1.817316339314397e+00    1.817316339314397e+00
#      4    2 -     6.680447209109452e-02    1.817842277933090e+00    1.817842277933090e+00
#      5    1 -     1.932770438543905e-01    5.259336249126288e+00    5.259336249126288e+00
#
#   LSjj.expandLevelsIntoLS():: Relativistic basis with 5 CsfR will be transformed into a nonrelativistic basis with 5 CsfNR.
#
#   LS-expansion of selected atomic levels:
#
#     Level   1      0 +   -3.96495992e+02  [eV]  has weight 1.0000e+00 of 1s^2 2s^2
#        1)   1.0000e+00   of     ^1S_0
#
#     Level   2      0 -   -3.94678938e+02  [eV]  has weight 1.0000e+00 of 1s^2 2s^1 2p^1
#        1)   1.0000e+00   of     ^3P_0
#
#     Level   3      1 -   -3.94678675e+02  [eV]  has weight 1.0000e+00 of 1s^2 2s^1 2p^1
#        1)   1.0000e+00   of     ^3P_1
#
#     Level   4      2 -   -3.94678149e+02  [eV]  has weight 1.0000e+00 of 1s^2 2s^1 2p^1
#        1)   1.0000e+00   of     ^3P_2
#
#     Level   5      1 -   -3.91236655e+02  [eV]  has weight 1.0000e+00 of 1s^2 2s^1 2p^1
#        1)   1.0000e+00   of     ^1P_1
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# Apart from the successfull SCF iteration, the final part of this output shows the LS-expansion of all selected levels. While, in these simple computations, the $2s^2\; ^1S_0$ and the $2s 2p\; ^3P_{0,2}$ must be pure, configuation mixing will generally affect the two $2s 2p\; ^{1,3}P_1$ already in this single-configurations approximation. For neutral beryllium, however, this mixing is so *small* that both these levels appear basically *pure* in LSJ notation.
#
# We can repeat analogue computations for beryllium-like argon ($Z=18$) and xenon ($Z=54$), with focus especially to the corresponding LSJ-expansions:

# %%
wa = Atomic.Computation("jj-LS level transformation",  Nuclear.Model(18.); 
                        configs=[Configuration("[He] 2s^2"), Configuration("[He] 2s 2p")],  
                        asfSettings=asfSettings )
perform(wa)
# Out:
# Define a radial grid of type MeshGL with 400 grid points
#  [rnt=2.000e-06, h=5.000e-02, hp=0.000e+00, NoPoints=390, r_max=9.161e+02;
#   B-splines with break points at every 7th point, nsL=56, nsS=57, orderL=7, orderS=8, orderGL=7]
#
# ... in perform['computation: SCF'] ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^0 2p_3/2^1
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^1 2p_3/2^0
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 18.0 with mass = 37.62, radius R = 3.37121133160794 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.62704538e+02    -1.62704858e+02    +1.97039609e-06
#       2      2s_1/2      -4.07203374e+01    -4.07203638e+01    +6.49688015e-07
#       3      3s_1/2      -1.80783502e+01    -1.80782839e+01    -3.66736097e-06
#       4      4s_1/2      -1.01630048e+01    -1.01607532e+01    -2.21550873e-04
#       5      5s_1/2      -6.52598976e+00    -6.49914079e+00    -4.11416134e-03
#       6      6s_1/2      -4.90691584e+00    -4.51139835e+00    -8.06040913e-02
#       7      7s_1/2      -4.20146491e+00    -3.31344481e+00    -2.11359637e-01
#       8      8s_1/2      -3.08011967e+00    -2.53622787e+00    -1.76581385e-01
#       :       :
#      51     51s_1/2      +8.43772143e+07    -6.23045948e-02    +1.00000000e+00
#      52     52s_1/2      +1.28107975e+08    -5.99309256e-02    +1.00000000e+00
#      53     53s_1/2      +2.02422364e+08    -5.76903640e-02    +1.00000000e+00
#      54     54s_1/2      +3.44842071e+08    -5.55731408e-02    +1.00000000e+00
#      55     55s_1/2      +6.89686771e+08    -5.35703666e-02    +1.00000000e+00
#      56     56s_1/2      +2.35245373e+09    -5.16739387e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -4.07203674e+01    -4.07203638e+01    -8.83757343e-08
#       2      3p_1/2      -1.80783120e+01    -1.80782839e+01    -1.55553280e-06
#       3      4p_1/2      -1.01616238e+01    -1.01607532e+01    -8.56729898e-05
#       4      5p_1/2      -6.50673320e+00    -6.49914079e+00    -1.16685570e-03
#       5      6p_1/2      -4.56718050e+00    -4.51139835e+00    -1.22136939e-02
#       6      7p_1/2      -3.62184191e+00    -3.31344481e+00    -8.51492432e-02
#       7      8p_1/2      -2.93197737e+00    -2.53622787e+00    -1.34976997e-01
#       8      9p_1/2      -2.17891209e+00    -2.00353566e+00    -8.04880683e-02
#       :       :
#      50     51p_1/2      +7.01712871e+07    -6.23045948e-02    +1.00000000e+00
#      51     52p_1/2      +1.05321550e+08    -5.99309256e-02    +1.00000000e+00
#      52     53p_1/2      +1.63031451e+08    -5.76903640e-02    +1.00000000e+00
#      53     54p_1/2      +2.66863504e+08    -5.55731408e-02    +1.00000000e+00
#      54     55p_1/2      +4.87881745e+08    -5.35703666e-02    +1.00000000e+00
#      55     56p_1/2      +1.16211058e+09    -5.16739387e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -4.05437723e+01    -4.05437672e+01    -1.25441315e-07
#       2      3p_3/2      -1.80259817e+01    -1.80259403e+01    -2.29906936e-06
#       3      4p_3/2      -1.01404193e+01    -1.01386787e+01    -1.71648740e-04
#       4      5p_3/2      -6.53303125e+00    -6.48784308e+00    -6.91687611e-03
#       5      6p_3/2      -5.53748745e+00    -4.50486250e+00    -1.86478969e-01
#       6      7p_3/2      -4.36801744e+00    -3.30933006e+00    -2.42372516e-01
#       7      8p_3/2      -3.13479184e+00    -2.53347193e+00    -1.91821321e-01
#       8      9p_3/2      -2.27815763e+00    -2.00160044e+00    -1.21395108e-01
#       :       :
#      51     52p_3/2      +1.00047614e+08    -5.99209070e-02    +1.00000000e+00
#      52     53p_3/2      +1.53719087e+08    -5.76809020e-02    +1.00000000e+00
#      53     54p_3/2      +2.48187341e+08    -5.55641948e-02    +1.00000000e+00
#      54     55p_3/2      +4.40820909e+08    -5.35618998e-02    +1.00000000e+00
#      55     56p_3/2      +9.65321960e+08    -5.16659174e-02    +1.00000000e+00
#      56     57p_3/2      +3.73435402e+09    -4.98688525e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# (Re-) Define the standard grid with 390 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.3870434e+02;   self-cons'cy = 7.9627e-02  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.9791064e+01;   self-cons'cy = 1.5500e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.8533309e+01;   self-cons'cy = 1.7598e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8449946e+01;   self-cons'cy = 1.7529e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.3971984e+02;   self-cons'cy = 3.6473e-03  [1.2261e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.0063318e+01;   self-cons'cy = 4.5486e-03  [1.2261e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.8687263e+01;   self-cons'cy = 2.6905e-03  [4.5164e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8565006e+01;   self-cons'cy = 2.0181e-03  [5.2649e-03 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.3968046e+02;   self-cons'cy = 1.4094e-04  [4.2422e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.0054025e+01;   self-cons'cy = 1.5458e-04  [4.2422e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.8684373e+01;   self-cons'cy = 5.0383e-05  [9.0541e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8563042e+01;   self-cons'cy = 3.4380e-05  [9.7619e-05 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.3968188e+02;   self-cons'cy = 5.0967e-06  [1.3673e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.0054325e+01;   self-cons'cy = 4.9845e-06  [1.3673e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.8684415e+01;   self-cons'cy = 7.3059e-07  [1.2963e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8563067e+01;   self-cons'cy = 4.4891e-07  [1.2505e-06 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.3968183e+02;   self-cons'cy = 1.8035e-07  [4.4199e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.0054315e+01;   self-cons'cy = 1.6163e-07  [4.4199e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.8684414e+01;   self-cons'cy = 5.1854e-09  [8.6425e-09 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8563067e+01;   self-cons'cy = 1.3343e-09  [2.7812e-09 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 2^- ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^+ ...   ... done.
# Compute CI matrix of dimension 2 x 2 for the symmetry 1^- ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    0 +     -3.791889988378534e+02    -1.031825822191416e+04    -1.031825822191416e+04
#      2    0 -     -3.783494791379018e+02    -1.029541372728738e+04    -1.029541372728738e+04
#      3    1 -     -3.783136270435646e+02    -1.029443814210875e+04    -1.029443814210875e+04
#      4    2 -     -3.782331166235951e+02    -1.029224734199232e+04    -1.029224734199232e+04
#      5    1 -     -3.772704364513550e+02    -1.026605148021170e+04    -1.026605148021170e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    0 -     8.395196999515520e-01    2.284449462677625e+01    2.284449462677625e+01
#      3    1 -     3.585209433725822e-02    9.755851786365896e-01    9.755851786365896e-01
#      4    2 -     8.051041996947106e-02    2.190800116421594e+00    2.190800116421594e+00
#      5    1 -     9.626801722401410e-01    2.619586178062657e+01    2.619586178062657e+01
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    0 -     8.395196999515520e-01    2.284449462677625e+01    2.284449462677625e+01
#      3    1 -     8.753717942888102e-01    2.382007980541285e+01    2.382007980541285e+01
#      4    2 -     9.558822142582812e-01    2.601087992183444e+01    2.601087992183444e+01
#      5    1 -     1.918562386498422e+00    5.220674170246100e+01    5.220674170246100e+01
#
#   LSjj.expandLevelsIntoLS():: Relativistic basis with 5 CsfR will be transformed into a nonrelativistic basis with 5 CsfNR.
#
#   LS-expansion of selected atomic levels:
#
#     Level   1      0 +   -1.03182582e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2
#        1)   1.0000e+00   of     ^1S_0
#
#     Level   2      0 -   -1.02954137e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^1 2p^1
#        1)   1.0000e+00   of     ^3P_0
#
#     Level   3      1 -   -1.02944381e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^1 2p^1
#        1)   8.5339e-01   of     ^1P_1
#        2)   1.4661e-01   of     ^3P_1
#
#     Level   4      2 -   -1.02922473e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^1 2p^1
#        1)   1.0000e+00   of     ^3P_2
#
#     Level   5      1 -   -1.02660515e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^1 2p^1
#        1)   8.5339e-01   of     ^3P_1
#        2)   1.4661e-01   of     ^1P_1
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %%
wa = Atomic.Computation("jj-LS level transformation",  Nuclear.Model(54.); 
                        configs=[Configuration("[He] 2s^2"), Configuration("[He] 2s 2p")],  
                        asfSettings=asfSettings )
perform(wa)
# Out:
# Define a radial grid of type MeshGL with 400 grid points
#  [rnt=2.000e-06, h=5.000e-02, hp=0.000e+00, NoPoints=390, r_max=9.161e+02;
#   B-splines with break points at every 7th point, nsL=56, nsS=57, orderL=7, orderS=8, orderGL=7]
#
# ... in perform['computation: SCF'] ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^0 2p_3/2^1
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^1 2p_3/2^0
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 54.0 with mass = 122.58, radius R = 4.722849091608491 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.51935928e+03    -1.51947334e+03    +7.50765232e-05
#       2      2s_1/2      -3.83773854e+02    -3.83790162e+02    +4.24935903e-05
#       3      3s_1/2      -1.68797617e+02    -1.68801804e+02    +2.48055279e-05
#       4      4s_1/2      -9.42194949e+01    -9.42128372e+01    -7.06620685e-05
#       5      5s_1/2      -6.01304950e+01    -5.99659315e+01    -2.73677296e-03
[1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.4822466e+02;   self-cons'cy = 4.8565e-02  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4329190e+02;   self-cons'cy = 5.5699e-02  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.2946463e+02;   self-cons'cy = 5.5397e-02  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.4443472e+03;   self-cons'cy = 3.8040e-04  [2.5136e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.4853490e+02;   self-cons'cy = 4.4525e-04  [2.5136e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4347699e+02;   self-cons'cy = 2.6950e-04  [1.1666e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.2959602e+02;   self-cons'cy = 1.9936e-04  [5.2227e-04 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.4443329e+03;   self-cons'cy = 4.9731e-06  [2.6439e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.4853141e+02;   self-cons'cy = 5.0025e-06  [2.6439e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4347589e+02;   self-cons'cy = 1.5970e-06  [6.2375e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.2959531e+02;   self-cons'cy = 1.0853e-06  [2.8834e-06 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.4443330e+03;   self-cons'cy = 6.2207e-08  [2.9324e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.4853145e+02;   self-cons'cy = 5.6023e-08  [2.9324e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4347590e+02;   self-cons'cy = 8.4224e-09  [3.2800e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.2959531e+02;   self-cons'cy = 5.4576e-09  [1.4479e-08 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.4443330e+03;   self-cons'cy = 7.7317e-10  [3.3598e-09 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.4853145e+02;   self-cons'cy = 6.4861e-10  [3.3598e-09 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.4347590e+02;   self-cons'cy = 3.6702e-11  [1.4025e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.2959531e+02;   self-cons'cy = 2.1777e-11  [5.7591e-10 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 2^- ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^+ ...   ... done.
# Compute CI matrix of dimension 2 x 2 for the symmetry 1^- ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    0 +     -3.716450568507916e+03    -1.011297710439174e+05    -1.011297710439174e+05
#      2    0 -     -3.712964310659564e+03    -1.010349051358406e+05    -1.010349051358406e+05
#      3    1 -     -3.712050373980091e+03    -1.010100356520576e+05    -1.010100356520576e+05
#      4    2 -     -3.699280452576406e+03    -1.006625483912969e+05    -1.006625483912969e+05
#      5    1 -     -3.696939456451874e+03    -1.005988466420809e+05    -1.005988466420809e+05
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    0 -     3.486257848351670e+00    9.486590807675191e+01    9.486590807675191e+01
#      3    1 -     9.139366794738635e-01    2.486948378300031e+01    2.486948378300031e+01
#      4    2 -     1.276992140368475e+01    3.474872607607259e+02    3.474872607607259e+02
#      5    1 -     2.340996124532012e+00    6.370174921596457e+01    6.370174921596457e+01
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    0 -     3.486257848351670e+00    9.486590807675191e+01    9.486590807675191e+01
#      3    1 -     4.400194527825533e+00    1.197353918597522e+02    1.197353918597522e+02
#      4    2 -     1.717011593151028e+01    4.672226526204781e+02    4.672226526204781e+02
#      5    1 -     1.951111205604229e+01    5.309244018364427e+02    5.309244018364427e+02
#
#   LSjj.expandLevelsIntoLS():: Relativistic basis with 5 CsfR will be transformed into a nonrelativistic basis with 5 CsfNR.
#
#   LS-expansion of selected atomic levels:
#
#     Level   1      0 +   -1.01129771e+05  [eV]  has weight 1.0000e+00 of 1s^2 2s^2
#        1)   1.0000e+00   of     ^1S_0
#
#     Level   2      0 -   -1.01034905e+05  [eV]  has weight 1.0000e+00 of 1s^2 2s^1 2p^1
#        1)   1.0000e+00   of     ^3P_0
#
#     Level   3      1 -   -1.01010036e+05  [eV]  has weight 1.0000e+00 of 1s^2 2s^1 2p^1
#        1)   7.5858e-01   of     ^3P_1
#        2)   2.4142e-01   of     ^1P_1
#
#     Level   4      2 -   -1.00662548e+05  [eV]  has weight 1.0000e+00 of 1s^2 2s^1 2p^1
#        1)   1.0000e+00   of     ^3P_2
#
#     Level   5      1 -   -1.00598847e+05  [eV]  has weight 1.0000e+00 of 1s^2 2s^1 2p^1
#        1)   7.5858e-01   of     ^1P_1
#        2)   2.4142e-01   of     ^3P_1
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# From the last two computations, we see that relative contribution of the $^3P_1$ (non-relativistic LSJ) configuration state of the $2s 2p\; ^{3}P_1$ level drops from 1.00 ($Z=4$) to 0.85 ($Z=18$) to 0.76 ($Z=54$), and similarly also for the $2s 2p\; ^{1}P_1$ level. This change in non-relativistic LSJ decomposition is also the main reason why the $2s 2p\; ^{3}P_1 - 2s^2\; ^1S_0$ (intercombination) line is very week, when compared with the $2s 2p\; ^{1}P_1 - 2s^2\; ^1S_0$ resonance line, for neutral beryllium but become comparable to each other for medium and heavy elements. The transition strength of all these transitions arise from (resonance) decay within the singlett system, while the $2s 2p\; ^{3}P$ represent the lowest term (levels) of the triplett system.
#
# The jjJ --> LSJ transformation is presently restricted to configuration expansions for which all non-relativistic CSF have **not more than two open non-relativistic shells**. This restriction can be released if the re-coupling coefficients are implemented for a larger number of open shells. Since these jjJ --> LSJ transformation can become quite expensive for complex shell structure, they can be further controlled by selecting individual levels (or symmetries of levels) as well as a minimum with which a (relativistic) CSF must contribute to least on the (selected) levels to be taken into account in the expansion.
#
# In `JAC`, an improved control about such jjJ --> LSJ transformation is prepared (but not yet realized in all detail) by the parameters of the `LSjjSettings`, and is shown together with its  default settings:

# %%
?LSjjSettings
# Out:
# search: LSjjSettings
#   struct  ManyElectron.LSjjSettings ... defines a type for the details and
#   parameters for performing jj-LS expansions.
#
#   + makeIt         ::Bool            ... True, if the jj-LS expansion is to be made and false otherwise.
#   + minWeight      ::Float64         ... minimum weight with which a (relativistic) CSF must contribute to (at least one) level.
#   + printWeight    ::Float64         ... minimum weight of a nonrelativistic CSF to be printed out in the final expansion.
#   + selectLevels   ::Bool            ... True, if levels are selected individually for the computations.
#   + selectedLevels ::Array{Int64,1}  ... List of levels.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   LSjjSettings(makeIt::Bool) ... constructor for the default values of jj-LS
#   transformations.

# %%
LSjjSettings(true)
# Out:
# makeIt:            true
# minWeight:         0.05
# printWeight:       0.1
# selectLines:       false
# selectedLines:     Int64[]

# %% [markdown]
# As seen from beryllium-example above, the LS-coupling notation of levels can often be derived for simple shell structure by considering the fine-structure splitting (energies) and the total $J$ values of the atomic levels. For beryllium-like ions, for exmaple, the $^3P_{0,1,2}$ triplet can be identified quite easily by just looking for it fine-structure energies as obtained from a simple CI computations.
#
# This identification becomes much less obvious if open $d$-shells or even $f$-shells are involved
# as, for example, for the levels of $3d^3$ ground configuration of scandium-like iron. Following similar lines as above, we obtain:

# %%
wa = Atomic.Computation("jj-LS level transformation",  Nuclear.Model(26.); 
                        configs=[Configuration("[Ar] 3d^3")], asfSettings=asfSettings )
perform(wa)
# Out:
# Define a radial grid of type MeshGL with 400 grid points
#  [rnt=2.000e-06, h=5.000e-02, hp=0.000e+00, NoPoints=390, r_max=9.161e+02;
#   B-splines with break points at every 7th point, nsL=56, nsS=57, orderL=7, orderS=8, orderGL=7]
#
# ... in perform['computation: SCF'] ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^2 3p_3/2^4 3d_3/2^0 3d_5/2^3
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^2 3p_3/2^4 3d_3/2^1 3d_5/2^2
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^2 3p_3/2^4 3d_3/2^2 3d_5/2^1
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^2 3p_3/2^4 3d_3/2^3 3d_5/2^0
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 26.0 with mass = 55.38, radius R = 3.756573410087755 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -3.41095882e+02    -3.41097837e+02    +5.73282577e-06
#       2      2s_1/2      -8.54687335e+01    -8.54689584e+01    +2.63136714e-06
#       3      3s_1/2      -3.78995149e+01    -3.78994478e+01    -1.77118976e-06
#       4      4s_1/2      -2.12860102e+01    -2.12819385e+01    -1.91283922e-04
#       5      5s_1/2      -1.36596748e+01    -1.36039714e+01    -4.07794550e-03
#       6      6s_1/2      -1.02231533e+01    -9.43887322e+00    -7.67160661e-02
#       7      7s_1/2      -8.71004839e+00    -6.93005925e+00    -2.04360420e-01
#       8      8s_1/2      -6.39173280e+00    -5.30306679e+00    -1.70324081e-01
#       :       :
#      51     51s_1/2      +8.42794522e+07    -1.30041283e-01    +1.00000000e+00
#      52     52s_1/2      +1.28010239e+08    -1.25086123e-01    +1.00000000e+00
#      53     53s_1/2      +2.02324641e+08    -1.20408879e-01    +1.00000000e+00
#      54     54s_1/2      +3.44744353e+08    -1.15989152e-01    +1.00000000e+00
#      55     55s_1/2      +6.89589055e+08    -1.11808377e-01    +1.00000000e+00
#      56     56s_1/2      +2.35235601e+09    -1.07849636e-01    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 3s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -8.54689639e+01    -8.54689584e+01    -6.48489779e-08
#       2      3p_1/2      -3.78994938e+01    -3.78994478e+01    -1.21351773e-06
#       3      4p_1/2      -2.12835731e+01    -2.12819385e+01    -7.68010407e-05
#       4      5p_1/2      -1.36205252e+01    -1.36039714e+01    -1.21535783e-03
#       5      6p_1/2      -9.56125779e+00    -9.43887322e+00    -1.28000495e-02
#       6      7p_1/2      -7.52775477e+00    -6.93005925e+00    -7.93989094e-02
#       7      8p_1/2      -6.03969738e+00    -5.30306679e+00    -1.21964819e-01
#       8      9p_1/2      -4.48651176e+00    -4.18833237e+00    -6.64612987e-02
#       :       :
#      50     51p_1/2      +7.00735016e+07    -1.30041283e-01    +1.00000000e+00
#      51     52p_1/2      +1.05223801e+08    -1.25086123e-01    +1.00000000e+00
#      52     53p_1/2      +1.62933722e+08    -1.20408879e-01    +1.00000000e+00
#      53     54p_1/2      +2.66765784e+08    -1.15989152e-01    +1.00000000e+00
#      54     55p_1/2      +4.87784029e+08    -1.11808377e-01    +1.00000000e+00
#      55     56p_1/2      +1.16201287e+09    -1.07849636e-01    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 3p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      
-01    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 3d_5/2.
# (Re-) Define the standard grid with 390 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.3883217e+02;   self-cons'cy = 1.7634e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.1931166e+01;   self-cons'cy = 5.9160e-01  [1.0000e+02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -3.7953960e+00;   self-cons'cy = 8.1794e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.9540456e+01;   self-cons'cy = 6.2783e-01  [1.0000e+02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.3716966e+00;   self-cons'cy = 8.3661e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.2473434e+01;   self-cons'cy = 5.8058e-01  [1.0000e+02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -3.9730649e+00;   self-cons'cy = 8.0918e-01  [1.0000e+02 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -3.2592626e+00;   self-cons'cy = 8.4073e-01  [1.0000e+02 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -3.6225492e+00;   self-cons'cy = 8.2422e-01  [1.0000e+02 for sym-block kappa = -3]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6494960e+02;   self-cons'cy = 5.1843e-02  [1.0695e+00 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.6275002e+01;   self-cons'cy = 2.4643e-01  [1.0695e+00 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -7.5479519e+00;   self-cons'cy = 3.3082e-01  [1.0695e+00 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.1163014e+01;   self-cons'cy = 2.2923e-01  [4.1787e-01 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -5.8556258e+00;   self-cons'cy = 2.6919e-01  [4.1787e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.9408345e+01;   self-cons'cy = 1.3367e-01  [5.0877e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -5.3299171e+00;   self-cons'cy = 1.4585e-01  [5.0877e-01 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -2.8739012e+00;   self-cons'cy = 6.2832e-02  [1.5208e-01 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -2.8883274e+00;   self-cons'cy = 1.1277e-01  [2.4371e-01 for sym-block kappa = -3]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.5885842e+02;   self-cons'cy = 1.1629e-02  [1.5570e+00 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.2823532e+01;   self-cons'cy = 4.9950e-02  [1.5570e+00 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -6.2518766e+00;   self-cons'cy = 9.3920e-02  [1.5570e+00 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.8943833e+01;   self-cons'cy = 3.6921e-02  [1.2796e-01 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -5.1151177e+00;   self-cons'cy = 6.7498e-02  [1.2796e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8708445e+01;   self-cons'cy = 1.2043e-02  [1.0679e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -5.1205005e+00;   self-cons'cy = 2.0039e-02  [1.0679e-01 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -3.1782627e+00;   self-cons'cy = 5.0290e-02  [1.4255e-01 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -3.1314535e+00;   self-cons'cy = 4.0388e-02  [7.8832e-02 for sym-block kappa = -3]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.5967358e+02;   self-cons'cy = 1.5720e-03  [3.5645e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.3207078e+01;   self-cons'cy = 5.8086e-03  [3.5645e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -6.3579826e+00;   self-cons'cy = 8.4145e-03  [3.5645e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.9069139e+01;   self-cons'cy = 2.1600e-03  [2.8548e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -5.1266622e+00;   self-cons'cy = 1.1272e-03  [2.8548e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8599035e+01;   self-cons'cy = 1.9092e-03  [4.4068e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -5.0603517e+00;   self-cons'cy = 5.9080e-03  [4.4068e-02 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -3.0854118e+00;   self-cons'cy = 1.4824e-02  [4.0837e-02 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -3.0872816e+00;   self-cons'cy = 7.1030e-03  [1.6426e-02 for sym-block kappa = -3]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.5966464e+02;   self-cons'cy = 1.7222e-05  [1.5023e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.3227634e+01;   self-cons'cy = 3.0941e-04  [1.5023e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -6.3728378e+00;   self-cons'cy = 1.1669e-03  [1.5023e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.9119552e+01;   self-cons'cy = 8.6637e-04  [4.7711e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -5.1504909e+00;   self-cons'cy = 2.3186e-03  [4.7711e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8657178e+01;   self-cons'cy = 1.0155e-03  [1.4711e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -5.0851734e+00;   self-cons'cy = 2.4466e-03  [1.4711e-02 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -3.0963886e+00;   self-cons'cy = 1.7757e-03  [7.2285e-03 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -3.0870906e+00;   self-cons'cy = 3.0942e-05  [3.3330e-04 for sym-block kappa = -3]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.5963612e+02;   self-cons'cy = 5.4914e-05  [5.8678e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.3207023e+01;   self-cons'cy = 3.1025e-04  [5.8678e-03 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -6.3642713e+00;   self-cons'cy = 6.7256e-04  [5.8678e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.9101008e+01;   self-cons'cy = 3.1850e-04  [1.2199e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -5.1433910e+00;   self-cons'cy = 6.8972e-04  [1.2199e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8646100e+01;   self-cons'cy = 1.9332e-04  [2.2707e-03 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -5.0808728e+00;   self-cons'cy = 4.2304e-04  [2.2707e-03 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -3.0973557e+00;   self-cons'cy = 1.5614e-04  [3.0860e-04 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -3.0890681e+00;   self-cons'cy = 3.2019e-04  [6.0940e-04 for sym-block kappa = -3]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.5964378e+02;   self-cons'cy = 1.4759e-05  [8.8146e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.3211506e+01;   self-cons'cy = 6.7504e-05  [8.8146e-04 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -6.3658843e+00;   self-cons'cy = 1.2671e-04  [8.8146e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.9103782e+01;   self-cons'cy = 4.7647e-05  [1.1914e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -5.1442644e+00;   self-cons'cy = 8.4905e-05  [1.1914e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8646580e+01;   self-cons'cy = 8.3840e-06  [3.4382e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -5.0809580e+00;   self-cons'cy = 8.3827e-06  [3.4382e-05 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -3.0966043e+00;   self-cons'cy = 1.2131e-04  [3.9768e-04 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -3.0885358e+00;   self-cons'cy = 8.6164e-05  [1.8221e-04 for sym-block kappa = -3]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.5964299e+02;   self-cons'cy = 1.5355e-06  [1.9354e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.3211208e+01;   self-cons'cy = 4.4921e-06  [1.9354e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -6.3658259e+00;   self-cons'cy = 4.5798e-06  [1.9354e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.9103840e+01;   self-cons'cy = 9.9712e-07  [2.0877e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -5.1443370e+00;   self-cons'cy = 7.0547e-06  [2.0877e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8646929e+01;   self-cons'cy = 6.0932e-06  [1.0765e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -5.0811211e+00;   self-cons'cy = 1.6052e-05  [1.0765e-04 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -3.0967664e+00;   self-cons'cy = 2.6178e-05  [9.4850e-05 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -3.0885939e+00;   self-cons'cy = 9.4045e-06  [2.2854e-05 for sym-block kappa = -3]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.5964287e+02;   self-cons'cy = 2.3103e-07  [4.3964e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.3211092e+01;   self-cons'cy = 1.7413e-06  [4.3964e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -6.3657711e+00;   self-cons'cy = 4.3119e-06  [4.3964e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.9103704e+01;   self-cons'cy = 2.3382e-06  [1.0835e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -5.1442794e+00;   self-cons'cy = 5.5986e-06  [1.0835e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8646814e+01;   self-cons'cy = 2.0060e-06  [2.7614e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -5.0810734e+00;   self-cons'cy = 4.6989e-06  [2.7614e-05 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -3.0967552e+00;   self-cons'cy = 1.8235e-06  [8.4034e-06 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -3.0886014e+00;   self-cons'cy = 1.2033e-06  [1.7392e-06 for sym-block kappa = -3]
#
# Iteration 10 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.5964293e+02;   self-cons'cy = 1.2933e-07  [1.1062e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.3211136e+01;   self-cons'cy = 6.6692e-07  [1.1062e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -6.3657885e+00;   self-cons'cy = 1.3669e-06  [1.1062e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.9103738e+01;   self-cons'cy = 5.8765e-07  [2.0196e-06 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -5.1442918e+00;   self-cons'cy = 1.2055e-06  [2.0196e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8646830e+01;   self-cons'cy = 2.7672e-07  [2.7829e-06 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -5.0810792e+00;   self-cons'cy = 5.7171e-07  [2.7829e-06 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -3.0967512e+00;   self-cons'cy = 6.4290e-07  [1.8429e-06 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -3.0885968e+00;   self-cons'cy = 7.3425e-07  [1.4641e-06 for sym-block kappa = -3]
#
# Iteration 11 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.5964292e+02;   self-cons'cy = 2.4889e-08  [1.0791e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.3211129e+01;   self-cons'cy = 1.0452e-07  [1.0791e-06 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -6.3657861e+00;   self-cons'cy = 1.8200e-07  [1.0791e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.9103735e+01;   self-cons'cy = 5.7026e-08  [8.2241e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -5.1442910e+00;   self-cons'cy = 8.2241e-08  [8.2241e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8646831e+01;   self-cons'cy = 1.2457e-08  [4.4818e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -5.0810797e+00;   self-cons'cy = 4.9749e-08  [4.4818e-07 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -3.0967527e+00;   self-cons'cy = 2.5274e-07  [8.6235e-07 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -3.0885977e+00;   self-cons'cy = 1.4615e-07  [3.1999e-07 for sym-block kappa = -3]
#
# Iteration 12 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.5964292e+02;   self-cons'cy = 1.0999e-09  [1.8919e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.3211129e+01;   self-cons'cy = 7.5911e-10  [1.8919e-07 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -6.3657860e+00;   self-cons'cy = 1.0248e-08  [1.8919e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.9103734e+01;   self-cons'cy = 1.0148e-08  [6.7682e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -5.1442907e+00;   self-cons'cy = 3.0189e-08  [6.7682e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.8646830e+01;   self-cons'cy = 1.5394e-08  [2.4206e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -5.0810793e+00;   self-cons'cy = 3.8285e-08  [2.4206e-07 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -3.0967525e+00;   self-cons'cy = 4.0320e-08  [1.5275e-07 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -3.0885977e+00;   self-cons'cy = 7.5892e-09  [2.2811e-08 for sym-block kappa = -3]
# Compute CI matrix of dimension 2 x 2 for the symmetry 1/2^+ ...   ... done.
# Compute CI matrix of dimension 5 x 5 for the symmetry 5/2^+ ...   ... done.
# Compute CI matrix of dimension 3 x 3 for the symmetry 9/2^+ ...   ... done.
# Compute CI matrix of dimension 5 x 5 for the symmetry 3/2^+ ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 11/2^+ ...   ... done.
# Compute CI matrix of dimension 3 x 3 for the symmetry 7/2^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1
+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^6 3d^3
#        1)   9.9807e-01   of     ^4P_5/2
#        2)   9.9951e-04   of     ^2D_5/2
#        3)   9.2444e-04   of     ^2D_5/2
#
#     Level   9      9/2 +   -3.44183163e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^6 3d^3
#        1)   9.7447e-01   of     ^2G_9/2
#        2)   2.3484e-02   of     ^2H_9/2
#        3)   2.0416e-03   of     ^4F_9/2
#
#     Level   10      1/2 +   -3.44174790e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^6 3d^3
#        1)   9.9056e-01   of     ^2P_1/2
#        2)   9.4429e-03   of     ^4P_1/2
#
#     Level   11      3/2 +   -3.44174687e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^6 3d^3
#        1)   7.6397e-01   of     ^2P_3/2
#        2)   1.6565e-01   of     ^2D_3/2
#        3)   4.7412e-02   of     ^2D_3/2
#
#     Level   12      9/2 +   -3.44174652e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^6 3d^3
#        1)   9.7651e-01   of     ^2H_9/2
#        2)   2.3458e-02   of     ^2G_9/2
#
#     Level   13      11/2 +   -3.44173951e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^6 3d^3
#        1)   1.0000e+00   of     ^2H_11/2
#
#     Level   14      3/2 +   -3.44170852e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^6 3d^3
#        1)   6.0733e-01   of     ^2D_3/2
#        2)   2.1336e-01   of     ^2P_3/2
#        3)   1.7671e-01   of     ^2D_3/2
#
#     Level   15      5/2 +   -3.44170493e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^6 3d^3
#        1)   7.9213e-01   of     ^2D_5/2
#        2)   2.0531e-01   of     ^2D_5/2
#        3)   1.7206e-03   of     ^4P_5/2
#
#     Level   16      7/2 +   -3.44147129e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^6 3d^3
#        1)   9.9951e-01   of     ^2F_7/2
#        2)   4.3063e-04   of     ^2G_7/2
#
#     Level   17      5/2 +   -3.44146704e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^6 3d^3
#        1)   9.9878e-01   of     ^2F_5/2
#        2)   6.8075e-04   of     ^2D_5/2
#        3)   4.9278e-04   of     ^2D_5/2
#
#     Level   18      5/2 +   -3.44109883e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^6 3d^3
#        1)   7.9300e-01   of     ^2D_5/2
#        2)   2.0579e-01   of     ^2D_5/2
#        3)   9.9941e-04   of     ^2F_5/2
#
#     Level   19      3/2 +   -3.44109435e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^6 3d^3
#        1)   7.7489e-01   of     ^2D_3/2
#        2)   2.2506e-01   of     ^2D_3/2
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# Apparently, there are 19 levels which belong to the single $3d^3$ configuration; although there is usually one dominant CSF in non-relativistic LSJ -coupling, the mixing of different terms can become quite sizeable (see levels 14 and 15).
# How many levels do we see ... and what can be said about the LS-coupling of the levels in the ground configuration ??
#
# Of course, the complexity increases rapidly if we consider the level structure of the potassium-like iron but with a $2p$ hole:

# %%
wa = Atomic.Computation("jj-LS level transformation",  Nuclear.Model(26.); 
                        configs=[Configuration("[Ne] 3s^2 3p^5 3d^2")], asfSettings=asfSettings)
perform(wa)
# Out:
# Define a radial grid of type MeshGL with 400 grid points
#  [rnt=2.000e-06, h=5.000e-02, hp=0.000e+00, NoPoints=390, r_max=9.161e+02;
#   B-splines with break points at every 7th point, nsL=56, nsS=57, orderL=7, orderS=8, orderGL=7]
#
# ... in perform['computation: SCF'] ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2
-01    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 3d_5/2.
# (Re-) Define the standard grid with 390 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.4454537e+02;   self-cons'cy = 1.6486e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.6618575e+01;   self-cons'cy = 5.2504e-01  [1.0000e+02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -6.0905158e+00;   self-cons'cy = 7.2310e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.4014379e+01;   self-cons'cy = 5.6131e-01  [1.0000e+02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -5.5072423e+00;   self-cons'cy = 7.4625e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -2.6220360e+01;   self-cons'cy = 5.2718e-01  [1.0000e+02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -6.0090804e+00;   self-cons'cy = 7.2485e-01  [1.0000e+02 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -5.0375660e+00;   self-cons'cy = 7.6408e-01  [1.0000e+02 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -5.2555372e+00;   self-cons'cy = 7.5469e-01  [1.0000e+02 for sym-block kappa = -3]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6572123e+02;   self-cons'cy = 4.1500e-02  [3.9802e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.7488140e+01;   self-cons'cy = 1.6955e-01  [3.9802e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.9700869e+00;   self-cons'cy = 1.9120e-01  [3.9802e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.2715612e+01;   self-cons'cy = 1.5338e-01  [1.9937e-01 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.4426397e+00;   self-cons'cy = 1.4945e-01  [1.9937e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.1464537e+01;   self-cons'cy = 9.0911e-02  [1.7054e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -7.1246919e+00;   self-cons'cy = 8.4942e-02  [1.7054e-01 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -4.8496086e+00;   self-cons'cy = 1.9010e-02  [2.6369e-01 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -4.8433680e+00;   self-cons'cy = 4.0813e-02  [7.0657e-02 for sym-block kappa = -3]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6144411e+02;   self-cons'cy = 8.1134e-03  [1.1691e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.5214821e+01;   self-cons'cy = 3.1269e-02  [1.1691e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.1896249e+00;   self-cons'cy = 4.5482e-02  [1.1691e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.1261676e+01;   self-cons'cy = 2.2726e-02  [4.4184e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.0034287e+00;   self-cons'cy = 3.0403e-02  [4.4184e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.0923633e+01;   self-cons'cy = 8.6700e-03  [2.6217e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -6.9688137e+00;   self-cons'cy = 1.1060e-02  [2.6217e-02 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -4.9923432e+00;   self-cons'cy = 1.4503e-02  [1.6914e-01 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -4.9740465e+00;   self-cons'cy = 1.3311e-02  [2.1344e-02 for sym-block kappa = -3]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6204331e+02;   self-cons'cy = 1.1446e-03  [1.2680e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.5511381e+01;   self-cons'cy = 4.1931e-03  [1.2680e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.2818632e+00;   self-cons'cy = 5.5999e-03  [1.2680e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.1397732e+01;   self-cons'cy = 2.1713e-03  [3.1731e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.0367341e+00;   self-cons'cy = 2.3722e-03  [3.1731e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.0927796e+01;   self-cons'cy = 6.7312e-05  [1.0061e-03 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -6.9638748e+00;   self-cons'cy = 3.5448e-04  [1.0061e-03 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -4.9610484e+00;   self-cons'cy = 3.1441e-03  [4.4509e-02 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -4.9528320e+00;   self-cons'cy = 2.1371e-03  [3.5152e-03 for sym-block kappa = -3]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6198700e+02;   self-cons'cy = 1.0747e-04  [8.8445e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.5487069e+01;   self-cons'cy = 3.4243e-04  [8.8445e-04 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.2751599e+00;   self-cons'cy = 4.0486e-04  [8.8445e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.1395465e+01;   self-cons'cy = 3.6105e-05  [1.5128e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.0377133e+00;   self-cons'cy = 6.9574e-05  [1.5128e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.0937527e+01;   self-cons'cy = 1.5729e-04  [7.1395e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -6.9680931e+00;   self-cons'cy = 3.0278e-04  [7.1395e-04 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -4.9647524e+00;   self-cons'cy = 3.7317e-04  [5.3528e-03 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -4.9546241e+00;   self-cons'cy = 1.8088e-04  [3.0295e-04 for sym-block kappa = -3]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6198817e+02;   self-cons'cy = 2.2383e-06  [5.8268e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.5486768e+01;   self-cons'cy = 4.2391e-06  [5.8268e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.2748213e+00;   self-cons'cy = 2.0463e-05  [5.8268e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.1393324e+01;   self-cons'cy = 3.4091e-05  [8.9159e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.0368231e+00;   self-cons'cy = 6.3251e-05  [8.9159e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.0935327e+01;   self-cons'cy = 3.5552e-05  [1.3790e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -6.9672605e+00;   self-cons'cy = 5.9748e-05  [1.3790e-04 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -4.9645762e+00;   self-cons'cy = 1.7749e-05  [2.9947e-04 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -4.9546563e+00;   self-cons'cy = 3.2476e-06  [3.9060e-06 for sym-block kappa = -3]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6198896e+02;   self-cons'cy = 1.5110e-06  [2.8874e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.5487284e+01;   self-cons'cy = 7.2738e-06  [2.8874e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.2750188e+00;   self-cons'cy = 1.1938e-05  [2.8874e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.1393828e+01;   self-cons'cy = 8.0251e-06  [1.7084e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.0369964e+00;   self-cons'cy = 1.2309e-05  [1.7084e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.0935613e+01;   self-cons'cy = 4.6236e-06  [1.5864e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -6.9673583e+00;   self-cons'cy = 7.0171e-06  [1.5864e-05 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -4.9645408e+00;   self-cons'cy = 3.5629e-06  [4.2179e-05 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -4.9546142e+00;   self-cons'cy = 4.2446e-06  [6.7876e-06 for sym-block kappa = -3]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6198877e+02;   self-cons'cy = 3.6285e-07  [5.0220e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.5487181e+01;   self-cons'cy = 1.4628e-06  [5.0220e-06 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.2749833e+00;   self-cons'cy = 2.1458e-06  [5.0220e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.1393761e+01;   self-cons'cy = 1.0675e-06  [1.9510e-06 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.0369763e+00;   self-cons'cy = 1.4253e-06  [1.9510e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.0935594e+01;   self-cons'cy = 3.0805e-07  [7.4322e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -6.9673534e+00;   self-cons'cy = 3.5335e-07  [7.4322e-07 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -4.9645519e+00;   self-cons'cy = 1.1173e-06  [1.4983e-05 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -4.9546227e+00;   self-cons'cy = 8.4992e-07  [1.3844e-06 for sym-block kappa = -3]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6198880e+02;   self-cons'cy = 4.8517e-08  [5.1695e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.5487193e+01;   self-cons'cy = 1.7264e-07  [5.1695e-07 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.2749871e+00;   self-cons'cy = 2.2860e-07  [5.1695e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.1393766e+01;   self-cons'cy = 7.4689e-08  [8.9465e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.0369773e+00;   self-cons'cy = 6.8691e-08  [8.9465e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.0935593e+01;   self-cons'cy = 2.2970e-08  [1.4687e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -6.9673526e+00;   self-cons'cy = 5.9641e-08  [1.4687e-07 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -4.9645502e+00;   self-cons'cy = 1.7160e-07  [2.4106e-06 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -4.9546217e+00;   self-cons'cy = 1.0050e-07  [1.6615e-07 for sym-block kappa = -3]
#
# Iteration 10 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.6198879e+02;   self-cons'cy = 3.4101e-09  [1.3871e-08 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.5487192e+01;   self-cons'cy = 8.7956e-09  [1.3871e-08 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.2749870e+00;   self-cons'cy = 7.5818e-09  [1.3871e-08 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.1393766e+01;   self-cons'cy = 4.5127e-09  [1.8380e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.0369774e+00;   self-cons'cy = 1.2718e-08  [1.8380e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.0935593e+01;   self-cons'cy = 1.0862e-08  [4.5879e-08 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -6.9673528e+00;   self-cons'cy = 1.9620e-08  [4.5879e-08 for sym-block kappa = -2]
#   3d_3/2::  en [a.u.] = -4.9645503e+00;   self-cons'cy = 1.5299e-08  [2.2884e-07 for sym-block kappa = 2]
#   3d_5/2::  en [a.u.] = -4.9546217e+00;   self-cons'cy = 5.1677e-09  [8.9334e-09 for sym-block kappa = -3]
# Compute CI matrix of dimension 5 x 5 for the symmetry 9/2^- ...   ... done.
# Compute CI matrix of dimension 11 x 11 for the symmetry 3/2^- ...   ... done.
# Compute CI matrix of dimension 7 x 7 for the symmetry 1/2^- ...   ... done.
# Compute CI matrix of dimension 11 x 11 for the symmetry 5/2^- ...   ... done.
# Compute CI matrix of dimension 2 x 2 for the symmetry 11/2^- ...   ... done.
# Compute CI matrix of dimension 9 x 9 for the symmetry 7/2^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 -     -1.255049807547729e+03    -3.415164478750798e+04    -3.415164478750798e+04
#      2    3/2 -     -1.255045530296523e+03    -3.415152839757429e+04    -3.415152839757429e+04
#      3    5/2 -     -1.255038293424478e+03    -3.415133147225549e+04    -3.415133147225549e+04
#      4    7/2 -     -1.255027549658870e+03    -3.415103911950224e+04    -3.415103911950224e+04
#      5    11/2 -     -1.254944941322418e+03    -3.414879123217056e+04    -3.414879123217056e+04
#      6    9/2 -     -1.254937323858396e+03    -3.414858395041658e+04    -3.414858395041658e+04
#      7    7/2 -     -1.254927710626865e+03    -3.414832236106247e+04    -3.414832236106247e+04
#      8    5/2 -     -1.254923625596382e+03    -3.414821120172110e+04    -3.414821120172110e+04
#      9    5/2 -     -1.254917285745802e+03    -3.414803868559967e+04    -3.414803868559967e+04
#     10    3/2 -     -1.254909170594734e+03    -3.414781786109133e+04    -3.414781786109133e+04
#     11    1/2 -     -1.254898554581327e+03    -3.414752898465253e+04    -3.414752898465253e+04
#     12    3/2 -     -1.254872744685473e+03    -3.414682666161330e+04    -3.414682666161330e+04
#     13    5/2 -     -1.254866383276919e+03    -3.414665355886952e+04    -3.414665355886952e+04
#     14    9/2 -     -1.254864074728475e+03    -3.414659074006667e+04    -3.414659074006667e+04
#     15    7/2 -     -1.254859602124260e+03    -3.414646903430685e+04    -3.414646903430685e+04
#     16    5/2 -     -1.254843392287710e+03    -3.414602794218718e+04    -3.414602794218718e+04
#     17    5/2 -     -1.254840616975025e+03    -3.414595242208238e+04    -3.414595242208238e+04
#     18    3/2 -     -1.254835256570806e+03    -3.414580655805394e+04    -3.414580655805394e+04
#     19    7/2 -     -1.254823620584136e+03    -3.414548992672895e+04    -3.414548992672895e+04
#     20    1/2 -     -1.254797675198159e+03    -3.414478391681568e+04    -3.414478391681568e+04
#     39    1/2 -     6.567287347038473e-01    1.787049911045256e+01    1.787049911045256e+01
#     40    5/2 -     8.017248875944460e-01    2.181604539817358e+01    2.181604539817358e+01
#     41    7/2 -     8.309790186794999e-01    2.261209085180866e+01    2.261209085180866e+01
#     42    1/2 -     1.040891227448355e+00    2.832409299492882e+01    2.832409299492882e+01
#     43    3/2 -     1.055694780875683e+00    2.872691820170753e+01    2.872691820170753e+01
#     44    5/2 -     1.105683278668721e+00    3.008717451171380e+01    3.008717451171380e+01
#     45    3/2 -     1.108283008729813e+00    3.015791676995398e+01    3.015791676995398e+01
#
#   LSjj.expandLevelsIntoLS():: Relativistic basis with 45 CsfR will be transformed into a nonrelativistic basis with 45 CsfNR.
#
#   LS-expansion of selected atomic levels:
#
#     Level   1      1/2 -   -3.41516448e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   8.1087e-01   of     ^4D_1/2
#        2)   1.0562e-01   of     ^2P_1/2
#        3)   7.0238e-02   of     ^4D_1/2
#
#     Level   2      3/2 -   -3.41515284e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   5.3370e-01   of     ^4D_3/2
#        2)   1.5041e-01   of     ^4F_3/2
#        3)   1.0884e-01   of     ^2D_3/2
#
#     Level   3      5/2 -   -3.41513315e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   3.0734e-01   of     ^4F_5/2
#        2)   1.9775e-01   of     ^4D_5/2
#        3)   1.7402e-01   of     ^2D_5/2
#
#     Level   4      7/2 -   -3.41510391e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   3.8262e-01   of     ^2F_7/2
#        2)   3.3580e-01   of     ^4F_7/2
#        3)   2.7746e-01   of     ^4D_7/2
#
#     Level   5      11/2 -   -3.41487912e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   9.9958e-01   of     ^4G_11/2
#        2)   4.2434e-04   of     ^2H_11/2
#
#     Level   6      9/2 -   -3.41485840e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   3.3815e-01   of     ^4F_9/2
#        2)   3.3764e-01   of     ^4G_9/2
#        3)   3.2390e-01   of     ^2G_9/2
#
#     Level   7      7/2 -   -3.41483224e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   3.5073e-01   of     ^4F_7/2
#        2)   3.1976e-01   of     ^2G_7/2
#        3)   2.7850e-01   of     ^2F_7/2
#
#     Level   8      5/2 -   -3.41482112e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   4.8651e-01   of     ^4P_5/2
#        2)   2.7216e-01   of     ^2D_5/2
#        3)   2.2306e-01   of     ^4D_5/2
#
#     Level   9      5/2 -   -3.41480387e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   6.6507e-01   of     ^2F_5/2
#        2)   2.3057e-01   of     ^4F_5/2
#        3)   3.8367e-02   of     ^4G_5/2
#
#     Level   10      3/2 -   -3.41478179e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   4.6470e-01   of     ^4S_3/2
#        2)   2.3259e-01   of     ^2P_3/2
#        3)   1.9625e-01   of     ^4D_3/2
#
#     Level   11      1/2 -   -3.41475290e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   8.0465e-01   of     ^2S_1/2
#        2)   1.0566e-01   of     ^2P_1/2
#        3)   6.8602e-02   of     ^4D_1/2
#
#     Level   12      3/2 -   -3.41468267e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   6.6301e-01   of     ^2D_3/2
#        2)   1.6674e-01   of     ^2P_3/2
#        3)   8.8258e-02   of     ^4F_3/2
#
#     Level   13      5/2 -   -3.41466536e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   3.3948e-01   of     ^2D_5/2
#        2)   2.3079e-01   of     ^4G_5/2
#        3)   1.5042e-01   of     ^2F_5/2
#
#     Level   14      9/2 -   -3.41465907e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   6.6394e-01   of     ^2G_9/2
#        2)   2.4123e-01   of     ^4F_9/2
#        3)   9.4350e-02   of     ^4G_9/2
#
#     Level   15      7/2 -   -3.41464690e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   4.0117e-01   of     ^2G_7/2
#        2)   2.6471e-01   of     ^4D_7/2
#        3)   2.4454e-01   of     ^4G_7/2
#
#     Level   16      5/2 -   -3.41460279e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   3.4210e-01   of     ^4D_5/2
#        2)   2.4840e-01   of     ^2D_5/2
#        3)   2.2976e-01   of     ^2F_5/2
#
#     Level   17      5/2 -   -3.41459524e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   4.8483e-01   of     ^2F_5/2
#        2)   3.6498e-01   of     ^4G_5/2
#        3)   7.4324e-02   of     ^2D_5/2
#
#     Level   18      3/2 -   -3.41458066e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   4.7392e-01   of     ^2P_3/2
#        2)   1.6049e-01   of     ^2D_3/2
#        3)   1.2752e-01   of     ^4D_3/2
#
#     Level   19      7/2 -   -3.41454899e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   4.7063e-01   of     ^2G_7/2
#        2)   3.8495e-01   of     ^4D_7/2
#        3)   5.0484e-02   of     ^2G_7/2
#
#     Level   20      1/2 -   -3.41447839e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   6.9981e-01   of     ^2P_1/2
#        2)   8.0427e-02   of     ^4D_1/2
#        3)   7.4771e-02   of     ^2P_1/2
#
#     Level   21      11/2 -   -3.41440841e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   9.9958e-01   of     ^2H_11/2
#        2)   4.2434e-04   of     ^4G_11/2
#
#     Level   22      3/2 -   -3.41440431e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   5.0797e-01   of     ^2D_3/2
#        2)   1.3025e-01   of     ^2P_3/2
#        3)   1.2454e-01   of     ^4S_3/2
#
#     Level   23      7/2 -   -3.41437825e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   6.5879e-01   of     ^2F_7/2
#        2)   1.4121e-01   of     ^4G_7/2
#        3)   6.6572e-02   of     ^2G_7/2
#
#     Level   24      7/2 -   -3.41434428e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   4.2504e-01   of     ^4G_7/2
#        2)   2.9595e-01   of     ^2F_7/2
#        3)   9.1965e-02   of     ^2G_7/2
#
#     Level   25      9/2 -   -3.41430788e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   5.3839e-01   of     ^2G_9/2
#        2)   2.5848e-01   of     ^4G_9/2
#        3)   1.9563e-01   of     ^4F_9/2
#
#     Level   26      9/2 -   -3.41427548e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   3.7948e-01   of     ^2G_9/2
#        2)   2.5794e-01   of     ^4G_9/2
#        3)   1.8632e-01   of     ^4F_9/2
#
#     Level   27      5/2 -   -3.41422073e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   5.3529e-01   of     ^2D_5/2
#        2)   4.0274e-01   of     ^2F_5/2
#        3)   2.4106e-02   of     ^2D_5/2
#
#     Level   28      7/2 -   -3.41421770e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   6.8179e-01   of     ^4D_7/2
#        2)   1.6497e-01   of     ^2F_7/2
#        3)   1.0885e-01   of     ^4F_7/2
#
#     Level   29      5/2 -   -3.41420016e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   5.4343e-01   of     ^2D_5/2
#        2)   1.1146e-01   of     ^4D_5/2
#        3)   1.1137e-01   of     ^4F_5/2
#
#     Level   30      3/2 -   -3.41417459e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   5.3473e-01   of     ^2D_3/2
#        2)   1.2372e-01   of     ^2P_3/2
#        3)   1.0162e-01   of     ^4P_3/2
#
#     Level   31      1/2 -   -3.41414885e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   3.8941e-01   of     ^2P_1/2
#        2)   3.7131e-01   of     ^4D_1/2
#        3)   1.8346e-01   of     ^4D_1/2
#
#     Level   32      3/2 -   -3.41394275e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   4.6353e-01   of     ^4D_3/2
#        2)   2.2167e-01   of     ^2D_3/2
#        3)   1.2102e-01   of     ^2P_3/2
#
#     Level   33      5/2 -   -3.41389015e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   5.5321e-01   of     ^4D_5/2
#        2)   3.0750e-01   of     ^4P_5/2
#        3)   5.2202e-02   of     ^2F_5/2
#
#     Level   34      3/2 -   -3.41386143e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   4.9920e-01   of     ^4P_3/2
#        2)   4.1675e-01   of     ^2P_3/2
#        3)   7.4948e-02   of     ^4S_3/2
#
#     Level   35      1/2 -   -3.41386138e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   8.1326e-01   of     ^4P_1/2
#        2)   1.1643e-01   of     ^2P_1/2
#        3)   6.7371e-02   of     ^2S_1/2
#
#     Level   36      9/2 -   -3.41382110e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   8.2793e-01   of     ^2H_9/2
#        2)   8.1742e-02   of     ^2G_9/2
#        3)   5.1591e-02   of     ^4G_9/2
#
#     Level   37      7/2 -   -3.41381308e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   9.0165e-01   of     ^2F_7/2
#        2)   2.8861e-02   of     ^2G_7/2
#        3)   2.1347e-02   of     ^2G_7/2
#
#     Level   38      3/2 -   -3.41351031e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   7.9416e-01   of     ^2P_3/2
#        2)   1.9136e-01   of     ^2D_3/2
#        3)   6.3459e-03   of     ^4S_3/2
#
#     Level   39      1/2 -   -3.41337743e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   8.0446e-01   of     ^2P_1/2
#        2)   1.5171e-01   of     ^2P_1/2
#        3)   2.6840e-02   of     ^4D_1/2
#
#     Level   40      5/2 -   -3.41298287e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   4.6908e-01   of     ^2F_5/2
#        2)   3.1311e-01   of     ^4G_5/2
#        3)   7.7170e-02   of     ^2F_5/2
#
#     Level   41      7/2 -   -3.41290327e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   4.6431e-01   of     ^2G_7/2
#        2)   2.9180e-01   of     ^4D_7/2
#        3)   1.2512e-01   of     ^4G_7/2
#
#     Level   42      1/2 -   -3.41233207e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   3.8096e-01   of     ^4D_1/2
#        2)   2.0262e-01   of     ^2P_1/2
#        3)   1.3736e-01   of     ^2P_1/2
#
#     Level   43      3/2 -   -3.41229179e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   2.9552e-01   of     ^4S_3/2
#        2)   1.9450e-01   of     ^4D_3/2
#        3)   1.9212e-01   of     ^4P_3/2
#
#     Level   44      5/2 -   -3.41215576e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   2.6139e-01   of     ^4F_5/2
#        2)   2.3139e-01   of     ^4D_5/2
#        3)   1.4206e-01   of     ^2D_5/2
#
#     Level   45      3/2 -   -3.41214869e+04  [eV]  has weight 1.0000e+00 of 1s^2 2s^2 2p^6 3s^2 3p^5 3d^2
#        1)   5.7071e-01   of     ^4F_3/2
#        2)   1.7462e-01   of     ^2P_3/2
#        3)   1.4223e-01   of     ^4D_3/2
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# This results in 45 fine-structure levels, and which are shown together with their corresponding LSJ expansions. For various applications, it migt be desirable to better recognized the parents terms in this LSJ expansion, a feature that could be implemented quite easily.
