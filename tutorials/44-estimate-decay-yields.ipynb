# %% [markdown]
# # K-shell fluorescence & Auger yields for neon-like ions

# %%
using JAC

# %% [markdown]
# The fluorescence yield $\omega_r$ characterizes the probability of an inner-shell (core) hole to be filled under photon emission, in contrast and competition with other nonradiative processes. It fulfills together with the Auger yield $\omega_a$ the simple relations: $\omega_r + \omega_a = 1$ but generally requires to consider all possible (radiative and non-radiative) decay channels.
#
# In Jac, the computation of all fluorescence and Auger yields is always traced back to single-step **cascade computation**. Here, we wish to compute the fluorescence and Auger yields for a few neon-like ions, and like to see how the *fluorescence* increases with the nuclear charge. Similar as for other (level) properties, we can estimate the yields by performing an `Atomic.Computation(...,  properties=[Yields, ..], configs=[..], yieldSettings=DecayYield.Settings(..), ..)`.
#
# To understand, how we can control the computation of yields, let us have a look at the internal definition and the default settings of `DecayYield.Settings(..)`

# %%
? DecayYield.Settings
# Out:
#   struct  DecayYield.Settings ... defines a type for the details and
#   parameters of computing fluorescence and Auger yields.
#
#   + approach                 ::String         ... Determines the applied cascade approach for the yields: {"AverageSCA", "SCA"}.
#   + printBefore   ::Bool           ... True if a list of selected levels is to be printed before the actual computations start.
#   + selectLevels             ::Bool           ... True if individual levels are selected for the computation.
#   + selectedLevels           ::Array{Level,1} ... List of selected levels.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   DecayYield.Settings() ... constructor for an empty instance of
#   DecayYield.Settings for the computation of fluorescence and Auger yields.

# %%
DecayYield.Settings()
# Out:
# approach:                 AverageSCA
# printBefore:   false
# selectLevels:             false
# selectedLevels:           Level[]

# %% [markdown]
# Here, the approach refers to one particular *cascade approaches* (cf. User Guide, chapter 8) that are available in JAC; because of the internal program structure (i.e. the dependencies of the individual modules), however, this approach need to be provided in `String` notation as indicated above.
#
# To compute the fluorescence yields for neon-like Mg, we can specify also the SCA approach in the settings and run the computation by:

# %%
ySettings = DecayYield.Settings("SCA", true, false, Int64[])
wa = Atomic.Computation(Atomic.Computation(), name="Yield computations for neon-like Mg", grid=Radial.Grid(false),
                        nuclearModel=Nuclear.Model(12.), properties=[Yields()],
                        configs=[Configuration("1s 2s^2 2p^6")], yieldSettings=ySettings )
perform(wa)
# Out:
# ... in performSCF ...
# >> include Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 12.0 with mass = 24.72, radius R = 3.0053184906569026 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -7.21385120e+01    -7.21385593e+01    +6.55305238e-07
#       2      2s_1/2      -1.80433022e+01    -1.80433081e+01    +3.29715426e-07
#       3      3s_1/2      -8.01539078e+00    -8.01539255e+00    +2.20001684e-07
#       4      4s_1/2      -4.50703052e+00    -4.50703270e+00    +4.83869911e-07
#       5      5s_1/2      -2.88077632e+00    -2.88376608e+00    +1.03783423e-03
#       6      6s_1/2      -1.87415788e+00    -2.00224317e+00    +6.83428515e-02
#       7      7s_1/2      -7.37397032e-01    -1.47082901e+00    +9.94622908e-01
#       8      8s_1/2      +7.48237543e-01    -1.12597992e+00    +2.50484285e+00
#      31     32p_3/2      +1.17420320e+02    -7.03205343e-02    +1.00059888e+00
#      32     33p_3/2      +1.25518162e+02    -6.61230392e-02    +1.00052680e+00
#      33     34p_3/2      +1.33870166e+02    -6.22904546e-02    +1.00046530e+00
#      34     35p_3/2      +1.42476949e+02    -5.87816764e-02    +1.00041257e+00
#      35     36p_3/2      +1.51340059e+02    -5.55612291e-02    +1.00036713e+00
#      36     37p_3/2      +1.60462703e+02    -5.25983656e-02    +1.00032779e+00
#      37     38p_3/2      +1.69850973e+02    -4.98663309e-02    +1.00029359e+00
#      38     39p_3/2      +1.79515770e+02    -4.73417554e-02    +1.00026372e+00
#       :       :
#      87     88p_3/2      +1.00137229e+08    -9.29791905e-03    +1.00000000e+00
#      88     89p_3/2      +1.53809020e+08    -9.09014658e-03    +1.00000000e+00
#      89     90p_3/2      +2.48277981e+08    -8.88926145e-03    +1.00000000e+00
#      90     91p_3/2      +4.40913257e+08    -8.69496258e-03    +1.00000000e+00
#      91     92p_3/2      +9.65419573e+08    -8.50696517e-03    +1.00000000e+00
#      92     93p_3/2      +3.73448114e+09    -8.32499965e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# (Re-) Define the standard grid with 600 grid points.
# >>  for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -4.6238171e+01;   self-cons'cy = 2.1880e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.4856398e+00;   self-cons'cy = 6.7619e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.6891643e+00;   self-cons'cy = 7.4058e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3567499e+00;   self-cons'cy = 6.8578e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.3328108e+01;   self-cons'cy = 7.1208e-02  [2.5560e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.5744876e+00;   self-cons'cy = 2.3055e-01  [2.5560e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.2356832e+00;   self-cons'cy = 2.2333e-01  [2.2333e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.8396152e+00;   self-cons'cy = 6.7098e-02  [6.7098e-02 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1140301e+01;   self-cons'cy = 2.0942e-02  [1.0454e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.7550880e+00;   self-cons'cy = 7.9326e-02  [1.0454e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7015454e+00;   self-cons'cy = 6.7295e-02  [6.7295e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7700036e+00;   self-cons'cy = 9.1478e-03  [1.0110e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1631461e+01;   self-cons'cy = 4.7791e-03  [2.0604e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.9256474e+00;   self-cons'cy = 1.7618e-02  [2.0604e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7875865e+00;   self-cons'cy = 1.1489e-02  [1.1489e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7569084e+00;   self-cons'cy = 1.7398e-03  [1.7398e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1551657e+01;   self-cons'cy = 7.7342e-04  [3.4499e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8971610e+00;   self-cons'cy = 2.9000e-03  [3.4499e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7797115e+00;   self-cons'cy = 1.0407e-03  [1.0407e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7659530e+00;   self-cons'cy = 1.2023e-03  [1.2023e-03 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1555975e+01;   self-cons'cy = 4.1876e-05  [1.6975e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8987166e+00;   self-cons'cy = 1.5880e-04  [1.6975e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7778176e+00;   self-cons'cy = 2.5060e-04  [2.5060e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7629992e+00;   self-cons'cy = 3.9232e-04  [3.9232e-04 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1558797e+01;   self-cons'cy = 2.7373e-05  [1.2656e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8997089e+00;   self-cons'cy = 1.0127e-04  [1.2656e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7790445e+00;   self-cons'cy = 1.6236e-04  [1.6236e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7636845e+00;   self-cons'cy = 9.1050e-05  [9.1050e-05 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557394e+01;   self-cons'cy = 1.3606e-05  [6.1604e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8992133e+00;   self-cons'cy = 5.0578e-05  [6.1604e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7786516e+00;   self-cons'cy = 5.1989e-05  [5.1989e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7635745e+00;   self-cons'cy = 1.4612e-05  [1.4612e-05 for sym-block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557805e+01;   self-cons'cy = 3.9857e-06  [1.7893e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8993587e+00;   self-cons'cy = 1.4844e-05  [1.7893e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7787415e+00;   self-cons'cy = 1.1900e-05  [1.1900e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7635800e+00;   self-cons'cy = 7.2005e-07  [7.9917e-07 for sym-block kappa = -2]
#
# Iteration 10 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557718e+01;   self-cons'cy = 8.4520e-07  [3.7643e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8993278e+00;   self-cons'cy = 3.1532e-06  [3.7643e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7787274e+00;   self-cons'cy = 1.8678e-06  [1.8678e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7635841e+00;   self-cons'cy = 5.4925e-07  [5.4925e-07 for sym-block kappa = -2]
#
# Iteration 11 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557730e+01;   self-cons'cy = 1.1569e-07  [5.0707e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8993321e+00;   self-cons'cy = 4.3310e-07  [5.0707e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7787280e+00;   self-cons'cy = 7.7107e-08  [7.7107e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7635821e+00;   self-cons'cy = 2.6639e-07  [2.6639e-07 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.121155 seconds (56.13 k allocations: 1.067 MiB)
#    ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -1.500861610515744e+02    -4.084052464634279e+03    -4.084052464634279e+03
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# DecayYield.computeOutcomes(): The computation of the fluorescence & Auger yields starts now ...
# -----------------------------------------------------------------------------------------------
#
#   Selected DecayYield levels:
#
#   -------------------------------------------
#      Level        J^P           Energy
#                                  [eV]
#   -------------------------------------------
#          1       1/2 +      -4.08405246e+03
#   -------------------------------------------
#
# Perform a cascade computation for all radiative decay channels of the levels from the initial configurations:
# MethodError: Cannot `convert` an object of type Type{Radiative} to an object of type JAC.Basics.AbstractProcess
# Closest candidates are:
#   convert(::Type{T}, !Matched::T) where T at essentials.jl:154
#
# Stacktrace:
#  [1] setindex!(::Array{JAC.Basics.AbstractProcess,1}, ::DataType, ::Int64) at ./array.jl:769
#  [2] copyto! at ./abstractarray.jl:731 [inlined]
#  [3] copyto! at ./abstractarray.jl:723 [inlined]
#  [4] Type at ./array.jl:497 [inlined]
#  [5] convert at ./array.jl:489 [inlined]
#  [6] Type at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:42 [inlined]
#  [7] JAC.Cascade.StepwiseDecayScheme() at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:54
#  [8] JAC.Cascade.Computation() at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:296
#  [9] #computeOutcomes#1(::Bool, ::Function, ::Array{Configuration,1}, ::AsfSettings, ::Multiplet, ::Model, ::JAC.Radial.Grid, ::JAC.DecayYield.Settings) at /home/fritzsch/fri/JAC.jl/src/module-DecayYield.jl:111
#  [10] computeOutcomes at /home/fritzsch/fri/JAC.jl/src/module-DecayYield.jl:94 [inlined]
#  [11] #perform#1(::Bool, ::Function, ::JAC.Atomic.Computation) at /home/fritzsch/fri/JAC.jl/src/module-BasicsPerform.jl:75
#  [12] perform(::JAC.Atomic.Computation) at /home/fritzsch/fri/JAC.jl/src/module-BasicsPerform.jl:23
#  [13] top-level scope at In[11]:5

# %% [markdown]
# Obviously, this results in a rather detailed output due to printed data of the underlying cascade computation. In this single-step cascade, all the neon-like configurations with total energies below of the given $1s 2s^2 2p^6$ configuration are generated automatically, together with all energetically allowed fluorine-like configuration due to the (Auger) emission of an electon. Here, we shall not discuss this output in detail but just go over to the final table: It report an fluorescence yield $\omega_r \approx 0.08$ in Babushkin gauge and a corresponding Auger yield of $\omega_a \approx 0.92$. The same yields in Coulomb gauge are (0., 1.), but this occurs since
# by default all radiative transitions are only considered in Babushkin (length) gauge. To modify this settings, the user would have to change the *call* of the cascade computations *inside* of the code.
#
# To see how the coupling of the radiation field and, hence, the fluorescence increases with an increasing  nuclear charge, let us next perform the same computations but for Z=18 and Z=26, respectively.

# %%
wa = Atomic.Computation(wa, name="Yield computations for neon-like Ar", nuclearModel=Nuclear.Model(18.))
perform(wa)
# Out:
# ... in performSCF ...
# >> include Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 18.0 with mass = 37.62, radius R = 3.37121133160794 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.62704537e+02    -1.62704858e+02    +1.97540662e-06
#       2      2s_1/2      -4.07203231e+01    -4.07203638e+01    +1.00176003e-06
#       3      3s_1/2      -1.80782718e+01    -1.80782839e+01    +6.69151274e-07
#       4      4s_1/2      -1.01607481e+01    -1.01607532e+01    +5.02099117e-07
#       5      5s_1/2      -6.49913788e+00    -6.49914079e+00    +4.47222422e-07
#       6      6s_1/2      -4.51067466e+00    -4.51139835e+00    +1.60439604e-04
#       7      7s_1/2      -3.25625280e+00    -3.31344481e+00    +1.75637504e-02
#       8      8s_1/2      -2.04356550e+00    -2.53622787e+00    +2.41079803e-01
#       9      9s_1/2      -4.89120985e-01    -2.00353566e+00    +3.09619649e+00
#      10     10s_1/2      +1.41729514e+00    -1.62260054e+00    +2.14485720e+00
#      11     11s_1/2      +3.64791723e+00    -1.34081096e+00    +1.36755520e+00
#      12     12s_1/2      +6.18567599e+00    -1.12652493e+00    +1.18211832e+00
#      13     13s_1/2      +9.01966837e+00    -9.59785324e-01    +1.10641027e+00
#      14     14s_1/2      +1.21423627e+01    -8.27499902e-01    +1.06814983e+00
#      15     15s_1/2      +1.55482442e+01    -7.20790988e-01    +1.04635835e+00
#      16     16s_1/2      +1.92330954e+01    -6.33466359e-01    +1.03293627e+00
#      17     17s_1/2      +2.31935812e+01    -5.61100307e-01    +1.02419205e+00
#      88     89p_3/2      +1.53725585e+08    -2.04539144e-02    +1.00000000e+00
#      89     90p_3/2      +2.48194563e+08    -2.00018873e-02    +1.00000000e+00
#      90     91p_3/2      +4.40829846e+08    -1.95646808e-02    +1.00000000e+00
#      91     92p_3/2      +9.65336164e+08    -1.91416541e-02    +1.00000000e+00
#      92     93p_3/2      +3.73439773e+09    -1.87322005e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# (Re-) Define the standard grid with 600 grid points.
# >>  for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2369708e+02;   self-cons'cy = 1.3620e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.7866211e+01;   self-cons'cy = 3.9009e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.5948796e+01;   self-cons'cy = 4.3713e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.6486616e+01;   self-cons'cy = 4.2183e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2991228e+02;   self-cons'cy = 2.4507e-02  [6.4646e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9747751e+01;   self-cons'cy = 5.0022e-02  [6.4646e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7624552e+01;   self-cons'cy = 4.9913e-02  [2.2064e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7362228e+01;   self-cons'cy = 2.5868e-02  [1.1386e-01 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2880391e+02;   self-cons'cy = 4.2842e-03  [2.5479e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9371578e+01;   self-cons'cy = 9.6160e-03  [2.5479e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7327478e+01;   self-cons'cy = 8.4995e-03  [4.7427e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7247755e+01;   self-cons'cy = 3.3075e-03  [1.7518e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2896937e+02;   self-cons'cy = 6.4191e-04  [3.1225e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9427066e+01;   self-cons'cy = 1.4301e-03  [3.1225e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7366664e+01;   self-cons'cy = 1.1295e-03  [6.0163e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7259569e+01;   self-cons'cy = 3.4236e-04  [1.7600e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2894753e+02;   self-cons'cy = 8.4699e-05  [4.2571e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9419700e+01;   self-cons'cy = 1.8961e-04  [4.2571e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7361918e+01;   self-cons'cy = 1.3665e-04  [7.3216e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258475e+01;   self-cons'cy = 3.1697e-05  [1.6302e-04 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2895014e+02;   self-cons'cy = 1.0116e-05  [5.0762e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9420581e+01;   self-cons'cy = 2.2689e-05  [5.0762e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362437e+01;   self-cons'cy = 1.4953e-05  [7.9985e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258558e+01;   self-cons'cy = 2.4017e-06  [1.2265e-05 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2894985e+02;   self-cons'cy = 1.0979e-06  [5.5263e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9420486e+01;   self-cons'cy = 2.4681e-06  [5.5263e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362386e+01;   self-cons'cy = 1.4672e-06  [7.8408e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258554e+01;   self-cons'cy = 1.0587e-07  [5.2616e-07 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2894988e+02;   self-cons'cy = 1.0674e-07  [5.3896e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9420495e+01;   self-cons'cy = 2.4062e-07  [5.3896e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362391e+01;   self-cons'cy = 1.2331e-07  [6.5791e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258554e+01;   self-cons'cy = 8.7192e-09  [4.7738e-08 for sym-block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2894988e+02;   self-cons'cy = 8.8451e-09  [4.4895e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9420494e+01;   self-cons'cy = 2.0034e-08  [4.4895e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362390e+01;   self-cons'cy = 7.5620e-09  [4.0165e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258554e+01;   self-cons'cy = 3.3275e-09  [1.7521e-08 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.082321 seconds (44.17 k allocations: 878.141 KiB)
#    ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -3.830160470444266e+02    -1.042239750798037e+04    -1.042239750798037e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# DecayYield.computeOutcomes(): The computation of the fluorescence & Auger yields starts now ...
# -----------------------------------------------------------------------------------------------
#
#   Selected DecayYield levels:
#
#   -------------------------------------------
#      Level        J^P           Energy
#                                  [eV]
#   -------------------------------------------
#          1       1/2 +      -1.04223975e+04
#   -------------------------------------------
#
# Perform a cascade computation for all radiative decay channels of the levels from the initial configurations:
# MethodError: Cannot `convert` an object of type Type{Radiative} to an object of type JAC.Basics.AbstractProcess
# Closest candidates are:
#   convert(::Type{T}, !Matched::T) where T at essentials.jl:154
#
# Stacktrace:
#  [1] setindex!(::Array{JAC.Basics.AbstractProcess,1}, ::DataType, ::Int64) at ./array.jl:769
#  [2] copyto! at ./abstractarray.jl:731 [inlined]
#  [3] copyto! at ./abstractarray.jl:723 [inlined]
#  [4] Type at ./array.jl:497 [inlined]
#  [5] convert at ./array.jl:489 [inlined]
#  [6] Type at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:42 [inlined]
#  [7] JAC.Cascade.StepwiseDecayScheme() at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:54
#  [8] JAC.Cascade.Computation() at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:296
#  [9] #computeOutcomes#1(::Bool, ::Function, ::Array{Configuration,1}, ::AsfSettings, ::Multiplet, ::Model, ::JAC.Radial.Grid, ::JAC.DecayYield.Settings) at /home/fritzsch/fri/JAC.jl/src/module-DecayYield.jl:111
#  [10] computeOutcomes at /home/fritzsch/fri/JAC.jl/src/module-DecayYield.jl:94 [inlined]
#  [11] #perform#1(::Bool, ::Function, ::JAC.Atomic.Computation) at /home/fritzsch/fri/JAC.jl/src/module-BasicsPerform.jl:75
#  [12] perform(::JAC.Atomic.Computation) at /home/fritzsch/fri/JAC.jl/src/module-BasicsPerform.jl:23
#  [13] top-level scope at In[12]:2

# %%
wa = Atomic.Computation(wa, name="Yield computations for neon-like Fe", nuclearModel=Nuclear.Model(26.))
perform(wa)
# Out:
# ... in performSCF ...
# >> include Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 26.0 with mass = 55.38, radius R = 3.756573410087755 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -3.41095880e+02    -3.41097837e+02    +5.73779766e-06
#       2      2s_1/2      -8.54687058e+01    -8.54689584e+01    +2.95488249e-06
#       3      3s_1/2      -3.78993728e+01    -3.78994478e+01    +1.97799548e-06
#       4      4s_1/2      -2.12819069e+01    -2.12819385e+01    +1.48493243e-06
#       5      5s_1/2      -1.36039552e+01    -1.36039714e+01    +1.18822797e-06
#       6      6s_1/2      -9.43886385e+00    -9.43887322e+00    +9.92072185e-07
#      29     30p_3/2      +9.13180503e+01    -3.75770208e-01    +1.00411496e+00
#      30     31p_3/2      +9.88171558e+01    -3.51911831e-01    +1.00356124e+00
#      31     32p_3/2      +1.06574003e+02    -3.30255569e-01    +1.00309884e+00
#      32     33p_3/2      +1.14588029e+02    -3.10538528e-01    +1.00271004e+00
#      33     34p_3/2      +1.22858862e+02    -2.92535903e-01    +1.00238107e+00
#      34     35p_3/2      +1.31386462e+02    -2.76054548e-01    +1.00210109e+00
#      35     36p_3/2      +1.40171387e+02    -2.60927768e-01    +1.00186149e+00
#      36     37p_3/2      +1.49215270e+02    -2.47011090e-01    +1.00165540e+00
#      37     38p_3/2      +1.58521670e+02    -2.34178802e-01    +1.00147727e+00
#      38     39p_3/2      +1.68097480e+02    -2.22321100e-01    +1.00132257e+00
#       :       :
#      87     88p_3/2      +9.99560042e+07    -4.36554908e-02    +1.00000000e+00
#      88     89p_3/2      +1.53627853e+08    -4.26798849e-02    +1.00000000e+00
#      89     90p_3/2      +2.48096841e+08    -4.17366212e-02    +1.00000000e+00
#      90     91p_3/2      +4.40732128e+08    -4.08242859e-02    +1.00000000e+00
#      91     92p_3/2      +9.65238448e+08    -3.99415415e-02    +1.00000000e+00
#      92     93p_3/2      +3.73430001e+09    -3.90871219e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# (Re-) Define the standard grid with 600 grid points.
# >>  for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8438062e+02;   self-cons'cy = 9.0675e-02  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.1572305e+01;   self-cons'cy = 2.4734e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.8295892e+01;   self-cons'cy = 2.7790e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.8394672e+01;   self-cons'cy = 2.7273e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.9025066e+02;   self-cons'cy = 1.0215e-02  [3.7921e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3406595e+01;   self-cons'cy = 1.7473e-02  [3.7921e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -5.0035145e+01;   self-cons'cy = 1.7688e-02  [3.7260e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9401249e+01;   self-cons'cy = 1.0293e-02  [2.1855e-02 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8958750e+02;   self-cons'cy = 1.1437e-03  [4.2007e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3187637e+01;   self-cons'cy = 2.0541e-03  [4.2007e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9849536e+01;   self-cons'cy = 1.8582e-03  [3.8393e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9315950e+01;   self-cons'cy = 8.6408e-04  [1.8627e-03 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8965188e+02;   self-cons'cy = 1.1114e-04  [4.1117e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3208873e+01;   self-cons'cy = 1.9960e-04  [4.1117e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9866036e+01;   self-cons'cy = 1.6547e-04  [3.4248e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322538e+01;   self-cons'cy = 6.6790e-05  [1.4375e-04 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964619e+02;   self-cons'cy = 9.8261e-06  [3.6448e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3206991e+01;   self-cons'cy = 1.7688e-05  [3.6448e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9864657e+01;   self-cons'cy = 1.3821e-05  [2.8578e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322040e+01;   self-cons'cy = 5.0425e-06  [1.0833e-05 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964666e+02;   self-cons'cy = 8.1786e-07  [3.0398e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3207148e+01;   self-cons'cy = 1.4740e-06  [3.0398e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9864767e+01;   self-cons'cy = 1.1029e-06  [2.2797e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322077e+01;   self-cons'cy = 3.7233e-07  [7.9914e-07 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964662e+02;   self-cons'cy = 6.5227e-08  [2.4279e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3207135e+01;   self-cons'cy = 1.1767e-07  [2.4279e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9864759e+01;   self-cons'cy = 8.5154e-08  [1.7595e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322074e+01;   self-cons'cy = 2.6978e-08  [5.7860e-08 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.055373 seconds (37.77 k allocations: 762.641 KiB)
#    ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -8.651826710830985e+02    -2.354281964065689e+04    -2.354281964065689e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# DecayYield.computeOutcomes(): The computation of the fluorescence & Auger yields starts now ...
# -----------------------------------------------------------------------------------------------
#
#   Selected DecayYield levels:
#
#   -------------------------------------------
#      Level        J^P           Energy
#                                  [eV]
#   -------------------------------------------
#          1       1/2 +      -2.35428196e+04
#   -------------------------------------------
#
# Perform a cascade computation for all radiative decay channels of the levels from the initial configurations:
# MethodError: Cannot `convert` an object of type Type{Radiative} to an object of type JAC.Basics.AbstractProcess
# Closest candidates are:
#   convert(::Type{T}, !Matched::T) where T at essentials.jl:154
#
# Stacktrace:
#  [1] setindex!(::Array{JAC.Basics.AbstractProcess,1}, ::DataType, ::Int64) at ./array.jl:769
#  [2] copyto! at ./abstractarray.jl:731 [inlined]
#  [3] copyto! at ./abstractarray.jl:723 [inlined]
#  [4] Type at ./array.jl:497 [inlined]
#  [5] convert at ./array.jl:489 [inlined]
#  [6] Type at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:42 [inlined]
#  [7] JAC.Cascade.StepwiseDecayScheme() at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:54
#  [8] JAC.Cascade.Computation() at /home/fritzsch/fri/JAC.jl/src/module-Cascade.jl:296
#  [9] #computeOutcomes#1(::Bool, ::Function, ::Array{Configuration,1}, ::AsfSettings, ::Multiplet, ::Model, ::JAC.Radial.Grid, ::JAC.DecayYield.Settings) at /home/fritzsch/fri/JAC.jl/src/module-DecayYield.jl:111
#  [10] computeOutcomes at /home/fritzsch/fri/JAC.jl/src/module-DecayYield.jl:94 [inlined]
#  [11] #perform#1(::Bool, ::Function, ::JAC.Atomic.Computation) at /home/fritzsch/fri/JAC.jl/src/module-BasicsPerform.jl:75
#  [12] perform(::JAC.Atomic.Computation) at /home/fritzsch/fri/JAC.jl/src/module-BasicsPerform.jl:23
#  [13] top-level scope at In[13]:2

# %% [markdown]
# From the output of these three computations, we see that the fluorescence yield $\omega_r$ increase from 8 % (Z=12) to 28 % (Z=18) and up to 40 % (Z=26).

# %% [markdown]
# We could consider also the yields for the $2s$ hole state of argon which is known to decay by fast **Coster-Kronig transitions**. Because of the (very) low energies of the emitted Coster-Kronig electrons, these computations require however further care in order to obtain reliable estimates. Since all these yield computations are always based on (rather elaborate) *cascade computations*, further improvements of the yield-computations might be possible but will require advice and support by the community.
