# %% [markdown]
# # K-shell fluorescence & Auger yields for neon-like ions

# %%
using JAC

# %% [markdown]
# The fluorescence yield $\omega_r$ characterizes the probability of an inner-shell (core) hole to be filled under photon emission, in contrast and competition with other nonradiative processes. It fulfills together with the Auger yield $\omega_a$ the simple relations: $\omega_r + \omega_a = 1$ but generally requires to consider all possible (radiative and non-radiative) decay channels.
#
# In Jac, the computation of all fluorescence and Auger yields is always traced back to single-step **cascade computation**. Here, we wish to compute the fluorescence and Auger yields for a few neon-like ions, and like to see how the *fluorescence* increases with the nuclear charge. Similar as for other (level) properties, we can estimate the yields by performing an `Atomic.Computation(...,  configs=[..], propertySettings= [DecayYield.Settings(..)], ..)`.
#
# To understand, how we can control the computation of yields, let us have a look at the internal definition and the default settings of `DecayYield.Settings(..)`

# %%
? DecayYield.Settings
# Out:
#   struct DecayYield.Settings <: AbstractPropertySettings ... defines a type
#   for the details and parameters of computing fluorescence and Auger yields.
#
#   + approach                 ::String         ... Determines the applied cascade approach for the yields:
#                                                   {"AverageSCA", "SCA"}.
#   + printBefore              ::Bool           ... True if a list of selected levels is to be printed before the
#                                                   actual computations start.
#   + levelSelection           ::LevelSelection ... Specifies the selected levels, if any.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   DecayYield.Settings() ... constructor for an empty instance of
#   DecayYield.Settings for the computation of fluorescence and Auger yields.

# %%
DecayYield.Settings()
# Out:
# approach:                 AverageSCA
# printBefore:              false
# levelSelection:           Inactive LevelSelection.

# %% [markdown]
# Here, the approach refers to one particular *cascade approaches* (cf. User Guide, chapter 8) that are available in JAC; because of the internal program structure (i.e. the dependencies of the individual modules), however, this approach need to be provided in `String` notation as indicated above.
#
# To compute the fluorescence yields for neon-like Mg, we can specify also the SCA approach in the settings and run the computation by:

# %%
grid      = Radial.Grid(Radial.Grid(false), h=0.04, rbox=10.0)
ySettings = DecayYield.Settings("SCA", true, LevelSelection())
wa = Atomic.Computation(Atomic.Computation(), name="Yield computations for neon-like Mg", grid=grid,
                        nuclearModel=Nuclear.Model(12.), configs=[Configuration("1s 2s^2 2p^6")], 
                        propertySettings=[ySettings] )
perform(wa)
# Out:
# ... in performSCF ...
# >> include Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 12.0 with mass = 24.72, radius R = 3.0053184906569026 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -7.21385120e+01    -7.21385593e+01    +6.55485744e-07
#       2      2s_1/2      -1.80433021e+01    -1.80433081e+01    +3.29806542e-07
#       3      3s_1/2      -8.01539078e+00    -8.01539255e+00    +2.20062469e-07
#      19     20p_3/2      +1.33195030e+01    -1.80031939e-01    +1.01351642e+00
#      20     21p_3/2      +1.52019596e+01    -1.63293003e-01    +1.01074158e+00
#      21     22p_3/2      +1.71852455e+01    -1.48784504e-01    +1.00865769e+00
#      22     23p_3/2      +1.92689393e+01    -1.36127082e-01    +1.00706459e+00
#      23     24p_3/2      +2.14526755e+01    -1.25018733e-01    +1.00582765e+00
#      24     25p_3/2      +2.37361337e+01    -1.15216618e-01    +1.00485406e+00
#      25     26p_3/2      +2.61190304e+01    -1.06523685e-01    +1.00407839e+00
#      26     27p_3/2      +2.86011125e+01    -9.87786860e-02    +1.00345367e+00
#      27     28p_3/2      +3.11821521e+01    -9.18486436e-02    +1.00294555e+00
#      28     29p_3/2      +3.38619422e+01    -8.56231060e-02    +1.00252859e+00
#      29     30p_3/2      +3.66402934e+01    -8.00097188e-02    +1.00218365e+00
#      30     31p_3/2      +3.95170312e+01    -7.49307795e-02    +1.00189616e+00
#      31     32p_3/2      +4.24919933e+01    -7.03205343e-02    +1.00165491e+00
#      32     33p_3/2      +4.55650282e+01    -6.61230392e-02    +1.00145118e+00
#      33     34p_3/2      +4.87359928e+01    -6.22904546e-02    +1.00127812e+00
#      34     35p_3/2      +5.20047518e+01    -5.87816764e-02    +1.00113031e+00
#      35     36p_3/2      +5.53711755e+01    -5.55612291e-02    +1.00100343e+00
#      36     37p_3/2      +5.88351393e+01    -5.25983656e-02    +1.00089400e+00
#      37     38p_3/2      +6.23965221e+01    -4.98663309e-02    +1.00079918e+00
#      38     39p_3/2      +6.60552054e+01    -4.73417554e-02    +1.00071670e+00
#       :       :
#     126    127p_3/2      +1.31967894e+08    -4.46414217e-03    +1.00000000e+00
#     127    128p_3/2      +1.89174816e+08    -4.39466141e-03    +1.00000000e+00
#     128    129p_3/2      +2.83644719e+08    -4.32679022e-03    +1.00000000e+00
#     129    130p_3/2      +4.62727573e+08    -4.26047929e-03    +1.00000000e+00
#     130    131p_3/2      +8.96297035e+08    -4.19568115e-03    +1.00000000e+00
#     131    132p_3/2      +2.69333087e+09    -4.13235013e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# (Re-) Define the standard grid with 889 grid points.
# >>  for various B-spline matrices:
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -4.6238635e+01;   self-cons'cy = 2.1879e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.4857314e+00;   self-cons'cy = 6.7618e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.6892498e+00;   self-cons'cy = 7.4058e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.3568032e+00;   self-cons'cy = 6.8577e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.3328194e+01;   self-cons'cy = 7.1204e-02  [2.9309e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.5744867e+00;   self-cons'cy = 2.3054e-01  [2.9309e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.2357122e+00;   self-cons'cy = 2.2332e-01  [2.2332e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.8396854e+00;   self-cons'cy = 6.7100e-02  [6.7100e-02 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1140572e+01;   self-cons'cy = 2.0940e-02  [1.2338e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.7551613e+00;   self-cons'cy = 7.9318e-02  [1.2338e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7016177e+00;   self-cons'cy = 6.7289e-02  [6.7289e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7700645e+00;   self-cons'cy = 9.1489e-03  [9.1489e-03 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1631679e+01;   self-cons'cy = 4.7786e-03  [2.3977e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.9257026e+00;   self-cons'cy = 1.7616e-02  [2.3977e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7876527e+00;   self-cons'cy = 1.1488e-02  [1.1488e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7569764e+00;   self-cons'cy = 1.7388e-03  [1.7388e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1551882e+01;   self-cons'cy = 7.7335e-04  [4.0249e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8972188e+00;   self-cons'cy = 2.8997e-03  [4.0249e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7797767e+00;   self-cons'cy = 1.0408e-03  [1.0408e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7660179e+00;   self-cons'cy = 1.2019e-03  [1.2019e-03 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1556202e+01;   self-cons'cy = 4.1894e-05  [1.9703e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8987751e+00;   self-cons'cy = 1.5887e-04  [1.9703e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7778840e+00;   self-cons'cy = 2.5043e-04  [2.5043e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7630650e+00;   self-cons'cy = 3.9219e-04  [3.9219e-04 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1559023e+01;   self-cons'cy = 2.7357e-05  [1.4787e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8997667e+00;   self-cons'cy = 1.0120e-04  [1.4787e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7791104e+00;   self-cons'cy = 1.6228e-04  [1.6228e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7637502e+00;   self-cons'cy = 9.1023e-05  [9.1023e-05 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557621e+01;   self-cons'cy = 1.3600e-05  [7.1904e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8992713e+00;   self-cons'cy = 5.0553e-05  [7.1904e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7787176e+00;   self-cons'cy = 5.1967e-05  [5.1967e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7636402e+00;   self-cons'cy = 1.4609e-05  [1.4609e-05 for sym-block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1558031e+01;   self-cons'cy = 3.9840e-06  [2.0874e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8994167e+00;   self-cons'cy = 1.4837e-05  [2.0874e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7788075e+00;   self-cons'cy = 1.1895e-05  [1.1895e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7636456e+00;   self-cons'cy = 7.2077e-07  [7.2077e-07 for sym-block kappa = -2]
#
# Iteration 10 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557944e+01;   self-cons'cy = 8.4487e-07  [4.3899e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8993858e+00;   self-cons'cy = 3.1520e-06  [4.3899e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7787934e+00;   self-cons'cy = 1.8673e-06  [1.8673e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7636497e+00;   self-cons'cy = 5.4870e-07  [5.4870e-07 for sym-block kappa = -2]
#
# Iteration 11 for symmetries ...
#   1s_1/2::  en [a.u.] = -5.1557956e+01;   self-cons'cy = 1.1567e-07  [5.9090e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8993901e+00;   self-cons'cy = 4.3301e-07  [5.9090e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.7787940e+00;   self-cons'cy = 7.7212e-08  [7.7212e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -3.7636477e+00;   self-cons'cy = 2.6619e-07  [2.6619e-07 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -1.500864199344239e+02    -4.084059509195432e+03    -4.084059509195432e+03
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# DecayYield.computeOutcomes(): The computation of the fluorescence & Auger yields starts now ...
# -----------------------------------------------------------------------------------------------
#
#   Selected DecayYield levels:
#
#   -------------------------------------------
#      Level        J^P           Energy
#                                  [eV]
#   -------------------------------------------
#          1       1/2 +      -4.08405951e+03
#   -------------------------------------------
#
# Perform a cascade computation for all radiative decay channels of the levels from the initial configurations:
#
# * Configurations and levels for all given initial multiplets of the cascade, relative to the lowest:
#
#   Configuration: 1s^1 2s^2 2p^6
#   --------------------------------------------
#     Level  J Parity          Energy [eV]
#   --------------------------------------------
#        1     1/2 +      0.000000000000000e+00
#   --------------------------------------------
#
# * Electron configuration(s) used:    decay
#
#   Configuration(s) with 9 electrons:
#       1s^1 2s^2 2p^6       av. BE = -1779.0  [eV]      (1)
#       1s^2 2s^1 2p^6       av. BE = -2993.0  [eV]      (2)
#       1s^2 2s^2 2p^5       av. BE = -3032.0  [eV]      (3)
#
#   A total of 3 configuration have been defined for this decay cascade, and selected configurations could be removed here:  [currently not supported]
#
# * Generate blocks for the decay cascade:
#
#   In the cascade approach JAC.Cascade.SCA(), the following assumptions/simplifications are made:
#     + orbitals are generated independently for each multiplet (block);
#     + configuration interaction is included for each block;
#     + only E1 dipole transitions are applied in all radiative decay stets;
#
#   Multiplet computations for 1s^1 2s^2 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^5  with 9 electrons ... and 2 CSF done.
#
# * Configuration 'blocks' (multiplets): for the decay cascade
#
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#       No.   Configurations                                                                             No. CSF        Range of total energies [eV]
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#         1   1s^1 2s^2 2p^6                                                                                   1        -4084.0 ... -4084.0
#         2   1s^2 2s^1 2p^6                                                                                   1        -5299.0 ... -5299.0
#         3   1s^2 2s^2 2p^5                                                                                   2        -5340.0 ... -5340.0
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# * Steps that are defined for the current decay cascade due to the given approach:
#
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    Step-No   Process     Initial:  No CSF, configuration(s)                         Final:  No CSF, configuration(s)                           Energies from ... to in [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        1     Radiative     1, 1s^1 2s^2 2p^6                                          1, 1s^2 2s^1 2p^6                                        1215.0 ... 1215.0
#        2     Radiative     1, 1s^1 2s^2 2p^6                                          2, 1s^2 2s^2 2p^5                                        1256.0 ... 1256.0
#        3     Radiative     1, 1s^2 2s^1 2p^6                                          2, 1s^2 2s^2 2p^5                                        41.0 ... 41.0
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# * Here, modify the individual steps explicitly in the code, if needed, ...... and just do it !!
#
#   A total of 3 steps are still defined in the cascade.
#
#   1) Perform Radiative amplitude computations for up to 1 decay lines (without selection rules):
#      Step 1:: A total of 0 Radiative lines are calculated, giving now rise to a total of 0 Radiative decay lines.
#
#   2) Perform Radiative amplitude computations for up to 2 decay lines (without selection rules):
#      Step 2:: A total of 2 Radiative lines are calculated, giving now rise to a total of 2 Radiative decay lines.
#
#   3) Perform Radiative amplitude computations for up to 2 decay lines (without selection rules):
#      Step 3:: A total of 2 Radiative lines are calculated, giving now rise to a total of 4 Radiative decay lines.
#   0.026753 seconds (1.78 k allocations: 101.188 KiB, 92.96% compilation time)
#
# Perform a cascade computation for all (single-electron) Auger decay channels of the levels from the initial configurations:
#
# * Configurations and levels for all given initial multiplets of the cascade, relative to the lowest:
#
#   Configuration: 1s^1 2s^2 2p^6
#   --------------------------------------------
#     Level  J Parity          Energy [eV]
#   --------------------------------------------
#        1     1/2 +      0.000000000000000e+00
#   --------------------------------------------
#
# * Electron configuration(s) used:    decay
#
#   Configuration(s) with 9 electrons:
#       1s^1 2s^2 2p^6       av. BE = -1779.0  [eV]      (1)
#       1s^2 2s^1 2p^6       av. BE = -2993.0  [eV]      (2)
#       1s^2 2s^2 2p^5       av. BE = -3032.0  [eV]      (3)
#
#   Configuration(s) with 8 electrons:
#       1s^2 2s^0 2p^6       av. BE = -2905.0  [eV]      (4)
#       1s^2 2s^1 2p^5       av. BE = -2944.0  [eV]      (5)
#       1s^2 2s^2 2p^4       av. BE = -2983.0  [eV]      (6)
#
#   A total of 6 configuration have been defined for this decay cascade, and selected configurations could be removed here:  [currently not supported]
#
# * Generate blocks for the decay cascade:
#
#   In the cascade approach JAC.Cascade.SCA(), the following assumptions/simplifications are made:
#     + orbitals are generated independently for each multiplet (block);
#     + configuration interaction is included for each block;
#     + only E1 dipole transitions are applied in all radiative decay stets;
#
#   Multiplet computations for 1s^1 2s^2 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^5  with 9 electrons ... and 2 CSF done.
#   Multiplet computations for 1s^2 2s^0 2p^6  with 8 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^5  with 8 electrons ... and 4 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^4  with 8 electrons ... and 5 CSF done.
#
# * Configuration 'blocks' (multiplets): for the decay cascade
#
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#       No.   Configurations                                                                             No. CSF        Range of total energies [eV]
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#         1   1s^1 2s^2 2p^6                                                                                   1        -4084.0 ... -4084.0
#         2   1s^2 2s^1 2p^6                                                                                   1        -5299.0 ... -5299.0
#         3   1s^2 2s^2 2p^5                                                                                   2        -5340.0 ... -5340.0
#         4   1s^2 2s^0 2p^6                                                                                   1        -5148.0 ... -5148.0
#         5   1s^2 2s^1 2p^5                                                                                   4        -5196.0 ... -5181.0
#         6   1s^2 2s^2 2p^4                                                                                   5        -5233.0 ... -5221.0
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# * Steps that are defined for the current decay cascade due to the given approach:
#
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    Step-No   Process     Initial:  No CSF, configuration(s)                         Final:  No CSF, configuration(s)                           Energies from ... to in [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        1     Auger         1, 1s^1 2s^2 2p^6                                          1, 1s^2 2s^0 2p^6                                        1064.0 ... 1064.0
#        2     Auger         1, 1s^1 2s^2 2p^6                                          4, 1s^2 2s^1 2p^5                                        1097.0 ... 1112.0
#        3     Auger         1, 1s^1 2s^2 2p^6                                          5, 1s^2 2s^2 2p^4                                        1137.0 ... 1149.0
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# * Here, modify the individual steps explicitly in the code, if needed, ...... and just do it !!
#
#   A total of 3 steps are still defined in the cascade.
#
#   1) Perform Auger amplitude computations for up to 1 decay lines (without selection rules):
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=3.9092e+01,  kappa=-1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=9.8870e-13].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.5198e+00 and phase phi=8.4195e-01 at r=6.2631e+00 a.u.
#      Step 1:: A total of 1 Auger lines are calculated, giving now rise to a total of 1 Auger decay lines.
#
#   2) Perform Auger amplitude computations for up to 4 decay lines (without selection rules):
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.0877e+01,  kappa=-2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.5987e-10].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.5128e+00 and phase phi=2.9170e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.0877e+01,  kappa=3 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=3.6147e-10].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.4541e+00 and phase phi=2.0695e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.0869e+01,  kappa=-2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.6286e-10].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.5125e+00 and phase phi=2.9173e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.0869e+01,  kappa=1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.5592e-10].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.5130e+00 and phase phi=2.9230e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.0865e+01,  kappa=1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.5602e-10].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.5128e+00 and phase phi=2.9232e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.0304e+01,  kappa=-2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=3.1388e-10].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.4958e+00 and phase phi=2.9272e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.0304e+01,  kappa=1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=3.0586e-10].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.4958e+00 and phase phi=2.9328e+00 at r=6.2631e+00 a.u.
#      Step 2:: A total of 4 Auger lines are calculated, giving now rise to a total of 5 Auger decay lines.
#
#   3) Perform Auger amplitude computations for up to 5 decay lines (without selection rules):
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.2210e+01,  kappa=-3 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=4.6584e-10].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.4912e+00 and phase phi=2.3519e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.2210e+01,  kappa=2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=4.4980e-10].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.4912e+00 and phase phi=2.3537e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.2202e+01,  kappa=-1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=7.6729e-12].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.5379e+00 and phase phi=7.5497e-01 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.2202e+01,  kappa=2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=4.5102e-10].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.4913e+00 and phase phi=2.3540e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.2198e+01,  kappa=-1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=6.8638e-12].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.5381e+00 and phase phi=7.5513e-01 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.2038e+01,  kappa=-3 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=4.6122e-10].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.4883e+00 and phase phi=2.3554e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.2038e+01,  kappa=2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=4.4691e-10].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.4884e+00 and phase phi=2.3571e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=4.1786e+01,  kappa=-1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=3.9768e-11].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.5365e+00 and phase phi=7.6445e-01 at r=6.2631e+00 a.u.
#      Step 3:: A total of 5 Auger lines are calculated, giving now rise to a total of 10 Auger decay lines.
#   7.886836 seconds (75.13 M allocations: 1.515 GiB, 2.40% gc time, 3.65% compilation time)
# ** compareKey = LevelKey[1/2 + (1), en=-150.0864199344239, occ=0.0]
# ** compareKey = LevelKey[1/2 + (1), en=-150.0864199344239, occ=0.0]
#
#   Fluorescence and Auger decay yields:
#
#     + No_R, rate_R, omega_R  ... number of fluorescence lines, total fluorescence rate and yield.
#     + No_A, rate_A, omega_A  ... number of Auger lines, total Auger rate and Auger yield.
#     + Approach:  SCA  ... all fluorescence rates and yields only in Babushkin gauge.
#
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#      Level        J^P           Energy          No_R    Cou -- rate_R  -- Bab    Cou -- omega_R -- Bab     No_A      rate_A      Cou -- omega_A -- Bab
#                                  [eV]
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#          1       1/2 +      -4.08405951e+03     0002    0.0000e+00 4.3085e-04    0.0000e+00 3.3096e-02     0010    1.2587e-02    1.0000e+00 9.6690e-01
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# Obviously, this results in a rather detailed output due to printed data of the underlying cascade computation. In this single-step cascade, all the neon-like configurations with total energies below of the given $1s 2s^2 2p^6$ configuration are generated automatically, together with all energetically allowed fluorine-like configuration due to the (Auger) emission of an electon. Here, we shall not discuss this output in detail but just go over to the final table: It report an fluorescence yield $\omega_r \approx 0.08$ in Babushkin gauge and a corresponding Auger yield of $\omega_a \approx 0.92$. The same yields in Coulomb gauge are (0., 1.), but this occurs since
# by default all radiative transitions are only considered in Babushkin (length) gauge. To modify this settings, the user would have to change the *call* of the cascade computations *inside* of the code.
#
# To see how the coupling of the radiation field and, hence, the fluorescence increases with an increasing  nuclear charge, let us next perform the same computations but for Z=18 and Z=26, respectively.

# %%
wa = Atomic.Computation(wa, name="Yield computations for neon-like Ar", nuclearModel=Nuclear.Model(18.))
perform(wa)
# Out:
# ... in performSCF ...
# >> include Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 18.0 with mass = 37.62, radius R = 3.37121133160794 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.62704537e+02    -1.62704858e+02    +1.97563229e-06
#       2      2s_1/2      -4.07203230e+01    -4.07203638e+01    +1.00187501e-06
#      18     19p_3/2      +9.16820277e+00    -4.48941404e-01    +1.04896722e+00
#      19     20p_3/2      +1.09018728e+01    -4.05161824e-01    +1.03716442e+00
#      20     21p_3/2      +1.27399748e+01    -3.67487266e-01    +1.02884521e+00
#      21     22p_3/2      +1.46816665e+01    -3.34833217e-01    +1.02280621e+00
#      22     23p_3/2      +1.67262330e+01    -3.06345708e-01    +1.01831528e+00
#      23     24p_3/2      +1.88730599e+01    -2.81344908e-01    +1.01490722e+00
#      24     25p_3/2      +2.11216136e+01    -2.59284192e-01    +1.01227578e+00
#      25     26p_3/2      +2.34714260e+01    -2.39719999e-01    +1.01021327e+00
#      26     27p_3/2      +2.59220829e+01    -2.22289371e-01    +1.00857529e+00
#      27     28p_3/2      +2.84732149e+01    -2.06692987e-01    +1.00725921e+00
#      28     29p_3/2      +3.11244898e+01    -1.92682235e-01    +1.00619070e+00
#      29     30p_3/2      +3.38756073e+01    -1.80049238e-01    +1.00531501e+00
#      30     31p_3/2      +3.67262934e+01    -1.68619102e-01    +1.00459124e+00
#      31     32p_3/2      +3.96762971e+01    -1.58243829e-01    +1.00398837e+00
#      32     33p_3/2      +4.27253869e+01    -1.48797500e-01    +1.00348265e+00
#      33     34p_3/2      +4.58733479e+01    -1.40172441e-01    +1.00305564e+00
#      34     35p_3/2      +4.91199794e+01    -1.32276137e-01    +1.00269292e+00
#      35     36p_3/2      +5.24650930e+01    -1.25028743e-01    +1.00238308e+00
#      36     37p_3/2      +5.59085107e+01    -1.18361057e-01    +1.00211705e+00
#      37     38p_3/2      +5.94500628e+01    -1.12212861e-01    +1.00188751e+00
#      38     39p_3/2      +6.30895870e+01    -1.06531558e-01    +1.00168858e+00
#       :       :
#     126    127p_3/2      +1.31884434e+08    -1.00446951e-02    +1.00000000e+00
#     127    128p_3/2      +1.89091393e+08    -9.88835465e-03    +1.00000000e+00
#     128    129p_3/2      +2.83561322e+08    -9.73563607e-03    +1.00000000e+00
#     129    130p_3/2      +4.62644208e+08    -9.58642830e-03    +1.00000000e+00
#     130    131p_3/2      +8.96213761e+08    -9.44062456e-03    +1.00000000e+00
#     131    132p_3/2      +2.69324907e+09    -9.29812207e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# (Re-) Define the standard grid with 889 grid points.
# >>  for various B-spline matrices:
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2369795e+02;   self-cons'cy = 1.3620e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.7866546e+01;   self-cons'cy = 3.9008e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.5949187e+01;   self-cons'cy = 4.3712e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.6486950e+01;   self-cons'cy = 4.2182e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2991265e+02;   self-cons'cy = 2.4505e-02  [1.4993e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9747956e+01;   self-cons'cy = 5.0018e-02  [1.4993e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7624813e+01;   self-cons'cy = 4.9908e-02  [9.0178e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7362517e+01;   self-cons'cy = 2.5867e-02  [4.5553e-02 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2880445e+02;   self-cons'cy = 4.2834e-03  [3.1952e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9371845e+01;   self-cons'cy = 9.6143e-03  [3.1952e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7327789e+01;   self-cons'cy = 8.4979e-03  [1.7141e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7248058e+01;   self-cons'cy = 3.3071e-03  [6.5799e-03 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2896988e+02;   self-cons'cy = 6.4176e-04  [4.6374e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9427319e+01;   self-cons'cy = 1.4298e-03  [4.6374e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7366966e+01;   self-cons'cy = 1.1292e-03  [2.2304e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7259870e+01;   self-cons'cy = 3.4230e-04  [6.6760e-04 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2894804e+02;   self-cons'cy = 8.4672e-05  [6.1757e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9419956e+01;   self-cons'cy = 1.8955e-04  [6.1757e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362222e+01;   self-cons'cy = 1.3661e-04  [2.7050e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258776e+01;   self-cons'cy = 3.1692e-05  [6.1768e-05 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2895065e+02;   self-cons'cy = 1.0113e-05  [7.3871e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9420837e+01;   self-cons'cy = 2.2680e-05  [7.3871e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362741e+01;   self-cons'cy = 1.4947e-05  [2.9561e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258859e+01;   self-cons'cy = 2.4015e-06  [4.6479e-06 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2895036e+02;   self-cons'cy = 1.0975e-06  [8.0385e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9420741e+01;   self-cons'cy = 2.4670e-06  [8.0385e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362690e+01;   self-cons'cy = 1.4666e-06  [2.8960e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258855e+01;   self-cons'cy = 1.0596e-07  [1.9950e-07 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.2895039e+02;   self-cons'cy = 1.0669e-07  [7.8413e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.9420750e+01;   self-cons'cy = 2.4051e-07  [7.8413e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.7362694e+01;   self-cons'cy = 1.2329e-07  [2.4169e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.7258855e+01;   self-cons'cy = 8.6955e-09  [1.8136e-08 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -3.830168713394362e+02    -1.042241993819007e+04    -1.042241993819007e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# DecayYield.computeOutcomes(): The computation of the fluorescence & Auger yields starts now ...
# -----------------------------------------------------------------------------------------------
#
#   Selected DecayYield levels:
#
#   -------------------------------------------
#      Level        J^P           Energy
#                                  [eV]
#   -------------------------------------------
#          1       1/2 +      -1.04224199e+04
#   -------------------------------------------
#
# Perform a cascade computation for all radiative decay channels of the levels from the initial configurations:
#
# * Configurations and levels for all given initial multiplets of the cascade, relative to the lowest:
#
#   Configuration: 1s^1 2s^2 2p^6
#   --------------------------------------------
#     Level  J Parity          Energy [eV]
#   --------------------------------------------
#        1     1/2 +      0.000000000000000e+00
#   --------------------------------------------
#
# * Electron configuration(s) used:    decay
#
#   Configuration(s) with 9 electrons:
#       1s^1 2s^2 2p^6       av. BE = -5362.0  [eV]      (1)
#       1s^2 2s^1 2p^6       av. BE = -8242.0  [eV]      (2)
#       1s^2 2s^2 2p^5       av. BE = -8317.0  [eV]      (3)
#
#   A total of 3 configuration have been defined for this decay cascade, and selected configurations could be removed here:  [currently not supported]
#
# * Generate blocks for the decay cascade:
#
#   In the cascade approach JAC.Cascade.SCA(), the following assumptions/simplifications are made:
#     + orbitals are generated independently for each multiplet (block);
#     + configuration interaction is included for each block;
#     + only E1 dipole transitions are applied in all radiative decay stets;
#
#   Multiplet computations for 1s^1 2s^2 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^5  with 9 electrons ... and 2 CSF done.
#
# * Configuration 'blocks' (multiplets): for the decay cascade
#
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#       No.   Configurations                                                                             No. CSF        Range of total energies [eV]
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#         1   1s^1 2s^2 2p^6                                                                                   1        -10422.0 ... -10422.0
#         2   1s^2 2s^1 2p^6                                                                                   1        -13319.0 ... -13319.0
#         3   1s^2 2s^2 2p^5                                                                                   2        -13396.0 ... -13394.0
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# * Steps that are defined for the current decay cascade due to the given approach:
#
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    Step-No   Process     Initial:  No CSF, configuration(s)                         Final:  No CSF, configuration(s)                           Energies from ... to in [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        1     Radiative     1, 1s^1 2s^2 2p^6                                          1, 1s^2 2s^1 2p^6                                        2897.0 ... 2897.0
#        2     Radiative     1, 1s^1 2s^2 2p^6                                          2, 1s^2 2s^2 2p^5                                        2972.0 ... 2974.0
#        3     Radiative     1, 1s^2 2s^1 2p^6                                          2, 1s^2 2s^2 2p^5                                        75.0 ... 77.0
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# * Here, modify the individual steps explicitly in the code, if needed, ...... and just do it !!
#
#   A total of 3 steps are still defined in the cascade.
#
#   1) Perform Radiative amplitude computations for up to 1 decay lines (without selection rules):
#      Step 1:: A total of 0 Radiative lines are calculated, giving now rise to a total of 0 Radiative decay lines.
#
#   2) Perform Radiative amplitude computations for up to 2 decay lines (without selection rules):
#      Step 2:: A total of 2 Radiative lines are calculated, giving now rise to a total of 2 Radiative decay lines.
#
#   3) Perform Radiative amplitude computations for up to 2 decay lines (without selection rules):
#      Step 3:: A total of 2 Radiative lines are calculated, giving now rise to a total of 4 Radiative decay lines.
#   0.000344 seconds (1.57 k allocations: 89.219 KiB)
#
# Perform a cascade computation for all (single-electron) Auger decay channels of the levels from the initial configurations:
#
# * Configurations and levels for all given initial multiplets of the cascade, relative to the lowest:
#
#   Configuration: 1s^1 2s^2 2p^6
#   --------------------------------------------
#     Level  J Parity          Energy [eV]
#   --------------------------------------------
#        1     1/2 +      0.000000000000000e+00
#   --------------------------------------------
#
# * Electron configuration(s) used:    decay
#
#   Configuration(s) with 9 electrons:
#       1s^1 2s^2 2p^6       av. BE = -5362.0  [eV]      (1)
#       1s^2 2s^1 2p^6       av. BE = -8242.0  [eV]      (2)
#       1s^2 2s^2 2p^5       av. BE = -8317.0  [eV]      (3)
#
#   Configuration(s) with 8 electrons:
#       1s^2 2s^0 2p^6       av. BE = -7915.0  [eV]      (4)
#       1s^2 2s^1 2p^5       av. BE = -7991.0  [eV]      (5)
#       1s^2 2s^2 2p^4       av. BE = -8067.0  [eV]      (6)
#
#   A total of 6 configuration have been defined for this decay cascade, and selected configurations could be removed here:  [currently not supported]
#
# * Generate blocks for the decay cascade:
#
#   In the cascade approach JAC.Cascade.SCA(), the following assumptions/simplifications are made:
#     + orbitals are generated independently for each multiplet (block);
#     + configuration interaction is included for each block;
#     + only E1 dipole transitions are applied in all radiative decay stets;
#
#   Multiplet computations for 1s^1 2s^2 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^5  with 9 electrons ... and 2 CSF done.
#   Multiplet computations for 1s^2 2s^0 2p^6  with 8 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^5  with 8 electrons ... and 4 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^4  with 8 electrons ... and 5 CSF done.
#
# * Configuration 'blocks' (multiplets): for the decay cascade
#
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#       No.   Configurations                                                                             No. CSF        Range of total energies [eV]
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#         1   1s^1 2s^2 2p^6                                                                                   1        -10422.0 ... -10422.0
#         2   1s^2 2s^1 2p^6                                                                                   1        -13319.0 ... -13319.0
#         3   1s^2 2s^2 2p^5                                                                                   2        -13396.0 ... -13394.0
#         4   1s^2 2s^0 2p^6                                                                                   1        -12764.0 ... -12764.0
#         5   1s^2 2s^1 2p^5                                                                                   4        -12852.0 ... -12825.0
#         6   1s^2 2s^2 2p^4                                                                                   5        -12918.0 ... -12897.0
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# * Steps that are defined for the current decay cascade due to the given approach:
#
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    Step-No   Process     Initial:  No CSF, configuration(s)                         Final:  No CSF, configuration(s)                           Energies from ... to in [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        1     Auger         1, 1s^1 2s^2 2p^6                                          1, 1s^2 2s^0 2p^6                                        2341.0 ... 2341.0
#        2     Auger         1, 1s^1 2s^2 2p^6                                          4, 1s^2 2s^1 2p^5                                        2403.0 ... 2429.0
#        3     Auger         1, 1s^1 2s^2 2p^6                                          5, 1s^2 2s^2 2p^4                                        2474.0 ... 2496.0
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# * Here, modify the individual steps explicitly in the code, if needed, ...... and just do it !!
#
#   A total of 3 steps are still defined in the cascade.
#
#   1) Perform Auger amplitude computations for up to 1 decay lines (without selection rules):
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=8.6041e+01,  kappa=-1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.0311e-08].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.1600e+00 and phase phi=2.1349e+00 at r=6.2631e+00 a.u.
#      Step 1:: A total of 1 Auger lines are calculated, giving now rise to a total of 1 Auger decay lines.
#
#   2) Perform Auger amplitude computations for up to 4 decay lines (without selection rules):
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=8.9268e+01,  kappa=-2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=3.8555e-08].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.2217e+00 and phase phi=1.0705e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=8.9268e+01,  kappa=3 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.3283e-07].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.1928e+00 and phase phi=1.5933e-01 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=8.9210e+01,  kappa=-2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=4.3579e-08].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.2208e+00 and phase phi=1.0714e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=8.9210e+01,  kappa=1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=4.0199e-08].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.2208e+00 and phase phi=1.0849e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=8.9178e+01,  kappa=1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=4.2924e-08].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.2204e+00 and phase phi=1.0854e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=8.8298e+01,  kappa=-2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.1490e-07].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.1945e+00 and phase phi=1.0829e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=8.8298e+01,  kappa=1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.1097e-07].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.1951e+00 and phase phi=1.0963e+00 at r=6.2631e+00 a.u.
#      Step 2:: A total of 4 Auger lines are calculated, giving now rise to a total of 5 Auger decay lines.
#
#   3) Perform Auger amplitude computations for up to 5 decay lines (without selection rules):
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=9.1721e+01,  kappa=-3 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.1066e-07].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.2630e+00 and phase phi=4.7662e-01 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=9.1721e+01,  kappa=2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.0434e-07].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.2630e+00 and phase phi=4.8108e-01 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=9.1655e+01,  kappa=-1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=5.0504e-08].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.2638e+00 and phase phi=2.0403e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=9.1655e+01,  kappa=2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.1104e-07].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.2633e+00 and phase phi=4.8235e-01 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=9.1635e+01,  kappa=-1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=4.8309e-08].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.2632e+00 and phase phi=2.0406e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=9.1383e+01,  kappa=-3 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.4128e-07].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.2547e+00 and phase phi=4.8202e-01 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=9.1383e+01,  kappa=2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.3455e-07].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.2551e+00 and phase phi=4.8647e-01 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=9.0933e+01,  kappa=-1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=8.3335e-10].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.2615e+00 and phase phi=2.0498e+00 at r=6.2631e+00 a.u.
#      Step 3:: A total of 5 Auger lines are calculated, giving now rise to a total of 10 Auger decay lines.
#   7.453056 seconds (75.05 M allocations: 1.498 GiB, 3.22% gc time)
# ** compareKey = LevelKey[1/2 + (1), en=-383.01687133943625, occ=0.0]
# ** compareKey = LevelKey[1/2 + (1), en=-383.01687133943625, occ=0.0]
#
#   Fluorescence and Auger decay yields:
#
#     + No_R, rate_R, omega_R  ... number of fluorescence lines, total fluorescence rate and yield.
#     + No_A, rate_A, omega_A  ... number of Auger lines, total Auger rate and Auger yield.
#     + Approach:  SCA  ... all fluorescence rates and yields only in Babushkin gauge.
#
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#      Level        J^P           Energy          No_R    Cou -- rate_R  -- Bab    Cou -- omega_R -- Bab     No_A      rate_A      Cou -- omega_A -- Bab
#                                  [eV]
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#          1       1/2 +      -1.04224199e+04     0002    0.0000e+00 2.8874e-03    0.0000e+00 1.3149e-01     0010    1.9072e-02    1.0000e+00 8.6851e-01
#   -----------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# Constants.warn():  Reset global array GBL_WARNINGS.

# %%
wa = Atomic.Computation(wa, name="Yield computations for neon-like Fe", nuclearModel=Nuclear.Model(26.))
perform(wa)
# Out:
# ... in performSCF ...
# >> include Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 26.0 with mass = 55.38, radius R = 3.756573410087755 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -3.41095880e+02    -3.41097837e+02    +5.73808741e-06
#       2      2s_1/2      -8.54687058e+01    -8.54689584e+01    +2.95503175e-06
#       3      3s_1/2      -3.78993728e+01    -3.78994478e+01    +1.97809590e-06
#       4      4s_1/2      -2.12819069e+01    -2.12819385e+01    +1.48505280e-06
#       5      5s_1/2      -1.36039552e+01    -1.36039714e+01    +1.18828747e-06
#       6      6s_1/2      -9.43886387e+00    -9.43887322e+00    +9.90247107e-07
#       7      7s_1/2      -6.93005337e+00    -6.93005925e+00    +8.47808453e-07
#       8      8s_1/2      -5.30306287e+00    -5.30306679e+00    +7.39618132e-07
#       9      9s_1/2      -4.18832347e+00    -4.18833237e+00    +2.12340232e-06
#      10     10s_1/2      -3.38998804e+00    -3.39139342e+00    +4.14567231e-04
#      11     11s_1/2      -2.76183303e+00    -2.80200932e+00    +1.45469653e-02
#      12     12s_1/2      -2.10286534e+00    -2.35390152e+00    +1.19378151e-01
#      13     13s_1/2      -1.29776407e+00    -2.00527939e+00    +5.45180231e-01
#      14     14s_1/2      -3.45832287e-01    -1.72873456e+00    +3.99876566e+00
#      15     15s_1/2      +7.40430753e-01    -1.50568590e+00    +3.03352696e+00
#      16     16s_1/2      +1.95273232e+00    -1.32317551e+00    +1.67760209e+00
#      17     17s_1/2      +3.28558957e+00    -1.17194372e+00    +1.35669206e+00
#      18     18s_1/2      +4.73513581e+00    -1.04523122e+00    +1.22073944e+00
#      19     19s_1/2      +6.29849858e+00    -9.38010549e-01    +1.14892606e+00
#      20     20s_1/2      +7.97345879e+00    -8.46479707e-01    +1.10616217e+00
#      21     21s_1/2      +9.75824968e+00    -7.67720412e-01    +1.07867399e+00
#      22     22s_1/2      +1.16514306e+01    -6.99462612e-01    +1.06003234e+00
#      23     23s_1/2      +1.36518036e+01    -6.39919074e-01    +1.04687432e+00
#      24     24s_1/2      +1.57583565e+01    -5.87667202e-01    +1.03729242e+00
#      25     25s_1/2      +1.79702221e+01    -5.41563273e-01    +1.03013670e+00
#      26     26s_1/2      +2.02866482e+01    -5.00679321e-01    +1.02468024e+00
#      27     27s_1/2      +2.27069758e+01    -4.64256076e-01    +1.02044553e+00
#      28     28s_1/2      +2.52306220e+01    -4.31667457e-01    +1.01710887e+00
#      29     29s_1/2      +2.78570668e+01    -4.02393493e-01    +1.01444493e+00
#      30     30s_1/2      +3.05858426e+01    -3.75999447e-01    +1.01229325e+00
#      31     31s_1/2      +3.34165264e+01    -3.52119585e-01    +1.01053729e+00
#   1s_1/2::  en [a.u.] = -2.8438209e+02;   self-cons'cy = 9.0673e-02  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.1573111e+01;   self-cons'cy = 2.4734e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.8296858e+01;   self-cons'cy = 2.7789e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.8395554e+01;   self-cons'cy = 2.7272e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.9025154e+02;   self-cons'cy = 1.0214e-02  [7.0939e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3407238e+01;   self-cons'cy = 1.7471e-02  [7.0939e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -5.0035920e+01;   self-cons'cy = 1.7685e-02  [4.7830e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9402039e+01;   self-cons'cy = 1.0292e-02  [2.6822e-02 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8958853e+02;   self-cons'cy = 1.1434e-03  [8.6708e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3188328e+01;   self-cons'cy = 2.0536e-03  [8.6708e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9850356e+01;   self-cons'cy = 1.8577e-03  [5.3203e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9316758e+01;   self-cons'cy = 8.6388e-04  [2.3893e-03 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8965288e+02;   self-cons'cy = 1.1110e-04  [8.3855e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3209557e+01;   self-cons'cy = 1.9952e-04  [8.3855e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9866850e+01;   self-cons'cy = 1.6540e-04  [4.7043e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9323344e+01;   self-cons'cy = 6.6768e-05  [1.8358e-04 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964719e+02;   self-cons'cy = 9.8214e-06  [7.4428e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3207676e+01;   self-cons'cy = 1.7679e-05  [7.4428e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9865472e+01;   self-cons'cy = 1.3814e-05  [3.9293e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322847e+01;   self-cons'cy = 5.0402e-06  [1.3969e-05 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964767e+02;   self-cons'cy = 8.1738e-07  [6.2058e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3207833e+01;   self-cons'cy = 1.4732e-06  [6.2058e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9865582e+01;   self-cons'cy = 1.1021e-06  [3.1410e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322883e+01;   self-cons'cy = 3.7204e-07  [1.0278e-06 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.8964763e+02;   self-cons'cy = 6.5211e-08  [4.8656e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -5.3207820e+01;   self-cons'cy = 1.1765e-07  [4.8656e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.9865574e+01;   self-cons'cy = 8.4978e-08  [2.4900e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -4.9322881e+01;   self-cons'cy = 2.6895e-08  [2.8111e-08 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -8.651846078247827e+02    -2.354287234208247e+04    -2.354287234208247e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# DecayYield.computeOutcomes(): The computation of the fluorescence & Auger yields starts now ...
# -----------------------------------------------------------------------------------------------
#
#   Selected DecayYield levels:
#
#   -------------------------------------------
#      Level        J^P           Energy
#                                  [eV]
#   -------------------------------------------
#          1       1/2 +      -2.35428723e+04
#   -------------------------------------------
#
# Perform a cascade computation for all radiative decay channels of the levels from the initial configurations:
#
# * Configurations and levels for all given initial multiplets of the cascade, relative to the lowest:
#
#   Configuration: 1s^1 2s^2 2p^6
#   --------------------------------------------
#     Level  J Parity          Energy [eV]
#   --------------------------------------------
#        1     1/2 +      0.000000000000000e+00
#   --------------------------------------------
#
# * Electron configuration(s) used:    decay
#
#   Configuration(s) with 9 electrons:
#       1s^1 2s^2 2p^6       av. BE = -13121.0  [eV]      (1)
#       1s^2 2s^1 2p^6       av. BE = -19388.0  [eV]      (2)
#       1s^2 2s^2 2p^5       av. BE = -19513.0  [eV]      (3)
#
#   A total of 3 configuration have been defined for this decay cascade, and selected configurations could be removed here:  [currently not supported]
#
# * Generate blocks for the decay cascade:
#
#   In the cascade approach JAC.Cascade.SCA(), the following assumptions/simplifications are made:
#     + orbitals are generated independently for each multiplet (block);
#     + configuration interaction is included for each block;
#     + only E1 dipole transitions are applied in all radiative decay stets;
#
#   Multiplet computations for 1s^1 2s^2 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^5  with 9 electrons ... and 2 CSF done.
#
# * Configuration 'blocks' (multiplets): for the decay cascade
#
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#       No.   Configurations                                                                             No. CSF        Range of total energies [eV]
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#         1   1s^1 2s^2 2p^6                                                                                   1        -23543.0 ... -23543.0
#         2   1s^2 2s^1 2p^6                                                                                   1        -29854.0 ... -29854.0
#         3   1s^2 2s^2 2p^5                                                                                   2        -29989.0 ... -29976.0
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# * Steps that are defined for the current decay cascade due to the given approach:
#
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    Step-No   Process     Initial:  No CSF, configuration(s)                         Final:  No CSF, configuration(s)                           Energies from ... to in [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        1     Radiative     1, 1s^1 2s^2 2p^6                                          1, 1s^2 2s^1 2p^6                                        6311.0 ... 6311.0
#        2     Radiative     1, 1s^1 2s^2 2p^6                                          2, 1s^2 2s^2 2p^5                                        6433.0 ... 6446.0
#        3     Radiative     1, 1s^2 2s^1 2p^6                                          2, 1s^2 2s^2 2p^5                                        122.0 ... 135.0
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# * Here, modify the individual steps explicitly in the code, if needed, ...... and just do it !!
#
#   A total of 3 steps are still defined in the cascade.
#
#   1) Perform Radiative amplitude computations for up to 1 decay lines (without selection rules):
#      Step 1:: A total of 0 Radiative lines are calculated, giving now rise to a total of 0 Radiative decay lines.
#
#   2) Perform Radiative amplitude computations for up to 2 decay lines (without selection rules):
#      Step 2:: A total of 2 Radiative lines are calculated, giving now rise to a total of 2 Radiative decay lines.
#
#   3) Perform Radiative amplitude computations for up to 2 decay lines (without selection rules):
#      Step 3:: A total of 2 Radiative lines are calculated, giving now rise to a total of 4 Radiative decay lines.
#   0.000303 seconds (1.57 k allocations: 89.219 KiB)
#
# Perform a cascade computation for all (single-electron) Auger decay channels of the levels from the initial configurations:
#
# * Configurations and levels for all given initial multiplets of the cascade, relative to the lowest:
#
#   Configuration: 1s^1 2s^2 2p^6
#   --------------------------------------------
#     Level  J Parity          Energy [eV]
#   --------------------------------------------
#        1     1/2 +      0.000000000000000e+00
#   --------------------------------------------
#
# * Electron configuration(s) used:    decay
#
#   Configuration(s) with 9 electrons:
#       1s^1 2s^2 2p^6       av. BE = -13121.0  [eV]      (1)
#       1s^2 2s^1 2p^6       av. BE = -19388.0  [eV]      (2)
#       1s^2 2s^2 2p^5       av. BE = -19513.0  [eV]      (3)
#
#   Configuration(s) with 8 electrons:
#       1s^2 2s^0 2p^6       av. BE = -18543.0  [eV]      (4)
#       1s^2 2s^1 2p^5       av. BE = -18668.0  [eV]      (5)
#       1s^2 2s^2 2p^4       av. BE = -18793.0  [eV]      (6)
#
#   A total of 6 configuration have been defined for this decay cascade, and selected configurations could be removed here:  [currently not supported]
#
# * Generate blocks for the decay cascade:
#
#   In the cascade approach JAC.Cascade.SCA(), the following assumptions/simplifications are made:
#     + orbitals are generated independently for each multiplet (block);
#     + configuration interaction is included for each block;
#     + only E1 dipole transitions are applied in all radiative decay stets;
#
#   Multiplet computations for 1s^1 2s^2 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^6  with 9 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^5  with 9 electrons ... and 2 CSF done.
#   Multiplet computations for 1s^2 2s^0 2p^6  with 8 electrons ... and 1 CSF done.
#   Multiplet computations for 1s^2 2s^1 2p^5  with 8 electrons ... and 4 CSF done.
#   Multiplet computations for 1s^2 2s^2 2p^4  with 8 electrons ... and 5 CSF done.
#
# * Configuration 'blocks' (multiplets): for the decay cascade
#
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#       No.   Configurations                                                                             No. CSF        Range of total energies [eV]
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#         1   1s^1 2s^2 2p^6                                                                                   1        -23543.0 ... -23543.0
#         2   1s^2 2s^1 2p^6                                                                                   1        -29854.0 ... -29854.0
#         3   1s^2 2s^2 2p^5                                                                                   2        -29989.0 ... -29976.0
#         4   1s^2 2s^0 2p^6                                                                                   1        -28368.0 ... -28368.0
#         5   1s^2 2s^1 2p^5                                                                                   4        -28517.0 ... -28473.0
#         6   1s^2 2s^2 2p^4                                                                                   5        -28633.0 ... -28589.0
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# * Steps that are defined for the current decay cascade due to the given approach:
#
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    Step-No   Process     Initial:  No CSF, configuration(s)                         Final:  No CSF, configuration(s)                           Energies from ... to in [eV]
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        1     Auger         1, 1s^1 2s^2 2p^6                                          1, 1s^2 2s^0 2p^6                                        4825.0 ... 4825.0
#        2     Auger         1, 1s^1 2s^2 2p^6                                          4, 1s^2 2s^1 2p^5                                        4930.0 ... 4974.0
#        3     Auger         1, 1s^1 2s^2 2p^6                                          5, 1s^2 2s^2 2p^4                                        5046.0 ... 5090.0
#   --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# * Here, modify the individual steps explicitly in the code, if needed, ...... and just do it !!
#
#   A total of 3 steps are still defined in the cascade.
#
#   1) Perform Auger amplitude computations for up to 1 decay lines (without selection rules):
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.7732e+02,  kappa=-1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.0772e-06].
# >> Pure-sine normalized continuum orbital with normalization constant N=6.3237e+00 and phase phi=1.0264e-01 at r=6.2631e+00 a.u.
#      Step 1:: A total of 1 Auger lines are calculated, giving now rise to a total of 1 Auger decay lines.
#
#   2) Perform Auger amplitude computations for up to 4 decay lines (without selection rules):
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.8280e+02,  kappa=-2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=2.2604e-06].
# >> Pure-sine normalized continuum orbital with normalization constant N=6.5609e+00 and phase phi=2.2002e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.8280e+02,  kappa=3 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=2.1994e-06].
# >> Pure-sine normalized continuum orbital with normalization constant N=6.6051e+00 and phase phi=1.4198e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.8251e+02,  kappa=-2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.1235e-06].
# >> Pure-sine normalized continuum orbital with normalization constant N=6.5490e+00 and phase phi=2.2257e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.8251e+02,  kappa=1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.3815e-06].
# >> Pure-sine normalized continuum orbital with normalization constant N=6.5471e+00 and phase phi=2.2480e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.8231e+02,  kappa=1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=7.3382e-07].
# >> Pure-sine normalized continuum orbital with normalization constant N=6.5485e+00 and phase phi=2.2668e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.8117e+02,  kappa=-2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.1006e-06].
# >> Pure-sine normalized continuum orbital with normalization constant N=6.5535e+00 and phase phi=2.3483e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.8117e+02,  kappa=1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=8.3414e-07].
# >> Pure-sine normalized continuum orbital with normalization constant N=6.5444e+00 and phase phi=2.3697e+00 at r=6.2631e+00 a.u.
#      Step 2:: A total of 4 Auger lines are calculated, giving now rise to a total of 5 Auger decay lines.
#
#   3) Perform Auger amplitude computations for up to 5 decay lines (without selection rules):
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.8706e+02,  kappa=-3 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.6163e-06].
# >> Pure-sine normalized continuum orbital with normalization constant N=6.8285e+00 and phase phi=1.6662e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.8706e+02,  kappa=2 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=1.8101e-06].
# >> Pure-sine normalized continuum orbital with normalization constant N=6.8287e+00 and phase phi=1.6734e+00 at r=6.2631e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.8669e+02,  kappa=-1 [mpt=689, r[mtp]=6.2631e+00, smallest eigenvalue=5.3568e-06].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.4279e+05 and phase phi=2.6887e+00 at r=6.2631e+00 a.u.
# Pure-sine normalized N=2.4279e+05==> enlarge box-size
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:33
#   [2] normalizeOrbitalPureSine(cOrbital::Orbital, grid::JAC.Radial.Grid, settings::JAC.Continuum.Settings)
#     @ JAC.Continuum ~/fri/JAC.jl/src/module-Continuum.jl:316
#   [3] generateOrbitalForLevel(energy::Float64, sh::Subshell, level::Level, nm::Model, grid::JAC.Radial.Grid, settings::JAC.Continuum.Settings)
#     @ JAC.Continuum ~/fri/JAC.jl/src/module-Continuum.jl:60
#   [4] computeAmplitudesProperties(line::JAC.AutoIonization.Line, nm::Model, grid::JAC.Radial.Grid, nrContinuum::Int64, settings::JAC.AutoIonization.Settings; printout::Bool)
#     @ JAC.AutoIonization ~/fri/JAC.jl/src/module-AutoIonization.jl:249
#   [5] computeLinesCascade(finalMultiplet::Multiplet, initialMultiplet::Multiplet, nm::Model, grid::JAC.Radial.Grid, settings::JAC.AutoIonization.Settings; output::Bool, printout::Bool)
#     @ JAC.AutoIonization ~/fri/JAC.jl/src/module-AutoIonization.jl:400
#   [6] computeSteps(scheme::JAC.Cascade.StepwiseDecayScheme, comp::JAC.Cascade.Computation, stepList::Vector{JAC.Cascade.Step})
#     @ JAC.Cascade ~/fri/JAC.jl/src/module-Cascade-inc-stepwise-decay.jl:56
#   [7] macro expansion
#     @ ./timing.jl:210 [inlined]
#   [8] perform(scheme::JAC.Cascade.StepwiseDecayScheme, comp::JAC.Cascade.Computation; output::Bool, outputToFile::Bool)
#     @ JAC.Cascade ~/fri/JAC.jl/src/module-Cascade-inc-stepwise-decay.jl:161
#   [9] perform(comp::JAC.Cascade.Computation; output::Bool, outputToFile::Bool)
#     @ JAC.BasicsAZ ~/fri/JAC.jl/src/module-BascisAZ-inc-perform.jl:210
#  [10] computeOutcomes(initialConfigs::Vector{Configuration}, asfSettings::AsfSettings, multiplet::Multiplet, nm::Model, grid::JAC.Radial.Grid, settings::JAC.DecayYield.Settings; output::Bool)
#     @ JAC.DecayYield ~/fri/JAC.jl/src/module-DecayYield.jl:118
#  [11] computeOutcomes
#     @ ~/fri/JAC.jl/src/module-DecayYield.jl:93 [inlined]
#  [12] perform(computation::JAC.Atomic.Computation; output::Bool)
#     @ JAC.BasicsAZ ~/fri/JAC.jl/src/module-BascisAZ-inc-perform.jl:57
#  [13] perform(computation::JAC.Atomic.Computation)
#     @ JAC.BasicsAZ ~/fri/JAC.jl/src/module-BascisAZ-inc-perform.jl:14
#  [14] top-level scope
#     @ In[6]:2
#  [15] eval
#     @ ./boot.jl:360 [inlined]
#  [16] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %% [markdown]
# From the output of these three computations, we see that the fluorescence yield $\omega_r$ increase from 8 % (Z=12) to 28 % (Z=18) and up to 40 % (Z=26).

# %% [markdown]
# We could consider also the yields for the $2s$ hole state of argon which is known to decay by fast **Coster-Kronig transitions**. Because of the (very) low energies of the emitted Coster-Kronig electrons, these computations require however further care in order to obtain reliable estimates. Since all these yield computations are always based on (rather elaborate) *cascade computations*, further improvements of the yield-computations might be possible but will require advice and support by the community.
