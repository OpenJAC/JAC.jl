# %% [markdown]
# # Compute the low-lying levels of $C^{2+} 1s^2 (2s^2 + 2s2p + 2p^2)$: $\;$ SCF and configuration interaction calculations

# %%
using JAC
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-5933068647986008627\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-13651268231872583268\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-5933068647986008627\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")

# %% [markdown]
# The low-lying levels (level structure) of beryllium-like ions, and especially C$^{2+}$, has been calculated in many case studies in the literature. While the level structure of these ions is still quite simple, they exhibit a considerable admixture of the $2s^2 2p^2$ configuration already for the $1s^2 2s^2\;\: ^1S_0$ ground level.
#
# We here show how the low-lying levels of C$^{2+}$ can be readily calculated in JAC by either following the default settings or by specifying further details for both, the SCF and configuration-interaction (CI) computations. As usual, we first need to specify a radial grid as well as the nuclear model for the subsequent computations:

# %%
grid     = Radial.Grid("grid: exponential")
nucModel = Nuclear.Model(6., "Fermi")
# Out:
# Define a radial grid of type MeshGL with 400 grid points
#  [rnt=2.000e-06, h=5.000e-02, hp=0.000e+00, NoPoints=390, r_max=9.161e+02;
#   B-splines with break points at every 7th point, nsL=56, nsS=57, orderL=7, orderS=8, orderGL=7]
# Fermi nuclear model for Z = 6.0 with mass = 12.18, radius R = 2.4934845703596404 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.

# %% [markdown]
# For a *quick* computation of the ground level of C$^{2+}$ ions, we can simply use the **standard settings** as given by `AsfSettings()`:

# %%
basis     = perform("computation: SCF", [Configuration("1s^2 2s^2")], nucModel, grid, AsfSettings())
multiplet = perform("computation: CI",  basis, nucModel, grid, AsfSettings());
# Out:
# ... in perform['computation: SCF'] ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 6.0 with mass = 12.18, radius R = 2.4934845703596404 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.80086331e+01    -1.80086350e+01    +1.02976431e-07
#       2      2s_1/2      -4.50269994e+00    -4.50269857e+00    -3.04312440e-07
#       3      3s_1/2      -2.00097395e+00    -2.00095940e+00    -7.27254410e-06
#       4      4s_1/2      -1.12570275e+00    -1.12543844e+00    -2.34794041e-04
#       5      5s_1/2      -7.22417687e-01    -7.20234830e-01    -3.02159998e-03
#       6      6s_1/2      -5.43499260e-01    -5.00139888e-01    -7.97781626e-02
#       7      7s_1/2      -4.77992204e-01    -3.67436826e-01    -2.31291173e-01
#       8      8s_1/2      -3.50617308e-01    -2.81311119e-01    -1.97669046e-01
#       :       :
#      51     51s_1/2      +8.45595432e+07    -6.92067167e-03    +1.00000000e+00
#      52     52s_1/2      +1.28290116e+08    -6.65704673e-03    +1.00000000e+00
#      53     53s_1/2      +2.02604410e+08    -6.40820299e-03    +1.00000000e+00
#      54     54s_1/2      +3.45024075e+08    -6.17305571e-03    +1.00000000e+00
#      55     55s_1/2      +6.89868760e+08    -5.95061791e-03    +1.00000000e+00
#      56     56s_1/2      +2.35263571e+09    -5.73998987e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# (Re-) Define the standard grid with 390 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.0316230e+01;   self-cons'cy = 2.7158e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.2238992e+00;   self-cons'cy = 5.7256e-01  [1.0000e+02 for sym-block kappa = -1]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1298726e+01;   self-cons'cy = 4.5454e-02  [1.7371e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4578100e+00;   self-cons'cy = 8.7225e-02  [1.7371e-01 for sym-block kappa = -1]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1135296e+01;   self-cons'cy = 7.2849e-03  [3.6604e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4168211e+00;   self-cons'cy = 1.4259e-02  [3.6604e-02 for sym-block kappa = -1]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1162290e+01;   self-cons'cy = 1.2106e-03  [5.6778e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4235023e+00;   self-cons'cy = 2.3523e-03  [5.6778e-03 for sym-block kappa = -1]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1157825e+01;   self-cons'cy = 2.0003e-04  [9.4730e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4223956e+00;   self-cons'cy = 3.8887e-04  [9.4730e-04 for sym-block kappa = -1]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1158564e+01;   self-cons'cy = 3.3082e-05  [1.5636e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4225785e+00;   self-cons'cy = 6.4291e-05  [1.5636e-04 for sym-block kappa = -1]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1158442e+01;   self-cons'cy = 5.4703e-06  [2.5861e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4225483e+00;   self-cons'cy = 1.0631e-05  [2.5861e-05 for sym-block kappa = -1]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1158462e+01;   self-cons'cy = 9.0458e-07  [4.2761e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4225533e+00;   self-cons'cy = 1.7578e-06  [4.2761e-06 for sym-block kappa = -1]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1158458e+01;   self-cons'cy = 1.4958e-07  [7.0716e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4225524e+00;   self-cons'cy = 2.9068e-07  [7.0716e-07 for sym-block kappa = -1]
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    0 +     -3.641932029348349e+01    -9.910201830919990e+02    -9.910201830919990e+02
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]

# %% [markdown]
# ... and, similarly, also for the 10 lowest levels of C$^{2+}$ ions as they arise from the
# $C^{2+} 1s^2 (2s^2 + 2s2p + 2p^2)$ configurations:

# %%
basis     = perform("computation: SCF", [Configuration("1s^2 2s^2"), Configuration("1s^2 2s 2p"), 
                                         Configuration("1s^2 2p^2")], nucModel, grid, AsfSettings())
multiplet = perform("computation: CI",  basis, nucModel, grid, AsfSettings());
# Out:
# ... in perform['computation: SCF'] ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^0 2p_3/2^1
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^1 2p_3/2^0
# >> include Configuration: 1s_1/2^2 2p_1/2^0 2p_3/2^2
# >> include Configuration: 1s_1/2^2 2p_1/2^1 2p_3/2^1
# >> include Configuration: 1s_1/2^2 2p_1/2^2 2p_3/2^0
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 6.0 with mass = 12.18, radius R = 2.4934845703596404 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.80086331e+01    -1.80086350e+01    +1.02976431e-07
#       2      2s_1/2      -4.50269994e+00    -4.50269857e+00    -3.04312440e-07
#       3      3s_1/2      -2.00097395e+00    -2.00095940e+00    -7.27254410e-06
#       4      4s_1/2      -1.12570275e+00    -1.12543844e+00    -2.34794041e-04
#       5      5s_1/2      -7.22417687e-01    -7.20234830e-01    -3.02159998e-03
#       6      6s_1/2      -5.43499260e-01    -5.00139888e-01    -7.97781626e-02
#       7      7s_1/2      -4.77992204e-01    -3.67436826e-01    -2.31291173e-01
#       8      8s_1/2      -3.50617308e-01    -2.81311119e-01    -1.97669046e-01
#       :       :
#      51     51s_1/2      +8.45595432e+07    -6.92067167e-03    +1.00000000e+00
#      52     52s_1/2      +1.28290116e+08    -6.65704673e-03    +1.00000000e+00
#      53     53s_1/2      +2.02604410e+08    -6.40820299e-03    +1.00000000e+00
#      54     54s_1/2      +3.45024075e+08    -6.17305571e-03    +1.00000000e+00
#      55     55s_1/2      +6.89868760e+08    -5.95061791e-03    +1.00000000e+00
#      56     56s_1/2      +2.35263571e+09    -5.73998987e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -4.50269897e+00    -4.50269857e+00    -8.86540654e-08
#       2      3p_1/2      -2.00096504e+00    -2.00095940e+00    -2.81855014e-06
#       3      4p_1/2      -1.12553178e+00    -1.12543844e+00    -8.29322950e-05
#       4      5p_1/2      -7.20764947e-01    -7.20234830e-01    -7.35493432e-04
#       5      6p_1/2      -5.03805548e-01    -5.00139888e-01    -7.27594233e-03
#       6      7p_1/2      -4.02528567e-01    -3.67436826e-01    -8.71782608e-02
#       7      8p_1/2      -3.37562144e-01    -2.81311119e-01    -1.66639019e-01
#       8      9p_1/2      -2.51626325e-01    -2.22265641e-01    -1.16683674e-01
#       :       :
#      50     51p_1/2      +7.03537670e+07    -6.92067167e-03    +1.00000000e+00
#      51     52p_1/2      +1.05503779e+08    -6.65704673e-03    +1.00000000e+00
#      52     53p_1/2      +1.63213540e+08    -6.40820299e-03    +1.00000000e+00
#      53     54p_1/2      +2.67045526e+08    -6.17305571e-03    +1.00000000e+00
#      54     55p_1/2      +4.88063740e+08    -5.95061791e-03    +1.00000000e+00
#      55     56p_1/2      +1.16229257e+09    -5.73998987e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -4.50053992e+00    -4.50053930e+00    -1.38182617e-07
#       2      3p_3/2      -2.00032651e+00    -2.00031959e+00    -3.45808418e-06
#       3      4p_3/2      -1.12540854e+00    -1.12516853e+00    -2.13264705e-04
#       4      5p_3/2      -7.24653977e-01    -7.20096642e-01    -6.28898055e-03
#       5      6p_3/2      -6.20146099e-01    -5.00059921e-01    -1.93641753e-01
#       6      7p_3/2      -4.89006479e-01    -3.67386470e-01    -2.48708379e-01
#       7      8p_3/2      -3.52280887e-01    -2.81277385e-01    -2.01553659e-01
#       8      9p_3/2      -2.56112113e-01    -2.22241949e-01    -1.32247413e-01
#       :       :
#      51     52p_3/2      +1.00229880e+08    -6.65692392e-03    +1.00000000e+00
#      52     53p_3/2      +1.53901193e+08    -6.40808699e-03    +1.00000000e+00
#      53     54p_3/2      +2.48369371e+08    -6.17294605e-03    +1.00000000e+00
#      54     55p_3/2      +4.41002908e+08    -5.95051411e-03    +1.00000000e+00
#      55     56p_3/2      +9.65503947e+08    -5.73989154e-03    +1.00000000e+00
#      56     57p_3/2      +3.73453601e+09    -5.54025693e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# (Re-) Define the standard grid with 390 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.0025692e+01;   self-cons'cy = 2.8476e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.1510993e+00;   self-cons'cy = 5.9281e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -9.0244506e-01;   self-cons'cy = 6.6608e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -9.7438985e-01;   self-cons'cy = 6.4405e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1312283e+01;   self-cons'cy = 6.0296e-02  [2.2867e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4565872e+00;   self-cons'cy = 1.1715e-01  [2.2867e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.1346471e+00;   self-cons'cy = 1.1399e-01  [1.5001e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.1175834e+00;   self-cons'cy = 6.8449e-02  [9.4985e-02 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1095186e+01;   self-cons'cy = 9.6886e-03  [5.1648e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4000354e+00;   self-cons'cy = 1.9797e-02  [5.1648e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.0939223e+00;   self-cons'cy = 1.8274e-02  [2.7054e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.0954888e+00;   self-cons'cy = 9.9837e-03  [2.2545e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1125824e+01;   self-cons'cy = 1.3788e-03  [6.3091e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4073480e+00;   self-cons'cy = 2.6048e-03  [6.3091e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.0985913e+00;   self-cons'cy = 2.1295e-03  [3.6302e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.0978024e+00;   self-cons'cy = 1.0548e-03  [2.2247e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1121783e+01;   self-cons'cy = 1.8166e-04  [7.6698e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4064549e+00;   self-cons'cy = 3.1739e-04  [7.6698e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.0980770e+00;   self-cons'cy = 2.3413e-04  [3.9088e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.0975646e+00;   self-cons'cy = 1.0834e-04  [2.3391e-04 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1122288e+01;   self-cons'cy = 2.2733e-05  [8.6858e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4065575e+00;   self-cons'cy = 3.6480e-05  [8.6858e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.0981294e+00;   self-cons'cy = 2.3863e-05  [4.0159e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.0975872e+00;   self-cons'cy = 1.0299e-05  [2.2531e-05 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1122228e+01;   self-cons'cy = 2.7232e-06  [9.3334e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4065463e+00;   self-cons'cy = 3.9804e-06  [9.3334e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.0981245e+00;   self-cons'cy = 2.2246e-06  [3.7732e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.0975853e+00;   self-cons'cy = 8.7244e-07  [1.9594e-06 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1122235e+01;   self-cons'cy = 3.1302e-07  [9.4298e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.4065475e+00;   self-cons'cy = 4.1033e-07  [9.4298e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.0981249e+00;   self-cons'cy = 1.7993e-07  [3.1138e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.0975854e+00;   self-cons'cy = 5.8194e-08  [1.3888e-07 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1^+ ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 2^- ...   ... done.
# Compute CI matrix of dimension 3 x 3 for the symmetry 0^+ ...   ... done.
# Compute CI matrix of dimension 2 x 2 for the symmetry 1^- ...   ... done.
# Compute CI matrix of dimension 2 x 2 for the symmetry 2^+ ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    0 +     -3.648596917604379e+01    -9.928337915631488e+02    -9.928337915631488e+02
#      2    0 -     -3.624303152917504e+01    -9.862231214754129e+02    -9.862231214754129e+02
#      3    1 -     -3.624287324522250e+01    -9.862188143496796e+02    -9.862188143496796e+02
#      4    2 -     -3.624255613958493e+01    -9.862101854657665e+02    -9.862101854657665e+02
#      5    1 -     -3.597168313486141e+01    -9.788393555718375e+02    -9.788393555718375e+02
#      6    0 +     -3.585249814849040e+01    -9.755961668999074e+02    -9.755961668999074e+02
#      7    1 +     -3.585234667467825e+01    -9.755920450875333e+02    -9.755920450875333e+02
#      8    2 +     -3.585204533623915e+01    -9.755838452509441e+02    -9.755838452509441e+02
#      9    2 +     -3.577601912766804e+01    -9.735150667418785e+02    -9.735150667418785e+02
#     10    0 +     -3.559491135345313e+01    -9.685868731864937e+02    -9.685868731864937e+02
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    0 -     2.429376468687465e-01    6.610670087735905e+00    6.610670087735905e+00
#      3    1 -     1.582839525369195e-04    4.307125733253475e-03    4.307125733253475e-03
#      4    2 -     3.171056375776971e-04    8.628883913244931e-03    8.628883913244931e-03
#      5    1 -     2.708730047235193e-01    7.370829893928966e+00    7.370829893928966e+00
#      6    0 +     1.191849863710104e-01    3.243188671930002e+00    3.243188671930002e+00
#      7    1 +     1.514738121457526e-04    4.121812374219038e-03    4.121812374219038e-03
#      8    2 +     3.013384391010732e-04    8.199836589043564e-03    8.199836589043564e-03
#      9    2 +     7.602620857111475e-02    2.068778509065636e+00    2.068778509065636e+00
#     10    0 +     1.811077742149081e-01    4.928193555384866e+00    4.928193555384866e+00
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    0 -     2.429376468687465e-01    6.610670087735905e+00    6.610670087735905e+00
#      3    1 -     2.430959308212834e-01    6.614977213469159e+00    6.614977213469159e+00
#      4    2 -     2.434130364588611e-01    6.623606097382404e+00    6.623606097382404e+00
#      5    1 -     5.142860411823804e-01    1.399443599131137e+01    1.399443599131137e+01
#      6    0 +     6.334710275533908e-01    1.723762466324137e+01    1.723762466324137e+01
#      7    1 +     6.336225013655366e-01    1.724174647561559e+01    1.724174647561559e+01
#      8    2 +     6.339238398046376e-01    1.724994631220464e+01    1.724994631220464e+01
#      9    2 +     7.099500483757524e-01    1.931872482127027e+01    1.931872482127027e+01
#     10    0 +     8.910578225906605e-01    2.424691837665514e+01    2.424691837665514e+01

# %% [markdown]
# From the comparison of the two ground-state energies, we see that the admixture of the $2p^2$ configuration has lowered the (total) ground state energy by about 1.8 eV, a rather remarkable admixture, as the $\: ^3P_0$ is just 6.6 eV above of the ground level.
#
# Further control about these electronic computations can be obtained by modifying the (so-called) **settings**. In general, all computations of the electronic structure, properties and processes as well as all more advanced computations can be controlled quite in details by various settings that are associated to the different computational requests. The SCF and configuration interaction calculations are controlled by `AsfSettings` that specify all details for the generation of the ASF. We can first have a look at the internal representation of these settings:

# %%
? AsfSettings
# Out:
# search: AsfSettings
#   struct  ManyElectron.AsfSettings ... a struct for defining the settings for
#   the atomic state functions, i.e. the self-consistent-field (SCF) and CI
#   computations
#
#   + generateScf          ::Bool               ... True, if a SCF need to be generated, and false otherwise (frozen orbitals).
#   + breitScf             ::Bool               ... True, if Breit interaction is to be included into the SCF computations.
#   + methodScf            ::String             ... Specify the SCF method: ["AL", "OL", "EOL", "meanDFS", "meanHS"].
#   + startScf             ::String             ... Specify how the start orbitals are obtained ["hydrogenic", "fromOrbitals"].
#   + startOrbitals        ::Dict{Subshell, Orbital}  ... List of start orbitals; hydrogenic orbitals are used
#                                                         if not found in this list.
#   + levelsScf            ::Array{Int64,1}     ... Levels on which the optimization need to be carried out.
#   + maxIterationsScf     ::Int64              ... maximum number of SCF iterations
#   + accuracyScf          ::Float64            ... convergence criterion for the SCF field.
#   + shellSequenceScf     ::Array{Subshell,1}  ... Sequence of subshells to be optimized.
#   + frozenSubshells      ::Array{Subshell,1}  ... Sequence of subshells to be kept frozen.
#
#   + coulombCI            ::Bool               ... logical flag to include Coulomb interactions.
#   + breitCI              ::Bool               ... logical flag to include Breit interactions.
#   + qedModel             ::AbstractQedModel   ... model for estimating QED corrections {NoneQed(), QedPetersburg(), QedSydney()}.
#   + methodCI             ::String             ... method for diagonalizing the matrix.
#   + jjLS                 ::LSjjSettings       ... settings to control a jj-LS transformation of atomic level, if requested.
#
#   + selectLevelsCI       ::Bool                          ... true, if specific level (number)s have been selected.
#   + selectedLevelsCI     ::Array{Int64,1}                ... Level number that have been selected.
#   + selectSymmetriesCI   ::Bool                          ... true, if specific level symmetries have been selected.
#   + selectedSymmetriesCI ::Array{LevelSymmetry,1}        ... Level symmetries that have been selected.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   ManyElectron.AsfSettings() ... constructor for setting the default values.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   ManyElectron.AsfSettings(settings::AsfSettings;
#
#           generateScf=..,       breitScf=..,            methodScf=..,          startScf=..,               startOrbitals=..,
#           levelsScf=..,         maxIterationsScf=..,    accuracyScf=..,        shellSequenceScf=..,       frozenSubshells=..,
#           coulombCI=..,         breitCI=..,             qedModel=..,           methodCI=..,               jjLS=..,
#           selectLevelsCI=..,    selectedLevelsCI=..,    selectSymmetriesCI=.., selectedSymmetriesCI=..,   printout::Bool=false)
#   ... constructor for re-defining a settings::AsfSettings.

# %% [markdown]
# ... as well as how the standard settings are presently defined:

# %%
defaultAsfSettings = AsfSettings()
# Out:
# generateScf:          false
# breitScf:             false
# methodScf:            meanDFS
# startScf:             hydrogenic
# startOrbitals:        Dict{Subshell,Orbital}()
# levelsScf:            [1]
# maxIterationsScf:     24
# accuracyScf:          1.0e-6
# shellSequenceScf:     Subshell[]
# frozenSubshells:      Subshell[]
# coulombCI:            true
# breitCI:              false
# qedModel :            NoneQed()
# methodCI:             eigen
# jjLS :                false
# selectLevelsCI:       false
# selectedLevelsCI:     Int64[]
# selectSymmetriesCI:   false
# selectedSymmetriesCI: LevelSymmetry[]

# %% [markdown]
# From this list, we easily see that the self-consistent field is by default based on a *(mean) Dirac-Fock-Slater* potential, a choice which we could overwrite by `meanCH` or any pre-defined potential. At present, however, no full treatment of the exchange interaction has yet been implemented in this first release of the program. The standard settings also show that the SCF is usually based on just the lowest level (cf. `levelScf`) as well as on the accuracy `1.0e-6` to terminate the SCF computations. Moreover, the individual orbitals are improved due to the standard subshell order (cf. `shellSequenceScf`).
#
# For the CI parameters, the treatment of the Breit and QED interaction is of particular interest. At present, both are set to `false`. QED estimates can either be neglected (`NoneQed()`) or estimated by using an effective Hamiltonian approach due to Shabaev and coworkers  (`QedPetersburg()`) or effective potential approach (`QedSydney()`; Flambaum et al.) However, further tests need to be done to better understand the reliability of these QED estimates to the level structure and state represetation of the ASF.
#
# As seen from the settings above, moreover, there are special features in order to *select* individual levels for the CI computations, either in terms of their (relative) level No within the given multiplet or in terms of their *level symmetry*, i.e. their total angular momentum and parity, respectively. A boolean value `selectLevelsCI` or `selectSymmetriesCI` here indicates whether (and which) of these selections are made. The selection of individual symmetries, in particular, may considerably reduced the computational effort as the Hamiltonian matrix will then be calculated only for the selected symmetries.
#
# In principle, these standard settings can be easily *re-defined* within the code by simply modifying the contructor `AsfSetings()` with no additional arguments. Alternatively, we can easily *overwrite* those parameters in some given (instance of) `AsfSetting` which we just wish to modify. This is achieved by

# %%
asfSettings = AsfSettings(defaultAsfSettings; generateScf=true, jjLS=LSjjSettings(true), 
                          selectedSymmetriesCI=[LevelSymmetry(0,"+"), LevelSymmetry(1,"-")] )
# Out:
# generateScf:          true
# breitScf:             false
# methodScf:            meanDFS
# startScf:             hydrogenic
# startOrbitals:        Dict{Subshell,Orbital}()
# levelsScf:            [1]
# maxIterationsScf:     24
# accuracyScf:          1.0e-6
# shellSequenceScf:     Subshell[]
# frozenSubshells:      Subshell[]
# coulombCI:            true
# breitCI:              false
# qedModel :            NoneQed()
# methodCI:             eigen
# jjLS :                true
# selectLevelsCI:       false
# selectedLevelsCI:     Int64[]
# selectSymmetriesCI:   false
# selectedSymmetriesCI: LevelSymmetry[0 +, 1 -]

# %%
basis     = perform("computation: SCF", 
                [Configuration("1s^2 2s^2"), Configuration("1s^2 2s 2p"), 
                 Configuration("1s^2 2p^2"), Configuration("1s^2 2s^2"), 
                 Configuration("1s^2 3p^2")],  nucModel, grid, asfSettings)
multiplet = perform("computation: CI",  basis, nucModel, grid, asfSettings);
# Out:
# ... in perform['computation: SCF'] ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^0 2p_3/2^1
# >> include Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^1 2p_3/2^0
# >> include Configuration: 1s_1/2^2 2p_1/2^0 2p_3/2^2
# >> include Configuration: 1s_1/2^2 2p_1/2^1 2p_3/2^1
# >> include Configuration: 1s_1/2^2 2p_1/2^2 2p_3/2^0
# >> include Configuration: 1s_1/2^2 2s_1/2^2
# >> include Configuration: 1s_1/2^2 3p_1/2^0 3p_3/2^2
# >> include Configuration: 1s_1/2^2 3p_1/2^1 3p_3/2^1
# >> include Configuration: 1s_1/2^2 3p_1/2^2 3p_3/2^0
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 6.0 with mass = 12.18, radius R = 2.4934845703596404 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.80086331e+01    -1.80086350e+01    +1.02976431e-07
#       2      2s_1/2      -4.50269994e+00    -4.50269857e+00    -3.04312440e-07
#       3      3s_1/2      -2.00097395e+00    -2.00095940e+00    -7.27254410e-06
#       4      4s_1/2      -1.12570275e+00    -1.12543844e+00    -2.34794041e-04
#       5      5s_1/2      -7.22417687e-01    -7.20234830e-01    -3.02159998e-03
#       6      6s_1/2      -5.43499260e-01    -5.00139888e-01    -7.97781626e-02
#       7      7s_1/2      -4.77992204e-01    -3.67436826e-01    -2.31291173e-01
#       8      8s_1/2      -3.50617308e-01    -2.81311119e-01    -1.97669046e-01
#       :       :
#      51     51s_1/2      +8.45595432e+07    -6.92067167e-03    +1.00000000e+00
#      52     52s_1/2      +1.28290116e+08    -6.65704673e-03    +1.00000000e+00
#      53     53s_1/2      +2.02604410e+08    -6.40820299e-03    +1.00000000e+00
#      54     54s_1/2      +3.45024075e+08    -6.17305571e-03    +1.00000000e+00
#      55     55s_1/2      +6.89868760e+08    -5.95061791e-03    +1.00000000e+00
#      56     56s_1/2      +2.35263571e+09    -5.73998987e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 1s_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -4.50269897e+00    -4.50269857e+00    -8.86540654e-08
#       2      3p_1/2      -2.00096504e+00    -2.00095940e+00    -2.81855014e-06
#       3      4p_1/2      -1.12553178e+00    -1.12543844e+00    -8.29322950e-05
#       4      5p_1/2      -7.20764947e-01    -7.20234830e-01    -7.35493432e-04
#       5      6p_1/2      -5.03805548e-01    -5.00139888e-01    -7.27594233e-03
#       6      7p_1/2      -4.02528567e-01    -3.67436826e-01    -8.71782608e-02
#       7      8p_1/2      -3.37562144e-01    -2.81311119e-01    -1.66639019e-01
#       8      9p_1/2      -2.51626325e-01    -2.22265641e-01    -1.16683674e-01
#       :       :
#      50     51p_1/2      +7.03537670e+07    -6.92067167e-03    +1.00000000e+00
#      51     52p_1/2      +1.05503779e+08    -6.65704673e-03    +1.00000000e+00
#      52     53p_1/2      +1.63213540e+08    -6.40820299e-03    +1.00000000e+00
#      53     54p_1/2      +2.67045526e+08    -6.17305571e-03    +1.00000000e+00
#      54     55p_1/2      +4.88063740e+08    -5.95061791e-03    +1.00000000e+00
#      55     56p_1/2      +1.16229257e+09    -5.73998987e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_1/2.
# >> Use hydrogenic orbital from this symmetry block also for 3p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -4.50053992e+00    -4.50053930e+00    -1.38182617e-07
#       2      3p_3/2      -2.00032651e+00    -2.00031959e+00    -3.45808418e-06
#       3      4p_3/2      -1.12540854e+00    -1.12516853e+00    -2.13264705e-04
#       4      5p_3/2      -7.24653977e-01    -7.20096642e-01    -6.28898055e-03
#       5      6p_3/2      -6.20146099e-01    -5.00059921e-01    -1.93641753e-01
#       6      7p_3/2      -4.89006479e-01    -3.67386470e-01    -2.48708379e-01
#       7      8p_3/2      -3.52280887e-01    -2.81277385e-01    -2.01553659e-01
#       8      9p_3/2      -2.56112113e-01    -2.22241949e-01    -1.32247413e-01
#       :       :
#      51     52p_3/2      +1.00229880e+08    -6.65692392e-03    +1.00000000e+00
#      52     53p_3/2      +1.53901193e+08    -6.40808699e-03    +1.00000000e+00
#      53     54p_3/2      +2.48369371e+08    -6.17294605e-03    +1.00000000e+00
#      54     55p_3/2      +4.41002908e+08    -5.95051411e-03    +1.00000000e+00
#      55     56p_3/2      +9.65503947e+08    -5.73989154e-03    +1.00000000e+00
#      56     57p_3/2      +3.73453601e+09    -5.54025693e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# >> Use hydrogenic orbital from this symmetry block also for 3p_3/2.
# (Re-) Define the standard grid with 390 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.0550747e+01;   self-cons'cy = 2.6114e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.3397022e+00;   self-cons'cy = 5.4139e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.0731892e+00;   self-cons'cy = 6.1506e-01  [1.0000e+02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.5012159e-01;   self-cons'cy = 7.0216e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.1510230e+00;   self-cons'cy = 5.9267e-01  [1.0000e+02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -3.8527684e-01;   self-cons'cy = 6.7700e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1604654e+01;   self-cons'cy = 4.7569e-02  [4.6786e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.6418683e+00;   self-cons'cy = 1.0134e-01  [4.6786e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.3349712e+00;   self-cons'cy = 1.0871e-01  [2.5036e-01 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -4.4084433e-01;   self-cons'cy = 1.1470e-01  [2.5036e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.3222760e+00;   self-cons'cy = 6.9241e-02  [2.5736e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -4.3742313e-01;   self-cons'cy = 6.3384e-02  [2.5736e-01 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1456540e+01;   self-cons'cy = 6.4227e-03  [9.3952e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.5997100e+00;   self-cons'cy = 1.3005e-02  [9.3952e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.3031315e+00;   self-cons'cy = 1.2069e-02  [3.6359e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -4.3192059e-01;   self-cons'cy = 1.0225e-02  [3.6359e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.3036566e+00;   self-cons'cy = 7.0906e-03  [4.5278e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -4.3212128e-01;   self-cons'cy = 6.0973e-03  [4.5278e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1473172e+01;   self-cons'cy = 7.2535e-04  [7.0418e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.6036497e+00;   self-cons'cy = 1.2298e-03  [7.0418e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.3057495e+00;   self-cons'cy = 1.0035e-03  [2.6458e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -4.3266537e-01;   self-cons'cy = 8.6143e-04  [2.6458e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.3050310e+00;   self-cons'cy = 5.2686e-04  [2.8049e-03 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -4.3251499e-01;   self-cons'cy = 4.5535e-04  [2.8049e-03 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1471345e+01;   self-cons'cy = 7.9632e-05  [6.5509e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.6032837e+00;   self-cons'cy = 1.1413e-04  [6.5509e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.3055452e+00;   self-cons'cy = 7.8236e-05  [2.2268e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -4.3260631e-01;   self-cons'cy = 6.8253e-05  [2.2268e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.3049304e+00;   self-cons'cy = 3.8550e-05  [2.2996e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -4.3248520e-01;   self-cons'cy = 3.4444e-05  [2.2996e-04 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1471539e+01;   self-cons'cy = 8.4523e-06  [5.1840e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.6033157e+00;   self-cons'cy = 9.9687e-06  [5.1840e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.3055588e+00;   self-cons'cy = 5.1833e-06  [1.4788e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -4.3261032e-01;   self-cons'cy = 4.6373e-06  [1.4788e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.3049364e+00;   self-cons'cy = 2.2786e-06  [1.4096e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -4.3248706e-01;   self-cons'cy = 2.1528e-06  [1.4096e-05 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1471519e+01;   self-cons'cy = 8.8136e-07  [4.0245e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.6033129e+00;   self-cons'cy = 8.4519e-07  [4.0245e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.3055581e+00;   self-cons'cy = 2.5876e-07  [8.3177e-07 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -4.3261010e-01;   self-cons'cy = 2.5325e-07  [8.3177e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.3049362e+00;   self-cons'cy = 7.9445e-08  [6.8313e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -4.3248697e-01;   self-cons'cy = 9.6739e-08  [6.8313e-07 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1471521e+01;   self-cons'cy = 9.0351e-08  [2.7094e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.6033132e+00;   self-cons'cy = 6.7937e-08  [2.7094e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.3055581e+00;   self-cons'cy = 4.3995e-10  [1.3549e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -4.3261011e-01;   self-cons'cy = 3.6771e-09  [1.3549e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.3049361e+00;   self-cons'cy = 6.8531e-09  [9.2143e-09 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -4.3248697e-01;   self-cons'cy = 2.3379e-09  [9.2143e-09 for sym-block kappa = -2]
# Compute CI matrix of dimension 2 x 2 for the symmetry 1^+ ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 2^- ...   ... done.
# Compute CI matrix of dimension 6 x 6 for the symmetry 0^+ ...   ... done.
# Compute CI matrix of dimension 2 x 2 for the symmetry 1^- ...   ... done.
# Compute CI matrix of dimension 4 x 4 for the symmetry 2^+ ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    0 +     -7.283806857406496e+01    -1.982024800920113e+03    -1.982024800920113e+03
#      2    0 -     -3.624436011286343e+01    -9.862592740790174e+02    -9.862592740790174e+02
#      3    1 -     -3.624421169772390e+01    -9.862552354973645e+02    -9.862552354973645e+02
#      4    2 -     -3.624391440445444e+01    -9.862471457354483e+02    -9.862471457354483e+02
#      5    1 -     -3.596255432390478e+01    -9.785909479729929e+02    -9.785909479729929e+02
#      6    0 +     -3.584854851057104e+01    -9.754886917778447e+02    -9.754886917778447e+02
#      7    1 +     -3.584840794015444e+01    -9.754848666619754e+02    -9.754848666619754e+02
#      8    2 +     -3.584812855231797e+01    -9.754772641317081e+02    -9.754772641317081e+02
#      9    2 +     -3.576715450431188e+01    -9.732738480538123e+02    -9.732738480538123e+02
#     10    0 +     -3.564245241263008e+01    -9.698805312995573e+02    -9.698805312995573e+02
#     11    0 +     -3.390375078434966e+01    -9.225680501188164e+02    -9.225680501188164e+02
#     12    1 +     -3.390369975861024e+01    -9.225666616377241e+02    -9.225666616377241e+02
#     13    2 +     -3.390359839475003e+01    -9.225639033865955e+02    -9.225639033865955e+02
#     14    2 +     -3.387404563795778e+01    -9.217597319135663e+02    -9.217597319135663e+02
#     15    0 +     -3.382946638709733e+01    -9.205466687099203e+02    -9.205466687099203e+02
#     16    0 +     3.019806626980426e-14    8.217312383251851e-13    8.217312383251851e-13
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    0 -     3.659370846120154e+01    9.957655268410952e+02    9.957655268410952e+02
#      3    1 -     1.484151395274580e-04    4.038581652893820e-03    4.038581652893820e-03
#      4    2 -     2.972932694547126e-04    8.089761916280058e-03    8.089761916280058e-03
#      5    1 -     2.813600805496677e-01    7.656197762455300e+00    7.656197762455300e+00
#      6    0 +     1.140058133337334e-01    3.102256195148282e+00    3.102256195148282e+00
#      7    1 +     1.405704166046462e-04    3.825115869221245e-03    3.825115869221245e-03
#      8    2 +     2.793878364641955e-04    7.602530267319856e-03    7.602530267319856e-03
#      9    2 +     8.097404800609098e-02    2.203416077895753e+00    2.203416077895753e+00
#     10    0 +     1.247020916818045e-01    3.393316754255012e+00    3.393316754255012e+00
#     11    0 +     1.738701628280417e+00    4.731248118074097e+01    4.731248118074097e+01
#     12    1 +     5.102573941684341e-05    1.388481092227656e-03    1.388481092227656e-03
#     13    2 +     1.013638602103129e-04    2.758251128660141e-03    2.758251128660141e-03
#     14    2 +     2.955275679225622e-02    8.041714730292608e-01    8.041714730292608e-01
#     15    0 +     4.457925086044412e-02    1.213063203645962e+00    1.213063203645962e+00
#     16    0 +     3.382946638709736e+01    9.205466687099211e+02    9.205466687099211e+02
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    0 -     3.659370846120154e+01    9.957655268410952e+02    9.957655268410952e+02
#      3    1 -     3.659385687634106e+01    9.957695654227481e+02    9.957695654227481e+02
#      4    2 -     3.659415416961052e+01    9.957776551846644e+02    9.957776551846644e+02
#      5    1 -     3.687551425016019e+01    1.003433852947120e+03    1.003433852947120e+03
#      6    0 +     3.698952006349392e+01    1.006536109142268e+03    1.006536109142268e+03
#      7    1 +     3.698966063391052e+01    1.006539934258137e+03    1.006539934258137e+03
#      8    2 +     3.698994002174699e+01    1.006547536788404e+03    1.006547536788404e+03
#      9    2 +     3.707091406975308e+01    1.008750952866300e+03    1.008750952866300e+03
#     10    0 +     3.719561616143488e+01    1.012144269620555e+03    1.012144269620555e+03
#     11    0 +     3.893431778971530e+01    1.059456750801296e+03    1.059456750801296e+03
#     12    1 +     3.893436881545472e+01    1.059458139282388e+03    1.059458139282388e+03
#     13    2 +     3.893447017931493e+01    1.059460897533517e+03    1.059460897533517e+03
#     14    2 +     3.896402293610718e+01    1.060265069006546e+03    1.060265069006546e+03
#     15    0 +     3.900860218696763e+01    1.061478132210192e+03    1.061478132210192e+03
#     16    0 +     7.283806857406499e+01    1.982024800920113e+03    1.982024800920113e+03

# %% [markdown]
# **Ensure that the level symmetries are taken properly into account above !!!**

# %% [markdown]
# We finish this (simple) tutorial by enlarging the configuration basis for the low-lying levels but by restricting the CI computations to the level symmetries $J^P = 0^+$ and $1^-$. This is achieved by specifying the settings to:
