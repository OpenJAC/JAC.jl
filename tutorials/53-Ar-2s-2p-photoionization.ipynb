# %% [markdown]
# # Photoionization of atomic argon: compute cross sections and angular parameters

# %%
using JAC

# %% [markdown]
# Here, we wish to calculate the cross sections and the $\beta_2$ angular parameters for the photoionzation of atomic argon by linearly-polarized synchrotron radiation. Since the ionization process depends on the energy and polarization of the incident radiatian, the **standard settings** (although available be default) are of little help, and at least the photon energies should normally be specified in advance.

# %% [markdown]
# Therefore, let us first have a look how these settings are defined internally:

# %%
? PhotoIonization.Settings
# Out:
#   struct  PhotoIonization.Settings ... defines a type for the details and
#   parameters of computing photoionization lines.
#
#   + multipoles              ::Array{EmMultipole}           ... Specifies the multipoles of the radiation field that are to be included.
#   + gauges                  ::Array{UseGauge}              ... Specifies the gauges to be included into the computations.
#   + photonEnergies          ::Array{Float64,1}             ... List of photon energies.
#   + calcAnisotropy          ::Bool                         ... True, if the beta anisotropy parameters are to be calculated and false otherwise (o/w).
#   + calcPartialCs           ::Bool                         ... True, if partial cross sections are to be calculated and false otherwise.
#   + calcTensors             ::Bool                         ... True, if statistical tensors of the excited atom are to be calculated and false o/w.
#   + printBefore             ::Bool                         ... True, if all energies and lines are printed before their evaluation.
#   + selectLines             ::Bool                         ... True, if lines are selected individually for the computations.
#   + selectedLines           ::Array{Tuple{Int64,Int64},1}  ... List of lines, given by tupels (inital-level, final-level).
#   + stokes                  ::ExpStokes                    ... Stokes parameters of the incident radiation.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   PhotoIonization.Settings() ... constructor for the default values of
#   photoionization line computations
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   PhotoIonization.Settings(set::PhotoIonization.Settings;
#
#       multipoles=..,          gauges=..,                  photonEnergies=..,          calcAnisotropy=..,
#       calcPartialCs0..,       calcTensors=..,             printBefore=..,             selectLines=..,
#       selectedLines=..,       stokes=..)
#
#   ... constructor for modifying the given PhotoIonization.Settings by 'overwriting' the previously selected parameters.

# %%
defaultSettings = PhotoIonization.Settings()
# Out:
# multipoles:               EmMultipole[E1]
# gauges:                   UseGauge[UseCoulomb]
# photonEnergies:           Float64[]
# calcAnisotropy:           false
# calcPartialCs:            false
# calcTensors:              false
# printBefore:              false
# selectLines:              false
# selectedLines:            Tuple{Int64,Int64}[]
# stokes:                   exp. Stokes parameters P1 = 0.0,  P2 = 0.0,  P3 = 0.0

# %% [markdown]
# As seen from these settings, the default only includes the E1 photoionization amplitudes, the use of Coulomb gauge, and *no* photon energies are yet defined.

# %% [markdown]
# We here wish to calculate the cross sections from just the Ar $3s^2 3p^6$ $^1S_0$ ground level at the two photon energies 50 eV and 100 eV, respectively. For this, let us re-set the energy units (to eV) and the `Photoionization.Settings` to:

# %%
setDefaults("unit: energy", "eV")
photoSettings = PhotoIonization.Settings(defaultSettings, gauges=[UseCoulomb, UseBabushkin], photonEnergies=[50., 100.], 
                                         calcAnisotropy=true, calcPartialCs=true, printBefore=true)
# Out:
# multipoles:               EmMultipole[E1]
# gauges:                   UseGauge[UseCoulomb, UseBabushkin]
# photonEnergies:           [50.0, 100.0]
# calcAnisotropy:           true
# calcPartialCs:            true
# calcTensors:              false
# printBefore:              true
# selectLines:              false
# selectedLines:            Tuple{Int64,Int64}[]
# stokes:                   exp. Stokes parameters P1 = 0.0,  P2 = 0.0,  P3 = 0.0

# %% [markdown]
# With these settings, we can proceed along standard lines and compute the cross section and $\beta_2$ parameters by:

# %%
grid = Radial.Grid(Radial.Grid(true), rnt = 2.0e-5,h = 5.0e-2, hp = 1.3e-2, NoPoints = 600)
wa   = Atomic.Computation(Atomic.Computation(), name="Photoionization of Ar: cross sections + beta's", 
              grid=grid, nuclearModel=Nuclear.Model(18.),
              initialConfigs=[Configuration("[Ne] 3s^2 3p^6")],
              finalConfigs  =[Configuration("[Ne] 3s^2 3p^5")], 
              process = Photo(),  processSettings=photoSettings)
perform(wa)
# Out:
# ... in performSCF ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^2 3p_3/2^4
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 18.0 with mass = 37.62, radius R = 3.37121133160794 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.62704537e+02    -1.62704858e+02    +1.97540689e-06
#       2      2s_1/2      -4.07203231e+01    -4.07203638e+01    +1.00176088e-06
#       3      3s_1/2      -1.80782718e+01    -1.80782839e+01    +6.69151578e-07
#       4      4s_1/2      -1.01607480e+01    -1.01607532e+01    +5.07972454e-07
#       5      5s_1/2      -6.49858586e+00    -6.49914079e+00    +8.53914787e-05
#       6      6s_1/2      -4.43740435e+00    -4.51139835e+00    +1.66750649e-02
#       7      7s_1/2      -2.56369564e+00    -3.31344481e+00    +2.92448590e-01
#       8      8s_1/2      -1.24286765e-01    -2.53622787e+00    +1.94062587e+01
#       9      9s_1/2      +2.91170747e+00    -2.00353566e+00    +1.68809648e+00
#      10     10s_1/2      +6.49834449e+00    -1.62260054e+00    +1.24969445e+00
#      11     11s_1/2      +1.06079630e+01    -1.34081096e+00    +1.12639665e+00
#      12     12s_1/2      +1.52230916e+01    -1.12652493e+00    +1.07400106e+00
#      13     13s_1/2      +2.03317253e+01    -9.59785324e-01    +1.04720629e+00
#      14     14s_1/2      +2.59250863e+01    -8.27499902e-01    +1.03191889e+00
#      15     15s_1/2      +3.19964503e+01    -7.20790988e-01    +1.02252722e+00
#      16     16s_1/2      +3.85404733e+01    -6.33466359e-01    +1.01643639e+00
#      17     17s_1/2      +4.55527787e+01    -5.61100307e-01    +1.01231759e+00
#      18     18s_1/2      +5.30296903e+01    -5.00461688e-01    +1.00943739e+00
#      19     19s_1/2      +6.09680514e+01    -4.49146904e-01    +1.00736692e+00
#      20     20s_1/2      +6.93650991e+01    -4.05338006e-01    +1.00584354e+00
#      21     21s_1/2      +7.82183741e+01    -3.67639453e-01    +1.00470017e+00
#      22     22s_1/2      +8.75256535e+01    -3.34965575e-01    +1.00382706e+00
#      23     23s_1/2      +9.72849015e+01    -3.06461538e-01    +1.00315014e+00
#      24     24s_1/2      +1.07494231e+02    -2.81446851e-01    +1.00261825e+00
#      25     25s_1/2      +1.18151875e+02    -2.59374382e-01    +1.00219526e+00
#      26     26s_1/2      +1.29256159e+02    -2.39800176e-01    +1.00185523e+00
#      27     27s_1/2      +1.40805491e+02    -2.22360963e-01    +1.00157921e+00
#      17     18p_3/2      +5.17576400e+01    -5.00219989e-01    +1.00966466e+00
#      18     19p_3/2      +5.95446142e+01    -4.48941404e-01    +1.00753958e+00
#      19     20p_3/2      +6.77855913e+01    -4.05161824e-01    +1.00597711e+00
#      20     21p_3/2      +7.64785004e+01    -3.67487266e-01    +1.00480511e+00
#      21     22p_3/2      +8.56214829e+01    -3.34833217e-01    +1.00391062e+00
#      22     23p_3/2      +9.52128434e+01    -3.06345708e-01    +1.00321748e+00
#      23     24p_3/2      +1.05251012e+02    -2.81344908e-01    +1.00267309e+00
#      24     25p_3/2      +1.15734514e+02    -2.59284192e-01    +1.00224034e+00
#      25     26p_3/2      +1.26661953e+02    -2.39719999e-01    +1.00189260e+00
#      26     27p_3/2      +1.38031985e+02    -2.22289371e-01    +1.00161042e+00
#      27     28p_3/2      +1.49843313e+02    -2.06692987e-01    +1.00137939e+00
#      28     29p_3/2      +1.62094671e+02    -1.92682235e-01    +1.00118870e+00
#      29     30p_3/2      +1.74784821e+02    -1.80049238e-01    +1.00103012e+00
#      30     31p_3/2      +1.87912540e+02    -1.68619102e-01    +1.00089733e+00
#      31     32p_3/2      +2.01476627e+02    -1.58243829e-01    +1.00078542e+00
#      32     33p_3/2      +2.15475894e+02    -1.48797500e-01    +1.00069055e+00
#      33     34p_3/2      +2.29909181e+02    -1.40172441e-01    +1.00060969e+00
#      34     35p_3/2      +2.44775368e+02    -1.32276137e-01    +1.00054040e+00
#      35     36p_3/2      +2.60073404e+02    -1.25028743e-01    +1.00048074e+00
#      36     37p_3/2      +2.75802367e+02    -1.18361057e-01    +1.00042915e+00
#      37     38p_3/2      +2.91961560e+02    -1.12212861e-01    +1.00038434e+00
#      38     39p_3/2      +3.08550685e+02    -1.06531558e-01    +1.00034526e+00
#       :       :
#      87     88p_3/2      +9.76328621e+06    -2.09214396e-02    +1.00000000e+00
#      88     89p_3/2      +1.50872593e+07    -2.04539144e-02    +1.00000000e+00
#      89     90p_3/2      +2.45105925e+07    -2.00018873e-02    +1.00000000e+00
#      90     91p_3/2      +4.37657072e+07    -1.95646808e-02    +1.00000000e+00
#      91     92p_3/2      +9.62200240e+07    -1.91416541e-02    +1.00000000e+00
#      92     93p_3/2      +3.73167477e+08    -1.87322005e-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# >> Use hydrogenic orbital from this symmetry block also for 3p_3/2.
# (Re-) Define the standard grid with 600 grid points.
# >>  for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -9.8394058e+01;   self-cons'cy = 2.4631e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.4442809e+00;   self-cons'cy = 8.4403e-01  [1.0000e+02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = 2.6415159e-01;   self-cons'cy = 1.0297e+00  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -3.2447659e+00;   self-cons'cy = 8.5239e-01  [1.0000e+02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = 1.2933657e-01;   self-cons'cy = 1.0144e+00  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -6.2320013e+00;   self-cons'cy = 7.3354e-01  [1.0000e+02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.4255365e-01;   self-cons'cy = 9.7345e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1934930e+02;   self-cons'cy = 9.6238e-02  [1.3090e+00 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.3763513e+01;   self-cons'cy = 5.9968e-01  [1.3090e+00 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.9740223e+00;   self-cons'cy = 1.3090e+00  [1.3090e+00 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -9.8977453e+00;   self-cons'cy = 5.0622e-01  [1.4154e+00 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.5202606e-01;   self-cons'cy = 1.4154e+00  [1.4154e+00 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.4231858e+00;   self-cons'cy = 1.4952e-01  [1.4952e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -3.1946182e-01;   self-cons'cy = 1.3684e-01  [1.4952e-01 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1296839e+02;   self-cons'cy = 2.7466e-02  [9.2730e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0068568e+01;   self-cons'cy = 1.5504e-01  [9.2730e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -5.8965621e-01;   self-cons'cy = 5.3999e-01  [9.2730e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.1650956e+00;   self-cons'cy = 9.5923e-02  [5.1033e-01 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -2.4381460e-01;   self-cons'cy = 5.1033e-01  [5.1033e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.4388567e+00;   self-cons'cy = 9.2936e-04  [2.8629e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -3.3829278e-01;   self-cons'cy = 2.8629e-02  [2.8629e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1431764e+02;   self-cons'cy = 5.9364e-03  [1.7528e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0863150e+01;   self-cons'cy = 3.7961e-02  [1.7528e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.4030332e-01;   self-cons'cy = 1.7528e-01  [1.7528e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3507317e+00;   self-cons'cy = 1.1240e-02  [8.3377e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -2.8816990e-01;   self-cons'cy = 8.3377e-02  [8.3377e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.2262069e+00;   self-cons'cy = 1.2760e-02  [1.1467e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.6869142e-01;   self-cons'cy = 1.1467e-01  [1.1467e-01 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1418905e+02;   self-cons'cy = 5.6276e-04  [1.3273e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0789644e+01;   self-cons'cy = 3.3948e-03  [1.3273e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.1828803e-01;   self-cons'cy = 1.3273e-02  [1.3273e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.4276677e+00;   self-cons'cy = 4.5854e-03  [4.4509e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.1501705e-01;   self-cons'cy = 4.4509e-02  [4.4509e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.3261209e+00;   self-cons'cy = 6.0363e-03  [5.7581e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -3.0152524e-01;   self-cons'cy = 5.7581e-02  [5.7581e-02 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1411163e+02;   self-cons'cy = 3.3908e-04  [1.4956e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0734431e+01;   self-cons'cy = 2.5652e-03  [1.4956e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -7.9417187e-01;   self-cons'cy = 1.4956e-02  [1.4956e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3670562e+00;   self-cons'cy = 3.6090e-03  [3.4746e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -2.9386126e-01;   self-cons'cy = 3.4746e-02  [3.4746e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.3005874e+00;   self-cons'cy = 1.5357e-03  [1.5306e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9243389e-01;   self-cons'cy = 1.5306e-02  [1.5306e-02 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1416395e+02;   self-cons'cy = 2.2917e-04  [9.1754e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0770582e+01;   self-cons'cy = 1.6810e-03  [9.1754e-03 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.0888056e-01;   self-cons'cy = 9.1754e-03  [9.1754e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3889404e+00;   self-cons'cy = 1.3060e-03  [1.2938e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0156508e-01;   self-cons'cy = 1.2938e-02  [1.2938e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.3016256e+00;   self-cons'cy = 6.2536e-05  [1.0890e-03 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9307148e-01;   self-cons'cy = 1.0890e-03  [1.0890e-03 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1414661e+02;   self-cons'cy = 7.5959e-05  [2.9163e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0758683e+01;   self-cons'cy = 5.5267e-04  [2.9163e-03 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.0417646e-01;   self-cons'cy = 2.9163e-03  [2.9163e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3849022e+00;   self-cons'cy = 2.4074e-04  [2.4634e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0008301e-01;   self-cons'cy = 2.4634e-03  [2.4634e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.3041592e+00;   self-cons'cy = 1.5258e-04  [1.2792e-03 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9382225e-01;   self-cons'cy = 1.2792e-03  [1.2792e-03 for sym-block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1414922e+02;   self-cons'cy = 1.1457e-05  [4.0307e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0760456e+01;   self-cons'cy = 8.2369e-05  [4.0307e-04 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.0482500e-01;   self-cons'cy = 4.0307e-04  [4.0307e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3843596e+00;   self-cons'cy = 3.2359e-05  [2.7075e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -2.9992056e-01;   self-cons'cy = 2.7075e-04  [2.7075e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.3027242e+00;   self-cons'cy = 8.6412e-05  [7.9372e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9335620e-01;   self-cons'cy = 7.9372e-04  [7.9372e-04 for sym-block kappa = -2]
#
# Iteration 10 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1414996e+02;   self-cons'cy = 3.2291e-06  [1.4267e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0760972e+01;   self-cons'cy = 2.3965e-05  [1.4267e-04 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.0505469e-01;   self-cons'cy = 1.4267e-04  [1.4267e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3851240e+00;   self-cons'cy = 4.5582e-05  [4.3538e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0018183e-01;   self-cons'cy = 4.3538e-04  [4.3538e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.3031615e+00;   self-cons'cy = 2.6337e-05  [2.5680e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9350691e-01;   self-cons'cy = 2.5680e-04  [2.5680e-04 for sym-block kappa = -2]
#
# Iteration 11 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1414926e+02;   self-cons'cy = 3.0483e-06  [1.2226e-04 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0760492e+01;   self-cons'cy = 2.2301e-05  [1.2226e-04 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.0485786e-01;   self-cons'cy = 1.2226e-04  [1.2226e-04 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3847943e+00;   self-cons'cy = 1.9655e-05  [1.9235e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0006637e-01;   self-cons'cy = 1.9235e-04  [1.9235e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.3031078e+00;   self-cons'cy = 3.2348e-06  [3.7405e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9348495e-01;   self-cons'cy = 3.7405e-05  [3.7405e-05 for sym-block kappa = -2]
#
# Iteration 12 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1414953e+02;   self-cons'cy = 1.1878e-06  [4.6058e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0760678e+01;   self-cons'cy = 8.6487e-06  [4.6058e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.0493201e-01;   self-cons'cy = 4.6058e-05  [4.6058e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3848728e+00;   self-cons'cy = 4.6804e-06  [4.7104e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0009464e-01;   self-cons'cy = 4.7104e-05  [4.7104e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.3030831e+00;   self-cons'cy = 1.4897e-06  [1.1492e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9347820e-01;   self-cons'cy = 1.1492e-05  [1.1492e-05 for sym-block kappa = -2]
#
# Iteration 13 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1414948e+02;   self-cons'cy = 2.4781e-07  [9.1211e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0760639e+01;   self-cons'cy = 1.7917e-06  [9.1211e-06 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.0491732e-01;   self-cons'cy = 9.1211e-06  [9.1211e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3848718e+00;   self-cons'cy = 5.8347e-08  [1.2420e-06 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0009390e-01;   self-cons'cy = 1.2420e-06  [1.2420e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.3031023e+00;   self-cons'cy = 1.1576e-06  [1.0424e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9348432e-01;   self-cons'cy = 1.0424e-05  [1.0424e-05 for sym-block kappa = -2]
#
# Iteration 14 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1414947e+02;   self-cons'cy = 1.4538e-08  [8.1562e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0760637e+01;   self-cons'cy = 1.1237e-07  [8.1562e-07 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.0491601e-01;   self-cons'cy = 8.1562e-07  [8.1562e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3848629e+00;   self-cons'cy = 5.3164e-07  [5.0120e-06 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0009089e-01;   self-cons'cy = 5.0120e-06  [5.0120e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.3030954e+00;   self-cons'cy = 4.1913e-07  [4.0045e-06 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9348197e-01;   self-cons'cy = 4.0045e-06  [4.0045e-06 for sym-block kappa = -2]
#
# Iteration 15 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1414948e+02;   self-cons'cy = 3.7247e-08  [1.5158e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0760643e+01;   self-cons'cy = 2.7305e-07  [1.5158e-06 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.0491845e-01;   self-cons'cy = 1.5158e-06  [1.5158e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3848677e+00;   self-cons'cy = 2.8161e-07  [2.7379e-06 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0009253e-01;   self-cons'cy = 2.7379e-06  [2.7379e-06 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.3030966e+00;   self-cons'cy = 7.7551e-08  [8.1732e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9348245e-01;   self-cons'cy = 8.1732e-07  [8.1732e-07 for sym-block kappa = -2]
#
# Iteration 16 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1414948e+02;   self-cons'cy = 1.7493e-08  [6.8504e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0760640e+01;   self-cons'cy = 1.2755e-07  [6.8504e-07 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -8.0491735e-01;   self-cons'cy = 6.8504e-07  [6.8504e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.3848663e+00;   self-cons'cy = 8.1654e-08  [8.1267e-07 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.0009205e-01;   self-cons'cy = 8.1267e-07  [8.1267e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.3030968e+00;   self-cons'cy = 1.0248e-08  [5.8479e-08 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -2.9348249e-01;   self-cons'cy = 5.8479e-08  [5.8479e-08 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^+ ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.840493 seconds (433.37 k allocations: 19.252 MiB, 0.82% gc time)
#    ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    0 +     -5.286308886308120e+02    -1.438477917262865e+04    -1.438477917262865e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# ... in performSCF ...
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^1 3p_3/2^4
# >> include Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^4 3s_1/2^2 3p_1/2^2 3p_3/2^3
# (Re-) Define a new standard subshell list.
# Start SCF process with hydrogenic orbitals.
# >> (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 18.0 with mass = 37.62, radius R = 3.37121133160794 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -1.62704537e+02    -1.62704858e+02    +1.97540689e-06
#       2      2s_1/2      -4.07203231e+01    -4.07203638e+01    +1.00176088e-06
#       3      3s_1/2      -1.80782718e+01    -1.80782839e+01    +6.69151578e-07
#       4      4s_1/2      -1.01607480e+01    -1.01607532e+01    +5.07972454e-07
#       5      5s_1/2      -6.49858586e+00    -6.49914079e+00    +8.53914787e-05
#       6      6s_1/2      -4.43740435e+00    -4.51139835e+00    +1.66750649e-02
#       7      7s_1/2      -2.56369564e+00    -3.31344481e+00    +2.92448590e-01
#       8      8s_1/2      -1.24286765e-01    -2.53622787e+00    +1.94062587e+01
#       9      9s_1/2      +2.91170747e+00    -2.00353566e+00    +1.68809648e+00
#      10     10s_1/2      +6.49834449e+00    -1.62260054e+00    +1.24969445e+00
#      11     11s_1/2      +1.06079630e+01    -1.34081096e+00    +1.12639665e+00
#      12     12s_1/2      +1.52230916e+01    -1.12652493e+00    +1.07400106e+00
#      13     13s_1/2      +2.03317253e+01    -9.59785324e-01    +1.04720629e+00
#      14     14s_1/2      +2.59250863e+01    -8.27499902e-01    +1.03191889e+00
#      15     15s_1/2      +3.19964503e+01    -7.20790988e-01    +1.02252722e+00
#      16     16s_1/2      +3.85404733e+01    -6.33466359e-01    +1.01643639e+00
#      17     17s_1/2      +4.55527787e+01    -5.61100307e-01    +1.01231759e+00
#      18     18s_1/2      +5.30296903e+01    -5.00461688e-01    +1.00943739e+00
-02    +1.00000000e+00
#   -----------------------------------------------------------------------------
# >> Use hydrogenic orbital from this symmetry block also for 2p_3/2.
# >> Use hydrogenic orbital from this symmetry block also for 3p_3/2.
# (Re-) Define the standard grid with 600 grid points.
# >>  for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.0033370e+02;   self-cons'cy = 2.3712e-01  [1.0000e+02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -4.8738049e+00;   self-cons'cy = 7.8621e-01  [1.0000e+02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -2.0407396e-01;   self-cons'cy = 9.7768e-01  [1.0000e+02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.5175278e+00;   self-cons'cy = 8.0028e-01  [1.0000e+02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -3.1080086e-01;   self-cons'cy = 9.6620e-01  [1.0000e+02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -7.1330045e+00;   self-cons'cy = 7.0078e-01  [1.0000e+02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -6.9193054e-01;   self-cons'cy = 9.2607e-01  [1.0000e+02 for sym-block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1906004e+02;   self-cons'cy = 8.5355e-02  [2.2169e+00 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.3711044e+01;   self-cons'cy = 4.7551e-01  [2.2169e+00 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -2.1520117e+00;   self-cons'cy = 8.2677e-01  [2.2169e+00 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.0082054e+01;   self-cons'cy = 3.8114e-01  [6.7600e-01 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -1.0639114e+00;   self-cons'cy = 5.4783e-01  [6.7600e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.9173370e+00;   self-cons'cy = 1.1117e-01  [1.1117e-01 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -7.4798011e-01;   self-cons'cy = 3.8926e-02  [1.1117e-01 for sym-block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1380420e+02;   self-cons'cy = 2.2570e-02  [1.9650e+00 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.0800053e+01;   self-cons'cy = 1.1876e-01  [1.9650e+00 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.1293570e+00;   self-cons'cy = 3.1165e-01  [1.9650e+00 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.7804827e+00;   self-cons'cy = 6.9003e-02  [4.1241e-01 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.2249907e-01;   self-cons'cy = 1.9112e-01  [4.1241e-01 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.9233783e+00;   self-cons'cy = 3.3863e-04  [1.8354e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -7.7595013e-01;   self-cons'cy = 1.8354e-02  [1.8354e-02 for sym-block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1481764e+02;   self-cons'cy = 4.4328e-03  [5.3354e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.1364340e+01;   self-cons'cy = 2.5459e-02  [5.3354e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.3010260e+00;   self-cons'cy = 7.0635e-02  [5.3354e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9054463e+00;   self-cons'cy = 7.0657e-03  [2.4913e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.4846440e-01;   self-cons'cy = 1.7652e-02  [2.4913e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.8006784e+00;   self-cons'cy = 6.9228e-03  [3.7255e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -7.3488709e-01;   self-cons'cy = 2.7179e-02  [3.7255e-02 for sym-block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1470448e+02;   self-cons'cy = 4.9306e-04  [1.0454e-01 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.1300677e+01;   self-cons'cy = 2.8088e-03  [1.0454e-01 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.2812716e+00;   self-cons'cy = 7.6499e-03  [1.0454e-01 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9368107e+00;   self-cons'cy = 1.7579e-03  [1.0491e-02 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.5961211e-01;   self-cons'cy = 7.3920e-03  [1.0491e-02 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.8485822e+00;   self-cons'cy = 2.7142e-03  [1.4199e-02 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -7.5002907e-01;   self-cons'cy = 1.0197e-02  [1.4199e-02 for sym-block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1468543e+02;   self-cons'cy = 8.3025e-05  [3.5301e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.1287724e+01;   self-cons'cy = 5.7347e-04  [3.5301e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.2757449e+00;   self-cons'cy = 2.1614e-03  [3.5301e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9152325e+00;   self-cons'cy = 1.2087e-03  [6.8751e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.5257069e-01;   self-cons'cy = 4.6565e-03  [6.8751e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.8376161e+00;   self-cons'cy = 6.2004e-04  [3.4424e-03 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -7.4652238e-01;   self-cons'cy = 2.3432e-03  [3.4424e-03 for sym-block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1470043e+02;   self-cons'cy = 6.5406e-05  [2.0449e-02 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.1297320e+01;   self-cons'cy = 4.2492e-04  [2.0449e-02 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.2793863e+00;   self-cons'cy = 1.4251e-03  [2.0449e-02 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9219010e+00;   self-cons'cy = 3.7386e-04  [2.1207e-03 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.5472513e-01;   self-cons'cy = 1.4293e-03  [2.1207e-03 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.8387301e+00;   self-cons'cy = 6.3025e-05  [4.0160e-04 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -7.4689316e-01;   self-cons'cy = 2.4828e-04  [4.0160e-04 for sym-block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1469568e+02;   self-cons'cy = 2.0728e-05  [6.1033e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.1294298e+01;   self-cons'cy = 1.3378e-04  [6.1033e-03 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.2782701e+00;   self-cons'cy = 4.3639e-04  [6.1033e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9206701e+00;   self-cons'cy = 6.8983e-05  [3.9930e-04 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.5432543e-01;   self-cons'cy = 2.6487e-04  [3.9930e-04 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.8390474e+00;   self-cons'cy = 1.7946e-05  [7.5508e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -7.4698684e-01;   self-cons'cy = 6.2707e-05  [7.5508e-05 for sym-block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1469657e+02;   self-cons'cy = 3.8911e-06  [1.0488e-03 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.1294865e+01;   self-cons'cy = 2.5080e-05  [1.0488e-03 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.2784733e+00;   self-cons'cy = 7.9483e-05  [1.0488e-03 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9207074e+00;   self-cons'cy = 2.0879e-06  [1.5254e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.5433865e-01;   self-cons'cy = 8.7644e-06  [1.5254e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.8388370e+00;   self-cons'cy = 1.1899e-05  [5.9792e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -7.4692177e-01;   self-cons'cy = 4.3560e-05  [5.9792e-05 for sym-block kappa = -2]
#
# Iteration 10 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1469654e+02;   self-cons'cy = 1.3689e-07  [3.9741e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.1294845e+01;   self-cons'cy = 8.8457e-07  [3.9741e-06 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.2784683e+00;   self-cons'cy = 1.9663e-06  [3.9741e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9207790e+00;   self-cons'cy = 4.0132e-06  [2.1858e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.5436138e-01;   self-cons'cy = 1.5069e-05  [2.1858e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.8389016e+00;   self-cons'cy = 3.6540e-06  [1.9399e-05 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -7.4694206e-01;   self-cons'cy = 1.3588e-05  [1.9399e-05 for sym-block kappa = -2]
#
# Iteration 11 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1469649e+02;   self-cons'cy = 2.1936e-07  [7.2716e-05 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.1294813e+01;   self-cons'cy = 1.4116e-06  [7.2716e-05 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.2784560e+00;   self-cons'cy = 4.8167e-06  [7.2716e-05 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9207467e+00;   self-cons'cy = 1.8067e-06  [1.0113e-05 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.5435105e-01;   self-cons'cy = 6.8475e-06  [1.0113e-05 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.8388898e+00;   self-cons'cy = 6.6980e-07  [3.7963e-06 for sym-block kappa = -2]
# ...
#   2p_3/2::  en [a.u.] = -8.8388901e+00;   self-cons'cy = 1.8603e-08  [1.9832e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -7.4693840e-01;   self-cons'cy = 8.9606e-08  [1.9832e-07 for sym-block kappa = -2]
#
# Iteration 13 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1469651e+02;   self-cons'cy = 2.6052e-08  [7.4173e-06 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.1294824e+01;   self-cons'cy = 1.6771e-07  [7.4173e-06 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.2784601e+00;   self-cons'cy = 5.4128e-07  [7.4173e-06 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9207539e+00;   self-cons'cy = 6.3750e-08  [3.7446e-07 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.5435335e-01;   self-cons'cy = 2.4568e-07  [3.7446e-07 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.8388908e+00;   self-cons'cy = 3.9670e-08  [1.8641e-07 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -7.4693862e-01;   self-cons'cy = 1.4254e-07  [1.8641e-07 for sym-block kappa = -2]
#
# Iteration 14 for symmetries ...
#   1s_1/2::  en [a.u.] = -1.1469651e+02;   self-cons'cy = 3.6681e-09  [9.2000e-07 for sym-block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.1294824e+01;   self-cons'cy = 2.3617e-08  [9.2000e-07 for sym-block kappa = -1]
#   3s_1/2::  en [a.u.] = -1.2784603e+00;   self-cons'cy = 7.3067e-08  [9.2000e-07 for sym-block kappa = -1]
#   2p_1/2::  en [a.u.] = -8.9207538e+00;   self-cons'cy = 6.3993e-09  [3.1534e-08 for sym-block kappa = 1]
#   3p_1/2::  en [a.u.] = -7.5435331e-01;   self-cons'cy = 2.3259e-08  [3.1534e-08 for sym-block kappa = 1]
#   2p_3/2::  en [a.u.] = -8.8388905e+00;   self-cons'cy = 1.7720e-08  [9.1102e-08 for sym-block kappa = -2]
#   3p_3/2::  en [a.u.] = -7.4693852e-01;   self-cons'cy = 6.5276e-08  [9.1102e-08 for sym-block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^- ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.362065 seconds (100.71 k allocations: 2.248 MiB)
#    ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 3/2^- ...  reset GBL_Storage_XL_Breit storage ...
# >> performCI() ...   0.361378 seconds (100.79 k allocations: 2.267 MiB)
#    ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    3/2 -     -5.281109190642775e+02    -1.437063008003503e+04    -1.437063008003503e+04
#      2    1/2 -     -5.281040134455089e+02    -1.437044216857701e+04    -1.437044216857701e+04
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     6.905618768541899e-03    1.879114580177506e-01    1.879114580177506e-01
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1/2 -     6.905618768541899e-03    1.879114580177506e-01    1.879114580177506e-01
#
# PhotoIonization.computeLines(): The computation of photo-ionization and properties starts now ...
# -------------------------------------------------------------------------------------------------
#
#
#   Selected photoionization lines:
#
#   -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        i-level-f         i--J^P--f       Energy_fi      omega      Energy e_p    List of multipoles, gauges, kappas and total symmetries
#                                            [eV]         [eV]         [eV]        partial (multipole, gauge, total J^P)
#   -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#        1 --    1       0 + --> 3/2 -     1.4149e+01   5.0000e+01   3.5851e+01    d_5/2 (E1, Cou; 1 -),  s_1/2 (E1, Cou; 1 -),  d_3/2 (E1, Cou; 1 -),  d_5/2 (E1, Bab; 1 -)
#                                                                                  s_1/2 (E1, Bab; 1 -),  d_3/2 (E1, Bab; 1 -)
#        1 --    1       0 + --> 3/2 -     1.4149e+01   1.0000e+02   8.5851e+01    d_5/2 (E1, Cou; 1 -),  s_1/2 (E1, Cou; 1 -),  d_3/2 (E1, Cou; 1 -),  d_5/2 (E1, Bab; 1 -)
#                                                                                  s_1/2 (E1, Bab; 1 -),  d_3/2 (E1, Bab; 1 -)
#        1 --    2       0 + --> 1/2 -     1.4337e+01   5.0000e+01   3.5663e+01    s_1/2 (E1, Cou; 1 -),  d_3/2 (E1, Cou; 1 -),  s_1/2 (E1, Bab; 1 -),  d_3/2 (E1, Bab; 1 -)
#        1 --    2       0 + --> 1/2 -     1.4337e+01   1.0000e+02   8.5663e+01    s_1/2 (E1, Cou; 1 -),  d_3/2 (E1, Cou; 1 -),  s_1/2 (E1, Bab; 1 -),  d_3/2 (E1, Bab; 1 -)
#   -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.3175e+00,  kappa=-3 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=1.4628e-03].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.1552e+00 and phase phi=3.9461e+00 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.3175e+00,  kappa=-1 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=3.2305e-05].
# >> Pure-sine normalized continuum orbital with normalization constant N=-3.2338e+00 and phase phi=1.1398e+00 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.3175e+00,  kappa=2 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=1.4580e-03].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.1561e+00 and phase phi=3.9474e+00 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.3175e+00,  kappa=-3 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=1.4628e-03].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.1552e+00 and phase phi=3.9461e+00 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.3175e+00,  kappa=-1 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=3.2305e-05].
# >> Pure-sine normalized continuum orbital with normalization constant N=-3.2338e+00 and phase phi=1.1398e+00 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.3175e+00,  kappa=2 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=1.4580e-03].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.1561e+00 and phase phi=3.9474e+00 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=3.1550e+00,  kappa=-3 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=6.4980e-04].
# >> Pure-sine normalized continuum orbital with normalization constant N=-2.6399e+00 and phase phi=3.3107e-01 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=3.1550e+00,  kappa=-1 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=7.1328e-05].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.5398e+00 and phase phi=-2.6858e+00 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=3.1550e+00,  kappa=2 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=6.4540e-04].
# >> Pure-sine normalized continuum orbital with normalization constant N=-2.6400e+00 and phase phi=3.3205e-01 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=3.1550e+00,  kappa=-3 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=6.4980e-04].
# >> Pure-sine normalized continuum orbital with normalization constant N=-2.6399e+00 and phase phi=3.3107e-01 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=3.1550e+00,  kappa=-1 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=7.1328e-05].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.5398e+00 and phase phi=-2.6858e+00 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=3.1550e+00,  kappa=2 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=6.4540e-04].
# >> Pure-sine normalized continuum orbital with normalization constant N=-2.6400e+00 and phase phi=3.3205e-01 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.3106e+00,  kappa=-1 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=2.7071e-05].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.2383e+00 and phase phi=1.1495e+00 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.3106e+00,  kappa=2 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=1.4935e-03].
# >> Pure-sine normalized continuum orbital with normalization constant N=-3.1586e+00 and phase phi=3.9566e+00 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.3106e+00,  kappa=-1 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=2.7071e-05].
# >> Pure-sine normalized continuum orbital with normalization constant N=3.2383e+00 and phase phi=1.1495e+00 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=1.3106e+00,  kappa=2 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=1.4935e-03].
# >> Pure-sine normalized continuum orbital with normalization constant N=-3.1586e+00 and phase phi=3.9566e+00 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=3.1481e+00,  kappa=-1 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=6.3789e-05].
# >> Pure-sine normalized continuum orbital with normalization constant N=-2.5393e+00 and phase phi=-2.6786e+00 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=3.1481e+00,  kappa=2 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=6.6848e-04].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.6399e+00 and phase phi=3.3934e-01 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=3.1481e+00,  kappa=-1 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=6.3789e-05].
# >> Pure-sine normalized continuum orbital with normalization constant N=-2.5393e+00 and phase phi=-2.6786e+00 at r=2.0507e+00 a.u.
# >> (Re-) Define a storage array for various B-spline matrices:
# >> Continuum B-spline-Galerkin orbital for energy=3.1481e+00,  kappa=2 [mpt=410, r[mtp]=2.2779e+00, smallest eigenvalue=6.6848e-04].
# >> Pure-sine normalized continuum orbital with normalization constant N=2.6399e+00 and phase phi=3.3934e-01 at r=2.0507e+00 a.u.
#
#   Total photoionization cross sections for initially unpolarized atoms by unpolarized plane-wave photons:
#
#   ----------------------------------------------------------------------------------------------------------------------------------
#        i-level-f         i--J^P--f       f--Energy--i        omega        Energy e_p     Multipoles   Cou -- Cross section -- Bab
#                                               [eV]            [eV]            [eV]                        [barn]          [barn]
#   ----------------------------------------------------------------------------------------------------------------------------------
#        1 --    1       0 + --> 3/2 -     1.414909e+01    5.000000e+01    3.585091e+01    E1           3.543823e+05    1.300759e+05                 1.265522e-02    4.645095e-03
#        1 --    1       0 + --> 3/2 -     1.414909e+01    1.000000e+02    8.585091e+01    E1           1.594099e+05    6.659856e+05                 5.692631e-03    2.378278e-02
#        1 --    2       0 + --> 1/2 -     1.433700e+01    5.000000e+01    3.566300e+01    E1           1.725604e+05    6.387931e+04                 6.162244e-03    2.281172e-03
#        1 --    2       0 + --> 1/2 -     1.433700e+01    1.000000e+02    8.566300e+01    E1           8.609788e+04    3.291412e+05                 3.074611e-03    1.175384e-02
#   ----------------------------------------------------------------------------------------------------------------------------------
#
#   Partial cross sections for initially unpolarized atoms by unpolarized plane-wave photons:
#
#   ------------------------------------------------------------------------------------------------------------------------------------------------
#        i-level-f         i--J^P--f       f--Energy--i        omega        Energy e_p     Multipoles   M_f    Cou -- Partial cross section -- Bab
#                                               [eV]            [eV]            [eV]                                   [barn]          [barn]
#   ------------------------------------------------------------------------------------------------------------------------------------------------
#        1 --    1       0 + --> 3/2 -     1.414909e+01    5.000000e+01    3.585091e+01    E1
#                                                                                                      -3/2       1.144680e+02    -6.370499e+01
#                                                                                                      -1/2       1.157684e+02    -4.378476e+01
#                                                                                                       1/2       1.157684e+02    -4.378476e+01
#                                                                                                       3/2       1.144680e+02    -6.370499e+01
#        1 --    1       0 + --> 3/2 -     1.414909e+01    1.000000e+02    8.585091e+01    E1
#                                                                                                      -3/2       -1.378629e+02    3.190926e+02
#                                                                                                      -1/2       -1.002355e+02    2.055330e+02
#                                                                                                       1/2       -1.002355e+02    2.055330e+02
#                                                                                                       3/2       -1.378629e+02    3.190926e+02
#        1 --    2       0 + --> 1/2 -     1.433700e+01    5.000000e+01    3.566300e+01    E1
#                                                                                                      -1/2       1.409806e+02    -2.265474e+01
#                                                                                                       1/2       1.409806e+02    -2.265474e+01
#        1 --    2       0 + --> 1/2 -     1.433700e+01    1.000000e+02    8.566300e+01    E1
#                                                                                                      -1/2       -1.154151e+02    2.505222e+02
#                                                                                                       1/2       -1.154151e+02    2.505222e+02
#   ------------------------------------------------------------------------------------------------------------------------------------------------
# Constants.warn():  Reset global array GBL_WARNINGS.

# %% [markdown]
# # **The following part of this nootebook is still under construction.**
# What can be seen from this output ?? .. and what else could be controlled ?? ... for this, we refer the user to the manual.
