# %% [markdown]
# # Compute the neon K-LL Auger spectrum

# %%
using JAC

# %% [markdown]
# In this tutorial, we wish to calculate the K-LL spectrum of atomic neon after $1s$ inner-shell ionization as it may occurs, for instance, following photon, electron or neutron impact. An autoionization of an atom or ion generally occurs if the initially-excited level is **energetically embedded into the continuum of the next higher charge state**, and then often also dominates the decay of the atom.
#
# Since the neon K-shell ($1s$) electron has a binding energy larger than 800 eV, this condition is fulfilled and may, in priciple, even lead to a 4-5 times multiple ionization, although the initial excitation energy does not tell much of how many electrons will be emitted eventually. This depends of course on the particular decay path
# of an atom and how easily further electrons can be *shaked-up* (or *off*) the atom during the de-excitation.

# %% [markdown]
# An Auger electron emission often leads to characteristic and energetically isolated lines as the kinetic energy of the emitted electrons are given simply by the difference of the (total) initial- and final-level energies. We therefore need to specify only the initial- and final-state multiplets as well as the process identifier `AugerX` in order to calculate the K-LL spectrum with just the standard settings, but by defining a grid that is appropriate to describe *outgoing* electrons:

# %%
wa = Atomic.Computation("Neon K-LL Auger spectrum",  Nuclear.Model(10.); 
            grid=JAC.Radial.Grid("grid: by given parameters"; rnt = 2.0e-6, h = 5.0e-2, 
                                                              hp = 1.0e-2, NoPoints = 600), 
            initialConfigs=[Configuration("1s 2s^2 2p^6")],
            finalConfigs  =[Configuration("1s^2 2s^2 2p^4"), Configuration("1s^2 2s 2p^5"), 
                            Configuration("1s^2 2p^6")], process = JAC.AugerX )
perform(wa)
# Out:
# Define a radial grid of type MeshGL with 610 grid points
#  [rnt=2.000e-06, h=5.000e-02, hp=1.000e-02, NoPoints=600, r_max=3.229e+00;
#   B-splines wit break points at every 7th point, nsL=86, nsS=87, orderL=7, orderS=8, orderGL=7]
# shellOccList = SubString{String}["1s", "2s^2", "2p^6"]
# shellOccList = SubString{String}["1s^2", "2s^2", "2p^4"]
# shellOccList = SubString{String}["1s^2", "2s", "2p^5"]
# shellOccList = SubString{String}["1s^2", "2p^6"]
#
# ... in perform('computation: SCF', ...
# perform-aa: Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 10.0 with mass = 20.5, radius R = 2.8580081360657426 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -5.00667217e+01    -5.00667420e+01    +4.04942396e-07
#       2      2s_1/2      -1.25208569e+01    -1.25208597e+01    +2.21401474e-07
#       3      3s_1/2      -5.55237930e+00    -5.56297036e+00    +1.90748146e-03
#       4      4s_1/2      -2.53406911e+00    -3.12838807e+00    +2.34531471e-01
#       5      5s_1/2      +1.11492726e+00    -2.00181447e+00    +2.79546644e+00
#       6      6s_1/2      +6.08980428e+00    -1.38996969e+00    +1.22824538e+00
#       7      7s_1/2      +1.22986147e+01    -1.02110261e+00    +1.08302582e+00
#       8      8s_1/2      +1.96843810e+01    -7.81722173e-01    +1.03971281e+00
#       :       :
#      81     81s_1/2      +8.45031707e+07    -7.62128657e-03    +1.00000000e+00
#      82     82s_1/2      +1.28234366e+08    -7.43652912e-03    +1.00000000e+00
#      83     83s_1/2      +2.02549706e+08    -7.25840955e-03    +1.00000000e+00
#      84     84s_1/2      +3.44971609e+08    -7.08661363e-03    +1.00000000e+00
#      85     85s_1/2      +6.89822385e+08    -6.92084556e-03    +1.00000000e+00
#      86     86s_1/2      +2.35262342e+09    -6.76082657e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 1s_1/2.
# Use hydrogenic orbital from this symmetriy block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -1.25208596e+01    -1.25208597e+01    +7.13213298e-09
#       2      3p_1/2      -5.55623611e+00    -5.56297036e+00    +1.21201567e-03
#       3      4p_1/2      -2.64947890e+00    -3.12838807e+00    +1.80755984e-01
#       4      5p_1/2      +7.31175060e-01    -2.00181447e+00    +3.73780464e+00
#       5      6p_1/2      +5.37799965e+00    -1.38996969e+00    +1.25845477e+00
#       6      7p_1/2      +1.12162626e+01    -1.02110261e+00    +1.09103769e+00
#       7      8p_1/2      +1.81978989e+01    -7.81722173e-01    +1.04295673e+00
#       8      9p_1/2      +2.62974095e+01    -6.17619366e-01    +1.02348594e+00
#       :       :
#      80     81p_1/2      +7.02969794e+07    -7.62128657e-03    +1.00000000e+00
#      81     82p_1/2      +1.05447514e+08    -7.43652912e-03    +1.00000000e+00
#      82     83p_1/2      +1.63158045e+08    -7.25840955e-03    +1.00000000e+00
#      83     84p_1/2      +2.66991502e+08    -7.08661363e-03    +1.00000000e+00
#      84     85p_1/2      +4.88013233e+08    -6.92084556e-03    +1.00000000e+00
#      85     86p_1/2      +1.16225386e+09    -6.76082657e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -1.25041629e+01    -1.25041630e+01    +7.09212094e-09
#       2      3p_3/2      -5.55123117e+00    -5.55802266e+00    +1.22342097e-03
#       3      4p_3/2      -2.64586941e+00    -3.12630099e+00    +1.81577966e-01
#       4      5p_3/2      +7.36191475e-01    -2.00074602e+00    +3.71769789e+00
#       5      6p_3/2      +5.38440084e+00    -1.38935143e+00    +1.25803269e+00
#       6      7p_3/2      +1.12239821e+01    -1.02071331e+00    +1.09094039e+00
#       7      8p_3/2      +1.82069305e+01    -7.81461386e-01    +1.04292109e+00
#       8      9p_3/2      +2.63077747e+01    -6.17436217e-01    +1.02346972e+00
#       :       :
#      81     82p_3/2      +1.00174076e+08    -7.43628709e-03    +1.00000000e+00
#      82     83p_3/2      +1.53846199e+08    -7.25817616e-03    +1.00000000e+00
#      83     84p_3/2      +2.48315874e+08    -7.08638848e-03    +1.00000000e+00
#      84     85p_3/2      +4.40952859e+08    -6.92062825e-03    +1.00000000e+00
#      85     86p_3/2      +9.65464441e+08    -6.76061676e-03    +1.00000000e+00
#      86     87p_3/2      +3.73455551e+09    -6.60609121e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_3/2.
# Re-define the standard grid with 600 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.85131620e+01;   self-consistency = 2.742885e-01  [1.000000e+02 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -8.08506526e-01;   self-consistency = 8.786879e-01  [1.000000e+02 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.39496696e-01;   self-consistency = 9.321783e-01  [1.000000e+02 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.10400161e+00;   self-consistency = 8.377442e-01  [1.000000e+02 for symmetry block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.60450379e+01;   self-consistency = 1.166680e-01  [6.962279e-01 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.98797485e+00;   self-consistency = 5.740759e-01  [6.962279e-01 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.78057558e+00;   self-consistency = 6.040699e-01  [6.040699e-01 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.24322748e+00;   self-consistency = 5.931499e-02  [5.931499e-02 for symmetry block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.33194211e+01;   self-consistency = 3.929414e-02  [4.669408e-01 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.90479623e+00;   self-consistency = 2.213835e-01  [4.669408e-01 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.20932123e+00;   self-consistency = 1.910616e-01  [1.910616e-01 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.32558088e+00;   self-consistency = 3.205899e-02  [3.205899e-02 for symmetry block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.39040018e+01;   self-consistency = 8.696087e-03  [6.800736e-02 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.10523605e+00;   self-consistency = 4.998459e-02  [6.800736e-02 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.25355103e+00;   self-consistency = 1.795862e-02  [1.795862e-02 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.23479438e+00;   self-consistency = 3.545828e-02  [3.545828e-02 for symmetry block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38987370e+01;   self-consistency = 7.764964e-05  [5.135161e-04 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.10307501e+00;   self-consistency = 5.135161e-04  [5.135161e-04 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.28727284e+00;   self-consistency = 1.327200e-02  [1.327200e-02 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.27241935e+00;   self-consistency = 1.500669e-02  [1.500669e-02 for symmetry block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38290819e+01;   self-consistency = 1.028456e-03  [9.330782e-03 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.07773312e+00;   self-consistency = 6.061481e-03  [9.330782e-03 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.26286552e+00;   self-consistency = 9.570980e-03  [9.570980e-03 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26315336e+00;   self-consistency = 3.654401e-03  [3.654401e-03 for symmetry block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38671074e+01;   self-consistency = 5.617083e-04  [4.992745e-03 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.09150698e+00;   self-consistency = 3.303686e-03  [4.992745e-03 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.27175719e+00;   self-consistency = 3.508086e-03  [3.508086e-03 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26338184e+00;   self-consistency = 9.043433e-05  [9.043433e-05 for symmetry block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38553059e+01;   self-consistency = 1.742627e-04  [1.538146e-03 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08723083e+00;   self-consistency = 1.023311e-03  [1.538146e-03 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.26998479e+00;   self-consistency = 6.973173e-04  [6.973173e-04 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26440562e+00;   self-consistency = 4.050094e-04  [4.050094e-04 for symmetry block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38569203e+01;   self-consistency = 2.384271e-05  [2.031710e-04 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08781281e+00;   self-consistency = 1.393943e-04  [2.031710e-04 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.26982858e+00;   self-consistency = 6.150679e-05  [6.150679e-05 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26382468e+00;   self-consistency = 2.297794e-04  [2.297794e-04 for symmetry block kappa = -2]
#
# Iteration 10 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38575214e+01;   self-consistency = 8.877426e-06  [8.190965e-05 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08803178e+00;   self-consistency = 5.243751e-05  [8.190965e-05 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.27013344e+00;   self-consistency = 1.200276e-04  [1.200276e-04 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26401019e+00;   self-consistency = 7.338679e-05  [7.338679e-05 for symmetry block kappa = -2]
#
# Iteration 11 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38569960e+01;   self-consistency = 7.759148e-06  [6.951858e-05 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08784113e+00;   self-consistency = 4.565695e-05  [6.951858e-05 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.26998856e+00;   self-consistency = 5.703658e-05  [5.703658e-05 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26398259e+00;   self-consistency = 1.091870e-05  [1.091870e-05 for symmetry block kappa = -2]
#
# Iteration 12 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38572043e+01;   self-consistency = 3.076317e-06  [2.726455e-05 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08791661e+00;   self-consistency = 1.807673e-05  [2.726455e-05 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.27002866e+00;   self-consistency = 1.578455e-05  [1.578455e-05 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26397434e+00;   self-consistency = 3.262322e-06  [3.262322e-06 for symmetry block kappa = -2]
#
# Iteration 13 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38571575e+01;   self-consistency = 6.911680e-07  [6.032525e-06 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08789968e+00;   self-consistency = 4.053441e-06  [6.032525e-06 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.27002510e+00;   self-consistency = 1.399038e-06  [1.399038e-06 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26398223e+00;   self-consistency = 3.119583e-06  [3.119583e-06 for symmetry block kappa = -2]
#
# Iteration 14 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38571568e+01;   self-consistency = 1.088467e-08  [1.467676e-07 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08789940e+00;   self-consistency = 6.823325e-08  [1.467676e-07 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.27002202e+00;   self-consistency = 1.213447e-06  [1.213447e-06 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26397901e+00;   self-consistency = 1.274993e-06  [1.274993e-06 for symmetry block kappa = -2]
#
# Iteration 15 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38571630e+01;   self-consistency = 9.202315e-08  [8.310755e-07 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08790166e+00;   self-consistency = 5.420519e-07  [8.310755e-07 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.27002412e+00;   self-consistency = 8.285269e-07  [8.285269e-07 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26397976e+00;   self-consistency = 2.984328e-07  [2.984328e-07 for symmetry block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -9.669744093959845e+01    -2.631271392553565e+03    -2.631271392553565e+03
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# ... in perform('computation: SCF', ...
# perform-aa: Configuration: 1s_1/2^2 2s_1/2^2 2p_3/2^4
# perform-aa: Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^1 2p_3/2^3
# perform-aa: Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^2
# perform-aa: Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^1 2p_3/2^4
# perform-aa: Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^2 2p_3/2^3
# perform-aa: Configuration: 1s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 10.0 with mass = 20.5, radius R = 2.8580081360657426 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -5.00667217e+01    -5.00667420e+01    +4.04942396e-07
#       2      2s_1/2      -1.25208569e+01    -1.25208597e+01    +2.21401474e-07
#       3      3s_1/2      -5.55237930e+00    -5.56297036e+00    +1.90748146e-03
#       4      4s_1/2      -2.53406911e+00    -3.12838807e+00    +2.34531471e-01
#       5      5s_1/2      +1.11492726e+00    -2.00181447e+00    +2.79546644e+00
#       6      6s_1/2      +6.08980428e+00    -1.38996969e+00    +1.22824538e+00
#       7      7s_1/2      +1.22986147e+01    -1.02110261e+00    +1.08302582e+00
#       8      8s_1/2      +1.96843810e+01    -7.81722173e-01    +1.03971281e+00
#       :       :
#      81     81s_1/2      +8.45031707e+07    -7.62128657e-03    +1.00000000e+00
#      82     82s_1/2      +1.28234366e+08    -7.43652912e-03    +1.00000000e+00
#      83     83s_1/2      +2.02549706e+08    -7.25840955e-03    +1.00000000e+00
#      84     84s_1/2      +3.44971609e+08    -7.08661363e-03    +1.00000000e+00
#      85     85s_1/2      +6.89822385e+08    -6.92084556e-03    +1.00000000e+00
#      86     86s_1/2      +2.35262342e+09    -6.76082657e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 1s_1/2.
# Use hydrogenic orbital from this symmetriy block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -1.25208596e+01    -1.25208597e+01    +7.13213298e-09
#       2      3p_1/2      -5.55623611e+00    -5.56297036e+00    +1.21201567e-03
#       3      4p_1/2      -2.64947890e+00    -3.12838807e+00    +1.80755984e-01
#       4      5p_1/2      +7.31175060e-01    -2.00181447e+00    +3.73780464e+00
#       5      6p_1/2      +5.37799965e+00    -1.38996969e+00    +1.25845477e+00
#       6      7p_1/2      +1.12162626e+01    -1.02110261e+00    +1.09103769e+00
#       7      8p_1/2      +1.81978989e+01    -7.81722173e-01    +1.04295673e+00
#       8      9p_1/2      +2.62974095e+01    -6.17619366e-01    +1.02348594e+00
#       :       :
#      80     81p_1/2      +7.02969794e+07    -7.62128657e-03    +1.00000000e+00
#      81     82p_1/2      +1.05447514e+08    -7.43652912e-03    +1.00000000e+00
#      82     83p_1/2      +1.63158045e+08    -7.25840955e-03    +1.00000000e+00
#      83     84p_1/2      +2.66991502e+08    -7.08661363e-03    +1.00000000e+00
#      84     85p_1/2      +4.88013233e+08    -6.92084556e-03    +1.00000000e+00
#      85     86p_1/2      +1.16225386e+09    -6.76082657e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -1.25041629e+01    -1.25041630e+01    +7.09212094e-09
#       2      3p_3/2      -5.55123117e+00    -5.55802266e+00    +1.22342097e-03
#       3      4p_3/2      -2.64586941e+00    -3.12630099e+00    +1.81577966e-01
#       4      5p_3/2      +7.36191475e-01    -2.00074602e+00    +3.71769789e+00
#       5      6p_3/2      +5.38440084e+00    -1.38935143e+00    +1.25803269e+00
#       6      7p_3/2      +1.12239821e+01    -1.02071331e+00    +1.09094039e+00
#       7      8p_3/2      +1.82069305e+01    -7.81461386e-01    +1.04292109e+00
#       8      9p_3/2      +2.63077747e+01    -6.17436217e-01    +1.02346972e+00
#       :       :
#      81     82p_3/2      +1.00174076e+08    -7.43628709e-03    +1.00000000e+00
#      82     83p_3/2      +1.53846199e+08    -7.25817616e-03    +1.00000000e+00
#      83     84p_3/2      +2.48315874e+08    -7.08638848e-03    +1.00000000e+00
#      84     85p_3/2      +4.40952859e+08    -6.92062825e-03    +1.00000000e+00
#      85     86p_3/2      +9.65464441e+08    -6.76061676e-03    +1.00000000e+00
#      86     87p_3/2      +3.73455551e+09    -6.60609121e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_3/2.
# Re-define the standard grid with 600 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.75853360e+01;   self-consistency = 2.895144e-01  [1.000000e+02 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.71205694e+00;   self-consistency = 7.594228e-01  [1.000000e+02 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.19895398e+00;   self-consistency = 8.252230e-01  [1.000000e+02 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.66991221e+00;   self-consistency = 7.643709e-01  [1.000000e+02 for symmetry block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.34365684e+01;   self-consistency = 9.588741e-02  [4.230236e+00 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.26826707e+00;   self-consistency = 3.124717e-01  [4.230236e+00 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.24413413e+00;   self-consistency = 3.035589e-01  [7.413886e-01 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.97292375e+00;   self-consistency = 8.318012e-02  [2.179476e-01 for symmetry block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.17739440e+01;   self-consistency = 2.549626e-02  [7.313007e-01 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.67186991e+00;   self-consistency = 1.004012e-01  [7.313007e-01 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.88626158e+00;   self-consistency = 8.664365e-02  [4.618902e-01 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.93739463e+00;   self-consistency = 9.085992e-03  [4.206278e-02 for symmetry block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.21303078e+01;   self-consistency = 5.576527e-03  [3.586921e-01 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.78879133e+00;   self-consistency = 2.141159e-02  [3.586921e-01 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93924247e+00;   self-consistency = 1.384939e-02  [5.122626e-02 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92472681e+00;   self-consistency = 3.280016e-03  [1.230334e-02 for symmetry block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20755607e+01;   self-consistency = 8.526801e-04  [4.134801e-02 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77094202e+00;   self-consistency = 3.210460e-03  [4.134801e-02 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93574148e+00;   self-consistency = 9.034865e-04  [3.600524e-03 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.93139873e+00;   self-consistency = 1.730214e-03  [6.570301e-03 for symmetry block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20778272e+01;   self-consistency = 3.532953e-05  [1.027208e-03 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77144075e+00;   self-consistency = 8.998326e-05  [1.027208e-03 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93414238e+00;   self-consistency = 4.132152e-04  [1.607619e-03 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92947202e+00;   self-consistency = 4.990342e-04  [1.921775e-03 for symmetry block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20798808e+01;   self-consistency = 3.200860e-05  [1.893423e-03 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77220081e+00;   self-consistency = 1.371062e-04  [1.893423e-03 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93495764e+00;   self-consistency = 2.107102e-04  [8.210410e-04 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92986258e+00;   self-consistency = 1.011988e-04  [3.922558e-04 for symmetry block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20789569e+01;   self-consistency = 1.440111e-05  [7.946193e-04 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77187689e+00;   self-consistency = 5.842780e-05  [7.946193e-04 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93472514e+00;   self-consistency = 6.008344e-05  [2.345000e-04 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92981433e+00;   self-consistency = 1.250165e-05  [4.934757e-05 for symmetry block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20792067e+01;   self-consistency = 3.893712e-06  [2.082195e-04 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77196230e+00;   self-consistency = 1.540781e-05  [2.082195e-04 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93477187e+00;   self-consistency = 1.207794e-05  [4.717381e-05 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92981199e+00;   self-consistency = 6.071992e-07  [2.015952e-06 for symmetry block kappa = -2]
#
# Iteration 10 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20791591e+01;   self-consistency = 7.413797e-07  [3.828970e-05 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77194647e+00;   self-consistency = 2.855853e-06  [3.828970e-05 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93476621e+00;   self-consistency = 1.464479e-06  [5.732195e-06 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92981553e+00;   self-consistency = 9.174127e-07  [3.471915e-06 for symmetry block kappa = -2]
#
# Iteration 11 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20791642e+01;   self-consistency = 7.861960e-08  [3.675741e-06 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77194803e+00;   self-consistency = 2.806556e-07  [3.675741e-06 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93476589e+00;   self-consistency = 8.293368e-08  [3.192364e-07 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92981427e+00;   self-consistency = 3.262807e-07  [1.250118e-06 for symmetry block kappa = -2]
#
# Iteration 12 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20791648e+01;   self-consistency = 9.516055e-09  [6.421447e-07 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77194828e+00;   self-consistency = 4.534380e-08  [6.421447e-07 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93476632e+00;   self-consistency = 1.120694e-07  [4.365657e-07 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92981457e+00;   self-consistency = 7.791825e-08  [3.008594e-07 for symmetry block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^- ...   ... done.
# Compute CI matrix of dimension 2 x 2 for the symmetry 1^- ...   ... done.
# Compute CI matrix of dimension 3 x 3 for the symmetry 0^+ ...   ... done.
# Compute CI matrix of dimension 2 x 2 for the symmetry 2^+ ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 1^+ ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 2^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    2 +     -1.264990270550121e+02    -3.442213856348358e+03    -3.442213856348358e+03
#      2    1 +     -1.264960250137468e+02    -3.442132166644640e+03    -3.442132166644640e+03
#      3    0 +     -1.264946130167134e+02    -3.442093744248305e+03    -3.442093744248305e+03
#      4    2 +     -1.263732526276202e+02    -3.438791359853152e+03    -3.438791359853152e+03
#      5    0 +     -1.262583872059620e+02    -3.435665712524061e+03    -3.435665712524061e+03
#      6    2 -     -1.255200756792340e+02    -3.415575232567250e+03    -3.415575232567250e+03
#      7    1 -     -1.255172180519128e+02    -3.415497472567112e+03    -3.415497472567112e+03
#      8    0 -     -1.255157751959884e+02    -3.415458210457582e+03    -3.415458210457582e+03
#      9    1 -     -1.250741774570168e+02    -3.403441723916865e+03    -3.403441723916865e+03
#     10    0 +     -1.241149908955826e+02    -3.377340928128484e+03    -3.377340928128484e+03
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1 +     3.002041265318667e-03    8.168970371855548e-02    8.168970371855548e-02
#      3    0 +     1.411997033372359e-03    3.842239633419007e-02    3.842239633419007e-02
#      4    2 +     1.213603890932262e-01    3.302384395153176e+00    3.302384395153176e+00
#      5    0 +     1.148654216581804e-01    3.125647329090814e+00    3.125647329090814e+00
#      6    2 -     7.383115267280118e-01    2.009047995681147e+01    2.009047995681147e+01
#      7    1 -     2.857627321176892e-03    7.776000013784293e-02    7.776000013784293e-02
#      8    0 -     1.442855924381092e-03    3.926210952957783e-02    3.926210952957783e-02
#      9    1 -     4.415977389716801e-01    1.201648654071758e+01    1.201648654071758e+01
#     10    0 +     9.591865614341231e-01    2.610079578838037e+01    2.610079578838037e+01
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1 +     3.002041265318667e-03    8.168970371855548e-02    8.168970371855548e-02
#      3    0 +     4.414038298691025e-03    1.201121000527455e-01    1.201121000527455e-01
#      4    2 +     1.257744273919172e-01    3.422496495205922e+00    3.422496495205922e+00
#      5    0 +     2.406398490500976e-01    6.548143824296736e+00    6.548143824296736e+00
#      6    2 -     9.789513757781094e-01    2.663862378110821e+01    2.663862378110821e+01
#      7    1 -     9.818090030992863e-01    2.671638378124605e+01    2.671638378124605e+01
#      8    0 -     9.832518590236674e-01    2.675564589077563e+01    2.675564589077563e+01
#      9    1 -     1.424849597995347e+00    3.877213243149322e+01    3.877213243149322e+01
#     10    0 +     2.384036159429471e+00    6.487292821987359e+01    6.487292821987359e+01
#
# JAC.Auger.computeLines(): The computation of Auger rates and properties starts now ...
# --------------------------------------------------------------------------------------
#
# Continuum-Bessel orbital for q = 7.720309076120419,  l = 2
# Pure-sine normalized continuum orbital with normalization constant N=-9.1050e-01 (Delta-N=2.5514e+00) and phase phi=1.7661e+00 (Delta-N=1.2060e+00).
# Compute (Coulomb) Auger matrix of dimension 2 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave d_5/2 ... done.
# Continuum-Bessel orbital for q = 7.720309076120419,  l = 2
# Pure-sine normalized continuum orbital with normalization constant N=-9.1050e-01 (Delta-N=2.5514e+00) and phase phi=1.7661e+00 (Delta-N=1.2060e+00).
# Compute (Coulomb) Auger matrix of dimension 2 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave d_3/2 ... done.
# Continuum-Bessel orbital for q = 7.719920216446325,  l = 0
# Pure-sine normalized continuum orbital with normalization constant N=-9.1791e-01 (Delta-N=2.3687e+00) and phase phi=1.9070e+00 (Delta-N=1.1717e+00).
# Compute (Coulomb) Auger matrix of dimension 1 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave s_1/2 ... done.
# Continuum-Bessel orbital for q = 7.719920216446325,  l = 2
# Pure-sine normalized continuum orbital with normalization constant N=-9.0874e-01 (Delta-N=2.5499e+00) and phase phi=1.7671e+00 (Delta-N=1.2060e+00).
# Compute (Coulomb) Auger matrix of dimension 1 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave d_3/2 ... done.
# Continuum-Bessel orbital for q = 7.719737311219205,  l = 0
# Pure-sine normalized continuum orbital with normalization constant N=-9.1729e-01 (Delta-N=2.3685e+00) and phase phi=1.9075e+00 (Delta-N=1.1717e+00).
# Compute (Coulomb) Auger matrix of dimension 3 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave s_1/2 ... done.
# Continuum-Bessel orbital for q = 7.704000478715164,  l = 2
# Pure-sine normalized continuum orbital with normalization constant N=-6.2967e-01 (Delta-N=2.5581e+00) and phase phi=1.6569e+00 (Delta-N=1.2240e+00).
# Compute (Coulomb) Auger matrix of dimension 2 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave d_5/2 ... done.
# Continuum-Bessel orbital for q = 7.704000478715164,  l = 2
# Pure-sine normalized continuum orbital with normalization constant N=-6.2967e-01 (Delta-N=2.5581e+00) and phase phi=1.6569e+00 (Delta-N=1.2240e+00).
# Compute (Coulomb) Auger matrix of dimension 2 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave d_3/2 ... done.
# Continuum-Bessel orbital for q = 7.689076182008286,  l = 0
# Pure-sine normalized continuum orbital with normalization constant N=-3.9723e-01 (Delta-N=2.4539e+00) and phase phi=1.6847e+00 (Delta-N=1.2240e+00).
# Compute (Coulomb) Auger matrix of dimension 3 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave s_1/2 ... done.
# Continuum-Bessel orbital for q = 7.592448187460425,  l = 1
# Pure-sine normalized continuum orbital with normalization constant N=9.0185e-01 (Delta-N=1.2565e+01) and phase phi=1.6860e+00 (Delta-N=6.1238e-01).
# Compute (Coulomb) Auger matrix of dimension 1 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave p_3/2 ... done.
# Continuum-Bessel orbital for q = 7.592448187460425,  l = 3
# Pure-sine normalized continuum orbital with normalization constant N=7.8706e-01 (Delta-N=1.5239e+01) and phase phi=1.6755e+00 (Delta-N=6.7841e-01).
# Compute (Coulomb) Auger matrix of dimension 1 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave f_5/2 ... done.
# Continuum-Bessel orbital for q = 7.592071800544877,  l = 1
# Pure-sine normalized continuum orbital with normalization constant N=9.5574e-01 (Delta-N=1.2597e+01) and phase phi=1.6854e+00 (Delta-N=6.1357e-01).
# Compute (Coulomb) Auger matrix of dimension 2 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave p_3/2 ... done.
# Continuum-Bessel orbital for q = 7.592071800544877,  l = 1
# Pure-sine normalized continuum orbital with normalization constant N=9.5574e-01 (Delta-N=1.2597e+01) and phase phi=1.6854e+00 (Delta-N=6.1357e-01).
# Compute (Coulomb) Auger matrix of dimension 2 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave p_1/2 ... done.
# Continuum-Bessel orbital for q = 7.5918817504476435,  l = 1
# Pure-sine normalized continuum orbital with normalization constant N=9.8290e-01 (Delta-N=1.2614e+01) and phase phi=1.6851e+00 (Delta-N=6.1419e-01).
# Compute (Coulomb) Auger matrix of dimension 1 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave p_1/2 ... done.
# Continuum-Bessel orbital for q = 7.533490096551307,  l = 1
# Pure-sine normalized continuum orbital with normalization constant N=1.5717e+00 (Delta-N=1.6593e+01) and phase phi=1.8050e+00 (Delta-N=7.1410e-01).
# Compute (Coulomb) Auger matrix of dimension 2 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave p_3/2 ... done.
# Continuum-Bessel orbital for q = 7.533490096551307,  l = 1
# Pure-sine normalized continuum orbital with normalization constant N=1.5717e+00 (Delta-N=1.6593e+01) and phase phi=1.8050e+00 (Delta-N=7.1410e-01).
# Compute (Coulomb) Auger matrix of dimension 2 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave p_1/2 ... done.
# Continuum-Bessel orbital for q = 7.405072579790719,  l = 0
# Pure-sine normalized continuum orbital with normalization constant N=3.3999e+00 (Delta-N=2.8073e+00) and phase phi=8.7488e-01 (Delta-N=7.8091e-01).
# Compute (Coulomb) Auger matrix of dimension 3 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave s_1/2 ... done.
#
#   Auger rates (without angular parameters):
#
#   -------------------------------------------------------------------------------------------------------------------
#        i-level-f           i--J^P--f            Energy         Electron energy     Auger rate          alpha_2
#                                                  [eV]               [eV]              [1/s]
#   -------------------------------------------------------------------------------------------------------------------
#         1 --     1       1/2 + --> 2 +      -2.63127139e+03    8.10942464e+02    1.73834480e+11    0.00000000e+00
#         1 --     2       1/2 + --> 1 +      -2.63127139e+03    8.10860774e+02    5.43649215e+11    0.00000000e+00
#         1 --     3       1/2 + --> 0 +      -2.63127139e+03    8.10822352e+02    2.63224587e+11    0.00000000e+00
#         1 --     4       1/2 + --> 2 +      -2.63127139e+03    8.07519967e+02    3.04968096e+13    0.00000000e+00
#         1 --     5       1/2 + --> 0 +      -2.63127139e+03    8.04394320e+02    2.17096775e+11    0.00000000e+00
#         1 --     6       1/2 + --> 2 -      -2.63127139e+03    7.84303840e+02    1.27751131e+13    0.00000000e+00
#         1 --     7       1/2 + --> 1 -      -2.63127139e+03    7.84226080e+02    1.38420809e+13    0.00000000e+00
#         1 --     8       1/2 + --> 0 -      -2.63127139e+03    7.84186818e+02    5.80464190e+12    0.00000000e+00
#         1 --     9       1/2 + --> 1 -      -2.63127139e+03    7.72170331e+02    3.53960941e+12    0.00000000e+00
#         1 --    10       1/2 + --> 0 +      -2.63127139e+03    7.46069536e+02    1.56778108e+14    0.00000000e+00
#   -------------------------------------------------------------------------------------------------------------------
#
#   Auger lifetimes, total rates and widths:
#
#   -------------------------------------------------------------------------------------------------------------------
#      Level       J^P         Lifetime          Total rate                              Widths
#                                [sec]              [1/s]             Hartrees           Kaysers             eV
#   -------------------------------------------------------------------------------------------------------------------
#          1      1/2 +     4.45564942e-15     2.24434168e+14      1.47725252e-01    1.19148451e+03    1.47725252e-01
#   -------------------------------------------------------------------------------------------------------------------
# JAC.warn():  Reset global array JAC_WARNINGS.

# %% [markdown]
# This computation just applies simple *Bessel-type* continuum orbitals which are normalized on the basis of a pure sine behaviour at large radii. Moreover, the Auger amplitudes are computed by including the Coulomb interaction. Further control about this computation can be gained by re-defining the method for the integration of the continuum orbitals as well as by means of the `Auger.Settings`. For example, we can use a B-spline-Galerkin method and a normalization for a pure asymptotic Coulomb field to generate all continuum orbitals of interest:

# %%
JAC.define("method: continuum, Galerkin")
JAC.define("method: normalization, pure Coulomb")

# %% [markdown]
# Moreover, we can first have a look how the standard settings are defined at present:

# %%
? Auger.Settings
# Out:
#   struct  Settings ... defines a type for the details and parameters of
#   computing Auger lines.
#
#   + calcAnisotropy          ::Bool                         ... True, if the intrinsic alpha_2,4 angular parameters are to be calculated,
#                                                                and false otherwise.
#   + printBeforeComputation  ::Bool                         ... True, if all energies and lines are printed before their evaluation.
#   + selectLines             ::Bool                         ... True, if lines are selected individually for the computations.
#   + selectedLines           ::Array{Tuple{Int64,Int64},1}  ... List of lines, given by tupels (inital-level, final-level).
#   + minAugerEnergy          ::Float64                      ... Minimum energy of free (Auger) electrons to be included.
#   + maxAugerEnergy          ::Float64                      ... Maximum energy of free (Auger) electrons to be included.
#   + maxKappa                ::Int64                        ... Maximum kappa value of partial waves to be included.
#   + operator                ::String                       ... Auger operator that is to be used for evaluating the Auger amplitudes:
#                                                                allowed values are: "Coulomb", "Breit", "Coulomb+Breit"
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   JAC.Auger.Settings() ... constructor for the default values of Auger line
#   computations

# %%
Auger.Settings()
# Out:
# Auger.Settings(with printBeforeComputation = false, selectLines = false, selectedLines = Tuple{Int64,Int64}[],
#                  minAugerEnergy = 0.0, maxAugerEnergy = 1.0e6, maxKappa = 100, calcAnisotropy = false, operator = Coulomb)

# %% [markdown]
# Obviously, neither the Auger energies nor the symmetries of the (outgoing) partial wave are restricted. Apart from the Coulomb interaction, we could just included the Breit interaction (mainly for test purposes) or both, Coulomb+Breit together, and independent of whether this interaction has been incorporated in the SCF and CI computations before. In addition, we can also calculate the angular anisotropy coefficients as well as specify individual lines or symmetries to be included. We here leave the selection of individual lines to later and define the settings as:

# %%
augerSettings = Auger.Settings(true, true, false, Tuple{Int64,Int64}[], 0.0, 1.0e5, 10, "Coulomb+Breit")
# Out:
# Auger.Settings(with printBeforeComputation = true, selectLines = false, selectedLines = Tuple{Int64,Int64}[],
#                  minAugerEnergy = 0.0, maxAugerEnergy = 100000.0, maxKappa = 10, calcAnisotropy = true, operator = Coulomb+Breit)

# %% [markdown]
# and re-run the computations with these settings:

# %%
wb = Atomic.Computation("Neon K-LL Auger spectrum",  Nuclear.Model(10.); 
            grid=JAC.Radial.Grid("grid: by given parameters"; rnt = 2.0e-6, h = 5.0e-2, 
                                                              hp = 1.0e-2, NoPoints = 600), 
            initialConfigs=[Configuration("1s 2s^2 2p^6")],
            finalConfigs  =[Configuration("1s^2 2s^2 2p^4"), Configuration("1s^2 2s 2p^5"), 
                            Configuration("1s^2 2p^6")], process = JAC.AugerX,
            processSettings = augerSettings )
perform(wb)
# Out:
# Define a radial grid of type MeshGL with 610 grid points
#  [rnt=2.000e-06, h=5.000e-02, hp=1.000e-02, NoPoints=600, r_max=3.229e+00;
#   B-splines wit break points at every 7th point, nsL=86, nsS=87, orderL=7, orderS=8, orderGL=7]
# shellOccList = SubString{String}["1s", "2s^2", "2p^6"]
# shellOccList = SubString{String}["1s^2", "2s^2", "2p^4"]
# shellOccList = SubString{String}["1s^2", "2s", "2p^5"]
# shellOccList = SubString{String}["1s^2", "2p^6"]
#
# ... in perform('computation: SCF', ...
# perform-aa: Configuration: 1s_1/2^1 2s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 10.0 with mass = 20.5, radius R = 2.8580081360657426 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -5.00667217e+01    -5.00667420e+01    +4.04942396e-07
#       2      2s_1/2      -1.25208569e+01    -1.25208597e+01    +2.21401474e-07
#       3      3s_1/2      -5.55237930e+00    -5.56297036e+00    +1.90748146e-03
#       4      4s_1/2      -2.53406911e+00    -3.12838807e+00    +2.34531471e-01
#       5      5s_1/2      +1.11492726e+00    -2.00181447e+00    +2.79546644e+00
#       6      6s_1/2      +6.08980428e+00    -1.38996969e+00    +1.22824538e+00
#       7      7s_1/2      +1.22986147e+01    -1.02110261e+00    +1.08302582e+00
#       8      8s_1/2      +1.96843810e+01    -7.81722173e-01    +1.03971281e+00
#       :       :
#      81     81s_1/2      +8.45031707e+07    -7.62128657e-03    +1.00000000e+00
#      82     82s_1/2      +1.28234366e+08    -7.43652912e-03    +1.00000000e+00
#      83     83s_1/2      +2.02549706e+08    -7.25840955e-03    +1.00000000e+00
#      84     84s_1/2      +3.44971609e+08    -7.08661363e-03    +1.00000000e+00
#      85     85s_1/2      +6.89822385e+08    -6.92084556e-03    +1.00000000e+00
#      86     86s_1/2      +2.35262342e+09    -6.76082657e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 1s_1/2.
# Use hydrogenic orbital from this symmetriy block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -1.25208596e+01    -1.25208597e+01    +7.13213298e-09
#       2      3p_1/2      -5.55623611e+00    -5.56297036e+00    +1.21201567e-03
#       3      4p_1/2      -2.64947890e+00    -3.12838807e+00    +1.80755984e-01
#       4      5p_1/2      +7.31175060e-01    -2.00181447e+00    +3.73780464e+00
#       5      6p_1/2      +5.37799965e+00    -1.38996969e+00    +1.25845477e+00
#       6      7p_1/2      +1.12162626e+01    -1.02110261e+00    +1.09103769e+00
#       7      8p_1/2      +1.81978989e+01    -7.81722173e-01    +1.04295673e+00
#       8      9p_1/2      +2.62974095e+01    -6.17619366e-01    +1.02348594e+00
#       :       :
#      80     81p_1/2      +7.02969794e+07    -7.62128657e-03    +1.00000000e+00
#      81     82p_1/2      +1.05447514e+08    -7.43652912e-03    +1.00000000e+00
#      82     83p_1/2      +1.63158045e+08    -7.25840955e-03    +1.00000000e+00
#      83     84p_1/2      +2.66991502e+08    -7.08661363e-03    +1.00000000e+00
#      84     85p_1/2      +4.88013233e+08    -6.92084556e-03    +1.00000000e+00
#      85     86p_1/2      +1.16225386e+09    -6.76082657e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -1.25041629e+01    -1.25041630e+01    +7.09212094e-09
#       2      3p_3/2      -5.55123117e+00    -5.55802266e+00    +1.22342097e-03
#       3      4p_3/2      -2.64586941e+00    -3.12630099e+00    +1.81577966e-01
#       4      5p_3/2      +7.36191475e-01    -2.00074602e+00    +3.71769789e+00
#       5      6p_3/2      +5.38440084e+00    -1.38935143e+00    +1.25803269e+00
#       6      7p_3/2      +1.12239821e+01    -1.02071331e+00    +1.09094039e+00
#       7      8p_3/2      +1.82069305e+01    -7.81461386e-01    +1.04292109e+00
#       8      9p_3/2      +2.63077747e+01    -6.17436217e-01    +1.02346972e+00
#       :       :
#      81     82p_3/2      +1.00174076e+08    -7.43628709e-03    +1.00000000e+00
#      82     83p_3/2      +1.53846199e+08    -7.25817616e-03    +1.00000000e+00
#      83     84p_3/2      +2.48315874e+08    -7.08638848e-03    +1.00000000e+00
#      84     85p_3/2      +4.40952859e+08    -6.92062825e-03    +1.00000000e+00
#      85     86p_3/2      +9.65464441e+08    -6.76061676e-03    +1.00000000e+00
#      86     87p_3/2      +3.73455551e+09    -6.60609121e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_3/2.
# Re-define the standard grid with 600 grid points.
# (Re-) Define a storage array for various B-spline matrices:
#
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.85131620e+01;   self-consistency = 2.742885e-01  [1.000000e+02 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -8.08506526e-01;   self-consistency = 8.786879e-01  [1.000000e+02 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -4.39496696e-01;   self-consistency = 9.321783e-01  [1.000000e+02 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.10400161e+00;   self-consistency = 8.377442e-01  [1.000000e+02 for symmetry block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.60450379e+01;   self-consistency = 1.166680e-01  [6.962279e-01 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.98797485e+00;   self-consistency = 5.740759e-01  [6.962279e-01 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.78057558e+00;   self-consistency = 6.040699e-01  [6.040699e-01 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.24322748e+00;   self-consistency = 5.931499e-02  [5.931499e-02 for symmetry block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.33194211e+01;   self-consistency = 3.929414e-02  [4.669408e-01 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.90479623e+00;   self-consistency = 2.213835e-01  [4.669408e-01 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.20932123e+00;   self-consistency = 1.910616e-01  [1.910616e-01 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.32558088e+00;   self-consistency = 3.205899e-02  [3.205899e-02 for symmetry block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.39040018e+01;   self-consistency = 8.696087e-03  [6.800736e-02 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.10523605e+00;   self-consistency = 4.998459e-02  [6.800736e-02 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.25355103e+00;   self-consistency = 1.795862e-02  [1.795862e-02 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.23479438e+00;   self-consistency = 3.545828e-02  [3.545828e-02 for symmetry block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38987370e+01;   self-consistency = 7.764964e-05  [5.135161e-04 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.10307501e+00;   self-consistency = 5.135161e-04  [5.135161e-04 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.28727284e+00;   self-consistency = 1.327200e-02  [1.327200e-02 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.27241935e+00;   self-consistency = 1.500669e-02  [1.500669e-02 for symmetry block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38290819e+01;   self-consistency = 1.028456e-03  [9.330782e-03 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.07773312e+00;   self-consistency = 6.061481e-03  [9.330782e-03 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.26286552e+00;   self-consistency = 9.570980e-03  [9.570980e-03 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26315336e+00;   self-consistency = 3.654401e-03  [3.654401e-03 for symmetry block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38671074e+01;   self-consistency = 5.617083e-04  [4.992745e-03 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.09150698e+00;   self-consistency = 3.303686e-03  [4.992745e-03 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.27175719e+00;   self-consistency = 3.508086e-03  [3.508086e-03 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26338184e+00;   self-consistency = 9.043433e-05  [9.043433e-05 for symmetry block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38553059e+01;   self-consistency = 1.742627e-04  [1.538146e-03 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08723083e+00;   self-consistency = 1.023311e-03  [1.538146e-03 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.26998479e+00;   self-consistency = 6.973173e-04  [6.973173e-04 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26440562e+00;   self-consistency = 4.050094e-04  [4.050094e-04 for symmetry block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38569203e+01;   self-consistency = 2.384271e-05  [2.031710e-04 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08781281e+00;   self-consistency = 1.393943e-04  [2.031710e-04 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.26982858e+00;   self-consistency = 6.150679e-05  [6.150679e-05 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26382468e+00;   self-consistency = 2.297794e-04  [2.297794e-04 for symmetry block kappa = -2]
#
# Iteration 10 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38575214e+01;   self-consistency = 8.877426e-06  [8.190965e-05 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08803178e+00;   self-consistency = 5.243751e-05  [8.190965e-05 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.27013344e+00;   self-consistency = 1.200276e-04  [1.200276e-04 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26401019e+00;   self-consistency = 7.338679e-05  [7.338679e-05 for symmetry block kappa = -2]
#
# Iteration 11 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38569960e+01;   self-consistency = 7.759148e-06  [6.951858e-05 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08784113e+00;   self-consistency = 4.565695e-05  [6.951858e-05 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.26998856e+00;   self-consistency = 5.703658e-05  [5.703658e-05 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26398259e+00;   self-consistency = 1.091870e-05  [1.091870e-05 for symmetry block kappa = -2]
#
# Iteration 12 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38572043e+01;   self-consistency = 3.076317e-06  [2.726455e-05 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08791661e+00;   self-consistency = 1.807673e-05  [2.726455e-05 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.27002866e+00;   self-consistency = 1.578455e-05  [1.578455e-05 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26397434e+00;   self-consistency = 3.262322e-06  [3.262322e-06 for symmetry block kappa = -2]
#
# Iteration 13 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38571575e+01;   self-consistency = 6.911680e-07  [6.032525e-06 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08789968e+00;   self-consistency = 4.053441e-06  [6.032525e-06 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.27002510e+00;   self-consistency = 1.399038e-06  [1.399038e-06 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26398223e+00;   self-consistency = 3.119583e-06  [3.119583e-06 for symmetry block kappa = -2]
#
# Iteration 14 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38571568e+01;   self-consistency = 1.088467e-08  [1.467676e-07 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08789940e+00;   self-consistency = 6.823325e-08  [1.467676e-07 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.27002202e+00;   self-consistency = 1.213447e-06  [1.213447e-06 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26397901e+00;   self-consistency = 1.274993e-06  [1.274993e-06 for symmetry block kappa = -2]
#
# Iteration 15 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.38571630e+01;   self-consistency = 9.202315e-08  [8.310755e-07 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.08790166e+00;   self-consistency = 5.420519e-07  [8.310755e-07 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.27002412e+00;   self-consistency = 8.285269e-07  [8.285269e-07 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.26397976e+00;   self-consistency = 2.984328e-07  [2.984328e-07 for symmetry block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 1/2^+ ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    1/2 +     -9.669744093959845e+01    -2.631271392553565e+03    -2.631271392553565e+03
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#
# ... in perform('computation: SCF', ...
# perform-aa: Configuration: 1s_1/2^2 2s_1/2^2 2p_3/2^4
# perform-aa: Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^1 2p_3/2^3
# perform-aa: Configuration: 1s_1/2^2 2s_1/2^2 2p_1/2^2 2p_3/2^2
# perform-aa: Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^1 2p_3/2^4
# perform-aa: Configuration: 1s_1/2^2 2s_1/2^1 2p_1/2^2 2p_3/2^3
# perform-aa: Configuration: 1s_1/2^2 2p_1/2^2 2p_3/2^4
# (Re-) Define a new standard subshell list.
# (Re-) Define a storage array for various B-spline matrices:
# Nuclear model = Fermi nuclear model for Z = 10.0 with mass = 20.5, radius R = 2.8580081360657426 fm and nuclear spin I = 0, dipole moment mu = 0.0 and quadrupole moment Q = 0.0.
# Generate hydrogenic orbital for subshell 1s_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      1s_1/2      -5.00667217e+01    -5.00667420e+01    +4.04942396e-07
#       2      2s_1/2      -1.25208569e+01    -1.25208597e+01    +2.21401474e-07
#       3      3s_1/2      -5.55237930e+00    -5.56297036e+00    +1.90748146e-03
#       4      4s_1/2      -2.53406911e+00    -3.12838807e+00    +2.34531471e-01
#       5      5s_1/2      +1.11492726e+00    -2.00181447e+00    +2.79546644e+00
#       6      6s_1/2      +6.08980428e+00    -1.38996969e+00    +1.22824538e+00
#       7      7s_1/2      +1.22986147e+01    -1.02110261e+00    +1.08302582e+00
#       8      8s_1/2      +1.96843810e+01    -7.81722173e-01    +1.03971281e+00
#       :       :
#      81     81s_1/2      +8.45031707e+07    -7.62128657e-03    +1.00000000e+00
#      82     82s_1/2      +1.28234366e+08    -7.43652912e-03    +1.00000000e+00
#      83     83s_1/2      +2.02549706e+08    -7.25840955e-03    +1.00000000e+00
#      84     84s_1/2      +3.44971609e+08    -7.08661363e-03    +1.00000000e+00
#      85     85s_1/2      +6.89822385e+08    -6.92084556e-03    +1.00000000e+00
#      86     86s_1/2      +2.35262342e+09    -6.76082657e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 1s_1/2.
# Use hydrogenic orbital from this symmetriy block also for 2s_1/2.
# Generate hydrogenic orbital for subshell 2p_1/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_1/2      -1.25208596e+01    -1.25208597e+01    +7.13213298e-09
#       2      3p_1/2      -5.55623611e+00    -5.56297036e+00    +1.21201567e-03
#       3      4p_1/2      -2.64947890e+00    -3.12838807e+00    +1.80755984e-01
#       4      5p_1/2      +7.31175060e-01    -2.00181447e+00    +3.73780464e+00
#       5      6p_1/2      +5.37799965e+00    -1.38996969e+00    +1.25845477e+00
#       6      7p_1/2      +1.12162626e+01    -1.02110261e+00    +1.09103769e+00
#       7      8p_1/2      +1.81978989e+01    -7.81722173e-01    +1.04295673e+00
#       8      9p_1/2      +2.62974095e+01    -6.17619366e-01    +1.02348594e+00
#       :       :
#      80     81p_1/2      +7.02969794e+07    -7.62128657e-03    +1.00000000e+00
#      81     82p_1/2      +1.05447514e+08    -7.43652912e-03    +1.00000000e+00
#      82     83p_1/2      +1.63158045e+08    -7.25840955e-03    +1.00000000e+00
#      83     84p_1/2      +2.66991502e+08    -7.08661363e-03    +1.00000000e+00
#      84     85p_1/2      +4.88013233e+08    -6.92084556e-03    +1.00000000e+00
#      85     86p_1/2      +1.16225386e+09    -6.76082657e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_1/2.
# Generate hydrogenic orbital for subshell 2p_3/2
#   -----------------------------------------------------------------------------
#    Index    Subshell     Energies [a.u.]    Dirac-E  [a.u.]     Delta-E / |E|
#   -----------------------------------------------------------------------------
#       1      2p_3/2      -1.25041629e+01    -1.25041630e+01    +7.09212094e-09
#       2      3p_3/2      -5.55123117e+00    -5.55802266e+00    +1.22342097e-03
#       3      4p_3/2      -2.64586941e+00    -3.12630099e+00    +1.81577966e-01
#       4      5p_3/2      +7.36191475e-01    -2.00074602e+00    +3.71769789e+00
#       5      6p_3/2      +5.38440084e+00    -1.38935143e+00    +1.25803269e+00
#       6      7p_3/2      +1.12239821e+01    -1.02071331e+00    +1.09094039e+00
#       7      8p_3/2      +1.82069305e+01    -7.81461386e-01    +1.04292109e+00
#       8      9p_3/2      +2.63077747e+01    -6.17436217e-01    +1.02346972e+00
#       :       :
#      81     82p_3/2      +1.00174076e+08    -7.43628709e-03    +1.00000000e+00
#      82     83p_3/2      +1.53846199e+08    -7.25817616e-03    +1.00000000e+00
#      83     84p_3/2      +2.48315874e+08    -7.08638848e-03    +1.00000000e+00
#      84     85p_3/2      +4.40952859e+08    -6.92062825e-03    +1.00000000e+00
#      85     86p_3/2      +9.65464441e+08    -6.76061676e-03    +1.00000000e+00
#      86     87p_3/2      +3.73455551e+09    -6.60609121e-03    +1.00000000e+00
#   -----------------------------------------------------------------------------
# Use hydrogenic orbital from this symmetriy block also for 2p_3/2.
# Re-define the standard grid with 600 grid points.
# (Re-) Define a storage array for various B-spline matrices:
# Iteration 1 for symmetries ...
#   1s_1/2::  en [a.u.] = -2.75853360e+01;   self-consistency = 2.895144e-01  [1.000000e+02 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -1.71205694e+00;   self-consistency = 7.594228e-01  [1.000000e+02 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.19895398e+00;   self-consistency = 8.252230e-01  [1.000000e+02 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.66991221e+00;   self-consistency = 7.643709e-01  [1.000000e+02 for symmetry block kappa = -2]
#
# Iteration 2 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.34365684e+01;   self-consistency = 9.588741e-02  [4.230236e+00 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -3.26826707e+00;   self-consistency = 3.124717e-01  [4.230236e+00 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -2.24413413e+00;   self-consistency = 3.035589e-01  [7.413886e-01 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.97292375e+00;   self-consistency = 8.318012e-02  [2.179476e-01 for symmetry block kappa = -2]
#
# Iteration 3 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.17739440e+01;   self-consistency = 2.549626e-02  [7.313007e-01 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.67186991e+00;   self-consistency = 1.004012e-01  [7.313007e-01 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.88626158e+00;   self-consistency = 8.664365e-02  [4.618902e-01 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.93739463e+00;   self-consistency = 9.085992e-03  [4.206278e-02 for symmetry block kappa = -2]
#
# Iteration 4 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.21303078e+01;   self-consistency = 5.576527e-03  [3.586921e-01 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.78879133e+00;   self-consistency = 2.141159e-02  [3.586921e-01 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93924247e+00;   self-consistency = 1.384939e-02  [5.122626e-02 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92472681e+00;   self-consistency = 3.280016e-03  [1.230334e-02 for symmetry block kappa = -2]
#
# Iteration 5 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20755607e+01;   self-consistency = 8.526801e-04  [4.134801e-02 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77094202e+00;   self-consistency = 3.210460e-03  [4.134801e-02 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93574148e+00;   self-consistency = 9.034865e-04  [3.600524e-03 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.93139873e+00;   self-consistency = 1.730214e-03  [6.570301e-03 for symmetry block kappa = -2]
#
# Iteration 6 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20778272e+01;   self-consistency = 3.532953e-05  [1.027208e-03 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77144075e+00;   self-consistency = 8.998326e-05  [1.027208e-03 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93414238e+00;   self-consistency = 4.132152e-04  [1.607619e-03 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92947202e+00;   self-consistency = 4.990342e-04  [1.921775e-03 for symmetry block kappa = -2]
#
# Iteration 7 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20798808e+01;   self-consistency = 3.200860e-05  [1.893423e-03 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77220081e+00;   self-consistency = 1.371062e-04  [1.893423e-03 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93495764e+00;   self-consistency = 2.107102e-04  [8.210410e-04 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92986258e+00;   self-consistency = 1.011988e-04  [3.922558e-04 for symmetry block kappa = -2]
#
# Iteration 8 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20789569e+01;   self-consistency = 1.440111e-05  [7.946193e-04 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77187689e+00;   self-consistency = 5.842780e-05  [7.946193e-04 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93472514e+00;   self-consistency = 6.008344e-05  [2.345000e-04 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92981433e+00;   self-consistency = 1.250165e-05  [4.934757e-05 for symmetry block kappa = -2]
#
# Iteration 9 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20792067e+01;   self-consistency = 3.893712e-06  [2.082195e-04 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77196230e+00;   self-consistency = 1.540781e-05  [2.082195e-04 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93477187e+00;   self-consistency = 1.207794e-05  [4.717381e-05 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92981199e+00;   self-consistency = 6.071992e-07  [2.015952e-06 for symmetry block kappa = -2]
#
# Iteration 10 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20791591e+01;   self-consistency = 7.413797e-07  [3.828970e-05 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77194647e+00;   self-consistency = 2.855853e-06  [3.828970e-05 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93476621e+00;   self-consistency = 1.464479e-06  [5.732195e-06 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92981553e+00;   self-consistency = 9.174127e-07  [3.471915e-06 for symmetry block kappa = -2]
#
# Iteration 11 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20791642e+01;   self-consistency = 7.861960e-08  [3.675741e-06 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77194803e+00;   self-consistency = 2.806556e-07  [3.675741e-06 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93476589e+00;   self-consistency = 8.293368e-08  [3.192364e-07 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92981427e+00;   self-consistency = 3.262807e-07  [1.250118e-06 for symmetry block kappa = -2]
#
# Iteration 12 for symmetries ...
#   1s_1/2::  en [a.u.] = -3.20791648e+01;   self-consistency = 9.516055e-09  [6.421447e-07 for symmetry block kappa = -1]
#   2s_1/2::  en [a.u.] = -2.77194828e+00;   self-consistency = 4.534380e-08  [6.421447e-07 for symmetry block kappa = -1]
#   2p_1/2::  en [a.u.] = -1.93476632e+00;   self-consistency = 1.120694e-07  [4.365657e-07 for symmetry block kappa = 1]
#   2p_3/2::  en [a.u.] = -1.92981457e+00;   self-consistency = 7.791825e-08  [3.008594e-07 for symmetry block kappa = -2]
# Compute CI matrix of dimension 1 x 1 for the symmetry 0^- ...   ... done.
# Compute CI matrix of dimension 2 x 2 for the symmetry 1^- ...   ... done.
# Compute CI matrix of dimension 3 x 3 for the symmetry 0^+ ...   ... done.
# Compute CI matrix of dimension 2 x 2 for the symmetry 2^+ ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 1^+ ...   ... done.
# Compute CI matrix of dimension 1 x 1 for the symmetry 2^- ...   ... done.
#
#   Eigenenergies:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      1    2 +     -1.264990270550121e+02    -3.442213856348358e+03    -3.442213856348358e+03
#      2    1 +     -1.264960250137468e+02    -3.442132166644640e+03    -3.442132166644640e+03
#      3    0 +     -1.264946130167134e+02    -3.442093744248305e+03    -3.442093744248305e+03
#      4    2 +     -1.263732526276202e+02    -3.438791359853152e+03    -3.438791359853152e+03
#      5    0 +     -1.262583872059620e+02    -3.435665712524061e+03    -3.435665712524061e+03
#      6    2 -     -1.255200756792340e+02    -3.415575232567250e+03    -3.415575232567250e+03
#      7    1 -     -1.255172180519128e+02    -3.415497472567112e+03    -3.415497472567112e+03
#      8    0 -     -1.255157751959884e+02    -3.415458210457582e+03    -3.415458210457582e+03
#      9    1 -     -1.250741774570168e+02    -3.403441723916865e+03    -3.403441723916865e+03
#     10    0 +     -1.241149908955826e+02    -3.377340928128484e+03    -3.377340928128484e+03
#
#   Energy of each level relative to immediately lower level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1 +     3.002041265318667e-03    8.168970371855548e-02    8.168970371855548e-02
#      3    0 +     1.411997033372359e-03    3.842239633419007e-02    3.842239633419007e-02
#      4    2 +     1.213603890932262e-01    3.302384395153176e+00    3.302384395153176e+00
#      5    0 +     1.148654216581804e-01    3.125647329090814e+00    3.125647329090814e+00
#      6    2 -     7.383115267280118e-01    2.009047995681147e+01    2.009047995681147e+01
#      7    1 -     2.857627321176892e-03    7.776000013784293e-02    7.776000013784293e-02
#      8    0 -     1.442855924381092e-03    3.926210952957783e-02    3.926210952957783e-02
#      9    1 -     4.415977389716801e-01    1.201648654071758e+01    1.201648654071758e+01
#     10    0 +     9.591865614341231e-01    2.610079578838037e+01    2.610079578838037e+01
#
#   Energy of each level relative to lowest level:
#
#   Level  J Parity          Hartrees                    eV                   [eV]
#
#      2    1 +     3.002041265318667e-03    8.168970371855548e-02    8.168970371855548e-02
#      3    0 +     4.414038298691025e-03    1.201121000527455e-01    1.201121000527455e-01
#      4    2 +     1.257744273919172e-01    3.422496495205922e+00    3.422496495205922e+00
#      5    0 +     2.406398490500976e-01    6.548143824296736e+00    6.548143824296736e+00
#      6    2 -     9.789513757781094e-01    2.663862378110821e+01    2.663862378110821e+01
#      7    1 -     9.818090030992863e-01    2.671638378124605e+01    2.671638378124605e+01
#      8    0 -     9.832518590236674e-01    2.675564589077563e+01    2.675564589077563e+01
#      9    1 -     1.424849597995347e+00    3.877213243149322e+01    3.877213243149322e+01
#     10    0 +     2.384036159429471e+00    6.487292821987359e+01    6.487292821987359e+01
#
# JAC.Auger.computeLines(): The computation of Auger rates and properties starts now ...
# --------------------------------------------------------------------------------------
#
#
#   Selected Auger lines:
#
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#        i-level-f           i--J^P--f            Energy          Energy e_A      List of kappas and total symmetries
#                                                  [eV]              [eV]         partial (total J^P)
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
#         1 --     1       1/2 + --> 2 +      -2.63127139e+03    8.10942464e+02   d_5/2 (1/2 +),  d_3/2 (1/2 +)
#         1 --     2       1/2 + --> 1 +      -2.63127139e+03    8.10860774e+02   s_1/2 (1/2 +),  d_3/2 (1/2 +)
#         1 --     3       1/2 + --> 0 +      -2.63127139e+03    8.10822352e+02   s_1/2 (1/2 +)
#         1 --     4       1/2 + --> 2 +      -2.63127139e+03    8.07519967e+02   d_5/2 (1/2 +),  d_3/2 (1/2 +)
#         1 --     5       1/2 + --> 0 +      -2.63127139e+03    8.04394320e+02   s_1/2 (1/2 +)
#         1 --     6       1/2 + --> 2 -      -2.63127139e+03    7.84303840e+02   p_3/2 (1/2 +),  f_5/2 (1/2 +)
#         1 --     7       1/2 + --> 1 -      -2.63127139e+03    7.84226080e+02   p_3/2 (1/2 +),  p_1/2 (1/2 +)
#         1 --     8       1/2 + --> 0 -      -2.63127139e+03    7.84186818e+02   p_1/2 (1/2 +)
#         1 --     9       1/2 + --> 1 -      -2.63127139e+03    7.72170331e+02   p_3/2 (1/2 +),  p_1/2 (1/2 +)
#         1 --    10       1/2 + --> 0 +      -2.63127139e+03    7.46069536e+02   s_1/2 (1/2 +)
#   ------------------------------------------------------------------------------------------------------------------------------------------------------
# (Re-) Define a storage array for various B-spline matrices:
# Continuum B-spline-Galerkin orbital for energy=2.9802e+01,  kappa=-3 [mpt=560, r[mtp]=2.7632e+00, smallest eigenvalue=6.4416e-05].
# Radial potential with effective charge Zbar=2.0008e+00 (Delta-Zbar=0.0000e+00).
# Coulomb-sine normalized continuum orbital (on P'/P) with normalization constant N=-1.5633e+00 (Delta-N=5.1587e-02) and phase phi=8.6161e-01 (Delta-N=2.2546e-02).
# Compute (Coulomb+Breit) Auger matrix of dimension 2 x 1 in the continuum- and initial-state bases for the transition [1- ...] and for partial wave d_5/2 ...
# stop b
#
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] amplitude(::String, ::JAC.Auger.Channel, ::Level, ::Level, ::JAC.Radial.Grid) at /home/fritzsch/fri/JAC.jl/src/module-Auger.jl:163
#  [3] computeAmplitudesProperties(::JAC.Auger.Line, ::Model, ::JAC.Radial.Grid, ::JAC.Auger.Settings) at /home/fritzsch/fri/JAC.jl/src/module-Auger.jl:203
#  [4] #computeLines#1(::Bool, ::Function, ::Multiplet, ::Multiplet, ::Model, ::JAC.Radial.Grid, ::JAC.Auger.Settings) at /home/fritzsch/fri/JAC.jl/src/module-Auger.jl:246
#  [5] computeLines at /home/fritzsch/fri/JAC.jl/src/module-Auger.jl:236 [inlined]
#  [6] #perform#33(::Bool, ::Function, ::JAC.Atomic.Computation) at /home/fritzsch/fri/JAC.jl/src/jac-perform.jl:108
#  [7] perform(::JAC.Atomic.Computation) at /home/fritzsch/fri/JAC.jl/src/jac-perform.jl:14
#  [8] top-level scope at In[7]:8

# %% [markdown]
# In the setting above, we could have specified also a computation for just a few selected transitions or just for transitions within a given energy interval. We shall leave the discussion of these *options* to one of the next tutorials
